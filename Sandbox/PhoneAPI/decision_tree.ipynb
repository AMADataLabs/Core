# %%
import pandas as pd

# %%
numbers = pd.read_csv('../GetPhoneInfo/wrong_and_connect.csv')
# numbers = numbers.drop(columns=['Not valid'])
# numbers1 = numbers.drop(columns=['ZipCode Match'])
# numbers2 = numbers2.drop(columns=['Possibly Portable VOIP'])

# %%
numbers=numbers.drop(columns=['Index'])

# %%
numbers3 = numbers4.drop(columns=['Possibly Disconnected'])

# %%
def decision_tree(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 12, stratify = y)
    model = tree.DecisionTreeClassifier(criterion='entropy') 
    model.fit(X_train, y_train)
    model.score(X_train, y_train)
    predicted= model.predict(X_test)
    confusion = confusion_matrix(list(y_test), predicted, labels = ['wrong','connected'])
    precision = confusion[0,0]/(confusion[0,0] + confusion[0,1])
    recall = confusion[0,0]/(confusion[0,0] + confusion[1,0])
    false_positives  = confusion[0,1]
    print(f'''
      Precision: {precision}
      Recall: {recall}
      False Positives: {false_positives}
      ''')
    new_list = {'TrainAccuracy': model.score(X_train, y_train),
             'TestAccuracy': model.score(X_test, y_test),
             'Precision': precision,
             'Recall':recall,
             'FalsePositives':false_positives,
            'False Positive Rate': f'{false_positives/all_negatives * 100}%'
            }
    return(new_list)

# %%
def test_variables(df):
    col_list =[]
    for col in df.columns:
        col_list.append(col)
    col_list.remove('OFFICE_TELEPHONE')
    col_list.remove('label')
    all_results = []
    #pd.DataFrame(columns=['Variables','TrainAccuracy','TestAccuracy','Precision','Recall','FalsePositives'])
    for col in col_list:
        variable = col
        X = df.drop(columns = ['OFFICE_TELEPHONE', 'label',col])
        y = df['label']
        model_results = decision_tree(X,y)
        model_results['Variable']=variable
        all_results.append(model_results)
    new_df = pd.DataFrame(all_results)
    new_df = new_df.sort_values(by=['Precision'])
    return(new_df)

# %%
test_variables(numbers3)
# Out:
#       Precision: 0.75
#       Recall: 0.782608695652174
#       False Positives: 12
#
#
#       Precision: 0.7291666666666666
#       Recall: 0.7608695652173914
#       False Positives: 13
#
#
#       Precision: 0.7291666666666666
#       Recall: 0.7608695652173914
#       False Positives: 13
#
#
#       Precision: 0.7291666666666666
#       Recall: 0.7608695652173914
#       False Positives: 13
#
#
#       Precision: 0.375
#       Recall: 0.9473684210526315
#       False Positives: 30
#    False Positive Rate  FalsePositives  Precision    Recall  TestAccuracy  \
# 4  63.829787234042556%              30   0.375000  0.947368      0.673684
# 1  27.659574468085108%              13   0.729167  0.760870      0.747368
# 2  27.659574468085108%              13   0.729167  0.760870      0.747368
# 3  27.659574468085108%              13   0.729167  0.760870      0.747368
# 0   25.53191489361702%              12   0.750000  0.782609      0.768421
#
#    TrainAccuracy            Variable
# ...

# %%
test3
# Out:
#     FalsePositives  Precision    Recall  TestAccuracy  TrainAccuracy  \
# 10              36   0.707317  0.731092      0.676190       0.895072
# 12              36   0.707317  0.743590      0.685714       0.903021
# 3               35   0.715447  0.745763      0.690476       0.906200
# 20              35   0.715447  0.739496      0.685714       0.906200
# 16              34   0.723577  0.780702      0.719048       0.877583
# 29              34   0.723577  0.754237      0.700000       0.906200
# 26              34   0.723577  0.741667      0.690476       0.906200
# 25              34   0.723577  0.767241      0.709524       0.904610
# 24              34   0.723577  0.767241      0.709524       0.904610
# 21              34   0.723577  0.747899      0.695238       0.906200
# 18              34   0.723577  0.747899      0.695238       0.906200
# 14              34   0.723577  0.773913      0.714286       0.903021
# 33              34   0.723577  0.741667      0.690476       0.895072
# ...

# %%
X = numbers.drop(columns = ['OFFICE_TELEPHONE', 'label'])
y = numbers['label']
print(X.shape, y.shape)
# Out:
# (378, 9) (378,)

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 8, stratify = y)
#Assumed you have, X (predictor) and Y (target) for training data set and x_test(predictor) of test_dataset
# Create tree object 

model = tree.DecisionTreeClassifier(criterion='entropy') # for classification, here you can change the algorithm as gini or entropy (information gain) by default it is gini  
# model = tree.DecisionTreeRegressor() for regression
# Train the model using the training sets and check score

model.fit(X_train, y_train)
model.score(X_train, y_train)
#Predict Output
predicted= model.predict(X_test)

# %%
# predicted

# %%
# pd.DataFrame({'Predicted': predicted, 'Actual': y_test})

# %%
# from sklearn.metrics import confusion_matrix
# confusion_matrix(list(y_test), predicted, labels = ['disconnected','connected'])

# %%
# model.score(X_train, y_train)

# %%
# model.score(X_test, y_test)

# %%
confusion = confusion_matrix(list(y_test), predicted, labels = ['disconnected','connected'])
precision = confusion[0,0]/(confusion[0,0] + confusion[0,1])
recall = confusion[0,0]/(confusion[0,0] + confusion[1,0])
false_positives  = confusion[0,1]
print(f'''
      Precision: {precision}
      Recall: {recall}
      False Positives: {false_positives}
      ''')
# Out:
#       Precision: nan
#       Recall: nan
#       False Positives: 0
# C:\Users\vigrose\AppData\Local\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in longlong_scalars
#
# C:\Users\vigrose\AppData\Local\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in longlong_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X = numbers3.drop(columns = ['OFFICE_TELEPHONE', 'label'])
y = numbers3['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 12, stratify = y)
model = tree.DecisionTreeClassifier(criterion='entropy') 
clf = model.fit(X_train, y_train)
model.score(X_train, y_train)
predicted= model.predict(X_test)
confusion = confusion_matrix(list(y_test), predicted, labels = ['wrong','connected'])
precision = confusion[0,0]/(confusion[0,0] + confusion[0,1])
recall = confusion[0,0]/(confusion[0,0] + confusion[1,0])
false_positives  = confusion[0,1]
all_negatives = list(y_test).count('connected')
print(f'''
    Precision: {precision}
    Recall: {recall}
    False Positives: {false_positives}
    ''')
new_list = {'TrainAccuracy': model.score(X_train, y_train),
             'TestAccuracy': model.score(X_test, y_test),
             'Precision': precision,
             'Recall':recall,
             'FalsePositives':false_positives,
            'False Positive Rate': f'{false_positives/all_negatives * 100}%'
            }
# Out:
#     Precision: 0.7291666666666666
#     Recall: 0.7777777777777778
#     False Positives: 13

# %%
new_list
# Out:
# {'TrainAccuracy': 0.6784452296819788,
#  'TestAccuracy': 0.7368421052631579,
#  'Precision': 0.7291666666666666,
#  'Recall': 0.7446808510638298,
#  'FalsePositives': 13,
#  'False Positive Rate': '27.659574468085108%'}

# %%
confusion
# Out:
# array([[31, 17],
#        [ 4, 43]], dtype=int64)

# %%
for name, importance in zip(X.columns, model.feature_importances_):
    print(name, importance)
# Out:
# Address Mismatch 0.08973459675990947
# Last Name Mismatch 0.08541895440198645
# State Mismatch 0.6489596492242637
# Workplace Mismatch 0.12722274178696316
# ZipCode Mismatch 0.048664057826877216

# %%
model.save("GetPhoneInfo_decision_tree.h5")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-328-37e9fa275e30> in <module>
# ----> 1 model.save("GetPhoneInfo_decision_tree.h5")
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'save'

# %%
# import graphviz
# export_graphviz(model, out_file='tree_all.dot', feature_names = X.columns, filled=True)
# with open('tree_all.dot') as f:
#     dot_graph = f.read()
# graphviz.Source(dot_graph)

# %%
X_test.to_csv('matching.csv')

# %%
matching = pd.read_csv('matching.csv')

# %%
matching = matching.rename(columns={'Unnamed: 0':'Index'})

# %%
JUST_NUMS = numbers[['Index', 'OFFICE_TELEPHONE']]
woop = pd.merge(matching, JUST_NUMS, on='Index')

# %%
matching.dtypes
# Out:
# Index                      int64
# Address Match              int64
# Business Phone             int64
# City Match                 int64
# Connected                  int64
# Disconnected               int64
# High Quality               int64
# INF                        int64
# Last Name Match            int64
# Low Quality                int64
# Mailable                   int64
# Medium Quality             int64
# NO SIC                     int64
# No Address                 int64
# No Date                    int64
# Ported                     int64
# Possibly Portable VOIP     int64
# Relevant Name              int64
# Relevant SIC               int64
# State Match                int64
# ZipCode Match              int64
# predicted                 object
# actual                    object
# dtype: object

# %%
RPV = pd.read_csv('../RPV_archive.csv')

# %%
X_test['predicted'] = predicted
X_test['actual']=y_test
# Out:
# C:\Users\vigrose\AppData\Local\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\vigrose\AppData\Local\Programs\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
yummu = pd.merge(woop, RPV, left_on='OFFICE_TELEPHONE', right_on = 'phone')

# %%
yummu['Actual']=y_test

# %%
yummu[['status', 'predicted','actual']]
# Out:
#               status     predicted        actual
# 0       disconnected  disconnected  disconnected
# 1          connected     connected     connected
# 2    disconnected-70  disconnected  disconnected
# 3    disconnected-70  disconnected  disconnected
# 4    disconnected-70  disconnected  disconnected
# 5    disconnected-70  disconnected  disconnected
# 6          connected     connected     connected
# 7          connected     connected  disconnected
# 8       disconnected  disconnected  disconnected
# 9       disconnected  disconnected  disconnected
# 10      disconnected  disconnected  disconnected
# 11      disconnected  disconnected  disconnected
# 12   disconnected-70     connected     connected
# 13      disconnected     connected     connected
# 14      disconnected     connected     connected
# 15         connected     connected     connected
# 16   disconnected-70  disconnected  disconnected
# 17         connected  disconnected  disconnected
# ...

# %%
yummu.groupby(['actual']).count()
# Out:
#               Index  Address Match  Business Phone  City Match  Connected  \
# actual
# connected       137            137             137         137        137
# disconnected    131            131             131         131        131
#
#               Disconnected  High Quality  INF  Last Name Match  Low Quality  \
# actual
# connected              137           137  137              137          137
# disconnected           131           131  131              131          131
#
#               ...  State Match  ZipCode Match  predicted  OFFICE_TELEPHONE  \
# actual        ...
# connected     ...          137            137        137               137
# disconnected  ...          131            131        131               131
#
#               phone  status  error_text  iscell  carrier  date_checked
# actual
# connected       137     137           0     137      137           137
# disconnected    131     131           0     131      131           131
#
# [2 rows x 29 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_train, y_train_categorical)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
predictions = rf.predict(X_test)

# %%
predictions
# Out:
# array([[0.60142077, 0.39857923],
#        [0.59766455, 0.40233545],
#        [0.45440588, 0.54559412],
#        [0.59766455, 0.40233545],
#        [0.98674831, 0.01325169],
#        [0.93791183, 0.06208817],
#        [0.45440588, 0.54559412],
#        [0.45440588, 0.54559412],
#        [0.95638889, 0.04361111],
#        [0.45440588, 0.54559412],
#        [0.60142077, 0.39857923],
#        [0.45440588, 0.54559412],
#        [0.45440588, 0.54559412],
#        [0.95638889, 0.04361111],
#        [0.59766455, 0.40233545],
#        [0.59766455, 0.40233545],
#        [0.59766455, 0.40233545],
#        [0.59766455, 0.40233545],
#        [0.58026482, 0.41973518],
#        [0.45440588, 0.54559412],
#        [0.45440588, 0.54559412],
#        [0.93791183, 0.06208817],
#        [0.83024851, 0.16975149],
#        [0.45440588, 0.54559412],
#        [0.59766455, 0.40233545],
#        [0.45440588, 0.54559412],
#        [0.93791183, 0.06208817],
#        [0.59766455, 0.40233545],
# ...

# %%
# predictions = rf.predict_classes(X_test)
prediction_labels = label_encoder.inverse_transform(predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-290d91c7f89d> in <module>
#       1 # predictions = rf.predict_classes(X_test)
# ----> 2 prediction_labels = label_encoder.inverse_transform(predictions)
#
# ~\AppData\Local\Programs\anaconda3\lib\site-packages\sklearn\preprocessing\label.py in inverse_transform(self, y)
#     271         """
#     272         check_is_fitted(self, 'classes_')
# --> 273         y = column_or_1d(y, warn=True)
#     274         # inverse transform of empty array is empty array
#     275         if _num_samples(y) == 0:
#
# ~\AppData\Local\Programs\anaconda3\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     795         return np.ravel(y)
#     796
# --> 797     raise ValueError("bad input shape {0}".format(shape))
#     798
#     799
#
# ValueError: bad input shape (95, 2)

# %%
numbers3.dtypes
# Out:
# Address Mismatch       int64
# Last Name Mismatch     int64
# OFFICE_TELEPHONE       int64
# State Mismatch         int64
# Workplace Mismatch     int64
# ZipCode Mismatch       int64
# label                 object
# dtype: object
