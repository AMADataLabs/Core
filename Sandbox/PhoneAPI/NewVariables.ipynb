# %%
import pandas as pd
import batch_variables2 as v

# %%
output = pd.read_csv('get_phone_batch_output.csv')

# %%
info = pd.read_csv('../../AMAIA/GetPhoneInfo_batch_sample_info.csv')

# %%
merged = pd.merge(output, info, right_on='OFFICE_TELEPHONE',left_on='phone')

# %%
merged = merged.fillna('None')

# %%
v.analyze_numbers(merged)
# Out:
# {'Address Matches': 346,
#  'City Matches': 606,
#  'ZipCode Matches': 505,
#  'No Address': 259,
#  'No Date': 467,
#  'Relevant Name': 577,
#  'Business Phone': 770,
#  'Residential Phone': 165,
#  'Low Quality': 402,
#  'Medium Quality': 99,
#  'High Quality': 456,
#  'Mailable': 725,
#  'Connected': 540,
#  'Ported': 533,
#  'Not Valid': 0,
#  'Unknown Contact': 35,
#  'Possibly Disconnected': 137,
#  'Possibly Portable VOIP': 36,
#  'Wireless': 7,
#  'First Name Match': 149,
#  'Last Name Match': 177,
#  'Workplace Match': 45,
#  'State Match': 844,
#  'No Name': 43}

# %%
breakdown = v.variable_breakdown(merged)

# %%
variables = pd.DataFrame(breakdown)

# %%
info
# Out:
#      PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 0            49576040023              DARSHIL             JATINBHAI
# 1            13203900028                CESAR               AUGUSTO
# 2             1205840032                 CARL               COLWELL
# 3            73706900141               CARMEN                   NaN
# 4             1103960416               CHUONG                 HOANG
# 5             5101840885                DAVID                 WAYNE
# 6              702930421            CHRISTINE                 CAROL
# 7             3519090995              ETINOSA                     O
# 8            30803870108              EULOGIO                     J
# 9             5606872404               DONALD                 DAVID
# 10            3519930021               GEORGE                     A
# 11            6506840072                GEOFF                     M
# 12            4812870420                DAVID                     D
# ...

# %%
variables.to_csv('testing_set.csv')
