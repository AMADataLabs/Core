# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from nameparser import HumanName

# %%
henry = pd.read_csv('Henry_Ford_Health_System_2020-01-06.csv')

# %%
len(henry)
# Out:
# 7133

# %%
ppd = pd.read_csv('ppd_spec.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (14,27,28,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# def clean_name(name):
#     name_split = name.split(',')
#     full_name = name_split[0].upper()
#     full_name_split = full_name.split(' ')
#     first_name = full_name_split[0]
# #     print(first_name)
#     last_name = full_name_split[-1]
# #     print(last_name)
#     full_name_split.remove(first_name)
#     middle_name = 'None'
#     if len(full_name_split) > 0:
#         full_name_split.remove(last_name)
#         if len(full_name_split)>0:
#             middle_name = full_name_split[0]
#             for word in full_name_split[1:]:
#                 middle_name = middle_name + ' ' + word
#     name_dict = {
#         'NAME':name,
#         'FIRST_NAME': first_name,
#         'LAST_NAME': last_name,
#         'MIDDLE_NAME': middle_name
#     }
#     return(name_dict)

def split_names(df):
    df = df.drop_duplicates()
    dict_list = []
    for row in df.itertuples():
        name_parsed = HumanName(row.NAME)
        name_dict = {
        'NAME':row.NAME,
        'FIRST_NAME': name_parsed.first.upper(),
        'LAST_NAME': name_parsed.last.upper(),
        'MIDDLE_NAME': name_parsed.middle.upper(),
        'SUFFIX':name_parsed.suffix.upper(),
        'NICKNAME':name_parsed.nickname.upper(),
        'TITLE':name_parsed.title.upper(),
        }
        dict_list.append(name_dict)
    name_df = pd.DataFrame(dict_list)
    new_df = pd.merge(name_df, df, on = 'NAME')
    return(new_df)

# %%
def match_ppd_name(ppd,df):
    count = len(df)
    matched = pd.merge(ppd, df, on = ['FIRST_NAME','LAST_NAME'], how = 'right')
    names = []
    duplicate_names = []
    missing_names =[]
    for row in matched.itertuples():
        if row.NAME not in names:
            names.append(row.NAME)
        elif row.NAME not in duplicate_names:
            duplicate_names.append(row.NAME)
        if pd.isna(row.ME)==True:
            missing_names.append(row.NAME)
    
    duplicates = matched[matched.NAME.isin(duplicate_names)]
    matched = matched.drop_duplicates('NAME', keep = False)
    
    print(f'{len(duplicates)} duplicates found.')
    print(f'{len(missing_names)} names missing.')
    
    return(duplicates, missing_names, matched)

# %%
def count_matches(matched_df):
    names = []
    duplicate_names = []
    for row in matched_df.itertuples():
        if row.NAME not in names:
            names.append(row.NAME)
        elif row.NAME not in duplicate_names:
            duplicate_names.append(row.NAME)
    
    duplicates = matched_df[matched_df.NAME.isin(duplicate_names)]
    matched = matched_df.drop_duplicates('NAME', keep = False)
    
    print(f'{len(duplicates)} duplicates found.')
    print(f'{len(matched)} unique matches found.')
    
    return(duplicates, matched)

# %%
def match_ppd_spec_fuzzy(matched_df):
    keep_list = []
    for row in matched_df.itertuples():
        keep = False
        if fuzz.ratio(row.SPECIALTY.upper(), row.DESC_PRIM) > 80:
            keep = True
        elif row.DESC_PRIM in row.SPECIALTY.upper():
            keep = True
        elif row.SPECIALTY.upper() in row.DESC_PRIM:
            keep = True
        keep_list.append(keep)
    matched_df['SPEC_MATCH']=keep_list
    matched_df = matched_df[matched_df['SPEC_MATCH']==True]
    return(matched_df)

# %%
def match_ppd_state(matched_df):
    state_match_list = []
    for row in matched_df.itertuples():
        state_match = False
        if row.POLO_STATE == row.LOCATION_ADDRESS_STATE:
            state_match = True
        state_match_list.append(state_match)
    matched_df['STATE_MATCH']=state_match_list
    matched_df = matched_df[matched_df['STATE_MATCH']==True]
    return(matched_df)
        
def match_ppd_city(matched_df):
    city_match_list = []
    for row in matched_df.itertuples():
        city_match = False
        if row.POLO_CITY == row.LOCATION_ADDRESS_CITY.upper():
            city_match = True
        city_match_list.append(city_match)
    matched_df['CITY_MATCH']=city_match_list
    matched_df = matched_df[matched_df['CITY_MATCH']==True]
    return(matched_df)

def match_ppd_spec_hard(matched_df):
    spec_match_list = []
    for row in matched_df.itertuples():
        spec_match = False
        if row.DESC_PRIM == row.SPECIALTY.upper():
            spec_match = True
        spec_match_list.append(spec_match)
    matched_df['SPEC_MATCH']=spec_match_list
    matched_df = matched_df[matched_df['SPEC_MATCH']==True]
    return(matched_df)

# %%
henry.drop_duplicates('NAME')
# Out:
#                     NAME                  SPECIALTY SECONDARY_SPECIALTY  \
# 0           Saadia Abbas            Family Medicine                None
# 3            Sami Abbasi                Dermatology                None
# 5       Tariq Abdelkarim          Pulmonary Disease                None
# 7         Firas Abdollah                    Urology                None
# 9      Mayada Abdul-Aziz          Internal Medicine                None
# ...                  ...                        ...                 ...
# 7125     Ashley Zuzelski         Emergency Medicine                None
# 7126      Dace Zvirbulis                  Neurology                None
# 7129  Raimonds Zvirbulis         Orthopedic Surgery                None
# 7131         Bryan Zweig                 Cardiology                None
# 7132      Michael Zydeck  Radiology, Neuroradiology                None
#
#              PHONE   FAX                                      LOCATION_NAME  \
# 0     586-421-3052  None         Henry Ford Medical Center Sterling Heights
# 3     734-675-0835  None                                               None
# 5     517-437-3879  None  Hillsdale Pulmonary Critical Care & Sleep Medi...
# 7     800-436-7936  None               Henry Ford Medical Center - Fairlane
# 9     800-436-7936  None                 Henry Ford Medical Center - Taylor
# ...            ...   ...                                                ...
# 7125  517-205-4811  None         Henry Ford Allegiance Emergency Department
# 7126  800-436-7936  None                                Henry Ford Hospital
# 7129  800-436-7936  None               Henry Ford Medical Center - Fairlane
# 7131  800-436-7936  None               Henry Ford Medical Center - Fairlane
# 7132  734-246-9142  None  Drs Harris, Birkhill, Wang, Songe & Associates...
#
#             LOCATION_ADDRESS LOCATION_ADDRESS_CITY LOCATION_ADDRESS_STATE  \
# 0            3500 15 Mile Rd      Sterling Heights                     MI
# 3     133 W Main St, Ste 251            Northville                     MI
# 5       3271 W Carleton Road             Hillsdale                     MI
# 7           19401 Hubbard Dr              Dearborn                     MI
# 9              24555 Haig Rd                Taylor                     MI
# ...                      ...                   ...                    ...
# 7125          205 N East Ave               Jackson                     MI
# 7126       2799 W Grand Blvd               Detroit                     MI
# 7129        19401 Hubbard Dr              Dearborn                     MI
# 7131        19401 Hubbard Dr              Dearborn                     MI
# 7132         2333 Biddle Ave             Wyandotte                     MI
#
#      LOCATION_ADDRESS_ZIP DEPARTMENT PROGRAM           PARENT_ORG_NAME
# 0                   48310       None    None  Henry Ford Health System
# 3                   48167       None    None  Henry Ford Health System
# 5                   49242       None    None  Henry Ford Health System
# 7                   48126       None    None  Henry Ford Health System
# 9                   48180       None    None  Henry Ford Health System
# ...                   ...        ...     ...                       ...
# 7125                49201       None    None  Henry Ford Health System
# 7126                48202       None    None  Henry Ford Health System
# 7129                48126       None    None  Henry Ford Health System
# 7131                48126       None    None  Henry Ford Health System
# 7132                48192       None    None  Henry Ford Health System
#
# [4518 rows x 13 columns]

# %%
henry_df = split_names(henry)
henry_df = henry_df.drop_duplicates('NAME')

# %%
henry_df.head()
# Out:
#                  NAME FIRST_NAME   LAST_NAME MIDDLE_NAME SUFFIX NICKNAME  \
# 0        Saadia Abbas     SAADIA       ABBAS
# 9         Sami Abbasi       SAMI      ABBASI
# 13   Tariq Abdelkarim      TARIQ  ABDELKARIM
# 17     Firas Abdollah      FIRAS    ABDOLLAH
# 21  Mayada Abdul-Aziz     MAYADA  ABDUL-AZIZ
#
#    TITLE          SPECIALTY SECONDARY_SPECIALTY         PHONE   FAX  \
# 0           Family Medicine                None  586-421-3052  None
# 9               Dermatology                None  734-675-0835  None
# 13        Pulmonary Disease                None  517-437-3879  None
# 17                  Urology                None  800-436-7936  None
# 21        Internal Medicine                None  800-436-7936  None
#
#                                         LOCATION_NAME        LOCATION_ADDRESS  \
# 0          Henry Ford Medical Center Sterling Heights         3500 15 Mile Rd
# 9                                                None  133 W Main St, Ste 251
# 13  Hillsdale Pulmonary Critical Care & Sleep Medi...    3271 W Carleton Road
# 17               Henry Ford Medical Center - Fairlane        19401 Hubbard Dr
# 21                 Henry Ford Medical Center - Taylor           24555 Haig Rd
#
#    LOCATION_ADDRESS_CITY LOCATION_ADDRESS_STATE LOCATION_ADDRESS_ZIP  \
# 0       Sterling Heights                     MI                48310
# 9             Northville                     MI                48167
# 13             Hillsdale                     MI                49242
# 17              Dearborn                     MI                48126
# 21                Taylor                     MI                48180
#
#    DEPARTMENT PROGRAM           PARENT_ORG_NAME
# 0        None    None  Henry Ford Health System
# 9        None    None  Henry Ford Health System
# 13       None    None  Henry Ford Health System
# 17       None    None  Henry Ford Health System
# 21       None    None  Henry Ford Health System

# %%
specs = list(henry_df['SPECIALTY'].unique())
bad_spec = ['Physician Assistant',
 'Nurse Practitioner',
 'Anesthesia - CRNA',
 'Midwife',
 'Anesthesia - CRNA, Nurse Practitioner',
 'Chiropractor',
 'Psychologist',
 'Optometrist',
 'Pediatric Dentistry',
 'Veterinarian',
 'Midwife, Nurse Practitioner']
specs = [x for x in specs if x not in bad_spec]

henry_df = henry_df[henry_df['SPECIALTY'].isin(specs)]

# %%
len(henry_df)
# Out:
# 3104

# %%
duplicate_names_henry, missing_names_henry, matched_henry = match_ppd_name(ppd, henry_df) 3104
# Out:
# 4454 duplicates found.
# 528 names missing.

# %%
new_matched = match_ppd_spec_fuzzy(duplicate_names_henry)
new_matched.head()
new_duplicates, new_matches = count_matches(new_matched)
new_matches.head()
print(len(matched_henry))
matched_henry = matched_henry.append(new_matches)
print(len(matched_henry))
print(f'{len(new_matches)} new matches confirmed. {len(matched_henry)} total matches confirmed.')

new_matched_2 = match_ppd_state(new_duplicates)
new_duplicates_2, new_matches_2 = count_matches(new_matched_2)
print(len(matched_henry))
matched_henry = matched_henry.append(new_matches_2)
print(len(matched_henry))
print(f'{len(new_matches_2)} new matches confirmed. {len(matched_henry)} total matches confirmed.')

new_matched_3 = match_ppd_city(new_duplicates_2)
new_duplicates_3, new_matches_3 = count_matches(new_matched_3)
matched_henry = matched_henry.append(new_matches_3)
print(f'{len(new_matches_3)} new matches confirmed. {len(matched_henry)} total matches confirmed.')

new_matched_4 = match_ppd_spec_hard(new_duplicates_3)
new_duplicates_4, new_matches_4 = count_matches(new_matched_4)
matched_henry = matched_henry.append(new_matches_4)
print(f'{len(new_matches_4)} new matches confirmed. {len(matched_henry)} total matches confirmed.')
# Out:
# 302 duplicates found.
# 328 unique matches found.
# 2512
# 2840
# 328 new matches confirmed. 2840 total matches confirmed.
# 22 duplicates found.
# 86 unique matches found.
# 2840
# 2926
# 86 new matches confirmed. 2926 total matches confirmed.
# 0 duplicates found.
# 0 unique matches found.
# 0 new matches confirmed. 2926 total matches confirmed.
# 0 duplicates found.
# 0 unique matches found.
# 0 new matches confirmed. 2926 total matches confirmed.
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_duplicates_2
# Out:
#      SPEC_CD_SEC                            DESC_SEC SPEC_CD_PRIM  \
# 216          SMI  SLEEP MEDICINE (INTERNAL MEDICINE)           IM
# 217           CD              CARDIOVASCULAR DISEASE           IM
# 218           FM                     FAMILY MEDICINE           IM
# 222           US                         UNSPECIFIED           IM
# 1414          CD              CARDIOVASCULAR DISEASE           IM
# 1428          US                         UNSPECIFIED           IM
# 2012          EM                  EMERGENCY MEDICINE           FM
# 2013          US                         UNSPECIFIED           FP
# 2648          US                         UNSPECIFIED           FM
# 2649          US                         UNSPECIFIED           FM
# 3061          US                         UNSPECIFIED           FM
# 3062          US                         UNSPECIFIED           FM
# 3343         OBG             OBSTETRICS & GYNECOLOGY           FM
# 3346          US                         UNSPECIFIED           FM
# 3468          US                         UNSPECIFIED           EM
# 3469          US                         UNSPECIFIED           EM
# 4669          US                         UNSPECIFIED           IM
# 4671          US                         UNSPECIFIED           IM
# 5186          US                         UNSPECIFIED          GYN
# 5187          US                         UNSPECIFIED          OBG
# 5580          US                         UNSPECIFIED           IM
# 5581          US                         UNSPECIFIED          MPD
#
#                          DESC_PRIM            ME            MAILING_NAME  \
# 216              INTERNAL MEDICINE  4.950375e+10        ASHOK K GUPTA MD
# 217              INTERNAL MEDICINE  4.950374e+10        ASHOK K GUPTA MD
# 218              INTERNAL MEDICINE  4.952972e+10        ASHOK K GUPTA MD
# 222              INTERNAL MEDICINE  4.952075e+10          ASHOK GUPTA MD
# 1414             INTERNAL MEDICINE  4.952170e+10         SYED A JAFRI MD
# 1428             INTERNAL MEDICINE  2.576151e+09         SYED S JAFRI DO
# 2012               FAMILY MEDICINE  2.507782e+09    BRADFORD J WOELKE MD
# 2013               FAMILY MEDICINE  2.507171e+09    BRADFORD J WOELKE MD
# 2648               FAMILY MEDICINE  2.507100e+09       CHERYL L SMITH MD
# 2649               FAMILY MEDICINE  2.576981e+09       CHERYL L SMITH DO
# 3061               FAMILY MEDICINE  2.512160e+09     WILLIAM J BARKER MD
# 3062               FAMILY MEDICINE  2.576981e+09     WILLIAM D BARKER DO
# 3343               FAMILY MEDICINE  1.720720e+09       RONALD P BAKER MD
# 3346               FAMILY MEDICINE  2.878560e+09       RONALD G BAKER DO
# 3468            EMERGENCY MEDICINE  1.611133e+09  CHRISTOPHER R CLARK MD
# 3469            EMERGENCY MEDICINE  3.843111e+09  CHRISTOPHER D CLARK MD
# 4669             INTERNAL MEDICINE  2.507011e+09         SAIMA A KHAN MD
# 4671             INTERNAL MEDICINE  7.040200e+10           SAIMA KHAN MD
# 5186                    GYNECOLOGY  1.676570e+09  SALVATORE J FINAZZO DO
# 5187       OBSTETRICS & GYNECOLOGY  1.175961e+09  SALVATORE J FINAZZO DO
# 5580             INTERNAL MEDICINE  6.540114e+10        RENNY ABRAHAM MD
# 5581  INTERNAL MEDICINE/PEDIATRICS  2.501991e+09        RENNY ABRAHAM MD
#
#      LAST_NAME   FIRST_NAME   MIDDLE_NAME_x  SUFFIX_x  ...  \
# 216      GUPTA        ASHOK           KUMAR       NaN  ...
# 217      GUPTA        ASHOK           KUMAR       NaN  ...
# 218      GUPTA        ASHOK               K       NaN  ...
# 222      GUPTA        ASHOK             NaN       NaN  ...
# 1414     JAFRI         SYED     ABBAS HASAN       NaN  ...
# 1428     JAFRI         SYED  SADIQ MOHAMMED       NaN  ...
# 2012    WOELKE     BRADFORD           JAMES       NaN  ...
# 2013    WOELKE     BRADFORD           JAMES       NaN  ...
# 2648     SMITH       CHERYL             LEE       NaN  ...
# 2649     SMITH       CHERYL             LEE       NaN  ...
# 3061    BARKER      WILLIAM           JAMES       NaN  ...
# 3062    BARKER      WILLIAM          DENNIS       NaN  ...
# 3343     BAKER       RONALD            PAUL       NaN  ...
# 3346     BAKER       RONALD               G       NaN  ...
# 3468     CLARK  CHRISTOPHER          ROBERT       NaN  ...
# 3469     CLARK  CHRISTOPHER          DONALD       NaN  ...
# 4669      KHAN        SAIMA           ASLAM       NaN  ...
# 4671      KHAN        SAIMA             NaN       NaN  ...
# 5186   FINAZZO    SALVATORE               J       NaN  ...
# 5187   FINAZZO    SALVATORE            JOHN       NaN  ...
# 5580   ABRAHAM        RENNY             NaN       NaN  ...
# 5581   ABRAHAM        RENNY             NaN       NaN  ...
#
#          LOCATION_ADDRESS LOCATION_ADDRESS_CITY LOCATION_ADDRESS_STATE  \
# 216     5500 Auto Club Dr              Dearborn                     MI
# 217     5500 Auto Club Dr              Dearborn                     MI
# 218     5500 Auto Club Dr              Dearborn                     MI
# 222     5500 Auto Club Dr              Dearborn                     MI
# 1414        14500 Hall Rd         Sterling Hgts                     MI
# 1428        14500 Hall Rd         Sterling Hgts                     MI
# 2012     6620 Highland Rd             Waterford                     MI
# 2013     6620 Highland Rd             Waterford                     MI
# 2648    19020 Fort Street             Riverview                     MI
# 2649    19020 Fort Street             Riverview                     MI
# 3061     30795 23 Mile Rd          Chesterfield                     MI
# 3062     30795 23 Mile Rd          Chesterfield                     MI
# 3343        7226 Allen Rd            Allen Park                     MI
# 3346        7226 Allen Rd            Allen Park                     MI
# 3468    2799 W Grand Blvd               Detroit                     MI
# 3469    2799 W Grand Blvd               Detroit                     MI
# 4669    5500 Auto Club Dr              Dearborn                     MI
# 4671    5500 Auto Club Dr              Dearborn                     MI
# 5186  1651 Kingsway Court               Trenton                     MI
# 5187  1651 Kingsway Court               Trenton                     MI
# 5580   5701 Bow Pointe Dr             Clarkston                     MI
# 5581   5701 Bow Pointe Dr             Clarkston                     MI
#
#      LOCATION_ADDRESS_ZIP DEPARTMENT  PROGRAM           PARENT_ORG_NAME  \
# 216                 48126       None     None  Henry Ford Health System
# 217                 48126       None     None  Henry Ford Health System
# 218                 48126       None     None  Henry Ford Health System
# 222                 48126       None     None  Henry Ford Health System
# 1414                48313       None     None  Henry Ford Health System
# 1428                48313       None     None  Henry Ford Health System
# 2012                48327       None     None  Henry Ford Health System
# 2013                48327       None     None  Henry Ford Health System
# 2648                48193       None     None  Henry Ford Health System
# 2649                48193       None     None  Henry Ford Health System
# 3061                48047       None     None  Henry Ford Health System
# 3062                48047       None     None  Henry Ford Health System
# 3343                48101       None     None  Henry Ford Health System
# 3346                48101       None     None  Henry Ford Health System
# 3468                48202       None     None  Henry Ford Health System
# 3469                48202       None     None  Henry Ford Health System
# 4669                48126       None     None  Henry Ford Health System
# 4671                48126       None     None  Henry Ford Health System
# 5186                48183       None     None  Henry Ford Health System
# 5187                48183       None     None  Henry Ford Health System
# 5580                48346       None     None  Henry Ford Health System
# 5581                48346       None     None  Henry Ford Health System
#
#      SPEC_MATCH STATE_MATCH CITY_MATCH
# 216        True        True      False
# 217        True        True      False
# 218        True        True      False
# 222        True        True      False
# 1414       True        True      False
# 1428       True        True      False
# 2012       True        True      False
# 2013       True        True      False
# 2648       True        True      False
# 2649       True        True      False
# 3061       True        True      False
# 3062       True        True      False
# 3343       True        True      False
# 3346       True        True      False
# 3468       True        True      False
# 3469       True        True      False
# 4669       True        True      False
# 4671       True        True      False
# 5186       True        True      False
# 5187       True        True      False
# 5580       True        True      False
# 5581       True        True      False
#
# [22 rows x 66 columns]

# %%
missing_df = henry_df[henry_df['NAME'].isin(missing_names_henry)]

# %%
add_matches = []
for name in missing_names_henry:
    if name != 'None':
        first_match = ppd[ppd['FIRST_NAME'] == name.upper().split(' ')[0]]
        last_match = ppd[ppd['LAST_NAME'] == name.upper().split(' ')[1]]
        if len(first_match) == 1:
            print(f'{name} : {list(first_match["MAILING_NAME"])[0]}')
            new_dict ={'MAILING_NAME': list(first_match['MAILING_NAME'])[0],
                       'ME': list(first_match['ME'])[0],
                       'DESC_PRIM': list(first_match['DESC_PRIM'])[0],
                       'NAME':name
            }
            add_matches.append(new_dict)
        if len(last_match) == 1:
            print(f'{name} : {list(last_match["MAILING_NAME"])[0]}')
            new_dict ={'MAILING_NAME': list(last_match['MAILING_NAME'])[0],
                       'ME': list(last_match['ME'])[0],
                       'DESC_PRIM': list(last_match['DESC_PRIM'])[0],
                       'NAME':name
            }
            add_matches.append(new_dict)
# Out:
# Muwaffak Abdulhak : MUWAFFAK M ABDUL-HAK MD
# Odaliz Abreu Lanfranco : ODALIZ E ABREU LANFRANCO MD
# Kheir Al-Zouhayli : M K AL-ZOUHAYLI MD
# Salah Alenzi : BADER A ALENZI MD
# Wamidh Alkhoory : WAMIDH L ALKHURRI MD
# Lisa Allenspach : ERIC J ALLENSPACH MD
# Mohamed-Rida Alsaden : MUHAMADRIDA A ALSADEN MD
# Karthikeyan Ananthasubramaniam : K ANANTHASUBRAMANIAM MD
# Graham Appleford : COLIN APPLEFORD DO
# Samah Arsanious : DAVID E ARSANIOUS MD
# Gregory Auner : JOHN D AUNER MD
# Fatima Awarke : FATME AWARKE DO
# Brian Bismack : GREGORY T BISMACK MD
# Abby Bonato : ALEXANDER E BONATO MD
# Jieli Chen : JIELI LI MD
# Laura Dalla Vecchia : KUMAR P DALLA MD
# Sairia Dass Ramcharan : SAIRIA DASS MD
# Janice Demaray : MICHAEL J DEMARAY MD
# Elaine Dziemianowicz : MARK S DZIEMIANOWICZ MD
# Samar El-Achkar : TAREK M EL-ACHKAR MD
# Stephanie Franso : DEANE FRANSO MD
# Stephen Frascone : RALPH J FRASCONE MD
# Shira Gordinier : MARY E GORDINIER MD
# Gurpriya Gupta : GURPRIYA K SETHI MD
# Xiaoxia Han : XIAOXIA ZHANG MD
# Paul Heilborn : PAUL-DAVID B HEILBORN MD
# Erica Herc : ZBIGNIEW S HERC MD
# Jyothsna Herek : PATRICK A HEREK MD
# Sufiya Hussain : SUFIYA SHAIK MD
# Inad Janineh : JOULIANA JANINEH DO
# Hilana Kaafarani : HAYTHAM M KAAFARANI MD
# David Kalmbach : THOMAS K KALMBACH MD
# Shefa Kani : SHEFA RAHMAN MD
# Vijayakiran Kaza : VIJAYAKIRAN SURAPANENI MD
# Steven Keteyian : COURTLAND KETEYIAN MD
# Philip Liethen : PATRICIA J LIETHEN MD
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-a50ba443a33b> in <module>
#       3     if name != 'None':
#       4         first_match = ppd[ppd['FIRST_NAME'] == name.upper().split(' ')[0]]
# ----> 5         last_match = ppd[ppd['LAST_NAME'] == name.upper().split(' ')[1]]
#       6         if len(first_match) == 1:
#       7             print(f'{name} : {list(first_match["MAILING_NAME"])[0]}')
#
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# KeyboardInterrupt:

# %%
attempts = pd.DataFrame(add_matches)
TEST = pd.merge(attempts, henry_df, on = 'NAME')
scores =[]
for row in TEST.itertuples():
    score =fuzz.ratio(row.MAILING_NAME,row.NAME.upper())
    scores.append(score)
TEST['SCORE']=scores

# %%
TEST[TEST['SCORE']>72]

# %%
first_df.to_csv('inf_test.csv')

# %%
for doc in missing_names_henry:
    matched = False
    for NAME in names:
        if fuzz.ratio(NAME, doc.upper())>70:
            potential_list.append(NAME)
            print(f'{NAME} : {doc}')
            matched = True
            if fuzz.ratio(NAME, doc.upper())>84:
                break
    if matched == False:
        print(f'{doc} not found')

# %%
names = list(ppd['MAILING_NAME'])

# %%
fuzz.ratio('MUWAFFAK M ABDUL-HAK MD','MUWAFFAK ABDULHAK')

# %%
missing_names_henry[9:].sort()

# %%
missing_names_henry.sort()

# %%
names.sort()

# %%
pd.merge(first_df, henry_df, on='LAST_NAME')[['NAME','MAILING_NAME']].head(50)

# %%
ppd.dtypes

# %%
missing_df.groupby('SPECIALTY').count().sort_values(by = 'NAME',ascending = False).head(50)

# %%
missing = missing_df[missing_df['SPECIALTY'].isin(specs)]

# %%
specs.remove(bad_spec)

# %%
specs = [x for x in specs if x not in bad_spec]

# %%
def look_for_doctor(name):
    potential_list =[]
    name_scores = []
    matched = False
    for NAME in names:
        score = fuzz.ratio(NAME, name.upper())
        if score > 70:
            potential_list.append(NAME)
            name_scores.append(score)
            print(f'{NAME} : {name}, {score}')
            matched = True
            if score >84:
                break
    if matched == False:
        print(f'{name} not found')
    return(potential_list, name_scores)

def match_doctor(name, specialty):
    potential_list, name_scores = look_for_doctor(name)
    if len(potential_list)==0:
        return([])
    filtered_ppd = ppd[ppd['MAILING_NAME'].isin(potential_list)]
    spec_scores = []
    for row in filtered_ppd.itertuples():
        spec_score = fuzz.ratio(row.DESC_PRIM, specialty.upper())
        spec_scores.append(spec_score)
    filtered_ppd['SPEC_SCORE']=spec_scores
    filtered_ppd['NAME_SCORE']=name_scores
    filtered_ppd['SCORE']=filtered_ppd['SPEC_SCORE']+filtered_ppd['NAME_SCORE']
    return(filtered_ppd)

def pick_match(name, specialty):
    filtered_ppd = match_doctor(name, specialty)
    if len(filtered_ppd)==0:
        return([])
    return(filtered_ppd[filtered_ppd.SPEC_SCORE == filtered_ppd.SPEC_SCORE.max()])

# %%
potential_finds = pick_match('JOELLE ABOOD', 'Obstetrics & Gynecology')

# %%
potential_finds = ppd[ppd['MAILING_NAME']=='JOELLE AOUN MD']

# %%
j_list = ['JOEL E ABBOTT DO',
 'JOEL E ARROYO MD',
 'JOEL E BORKOW MD',
 'JOEL E BROOK MD',
 'JOELLE AOUN MD',
 'JOELLE MORROW MD',
 'JOELLEN BROWN MD',
 'NOELLE BOCTOR MD']
for thing in j_list:
    print(thing)
    print(fuzz.ratio('JOELLE ABOOD',thing))
    print('')

# %%
fuzz.ratio('JOELLE ABOOD', 'JOELLE MORROW MD')

# %%
ppd = ppd.sort_values('MAILING_NAME')

# %%
num = 144
for row in missing[144:].itertuples():
    print(num)
    matches = pick_match(row.NAME, row.SPECIALTY)
    if len(matches)!=0:
        potential_finds.append(matches)
    num += 1

# %%
missing[144:150]

# %%
dict_list =[]
duplicate_df = henry_df[henry_df['NAME'].isin(duplicate_names_henry)]
duplicate_complete = pd.merge(duplicate_df, ppd, on=['FIRST_NAME','LAST_NAME'])
for row in duplicate_complete.itertuples():
    if row.SPECIALTY in specs:
        print(f'{row.NAME} : {row.MAILING_NAME}\n{row.SPECIALTY} : {row.DESC_PRIM}')
        print('')
        keep = False
        if fuzz.ratio(row.SPECIALTY.upper(), row.DESC_PRIM) > 80:
            keep = True
        elif row.DESC_PRIM in row.SPECIALTY.upper():
            keep = True
        elif row.SPECIALTY.upper() in row.DESC_PRIM:
            keep = True
        if keep == True:
            new_dict = {
                    'NAME': row.NAME,
                    'MAILING_NAME':row.MAILING_NAME,
                    'ME': row.ME
                }
            dict_list.append(new_dict)

# %%
duplicate_complete['DESC_PRIM']

# %%
len(pd.DataFrame(dict_list).drop_duplicates('NAME',keep=False))

# %%
len(henry_df[henry_df['SPECIALTY'].isin(specs)])

# %%
len(matched_henry[matched_henry['SPECIALTY'].isin(specs)].dropna(subset = ['ME']).drop_duplicates('NAME',keep=False)[['DESC_PRIM','SPECIALTY']])

# %%
len(missing)

# %%
'226 duplicates'

# %%
potential_finds

# %%
spec_name_matches = pd.DataFrame(dict_list)

# %%
spec_name_matches_ = pd.merge(spec_name_matches, henry_df, on='NAME')
spec_name_matches_ = pd.merge(spec_name_matches_, ppd, on='ME')

# %%
for col in spec_name_matches_.columns:
    print(col)

# %%
state_match_list = []
for row in spec_name_matches_.itertuples():
    state_match = False
    if row.POLO_STATE == row.LOCATION_ADDRESS_STATE:
        state_match = True
    state_match_list.append(state_match)

# %%
spec_name_matches_['STATE_MATCH']=state_match_list

# %%
spec_name_matches_[spec_name_matches_['STATE_MATCH']==True][['SPECIALTY','DESC_PRIM','NAME','MAILING_NAME_x', 'POLO_CITY','LOCATION_ADDRESS_CITY']][350:400]

# %%
2+2

# %%
matched_henry

# %%
matched_henry.dropna(subset = ['ME'])

# %%
len(henry_df)

# %%
for col in henry_df.columns:
    print(col)

# %%
all_henry = pd.merge(henry_df, matched_henry, on = ['NAME',
'FIRST_NAME',
'LAST_NAME',
'NICKNAME',
'TITLE',
'SPECIALTY',
'SECONDARY_SPECIALTY',
'PHONE',
'FAX',
'LOCATION_NAME',
'LOCATION_ADDRESS',
'LOCATION_ADDRESS_CITY',
'LOCATION_ADDRESS_STATE',
'LOCATION_ADDRESS_ZIP',
'DEPARTMENT',
'PROGRAM',
'PARENT_ORG_NAME'], how = 'left')

# %%
len(henry_df)

# %%
still_na = all_henry[all_henry['ME'].isna()]

# %%
def match_cleaned_last(still_na,ppd):
    cleaned_lasts_2 = []
    for last in list(still_na['LAST_NAME']):
        new_last = str(last).replace(' ','').replace(' ','').replace('-','').replace("'","")
        cleaned_lasts_2.append(new_last)
    still_na['CLEANED_LAST']=cleaned_lasts_2
    cleaned_lasts = []
    for last in list(ppd['LAST_NAME']):
        new_last = str(last).replace(' ','').replace(' ','').replace('-','').replace("'","")
        cleaned_lasts.append(new_last)
    ppd['CLEANED_LAST']=cleaned_lasts
    new_matches = pd.merge(still_na,ppd,on=['FIRST_NAME','CLEANED_LAST'])
    return(new_matches)

# %%
cleaned_matches = match_cleaned_last(still_na, ppd)

# %%
clean_duplicates, clean_matches = count_matches(cleaned_matches)

# %%
matched_henry.append(clean_matches)

# %%
ppd_last_names=list(ppd['LAST_NAME'])

# %%
ppd_last_names

# %%
cleaned_lasts_2 = []
for last in list(still_na['LAST_NAME']):
#     if "'" in str(last):
#         print(last)
    new_last = str(last).replace(' ','').replace(' ','').replace('-','').replace("'","")
    cleaned_lasts_2.append(new_last)

# %%
for row in still_na.itertuples():
    if " " in row.LAST_NAME:
        print(row.LAST_NAME)

# %%
ppd['CLEANED_LAST']=cleaned_lasts

# %%
still_na['CLEANED_LAST']=cleaned_lasts_2

# %%
len(still_na)

# %%
clean_duplicates.drop_duplicates('NAME')

# %%
clean_matches

# %%
still_na.drop_duplicates('NAME')

# %%
missing_list = []
COUNT = 0
for row in still_na.itertuples():
    if row.NAME not in founded_names:
        COUNT += 1
        print(row.NAME)
        print(row.SPECIALTY)
        print(row.LOCATION_ADDRESS_CITY)
        print(row.LOCATION_ADDRESS_STATE)
        new_dic  = {
            'NAME':row.NAME,
            'FIRST_NAME':row.FIRST_NAME,
            'MIDDLE_NAME': row.MIDDLE_NAME,
            'LAST_NAME':row.LAST_NAME,
            'SPEC':row.SPECIALTY,
            'CITY':row.LOCATION_ADDRESS_CITY,
            'STATE':row.LOCATION_ADDRESS_STATE
        }
        missing_list.append(new_dic)
print(COUNT)
MISSING_DF = pd.DataFrame(missing_list)

# %%
founded_names = list(cleaned_matches['NAME'])

# %%
ppd[ppd['FIRST_NAME']=='SHANA'][0:51]

# %%
ppd

# %%
first_match = pd.merge(MISSING_DF, ppd, on = 'FIRST_NAME')

# %%
first_match = first_match.rename(columns={'SPEC':'SPECIALTY'})

# %%
spec_first = match_ppd_spec_fuzzy(first_match)

# %%
spec_first_duplicates, spec_first_matches = count_matches(spec_first)

# %%
for row in MISSING_DF.itertuples():
    pd.merge(MISSING_DF, ppd, on=)

# %%
fuzz.ratio('LANFRANCO','ABREAU LANFRANCO')

# %%
spec_first_matches[['NAME','LAST_NAME_x','LAST_NAME_y']]

# %%
def match_check(thing_1, thing_2):
    match = False
    if str(thing_1).upper() == str(thing_2).upper():
        match = True
    if str(thing_2).upper() in str(thing_1).upper():
        match =True
    if fuzz.ratio(str(thing_1).upper(), str(thing_2).upper())>70:
        match =True
    return(match)

# %%
def check_first_matches(MISSING_DF):
    me_name_list =[]
    for row in MISSING_DF.itertuples():
        first_match = ppd[ppd['FIRST_NAME']==row.FIRST_NAME]
        if len(first_match)==1:
            me_name = {'NAME':row.NAME,
                       'ME': list(first_match['ME'])[0]
                        }
            if match_check(list(first_match['DESC_PRIM'])[0],row.SPEC)==True:
                if match_check(list(first_match['LAST_NAME'])[0],row.LAST_NAME)==True:
                    me_name_list.append(me_name)

        else:
            for line in first_match.itertuples():
                if match_check(line.DESC_PRIM,row.SPEC)==True:
                    if match_check(line.LAST_NAME,row.LAST_NAME)==True:
                        me_name = {'NAME':row.NAME,
                       'ME': line.ME
                        }
                        me_name_list.append(me_name)

# %%
MISSING_DF

# %%
match_check('ABREU LANFRANCO','LANFRANCO')

# %%
ppd[ppd['FIRST_NAME']=='ODALIZ']

# %%
me_name_list

# %%
matched_henry.dropna(subset = ['ME']).to_csv('Matched_Henry.csv',index=False)

# %%
matched_henry[['PHONE','TELEPHONE_NUMBER']]
# Out:
#              PHONE  TELEPHONE_NUMBER
# 0     800-436-7936      3.139163e+09
# 139   586-263-2371      5.862632e+09
# 173   586-726-4823      5.867265e+09
# 214   517-205-7525      5.172051e+09
# 215   800-436-7936      7.349367e+09
# ...            ...               ...
# 4921  248-880-0123      2.488800e+09
# 5346  517-205-7060               NaN
# 5358  800-436-7936      2.486669e+09
# 5459  586-726-0044      5.867260e+09
# 5693  517-205-2146      3.132710e+09
#
# [2926 rows x 2 columns]

# %%
for col in matched_henry.columns:
    print(col)
# Out:
# BIRTH_CITY
# BIRTH_COUNTRY
# BIRTH_STATE
# BIRTH_YEAR
# CITY
# CITY_MATCH
# DEPARTMENT
# DESC_PRIM
# DESC_SEC
# FAX
# FAX_NUMBER
# FIRST_NAME
# GME_INST_ID
# GME_INST_STATE
# GME_SPEC_1
# GME_SPEC_2
# LAST_NAME
# LOCATION_ADDRESS
# LOCATION_ADDRESS_CITY
# LOCATION_ADDRESS_STATE
# LOCATION_ADDRESS_ZIP
# LOCATION_NAME
# MAILING_LINE_1
# MAILING_LINE_2
# MAILING_NAME
# MD_DO_CODE
# ME
# MEDSCHOOL_GRAD_YEAR
# MEDSCHOOL_ID
# MEDSCHOOL_STATE
# MIDDLE_NAME_x
# MIDDLE_NAME_y
# MOST_RECENT_FORMER_FIRST_NAME
# MOST_RECENT_FORMER_LAST_NAME
# MOST_RECENT_FORMER_MIDDLE_NAME
# NAME
# NEXT_MOST_RECENT_FORMER_FIRST
# NEXT_MOST_RECENT_FORMER_LAST
# NEXT_MOST_RECENT_FORMER_MIDDLE
# NICKNAME
# PARENT_ORG_NAME
# PHONE
# POLO_CITY
# POLO_MAILING_LINE_1
# POLO_MAILING_LINE_2
# POLO_STATE
# POLO_ZIP
# POST_GRADUATE_YEAR
# PRIM_SPEC_CD
# PROGRAM
# SECONDARY_SPECIALTY
# SEC_SPEC_CD
# SPECIALTY
# SPEC_CD_PRIM
# SPEC_CD_SEC
# SPEC_MATCH
# STATE
# STATE_MATCH
# SUFFIX_x
# SUFFIX_y
# TELEPHONE_NUMBER
# TITLE
# TOP_CD
# TRAINING_TYPE
# YEAR_IN_PROGRAM
# ZIP

# %%
matched_henry.dropna(subset=['ME'])
# Out:
#            BIRTH_CITY BIRTH_COUNTRY BIRTH_STATE  BIRTH_YEAR           CITY  \
# 0                 NaN           NaN         NaN      1976.0   DEARBORN HTS
# 139           DETROIT           US1          MI      1958.0     WASHINGTON
# 173           DETROIT           US1          MI      1968.0  ROCHESTER HLS
# 214         HYDERABAD           IN1         NaN      1967.0        JACKSON
# 215   MAYFIELD HEIGHT           US1          OH      1981.0      ANN ARBOR
# ...               ...           ...         ...         ...            ...
# 4921              NaN           IZ1         NaN      1980.0   BLOOMFLD HLS
# 5346         STAUNTON           US1          VA      1972.0        JACKSON
# 5358           ADRIAN           US1          MI      1951.0      WATERFORD
# 5459              NaN           IN1         NaN      1964.0   STERLING HTS
# 5693        CLEVELAND           US1          OH      1957.0      ANN ARBOR
#
#      CITY_MATCH DEPARTMENT                             DESC_PRIM  \
# 0           NaN       None              CLINICAL NEUROPHYSIOLOGY
# 139         NaN       None                        ANESTHESIOLOGY
# 173         NaN       None                       FAMILY MEDICINE
# 214         NaN       None  PHYSICAL MEDICINE AND REHABILITATION
# 215         NaN       None                         PAIN MEDICINE
# ...         ...        ...                                   ...
# 4921        NaN       None                       FAMILY MEDICINE
# 5346        NaN       None                     INTERNAL MEDICINE
# 5358        NaN       None                     INTERNAL MEDICINE
# 5459        NaN       None                     INTERNAL MEDICINE
# 5693        NaN       None                               UROLOGY
#
#                                 DESC_SEC   FAX  ...  STATE STATE_MATCH  \
# 0     NEUROMUSCULAR MEDICINE (NEUROLOGY)  None  ...     MI         NaN
# 139                      PAIN MANAGEMENT  None  ...     MI         NaN
# 173                      PAIN MANAGEMENT  None  ...     MI         NaN
# 214                      PAIN MANAGEMENT  None  ...     MI         NaN
# 215                      PAIN MANAGEMENT  None  ...     MI         NaN
# ...                                  ...   ...  ...    ...         ...
# 4921                         UNSPECIFIED  None  ...     MI        True
# 5346                         UNSPECIFIED  None  ...     MI        True
# 5358                         UNSPECIFIED  None  ...     MI        True
# 5459                         UNSPECIFIED  None  ...     MI        True
# 5693                         UNSPECIFIED  None  ...     MI        True
#
#       SUFFIX_x  SUFFIX_y TELEPHONE_NUMBER TITLE TOP_CD TRAINING_TYPE  \
# 0          NaN               3.139163e+09         20.0           NaN
# 139        NaN               5.862632e+09         20.0           NaN
# 173        NaN               5.867265e+09         20.0           NaN
# 214        NaN               5.172051e+09         20.0           NaN
# 215        NaN               7.349367e+09         20.0           NaN
# ...        ...       ...              ...   ...    ...           ...
# 4921       NaN               2.488800e+09         20.0           NaN
# 5346       NaN                        NaN         20.0           NaN
# 5358       NaN               2.486669e+09         20.0           NaN
# 5459       NaN               5.867260e+09         20.0           NaN
# 5693       NaN               3.132710e+09         20.0           NaN
#
#      YEAR_IN_PROGRAM    ZIP
# 0                NaN  48127
# 139              NaN  48094
# 173              NaN  48309
# 214              NaN  49201
# 215              NaN  48108
# ...              ...    ...
# 4921             NaN  48302
# 5346             NaN  49201
# 5358             NaN  48327
# 5459             NaN  48313
# 5693             NaN  48104
#
# [2398 rows x 66 columns]

# %%
henry
# Out:
#                     NAME                  SPECIALTY SECONDARY_SPECIALTY  \
# 0           Saadia Abbas            Family Medicine                None
# 1           Saadia Abbas            Family Medicine                None
# 2           Saadia Abbas            Family Medicine                None
# 3            Sami Abbasi                Dermatology                None
# 4            Sami Abbasi                Dermatology                None
# ...                  ...                        ...                 ...
# 7128      Dace Zvirbulis                  Neurology                None
# 7129  Raimonds Zvirbulis         Orthopedic Surgery                None
# 7130  Raimonds Zvirbulis         Orthopedic Surgery                None
# 7131         Bryan Zweig                 Cardiology                None
# 7132      Michael Zydeck  Radiology, Neuroradiology                None
#
#              PHONE   FAX                                      LOCATION_NAME  \
# 0     586-421-3052  None         Henry Ford Medical Center Sterling Heights
# 1     586-421-3052  None                        HFM Urgent Care - Bruce Twp
# 2     586-421-3052  None                     HFM Urgent Care - Chesterfield
# 3     734-675-0835  None                                               None
# 4     734-675-0835  None                                 Abbasi Dermatology
# ...            ...   ...                                                ...
# 7128  800-436-7936  None        Henry Ford Medical Center - Farmington Road
# 7129  800-436-7936  None               Henry Ford Medical Center - Fairlane
# 7130  800-436-7936  None                Henry Ford West Bloomfield Hospital
# 7131  800-436-7936  None               Henry Ford Medical Center - Fairlane
# 7132  734-246-9142  None  Drs Harris, Birkhill, Wang, Songe & Associates...
#
#             LOCATION_ADDRESS LOCATION_ADDRESS_CITY LOCATION_ADDRESS_STATE  \
# 0            3500 15 Mile Rd      Sterling Heights                     MI
# 1             80650 Van Dyke        Bruce Township                     MI
# 2           30795 23 Mile Rd          Chesterfield                     MI
# 3     133 W Main St, Ste 251            Northville                     MI
# 4           21401 Allen Road             Woodhaven                     MI
# ...                      ...                   ...                    ...
# 7128      6530 Farmington Rd       West Bloomfield                     MI
# 7129        19401 Hubbard Dr              Dearborn                     MI
# 7130         6777 W Maple Rd       West Bloomfield                     MI
# 7131        19401 Hubbard Dr              Dearborn                     MI
# 7132         2333 Biddle Ave             Wyandotte                     MI
#
#      LOCATION_ADDRESS_ZIP DEPARTMENT PROGRAM           PARENT_ORG_NAME
# 0                   48310       None    None  Henry Ford Health System
# 1                   48065       None    None  Henry Ford Health System
# 2                   48047       None    None  Henry Ford Health System
# 3                   48167       None    None  Henry Ford Health System
# 4                   48183       None    None  Henry Ford Health System
# ...                   ...        ...     ...                       ...
# 7128                48322       None    None  Henry Ford Health System
# 7129                48126       None    None  Henry Ford Health System
# 7130                48322       None    None  Henry Ford Health System
# 7131                48126       None    None  Henry Ford Health System
# 7132                48192       None    None  Henry Ford Health System
#
# [7133 rows x 13 columns]

# %%
mathced_test = matched_henry[['NAME','ME','TELEPHONE_NUMBER','PHONE']]

# %%
pd.merge(henry, SIMPLE, on='NAME', how = 'left')
# Out:
#                     NAME                  SPECIALTY SECONDARY_SPECIALTY  \
# 0           Saadia Abbas            Family Medicine                None
# 1           Saadia Abbas            Family Medicine                None
# 2           Saadia Abbas            Family Medicine                None
# 3            Sami Abbasi                Dermatology                None
# 4            Sami Abbasi                Dermatology                None
# ...                  ...                        ...                 ...
# 7128      Dace Zvirbulis                  Neurology                None
# 7129  Raimonds Zvirbulis         Orthopedic Surgery                None
# 7130  Raimonds Zvirbulis         Orthopedic Surgery                None
# 7131         Bryan Zweig                 Cardiology                None
# 7132      Michael Zydeck  Radiology, Neuroradiology                None
#
#              PHONE   FAX                                      LOCATION_NAME  \
# 0     586-421-3052  None         Henry Ford Medical Center Sterling Heights
# 1     586-421-3052  None                        HFM Urgent Care - Bruce Twp
# 2     586-421-3052  None                     HFM Urgent Care - Chesterfield
# 3     734-675-0835  None                                               None
# 4     734-675-0835  None                                 Abbasi Dermatology
# ...            ...   ...                                                ...
# 7128  800-436-7936  None        Henry Ford Medical Center - Farmington Road
# 7129  800-436-7936  None               Henry Ford Medical Center - Fairlane
# 7130  800-436-7936  None                Henry Ford West Bloomfield Hospital
# 7131  800-436-7936  None               Henry Ford Medical Center - Fairlane
# 7132  734-246-9142  None  Drs Harris, Birkhill, Wang, Songe & Associates...
#
#             LOCATION_ADDRESS LOCATION_ADDRESS_CITY LOCATION_ADDRESS_STATE  \
# 0            3500 15 Mile Rd      Sterling Heights                     MI
# 1             80650 Van Dyke        Bruce Township                     MI
# 2           30795 23 Mile Rd          Chesterfield                     MI
# 3     133 W Main St, Ste 251            Northville                     MI
# 4           21401 Allen Road             Woodhaven                     MI
# ...                      ...                   ...                    ...
# 7128      6530 Farmington Rd       West Bloomfield                     MI
# 7129        19401 Hubbard Dr              Dearborn                     MI
# 7130         6777 W Maple Rd       West Bloomfield                     MI
# 7131        19401 Hubbard Dr              Dearborn                     MI
# 7132         2333 Biddle Ave             Wyandotte                     MI
#
#      LOCATION_ADDRESS_ZIP DEPARTMENT PROGRAM           PARENT_ORG_NAME  \
# 0                   48310       None    None  Henry Ford Health System
# 1                   48065       None    None  Henry Ford Health System
# 2                   48047       None    None  Henry Ford Health System
# 3                   48167       None    None  Henry Ford Health System
# 4                   48183       None    None  Henry Ford Health System
# ...                   ...        ...     ...                       ...
# 7128                48322       None    None  Henry Ford Health System
# 7129                48126       None    None  Henry Ford Health System
# 7130                48322       None    None  Henry Ford Health System
# 7131                48126       None    None  Henry Ford Health System
# 7132                48192       None    None  Henry Ford Health System
#
#                 ME
# 0     7.040297e+10
# 1     7.040297e+10
# 2     7.040297e+10
# 3     2.576010e+09
# 4     2.576010e+09
# ...            ...
# 7128  9.131694e+10
# 7129  2.501712e+09
# 7130  2.501712e+09
# 7131  1.720042e+09
# 7132  2.507923e+09
#
# [7133 rows x 14 columns]

# %%
# Out:
#                    NAME            ME  TELEPHONE_NUMBER         PHONE
# 0         Youssef Dakka  6.610204e+10      3.139163e+09  800-436-7936
# 139      Robert Peleman  2.507842e+09      5.862632e+09  586-263-2371
# 173   Theodore Tangalos  2.507942e+09      5.867265e+09  586-726-4823
# 214      Anandeep Kumar  4.957091e+10      5.172051e+09  517-205-7525
# 215         Sarah Money  3.843081e+09      7.349367e+09  800-436-7936
# ...                 ...           ...               ...           ...
# 4921       Fadi Ibrahim  3.050108e+10      2.488800e+09  248-880-0123
# 5346     Richard Santos  1.803980e+09               NaN  517-205-7060
# 5358    Christine Meyer  2.501831e+09      2.486669e+09  800-436-7936
# 5459     William Massey  4.950890e+10      5.867260e+09  586-726-0044
# 5693        David Burks  2.501842e+09      3.132710e+09  517-205-2146
#
# [2926 rows x 4 columns]

# %%
new_phone_count =0
no_count =0
yes_count =0
for row in mathced_test.itertuples():
    if np.isnan(row.TELEPHONE_NUMBER)==False:
        if str(int(row.TELEPHONE_NUMBER)) == str(row.PHONE).replace('-',''):
            yes_count +=1
        else:
            no_count += 1
    elif row.PHONE != 'None':
        new_phone_count += 1
    else:
        print(row.PHONE)
        print(row.TELEPHONE_NUMBER)
print(f'{yes_count} phones match. {no_count} phones do not match. {new_phone_count} physicians have no ppd phone number, but do have a number on the online roster')
# Out:
# None
# nan
# None
# nan
# None
# nan
# 674 phones match. 1305 phones do not match. 944 physicians have no ppd phone number, but do have a number on the online roster

# %%
import numpy as np

# %%
new_phone_count
# Out:
# 944

# %%
674+1305+944
# Out:
# 2923

# %%
mathced_test
# Out:
#                    NAME            ME  TELEPHONE_NUMBER         PHONE
# 0         Youssef Dakka  6.610204e+10      3.139163e+09  800-436-7936
# 139      Robert Peleman  2.507842e+09      5.862632e+09  586-263-2371
# 173   Theodore Tangalos  2.507942e+09      5.867265e+09  586-726-4823
# 214      Anandeep Kumar  4.957091e+10      5.172051e+09  517-205-7525
# 215         Sarah Money  3.843081e+09      7.349367e+09  800-436-7936
# ...                 ...           ...               ...           ...
# 4921       Fadi Ibrahim  3.050108e+10      2.488800e+09  248-880-0123
# 5346     Richard Santos  1.803980e+09               NaN  517-205-7060
# 5358    Christine Meyer  2.501831e+09      2.486669e+09  800-436-7936
# 5459     William Massey  4.950890e+10      5.867260e+09  586-726-0044
# 5693        David Burks  2.501842e+09      3.132710e+09  517-205-2146
#
# [2926 rows x 4 columns]
