# %%
import pandas as pd

# %%
spec = pd.read_csv('speciality_id.csv')

# %%
PPD = pd.read_csv('ppd_data_20191214.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,20,42,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
beth = pd.read_csv('Rosters/BethIsrael_Roster.csv')
brig = pd.read_csv('Rosters/Brigham_Roster.csv')
clev = pd.read_csv('Rosters/Cleveland_Roster.csv')
cinn = pd.read_csv('Rosters/CincinnatiChildrens_Roster.csv')
henr = pd.read_csv('Rosters/HenryFord_Roster.csv')
mass = pd.read_csv('Rosters/Mass_Roster.csv')
mayo = pd.read_csv('Rosters/Mayo_Roster.csv')
penn = pd.read_csv('Rosters/PennMedicine_Roster.csv')
uthe = pd.read_csv('Rosters/UTHealth_Roster.csv')
utso = pd.read_csv('Rosters/UTSouthwestern_Roster.csv')

# %%
ppd = pd.read_csv('PPD.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ppd.dtypes
# Out:
# ME                       int64
# MAILING_NAME            object
# LAST_NAME               object
# FIRST_NAME              object
# MIDDLE_NAME             object
# SUFFIX                 float64
# MAILING_LINE_1          object
# MAILING_LINE_2          object
# CITY                    object
# STATE                   object
# ZIP                     object
# TELEPHONE_NUMBER       float64
# POLO_MAILING_LINE_1     object
# POLO_MAILING_LINE_2     object
# POLO_CITY               object
# POLO_STATE              object
# POLO_ZIP                object
# dtype: object

# %%
beth.head()
# Out:
#    Unnamed: 0                                               Link  \
# 0           0  https://findadoc.bidmc.org/details/3480/amtul-...
# 1           1  https://findadoc.bidmc.org/details/2627/bassim...
# 2           2  https://findadoc.bidmc.org/details/1/ayesha-ab...
# 3           3  https://findadoc.bidmc.org/details/2/dorina-ab...
# 4           4  https://findadoc.bidmc.org/details/2248/charbe...
#
#                          Name            Specialty            Phone  \
# 0              Amtul Aala, MD           Nephrology  +1-617-632-9700
# 1      Bassima J Abdallah, MD    Internal Medicine  +1-617-313-1377
# 2           Ayesha Abdeen, MD  Orthopaedic Surgery  +1-617-667-3940
# 3       Dorina R. Abdulah, MD    Internal Medicine  +1-617-754-0747
# 4  Charbel M. Abou Rjeily, MD    Internal Medicine  +1-508-746-1259
#
#                Fax                                      Location_Name  \
# 0  +1-617-632-9820               Beth Israel Deaconess Medical Center
# ...

# %%
brig.head()
# Out:
#    Unnamed: 0                                               Link  Index  \
# 0           0  https://physiciandirectory.brighamandwomens.or...  13549
# 1           1  https://physiciandirectory.brighamandwomens.or...  13924
# 2           2  https://physiciandirectory.brighamandwomens.or...      1
# 3           3  https://physiciandirectory.brighamandwomens.or...    127
# 4           4  https://physiciandirectory.brighamandwomens.or...    537
#
#                          Name                                     Specialty
# 0         Carrie P. Aaron, MD                 Pulmonary and Critical Care,
# 1       Ali M. Abbas, MD, MPH  Gastroenterology, Hepatology and Endoscopy,
# 2               Reza Abdi, MD                      Renal (Kidney) Disease,
# 3  Elisa Abdulhayoglu, MD, MS                          Pediatric Medicine,
# 4  Raja-Elie E. Abdulnour, MD                 Pulmonary and Critical Care,

# %%
cinn.head()
# Out:
#    Unnamed: 0                                               Link  \
# 0           0  https://www.cincinnatichildrens.org/bio/a/clai...
# 1           1  https://www.cincinnatichildrens.org/bio/a/kath...
# 2           2  https://www.cincinnatichildrens.org/bio/a/juan...
# 3           3  https://www.cincinnatichildrens.org/bio/a/mich...
# 4           4  https://www.cincinnatichildrens.org/bio/a/mais...
#
#                               Name  \
# 0   Claire M. Aarnio-Peterson, PhD
# 1              Katherine Abell, MD
# 2              J. Pablo Abonia, MD
# 3      Michael J. Absalon, MD, PhD
# 4       Maisam A. Abu-El-Haija, MD
#
#                                               Titles  \
# 0  ['Pediatric Psychologist, Behavioral Medicine ...
# 1    ['Clinical Fellow, Division of Human Genetics']
# 2  ['Associate Professor, UC Department of Pediat...
# 3  ['Director, Medical Education Program', 'Assoc...
# 4  ['Medical Director, Pancreas Care Center', 'Pe...
#
# ...

# %%
henr.head()
# Out:
#    Unnamed: 0                                      Link               Name  \
# 0           0       /physician-directory/a/abbas-saadia       Saadia Abbas
# 1           1        /physician-directory/a/abbasi-sami        Sami Abbasi
# 2           2   /physician-directory/a/abdelkarim-tariq   Tariq Abdelkarim
# 3           3     /physician-directory/a/abdollah-firas     Firas Abdollah
# 4           4  /physician-directory/a/abdul-aziz-mayada  Mayada Abdul-Aziz
#
#            Specialty         Phone  \
# 0    Family Medicine  586-421-3052
# 1        Dermatology  734-675-0835
# 2  Pulmonary Disease  517-437-3879
# 3            Urology  800-436-7936
# 4  Internal Medicine  800-436-7936
#
#                                              Offices  \
# 0  ['Henry Ford Medical Center Sterling Heights',...
# 1                     ['None', 'Abbasi Dermatology']
# 2  ['Hillsdale Pulmonary Critical Care & Sleep Me...
# 3  ['Henry Ford Medical Center - Fairlane', 'Henr...
# ...

# %%
mass.head()
# Out:
#    Unnamed: 0                                         Department  \
# 0           0                                       Primary Care
# 1           1                                          Radiology
# 2           2  Department of Neurology, Department of Pediatrics
# 3           3                           Department of Psychiatry
# 4           4                            Department of Pathology
#
#                           Name                                    Practice  \
# 0            Diane E. Rich, MD  Massachusetts General Hospital, Boston, MA
# 1    Ralph Weissleder, MD, PhD  Massachusetts General Hospital, Boston, MA
# 2  Elizabeth Clark Dooling, MD  Massachusetts General Hospital, Boston, MA
# 3            Brian D. Ott, PhD  Massachusetts General Hospital, Boston, MA
# 4           David N. Louis, MD  Massachusetts General Hospital, Boston, MA
#
#         Phone
# 0  6176438000
# 1  6176434723
# 2  6177263877
# 3  6177248200
# 4  6177262966

# %%
penn.head()
# Out:
#    Unnamed: 0                                               Link  \
# 0           0  /providers/profile/nadine-al-naamani?fadf=penn...
# 1           1  /providers/profile/sara-attalla?fadf=pennmedicine
# 2           2  /providers/profile/valerianna-amorosa?fadf=pen...
# 3           3   /providers/profile/nicole-aqui?fadf=pennmedicine
# 4           4  /providers/profile/michael-acker?fadf=pennmedi...
#
#                         Name  \
# 0  Nadine Al-Naamani, MD, MS
# 1           Sara Attalla, MD
# 2  Valerianna K. Amorosa, MD
# 3            Nicole Aqui, MD
# 4       Michael A. Acker, MD
#
#                                                Title  \
# 0  Assistant Professor of Medicine at the Hospita...
# 1           Assistant Professor of Clinical Medicine
# 2  Medical Director for Penn Home Infusion Therap...
# 3  Associate Professor of Clinical Pathology and ...
# 4  Chief, Division of Cardiovascular SurgeryDirec...
#
#                            Specialty  \
# ...

# %%
uthe.head()
# Out:
#    Unnamed: 0                                               Link  \
# 0           0  https://www.utphysicians.com/provider/aamir-a-...
# 1           1  https://www.utphysicians.com/provider/lourice-...
# 2           2  https://www.utphysicians.com/provider/aleyamma...
# 3           3  https://www.utphysicians.com/provider/cilymol-...
# 4           4  https://www.utphysicians.com/provider/rodeo-a-...
#
#                          Name  \
# 0         Aamir A. Abbas, MD
# 1  Lourice K. Abdelmelek, MD
# 2       Aleyamma Abraham, MD
# 3       Cilymol Abraham, DNP
# 4    Rodeo A. Abrencillo, MD
#
#                                           Specialty     Secondary_Specialty  \
# 0  Advanced Heart Failure and Transplant Cardiology  Cardiovascular Disease
# 1                                   Family Medicine                    None
# 2                                   Family Medicine                    None
# 3                                        Pediatrics                    None
# ...

# %%
utso.head()
# Out:
#    Unnamed: 0                          Link                      Name  \
# 0           0        /doctors/suhny-abbara/        Suhny Abbara, M.D.
# 1           1  /doctors/kareem-abdelfattah/  Kareem Abdelfattah, M.D.
# 2           2     /doctors/abier-abdelnaby/     Abier Abdelnaby, M.D.
# 3           3      /doctors/kalil-abdullah/      Kalil Abdullah, M.D.
# 4           4  /doctors/nashila-abdulrahim/  Nashila Abdulrahim, D.O.
#
#                                           Centers  \
# 0  Harold C. Simmons Comprehensive Cancer Center
# 1                                            None
# 2  Harold C. Simmons Comprehensive Cancer Center
# 3                                            None
# 4                                     Transplant
#
#                                          Departments
# 0                       Radiology - Chest & Cardiac
# 1  Surgery Hernia & Abdominal Wall Repair Surgery...
# 2  Surgery Gastrointestinal Cancers Screening for...
# ...

# %%
penn.head()
# Out:
#    Unnamed: 0                                               Link  \
# 0           0  /providers/profile/nadine-al-naamani?fadf=penn...
# 1           1  /providers/profile/sara-attalla?fadf=pennmedicine
# 2           2  /providers/profile/valerianna-amorosa?fadf=pen...
# 3           3   /providers/profile/nicole-aqui?fadf=pennmedicine
# 4           4  /providers/profile/michael-acker?fadf=pennmedi...
#
#                         Name  \
# 0  Nadine Al-Naamani, MD, MS
# 1           Sara Attalla, MD
# 2  Valerianna K. Amorosa, MD
# 3            Nicole Aqui, MD
# 4       Michael A. Acker, MD
#
#                                                title  \
# 0  Assistant Professor of Medicine at the Hospita...
# 1           Assistant Professor of Clinical Medicine
# 2  Medical Director for Penn Home Infusion Therap...
# 3  Associate Professor of Clinical Pathology and ...
# 4  Chief, Division of Cardiovascular SurgeryDirec...
#
#                            Specialty  \
# ...

# %%
def clean_name(name):
    name_split = name.split(',')
    full_name = name_split[0].upper()
    full_name_split = full_name.split(' ')
    first_name = full_name_split[0]
#     print(first_name)
    last_name = full_name_split[-1]
#     print(last_name)
    full_name_split.remove(first_name)
    middle_name = 'None'
    if len(full_name_split) > 0:
        full_name_split.remove(last_name)
        if len(full_name_split)>0:
            middle_name = full_name_split[0]
            for word in full_name_split[1:]:
                middle_name = middle_name + ' ' + word
    name_dict = {
        'NAME':name,
        'FIRST_NAME': first_name,
        'LAST_NAME': last_name,
        'MIDDLE_NAME': middle_name
    }
    return(name_dict)
    
#     if len(full_name_split[1].split('.')[0]) == 1:
#         middle_name = full_name_split[1].split('.')[0]
#     else:
#         middle_name = 'None'

# %%
names = pd.DataFrame(dict_list)

# %%
pd.merge(names, ppd, on = ['FIRST_NAME','LAST_NAME']).sort_values('LAST_NAME')
# Out:
#         FIRST_NAME LAST_NAME MIDDLE_NAME_x           ME  \
# 35712         ERIN    AAKHUS            O.   1720103059
# 28902  CHRISTOPHER     AAKRE    (CHRIS) A.   2604111831
# 0            AMTUL      AALA          None  70420040286
# 9286        CARRIE     AARON            P.   3201070472
# 35679         CARY    AARONS            B.   1003020190
# ...            ...       ...           ...          ...
# 22782        BRYAN     ZWEIG          None   1720041509
# 9285      FRANKLIN   ZWEIMAN          None    511700647
# 48183        DAVID     ZWICK          None   3841781901
# 4799       JEFFREY   ZWICKER            I.   4114981074
# 22783      MICHAEL    ZYDECK          None   2507922549
#
#                  MAILING_NAME MIDDLE_NAME_y  SUFFIX  \
# 35712        ERIN O AAKHUS MD        OLIVIA     NaN
# 28902  CHRISTOPHER A AAKRE MD         ANSEL     NaN
# 0               AMTUL AALA MD           NaN     NaN
# 9286        CARRIE P AARON MD     PISTENMAA     NaN
# ...

# %%
len(ppd)
# Out:
# 1262298

# %%
for col in PPD.columns:
    print(col)
# Out:
# ME
# RECORD_ID
# UPDATE_TYPE
# ADDRESS_TYPE
# MAILING_NAME
# LAST_NAME
# FIRST_NAME
# MIDDLE_NAME
# SUFFIX
# MAILING_LINE_1
# MAILING_LINE_2
# CITY
# STATE
# ZIP
# SECTOR
# CARRIER_ROUTE
# ADDRESS_UNDELIVERABLE_FLAG
# FIPS_COUNTY
# FIPS_STATE
# PRINTER_CONTROL_CODE
# PC_ZIP
# PC_SECTOR
# DELIVERY_POINT_CODE
# CHECK_DIGIT
# PRINTER_CONTROL_CODE_2
# REGION
# DIVISION
# GROUP
# TRACT
# SUFFIX_CENSUS
# BLOCK_GROUP
# MSA_POPULATION_SIZE
# MICRO_METRO_IND
# CBSA
# CBSA_DIV_IND
# MD_DO_CODE
# BIRTH_YEAR
# BIRTH_CITY
# BIRTH_STATE
# BIRTH_COUNTRY
# GENDER
# TELEPHONE_NUMBER
# PRESUMED_DEAD_FLAG
# FAX_NUMBER
# TOP_CD
# PE_CD
# PRIM_SPEC_CD
# SEC_SPEC_CD
# MPA_CD
# PRA_RECIPIENT
# PRA_EXP_DT
# GME_CONF_FLG
# FROM_DT
# TO_DT
# YEAR_IN_PROGRAM
# POST_GRADUATE_YEAR
# GME_SPEC_1
# GME_SPEC_2
# TRAINING_TYPE
# GME_INST_STATE
# GME_INST_ID
# MEDSCHOOL_STATE
# MEDSCHOOL_ID
# MEDSCHOOL_GRAD_YEAR
# NO_CONTACT_IND
# NO_WEB_FLAG
# PDRP_FLAG
# PDRP_START_DT
# POLO_MAILING_LINE_1
# POLO_MAILING_LINE_2
# ...

# %%
ppd = PPD[['ME',
    'MAILING_NAME',
    'LAST_NAME',
    'FIRST_NAME',
    'MIDDLE_NAME',
    'SUFFIX',
    'MAILING_LINE_1',
    'MAILING_LINE_2',
    'CITY',
    'STATE',
    'ZIP',

    'MD_DO_CODE',
    'BIRTH_YEAR',
    'BIRTH_CITY',
    'BIRTH_STATE',
    'BIRTH_COUNTRY',
    'TELEPHONE_NUMBER',
    'FAX_NUMBER',
    'TOP_CD',
    'PRIM_SPEC_CD',
    'SEC_SPEC_CD',

    'YEAR_IN_PROGRAM',
    'POST_GRADUATE_YEAR',
    'GME_SPEC_1',
    'GME_SPEC_2',
    'TRAINING_TYPE',
    'GME_INST_STATE',
    'GME_INST_ID',
    'MEDSCHOOL_STATE',
    'MEDSCHOOL_ID',
    'MEDSCHOOL_GRAD_YEAR',

    'POLO_MAILING_LINE_1',
    'POLO_MAILING_LINE_2',
    'POLO_CITY',
    'POLO_STATE',
    'POLO_ZIP',

    'MOST_RECENT_FORMER_LAST_NAME',
    'MOST_RECENT_FORMER_MIDDLE_NAME',
    'MOST_RECENT_FORMER_FIRST_NAME',
    'NEXT_MOST_RECENT_FORMER_LAST',
    'NEXT_MOST_RECENT_FORMER_MIDDLE',
    'NEXT_MOST_RECENT_FORMER_FIRST']]

# %%
beth
# Out:
#       Unnamed: 0                                               Link  \
# 0              0  https://findadoc.bidmc.org/details/3480/amtul-...
# 1              1  https://findadoc.bidmc.org/details/2627/bassim...
# 2              2  https://findadoc.bidmc.org/details/1/ayesha-ab...
# 3              3  https://findadoc.bidmc.org/details/2/dorina-ab...
# 4              4  https://findadoc.bidmc.org/details/2248/charbe...
# ...          ...                                                ...
# 2994        2994  https://findadoc.bidmc.org/details/3497/dimita...
# 2995        2995  https://findadoc.bidmc.org/details/3843/kate-z...
# 2996        2996  https://findadoc.bidmc.org/details/3844/kangni...
# 2997        2997  https://findadoc.bidmc.org/details/3348/elizab...
# 2998        2998  https://findadoc.bidmc.org/details/3350/frankl...
#
#                             Name             Specialty            Phone  \
# 0                 Amtul Aala, MD            Nephrology  +1-617-632-9700
# ...

# %%
spec = spec.drop(columns=['Unnamed: 0','SPEC_ID'])

# %%
ppd = pd.merge(spec, ppd, left_on='SPEC_CD', right_on='PRIM_SPEC_CD')

# %%
PPD_ = pd.merge(spec, ppd, left_on = 'SPEC_CD', right_on = 'SEC_SPEC_CD', how = 'right', suffixes = ('_SEC','_PRIM'))

# %%
brig = brig.rename(columns={'link':'Link','index':'Index','speciality':'Specialty'})

# %%
def split_names(df):
    df = df.drop_duplicates()
    dict_list = []
    for row in df.itertuples():
        new_dict = clean_name(row.NAME)
        dict_list.append(new_dict)
    name_df = pd.DataFrame(dict_list)
    new_df = pd.merge(name_df, df, on = 'NAME')
    return(new_df)

# %%
def match_ppd(ppd,df):
    count = len(df)
    matched = pd.merge(ppd, df, on = ['FIRST_NAME','LAST_NAME'], how = 'right')
    print(f'Approximately {len(matched)-count} duplicates found')
    names = []
    duplicate_names = []
    missing_names =[]
    for row in matched.itertuples():
        if row.NAME not in names:
            names.append(row.NAME)
        elif row.NAME not in duplicate_names:
            duplicate_names.append(row.NAME)
        if pd.isna(row.ME)==True:
            missing_names.append(row.NAME)
    print(f'{len(duplicate_names)} duplicates found.')
    print(f'{len(missing_names)} names missing.')
    return(duplicate_names, missing_names, matched)

# %%
brig_ = split_names(brig)

# %%
pd.merge(PPD_, brig_, on = ['FIRST_NAME','LAST_NAME'], how = 'right')
# Out:
#      SPEC_CD_SEC                                           DESC_SEC  \
# 0            ACA  ADULT CARDIOTHORACIC ANESTHESIOLOGY (ANESTHESI...
# 1            PME                                    PAIN MANAGEMENT
# 2            CCM         CRITICAL CARE MEDICINE (INTERNAL MEDICINE)
# 3             US                                        UNSPECIFIED
# 4             US                                        UNSPECIFIED
# ...          ...                                                ...
# 5214         NaN                                                NaN
# 5215         NaN                                                NaN
# 5216         NaN                                                NaN
# 5217         NaN                                                NaN
# 5218         NaN                                                NaN
#
#      SPEC_CD_PRIM          DESC_PRIM            ME          MAILING_NAME  \
# 0              AN     ANESTHESIOLOGY  5.611188e+10  LUIGINO NASCIMBEN MD
# ...

# %%
duplicate_names_brig, missing_names_brig, matched_brig = match_ppd(PPD_,brig_)
# Out:
# Approximately 3099 duplicates found
# 473 duplicates found.
# 216 names missing.

# %%
duplicate_names_brig
# Out:
# ['David H. Hwang, MD',
#  'David T. Martin, MD',
#  'Michael J. Weaver, MD',
#  'Gary D. Johnson, MD',
#  'Alberto Ramirez, MD',
#  'Rajesh Patel, MD, MPH',
#  'Lawrence Jay Epstein, MD',
#  'David C. Brooks, MD',
#  'Thomas C. Lee, MD',
#  'Thomas Henry Lee, Jr., MD',
#  'Timothy R. Smith, MD, PhD, MPH',
#  'David T. Miller, MD, PhD',
#  'David Christopher Fisher, MD',
#  'Gary M. Hunninghake, MD',
#  'James D. Griffin, MD',
#  'Scott A. Goldberg, MD',
#  'Jeffrey Arnold Morgan, MD',
#  'Samir Kaushik Shah, MD',
#  'David Michael Levine, MD, MPH, MA',
#  'David W. Green, MD',
#  'Barbara J. Katz, MD',
#  'Anne S. Lee, MD, MPH',
#  'Stuart J. Klein, MD',
#  'Michael B. Miller, MD, PhD',
#  'Richard Max Kaufman, MD',
#  'John E. Ready, MD',
#  'John A. Lewis, MD',
#  'James H. Maguire, MD',
#  'Robert C. Green, MD',
#  'Katherine P. Liao, MD',
#  'David A. Silver, MD',
#  'Bruce David Levy, MD',
#  'Francis D. Moore, Jr., MD',
#  'Michael Wilson, MD, PhD',
#  'Jennifer Ang Chan, MD',
# ...

# %%
matched_brig['Specialty']
# Out:
# 0       Anesthesia and Pain Management,
# 1                            Pathology,
# 2                            Pathology,
# 3                            Pathology,
# 4                            Pathology,
#                       ...
# 5214                                None
# 5215                                None
# 5216       Oral Medicine and Dentistry,
# 5217                         Pathology,
# 5218                         Radiology,
# Name: Specialty, Length: 5219, dtype: object

# %%
matched_brig.dtypes
# Out:
# SPEC_CD_SEC                        object
# DESC_SEC                           object
# SPEC_CD_PRIM                       object
# DESC_PRIM                          object
# ME                                float64
# MAILING_NAME                       object
# LAST_NAME                          object
# FIRST_NAME                         object
# MIDDLE_NAME_x                      object
# SUFFIX                            float64
# MAILING_LINE_1                     object
# MAILING_LINE_2                     object
# CITY                               object
# STATE                              object
# ZIP                                object
# MD_DO_CODE                        float64
# BIRTH_YEAR                        float64
# BIRTH_CITY                         object
# BIRTH_STATE                        object
# BIRTH_COUNTRY                      object
# TELEPHONE_NUMBER                  float64
# FAX_NUMBER                        float64
# ...

# %%
duplicate_brig_df = matched_brig[matched_brig.Name.isin(duplicate_names_brig)]

# %%
duplicate_brig_df
# Out:
#      SPEC_CD_SEC                                    DESC_SEC SPEC_CD_PRIM  \
# 1            PME                             PAIN MANAGEMENT           AN
# 2            CCM  CRITICAL CARE MEDICINE (INTERNAL MEDICINE)            N
# 3             US                                 UNSPECIFIED           IM
# 4             US                                 UNSPECIFIED           IM
# 5             US                                 UNSPECIFIED           IM
# ...          ...                                         ...          ...
# 4821          US                                 UNSPECIFIED          PTH
# 4824          US                                 UNSPECIFIED           PM
# 4825          US                                 UNSPECIFIED          RHU
# 4887          US                                 UNSPECIFIED          PYG
# 4888          US                                 UNSPECIFIED          RHU
#
#                                  DESC_PRIM            ME        MAILING_NAME  \
# ...

# %%
middles =[]
middle_initial =[]
specialties =[]
for row in duplicate_brig_df.itertuples():
    if row.MIDDLE_NAME_x == row.MIDDLE_NAME_y.replace('.',''):
        middles.append(True)
    else:
        middles.append(False)
    if str(row.MIDDLE_NAME_x)[0] == str(row.MIDDLE_NAME_y)[0]:
        middle_initial.append(True)
    else:
        middle_initial.append(False)
    if str(row.Specialty).replace(',','').replace(' ','').upper() in str(row.DESC_PRIM).replace(' ',''):
        specialties.append(True)
    else:
        specialties.append(False)
duplicate_brig_df['Specialty_Match']=specialties
duplicate_brig_df['Middle_Match']=middles
duplicate_brig_df['Initial_Match']=middle_initial
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
duplicate_brig_df[(duplicate_brig_df['Initial_Match']==True)]
# Out:
#      SPEC_CD_SEC                DESC_SEC SPEC_CD_PRIM  \
# 8             US             UNSPECIFIED          PCP
# 12            CD  CARDIOVASCULAR DISEASE          ICE
# 31            US             UNSPECIFIED          CCS
# 48            US             UNSPECIFIED           IM
# 74            GP        GENERAL PRACTICE           IM
# ...          ...                     ...          ...
# 4797          US             UNSPECIFIED          PYM
# 4807          US             UNSPECIFIED           PD
# 4820          US             UNSPECIFIED          PHO
# 4825          US             UNSPECIFIED          RHU
# 4888          US             UNSPECIFIED          RHU
#
#                                          DESC_PRIM            ME  \
# 8                                    CYTOPATHOLOGY  1.602110e+09
# 12              CLINICAL CARDIAC ELECTROPHYSIOLOGY  9.170782e+10
# 31                SURGICAL CRITICAL CARE (SURGERY)  2.604111e+09
# ...

# %%
duplicate_brig_df[duplicate_brig_df['FIRST_NAME']=='ALBERTO']
# Out:
#     SPEC_CD_SEC           DESC_SEC SPEC_CD_PRIM               DESC_PRIM  \
# 106         PME    PAIN MANAGEMENT           AN          ANESTHESIOLOGY
# 107          IM  INTERNAL MEDICINE           CD  CARDIOVASCULAR DISEASE
# 108          US        UNSPECIFIED           FM         FAMILY MEDICINE
# 109          US        UNSPECIFIED           GS         GENERAL SURGERY
#
#                ME          MAILING_NAME LAST_NAME FIRST_NAME MIDDLE_NAME_x  \
# 106  3.080189e+10    ALBERTO RAMIREZ MD   RAMIREZ    ALBERTO           NaN
# 107  2.640562e+10    ALBERTO RAMIREZ MD   RAMIREZ    ALBERTO           NaN
# 108  3.010005e+08  ALBERTO A RAMIREZ MD   RAMIREZ    ALBERTO       ANTONIO
# 109  4.201000e+09  ALBERTO J RAMIREZ MD   RAMIREZ    ALBERTO        JAVIER
#
#      SUFFIX  ... NEXT_MOST_RECENT_FORMER_FIRST                 Name  \
# 106     NaN  ...                           NaN  Alberto Ramirez, MD
# 107     NaN  ...                           NaN  Alberto Ramirez, MD
# ...

# %%
names_matched = {}
for row in duplicate_brig_df.itertuples():   
    update = False
    if row.Name not in names_matched.keys():
        update = True
    else:
        if names_matched[row.Name]['Specialty_Match'] == False and names_matched[row.Name]['Initial_Match'] == False:
            if row.Specialty_Match == True or row.Initial_Match ==  True:
                update = True
        elif names_matched[row.Name]['Initial_Match'] == True:
            if row.Specialty_Match == True and row.Initial_Match ==  True:
                update = True
            if row.Specialty_Match == True or row.Initial_Match ==  True:
                print(f'Possible MEs for {row.Name}: {row.ME},{names_matched[row.Name]["ME"]}')
        elif names_matched[row.Name]['Specialty_Match'] == True:
            if row.Specialty_Match == True and row.Initial_Match ==  True:
                update = True
            if row.Specialty_Match == True or row.Initial_Match ==  True:
                print(f'Possible MEs for {row.Name}: {row.ME},{names_matched[row.Name]["ME"]}')
    if update == True:
        names_matched[row.Name] = {
                'Name': row.Name,
                'ME': row.ME,
                'Specialty_Match': row.Specialty_Match,
                'Initial_Match': row.Initial_Match
                }
# Out:
# Possible MEs for David T. Martin, MD: 2604110648.0,91707820182.0
# Possible MEs for David T. Martin, MD: 2101980343.0,91707820182.0
# Possible MEs for Michael J. Weaver, MD: 401070982.0,301720301.0
# Possible MEs for Michael J. Weaver, MD: 1643130641.0,301720301.0
# Possible MEs for Michael J. Weaver, MD: 3840711454.0,301720301.0
# Possible MEs for Michael J. Weaver, MD: 3006640710.0,301720301.0
# Possible MEs for Michael J. Weaver, MD: 514040583.0,301720301.0
# Possible MEs for Lawrence Jay Epstein, MD: 1001850403.0,55002830166.0
# Possible MEs for David C. Brooks, MD: 1606091431.0,4301760081.0
# Possible MEs for Thomas C. Lee, MD: 38502610144.0,4109900899.0
# Possible MEs for Thomas C. Lee, MD: 24221450058.0,4109900899.0
# Possible MEs for Thomas C. Lee, MD: 801930506.0,4109900899.0
# Possible MEs for Thomas C. Lee, MD: 514930627.0,4109900899.0
# Possible MEs for Thomas C. Lee, MD: 3840941026.0,4109900899.0
# Possible MEs for Thomas C. Lee, MD: 2301920892.0,4109900899.0
# ...

# %%
pd.DataFrame(names_matched).transpose().to_csv('Brigham_Match.csv')

# %%
duplicate_brig_df.to_csv('Brigham_Duplicates.csv')

# %%
missing_names_brig
# Out:
# ['Raja-Elie E. Abdulnour, MD',
#  'Maureen M. Achebe, MD',
#  'Christopher G. AhnAllen, PhD',
#  'Hiroyuki Aihara, MD, PhD',
#  'Rodolfo E. Alcedo-Guardia, MD',
#  'Raquel Oliva Alencar, MD, PhD',
#  'Cristina Baseggio Alexander, MD',
#  'Jessica R. Allegretti, MD, MPH',
#  'Jo Ellen M. Altschaefl, MD',
#  'Edwin Pascal Alyea, III, MD',
#  'Rebecca E. Amariglio, PhD',
#  'Stephen Alan Amira, PhD',
#  'MaryCatherine E. Arbour, MD',
#  'Dominique Y. Arce, MD, MPH',
#  'Alev J. Atalay, MD',
#  'K. Frank Austen, MD',
#  'Lindsay Barker, PhD',
#  'Adi Barlev-Ehrenberg, MD, MS',
#  'Kayla Behbahani, DO',
#  'Mandy Brown Belfort, MD',
#  'Yolanda Yvette Berger, LICSW',
#  'Monica Marie Bertagnolli, MD',
#  'Sharon L Bober, PhD',
#  'Tamara Bockow Kaplan, MD',
#  'Sheila A. Bond, MD',
#  'Sheila Borboli-Gerogiannis, MD',
#  'Donna J. Brezinski, MD',
#  'Kathryn A. Britton, MD',
#  'Kristine Specht Burk, MD',
#  'Brittany L. Bychkovsky, MD',
#  'Fernanda C. Cabral, MD',
# ...

# %%
PPD_[PPD_['LAST_NAME']=='ABDULNOUR']
# Out:
#         SPEC_CD_SEC     DESC_SEC SPEC_CD_PRIM  \
# 1028260          US  UNSPECIFIED          PCC
# 1134563          US  UNSPECIFIED           PN
#
#                                   DESC_PRIM           ME  \
# 1028260  PULMONARY & CRITICAL CARE MEDICINE  60501030310
# 1134563                PEDIATRIC NEPHROLOGY  87501950651
#
#                  MAILING_NAME  LAST_NAME FIRST_NAME  MIDDLE_NAME  SUFFIX  ...  \
# 1028260   RAJA E ABDULNOUR MD  ABDULNOUR       RAJA  ELIE EDWARD     NaN  ...
# 1134563  HUSAM A ABDULNOUR MD  ABDULNOUR      HUSAM    ABDULNOUR     NaN  ...
#
#             POLO_MAILING_LINE_2 POLO_CITY POLO_STATE POLO_ZIP  \
# 1028260             55 FRUIT ST    BOSTON         MA    02114
# 1134563  1510 FLORIDA AVE STE C   MODESTO         CA    95350
#
#         MOST_RECENT_FORMER_LAST_NAME  MOST_RECENT_FORMER_MIDDLE_NAME  \
# 1028260                    ABDULNOUR                    -ELIE EDWARD
# 1134563                          NaN                             NaN
#
# ...

# %%
for row in PPD_[PPD_['FIRST_NAME']=='MAUREEN'].itertuples():
    print(row.LAST_NAME)
    print(row.DESC_PRIM)
# Out:
# SACON
# OSTEOPATHIC MANIPULATIVE MEDICINE
# MULCAHY
# OTOLARYNGOLOGY-HEAD AND NECK SURGERY
# DOWNES
# PEDIATRICS
# KHALIL
# PSYCHIATRY
# TROTTER
# ANATOMIC/CLINICAL PATHOLOGY
# MAYS
# FAMILY MEDICINE
# SPITZER
# PSYCHIATRY
# ZELINKA
# EMERGENCY MEDICINE
# CALLAGHAN
# NEUROLOGY
# KRUSKAL
# PEDIATRICS
# MOONEY
# DERMATOLOGY
# DUDGEON
# INTERNAL MEDICINE
# WOOD
# INTERNAL MEDICINE
# MURRY
# LEGAL MEDICINE
# ALLINDER
# PSYCHIATRY
# MC GOVERN
# PSYCHIATRY
# KOOPS
# INTERNAL MEDICINE
# LAVIN
# OCCUPATIONAL MEDICINE
# AARON
# FAMILY MEDICINE
# HIRTHLER
# EMERGENCY MEDICINE
# O'BRIEN
# FAMILY MEDICINE
# KAVANAH
# MEDICAL ONCOLOGY
# KILLACKEY
# GYNECOLOGIC ONCOLOGY
# MOOMJY
# REPRODUCTIVE ENDOCRINOLOGY AND INFERTILITY
# JONAS
# PEDIATRIC GASTROENTEROLOGY
# CONLAN
# MEDICAL ONCOLOGY
# TIERNEY
# INTERNAL MEDICINE
# MILLER
# ALLERGY AND IMMUNOLOGY
# MC GEEHAN
# ALLERGY AND IMMUNOLOGY
# STEIN
# CARDIOVASCULAR DISEASE
# KANE
# CARDIOVASCULAR DISEASE
# LOWERY
# CARDIOVASCULAR DISEASE
# MARSHALL
# ...

# %%
brig_[brig_['LAST_NAME']=='ACHEBE']
# Out:
#                      Name FIRST_NAME LAST_NAME MIDDLE_NAME  Unnamed: 0  \
# 12  Maureen M. Achebe, MD    MAUREEN    ACHEBE          M.          12
#
#                                                  Link  Index     Specialty
# 12  https://physiciandirectory.brighamandwomens.or...   2051  Hematology,

# %%
name_list = ["ROSS",
"OKAM",
"HEWITT",
"O'SHAUGHNESSY"]
PPD_[(PPD_.FIRST_NAME == 'MAUREEN')&(PPD_.LAST_NAME.isin(name_list))]
# Out:
#        SPEC_CD_SEC     DESC_SEC SPEC_CD_PRIM                       DESC_PRIM  \
# 635259          US  UNSPECIFIED          HEM  HEMATOLOGY (INTERNAL MEDICINE)
# 635776          US  UNSPECIFIED          HEM  HEMATOLOGY (INTERNAL MEDICINE)
# 639512          US  UNSPECIFIED           HO     HEMATOLOGY/MEDICAL ONCOLOGY
# 650771          US  UNSPECIFIED          HSO      HAND SURGERY (ORTHOPEDICS)
#
#                  ME                MAILING_NAME      LAST_NAME FIRST_NAME  \
# 635259   1102841774             MAUREEN ROSS MD           ROSS    MAUREEN
# 635776  69012950012           MAUREEN M OKAM MD           OKAM    MAUREEN
# 639512   2105010624         MAUREEN R HEWITT MD         HEWITT    MAUREEN
# 650771   1102121615  MAUREEN A O'SHAUGHNESSY MD  O'SHAUGHNESSY    MAUREEN
#
#        MIDDLE_NAME  SUFFIX  ...        POLO_MAILING_LINE_2     POLO_CITY  \
# 635259         NaN     NaN  ...          ELM & CARLTON STS       BUFFALO
# ...

# %%
# PPD_[(PPD_['FIRST_NAME']=='JESSICA')&(PPD_['MIDDLE_NAME']=='R')]
PPD_.loc[PPD_['LAST_NAME']=='ALTSCHAEFL']['ME']
#     print(row.DESC_PRIM)
# Out:
# 85544    5605830031
# Name: ME, dtype: int64

# %%
brig_[brig_.Name.isin(missing_names_brig)].to_csv('Missing_Brig.csv')

# %%
PPD_.dtypes
# Out:
# SPEC_CD_SEC                        object
# DESC_SEC                           object
# SPEC_CD_PRIM                       object
# DESC_PRIM                          object
# ME                                  int64
# MAILING_NAME                       object
# LAST_NAME                          object
# FIRST_NAME                         object
# MIDDLE_NAME                        object
# SUFFIX                            float64
# MAILING_LINE_1                     object
# MAILING_LINE_2                     object
# CITY                               object
# STATE                              object
# ZIP                                object
# MD_DO_CODE                          int64
# BIRTH_YEAR                        float64
# BIRTH_CITY                         object
# BIRTH_STATE                        object
# BIRTH_COUNTRY                      object
# TELEPHONE_NUMBER                  float64
# FAX_NUMBER                        float64
# ...

# %%
for df in df_list:
    print(len(df))
# Out:
# 2999
# 2216
# 1908
# 4536
# 2683
# 3150
# 3252
# 1037
# 2399

# %%
df_list
# Out:
# [      Unnamed: 0                                               Link  \
#  0              0  https://findadoc.bidmc.org/details/3480/amtul-...
#  1              1  https://findadoc.bidmc.org/details/2627/bassim...
#  2              2  https://findadoc.bidmc.org/details/1/ayesha-ab...
#  3              3  https://findadoc.bidmc.org/details/2/dorina-ab...
#  4              4  https://findadoc.bidmc.org/details/2248/charbe...
#  ...          ...                                                ...
#  2994        2994  https://findadoc.bidmc.org/details/3497/dimita...
#  2995        2995  https://findadoc.bidmc.org/details/3843/kate-z...
#  2996        2996  https://findadoc.bidmc.org/details/3844/kangni...
#  2997        2997  https://findadoc.bidmc.org/details/3348/elizab...
#  2998        2998  https://findadoc.bidmc.org/details/3350/frankl...
#
#                              Name             Specialty            Phone  \
# ...

# %%
penn_ = split_names(penn)

# %%
penn_.to_csv('Penn_Scrape.csv', index=False)

# %%
henr_ = split_names(henr)
henr_.to_csv('Henr_Scrape.csv', index=False)

# %%
beth_ =split_names(beth)
beth_.to_csv('Beth_Scrape.csv', index=False)

# %%
penn
# Out:
#       Unnamed: 0                                               Link  \
# 0              0  /providers/profile/nadine-al-naamani?fadf=penn...
# 1              1  /providers/profile/sara-attalla?fadf=pennmedicine
# 2              2  /providers/profile/valerianna-amorosa?fadf=pen...
# 3              3   /providers/profile/nicole-aqui?fadf=pennmedicine
# 4              4  /providers/profile/michael-acker?fadf=pennmedi...
# ...          ...                                                ...
# 3247        3247  /providers/profile/toby-zachian?fadf=pennmedicine
# 3248        3248  /providers/profile/richard-ziegler?fadf=pennme...
# 3249        3249  /providers/profile/karl-zimmerman?fadf=pennmed...
# 3250        3250  /providers/profile/michael-zarro?fadf=pennmedi...
# 3251        3251  /providers/profile/bruce-zappan?fadf=pennmedicine
#
#                            Name  \
# 0     Nadine Al-Naamani, MD, MS
# 1              Sara Attalla, MD
# 2     Valerianna K. Amorosa, MD
# ...

# %%
henr_
# Out:
#                     Name FIRST_NAME   LAST_NAME MIDDLE_NAME  Unnamed: 0  \
# 0           Saadia Abbas     SAADIA       ABBAS        None           0
# 1            Sami Abbasi       SAMI      ABBASI        None           1
# 2       Tariq Abdelkarim      TARIQ  ABDELKARIM        None           2
# 3         Firas Abdollah      FIRAS    ABDOLLAH        None           3
# 4      Mayada Abdul-Aziz     MAYADA  ABDUL-AZIZ        None           4
# ...                  ...        ...         ...         ...         ...
# 4567     Ashley Zuzelski     ASHLEY    ZUZELSKI        None        4531
# 4568      Dace Zvirbulis       DACE   ZVIRBULIS        None        4532
# 4569  Raimonds Zvirbulis   RAIMONDS   ZVIRBULIS        None        4533
# 4570         Bryan Zweig      BRYAN       ZWEIG        None        4534
# 4571      Michael Zydeck    MICHAEL      ZYDECK        None        4535
#
#                                            Link                  Specialty  \
# ...

# %%
missing_names_brig
# Out:
# ['Raja-Elie E. Abdulnour, MD',
#  'Maureen M. Achebe, MD',
#  'Christopher G. AhnAllen, PhD',
#  'Hiroyuki Aihara, MD, PhD',
#  'Rodolfo E. Alcedo-Guardia, MD',
#  'Raquel Oliva Alencar, MD, PhD',
#  'Cristina Baseggio Alexander, MD',
#  'Jessica R. Allegretti, MD, MPH',
#  'Jo Ellen M. Altschaefl, MD',
#  'Edwin Pascal Alyea, III, MD',
#  'Rebecca E. Amariglio, PhD',
#  'Stephen Alan Amira, PhD',
#  'MaryCatherine E. Arbour, MD',
#  'Dominique Y. Arce, MD, MPH',
#  'Alev J. Atalay, MD',
#  'K. Frank Austen, MD',
#  'Lindsay Barker, PhD',
#  'Adi Barlev-Ehrenberg, MD, MS',
#  'Kayla Behbahani, DO',
#  'Mandy Brown Belfort, MD',
#  'Yolanda Yvette Berger, LICSW',
#  'Monica Marie Bertagnolli, MD',
#  'Sharon L Bober, PhD',
#  'Tamara Bockow Kaplan, MD',
#  'Sheila A. Bond, MD',
#  'Sheila Borboli-Gerogiannis, MD',
#  'Donna J. Brezinski, MD',
#  'Kathryn A. Britton, MD',
#  'Kristine Specht Burk, MD',
#  'Brittany L. Bychkovsky, MD',
#  'Fernanda C. Cabral, MD',
# ...

# %%
ME_list= []
options = [row.LAST_NAME, row.LAST_NAME.replace('-',' '), (row.MIDDLE_NAME + ' ' + row.LAST_NAME), (row.MIDDLE_NAME + '-' + row.LAST_NAME)]
for row in brig_[brig_.Name.isin(missing_names_brig)].itertuples():
    # PPD_[(PPD_['FIRST_NAME']=='JESSICA')&(PPD_['MIDDLE_NAME']=='R')]
    for option in options:
        last_name_match = PPD_[PPD_['LAST_NAME']==option]
        if len(last_name_match) >0:
            print(last_name_match)
            break
    if len(last_name_match)==1:
        ME=last_name_match.ME
    else:
        ME = 'none'
    ME_list.append(ME)
#     print(row.DESC_PRIM)
# Out:
#         SPEC_CD_SEC                               DESC_SEC SPEC_CD_PRIM  \
# 1795            PME                        PAIN MANAGEMENT           AN
# 2935            PME                        PAIN MANAGEMENT           PM
# 5046              A                                ALLERGY           PD
# 8970             AI                 ALLERGY AND IMMUNOLOGY          RHU
# 10397            AM                     AEROSPACE MEDICINE          OTO
# ...             ...                                    ...          ...
# 1254726          US                            UNSPECIFIED           VS
# 1257485          US                            UNSPECIFIED           VS
# 1257860          US                            UNSPECIFIED           VS
# 1258809         VIR  VASCULAR AND INTERVENTIONAL RADIOLOGY            R
# 1259017          VM                      VASCULAR MEDICINE          NEP
#
#                                     DESC_PRIM           ME     MAILING_NAME  \
# ...

# %%
ME_list
# Out:
# ['none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
#  'none',
# ...

# %%
PPD_[PPD_['LAST_NAME']==row.LAST_NAME].ME
# Out:
# 44821       3508702123
# 718750      3548920689
# 1261906    56101770325
# Name: ME, dtype: int64

# %%
penn_.groupby('Location').count()
# Out:
#                                                     Name  FIRST_NAME  \
# Location
# Abington Reproductive Medicine                         1           1
# Accurate  Foot and Diabetic Care                       2           2
# Advocare Chester County Office of Broomall Pedi...     4           4
# Advocare Pulmonary and Sleep Specialists               1           1
# Advocare Society Hill Pediatrics                       5           5
# ...                                                  ...         ...
# WellSpan Pulmonary and Sleep Medicine - Ephrata...     1           1
# West Chester Cardiology West Chester                   1           1
# Willowdale Internal Medicine Associates                1           1
# Women and Babies Hospital                              7           7
# Women's Health Care Group of PA                        1           1
#
#                                                     LAST_NAME  MIDDLE_NAME  \
# Location
# ...

# %%
penn
# Out:
#       Unnamed: 0                                               Link  \
# 0              0  /providers/profile/nadine-al-naamani?fadf=penn...
# 1              1  /providers/profile/sara-attalla?fadf=pennmedicine
# 2              2  /providers/profile/valerianna-amorosa?fadf=pen...
# 3              3   /providers/profile/nicole-aqui?fadf=pennmedicine
# 4              4  /providers/profile/michael-acker?fadf=pennmedi...
# ...          ...                                                ...
# 3247        3247  /providers/profile/toby-zachian?fadf=pennmedicine
# 3248        3248  /providers/profile/richard-ziegler?fadf=pennme...
# 3249        3249  /providers/profile/karl-zimmerman?fadf=pennmed...
# 3250        3250  /providers/profile/michael-zarro?fadf=pennmedi...
# 3251        3251  /providers/profile/bruce-zappan?fadf=pennmedicine
#
#                            Name  \
# 0     Nadine Al-Naamani, MD, MS
# 1              Sara Attalla, MD
# 2     Valerianna K. Amorosa, MD
# ...

# %%
cols = {'NAME': 'None',
        'SPECIALTY': 'None',
        'SECONDARY_SPECIALTY': 'None',
        'PHONE': 'None',
        'FAX': 'None',
        'LOCATION_NAME': 'None',
        'LOCATION_ADDRESS': 'None',
        'LOCATION_ADDRESS_CITY': 'None',
        'LOCATION_ADDRESS_STATE': 'None',
        'LOCATION_ADDRESS_ZIP': 'None',
        'DEPARTMENT': 'None',
        'PROGRAM': 'None',
        'PARENT_ORG_NAME': 'None'}

# %%
dict_list =[]
for row in henr.itertuples():
    office_index = 0
    office_list =row.Offices.replace('[','').replace(']','').split("', '")
    for office in office_list:
        print(office)
        new_dict = {'NAME': 'None',
        'SPECIALTY': 'None',
        'SECONDARY_SPECIALTY': 'None',
        'PHONE': 'None',
        'FAX': 'None',
        'LOCATION_NAME': 'None',
        'LOCATION_ADDRESS': 'None',
        'LOCATION_ADDRESS_CITY': 'None',
        'LOCATION_ADDRESS_STATE': 'None',
        'LOCATION_ADDRESS_ZIP': 'None',
        'DEPARTMENT': 'None',
        'PROGRAM': 'None',
        'PARENT_ORG_NAME': 'None'}
        
        new_dict['LOCATION_NAME'] = office.replace("'","")
        address_list = row.Addresses.replace('[','').replace(']','').split("', '")
        split_addresses = address_list[office_index].split(',')
        print(split_addresses)
        if len(split_addresses) == 3:
            new_dict['LOCATION_ADDRESS']=split_addresses[0]        
            new_dict['LOCATION_ADDRESS_CITY']=split_addresses[1]  
            new_dict['LOCATION_ADDRESS_STATE']=split_addresses[2].split(' ')[1]  
            new_dict['LOCATION_ADDRESS_ZIP']=split_addresses[2].split(' ')[2]  
            
        if len(split_addresses) == 4:
            new_dict['LOCATION_ADDRESS']=split_addresses[0] + ',' + split_addresses[1]      
            new_dict['LOCATION_ADDRESS_CITY']=split_addresses[2]  
            new_dict['LOCATION_ADDRESS_STATE']=split_addresses[3].split(' ')[1]  
            new_dict['LOCATION_ADDRESS_ZIP']=split_addresses[3].split(' ')[2]  
            
        new_dict['NAME']=row.Name
        new_dict['SPECIALTY']=row.Specialty
        new_dict['PHONE']=row.Phone
        
        office_index += 1
        dict_list.append(new_dict)
# Out:
# 'Henry Ford Medical Center Sterling Heights
# ["'3500 15 Mile Rd", ' Sterling Heights', ' MI 48310 ']
# HFM Urgent Care - Bruce Twp
# ['80650 Van Dyke', ' Bruce Township', ' MI 48065 ']
# HFM Urgent Care - Chesterfield'
# ['30795 23 Mile Rd', ' Chesterfield', " MI 48047 '"]
# 'None
# ["'133 W Main St", ' Ste 251', ' Northville', ' MI 48167 ']
# Abbasi Dermatology'
# ['21401 Allen Road', ' Woodhaven', " MI 48183 '"]
# 'Hillsdale Pulmonary Critical Care & Sleep Medicine
# ["'3271 W Carleton Road", ' Hillsdale', ' MI 49242 ']
# Tariq H Abdelkarim, MD'
# ['605 W Chicago Street', ' Ste 2', ' Coldwater', " MI 49036 '"]
# 'Henry Ford Medical Center - Fairlane
# ["'19401 Hubbard Dr", ' Dearborn', ' MI 48126 ']
# Henry Ford Medical Center - Lakeside'
# ['14500 Hall Rd', ' Sterling Hgts', " MI 48313 '"]
# 'Henry Ford Medical Center - Taylor'
# ["'24555 Haig Rd", ' Taylor', " MI 48180 '"]
# 'None'
# ["'13460 Fort Street", ' Southgate', " MI 48195 '"]
# 'Henry Ford Hospital
# ...

# %%
henr['Addresses']
# Out:
# 0       ['3500 15 Mile Rd, Sterling Heights, MI 48310 ...
# 1       ['133 W Main St, Ste 251, Northville, MI 48167...
# 2       ['3271 W Carleton Road, Hillsdale, MI 49242 ',...
# 3       ['19401 Hubbard Dr, Dearborn, MI 48126 ', '145...
# 4                    ['24555 Haig Rd, Taylor, MI 48180 ']
#                               ...
# 4531               ['205 N East Ave, Jackson, MI 49201 ']
# 4532    ['2799 W Grand Blvd, Detroit, MI 48202 ', '196...
# 4533    ['19401 Hubbard Dr, Dearborn, MI 48126 ', '677...
# 4534            ['19401 Hubbard Dr, Dearborn, MI 48126 ']
# 4535            ['2333 Biddle Ave, Wyandotte, MI 48192 ']
# Name: Addresses, Length: 4536, dtype: object

# %%
pd.DataFrame(dict_list).to_csv('Henry_Ford_Health_System_2020-01-06.csv')

# %%
henr_df = pd.DataFrame(dict_list)

# %%
mayo[(mayo['Location']=='Phoenix, AZ') & (mayo['Specialty']=="['Otolaryngologist']")]
# Out:
#                           Name             Specialty     Location
# 1111   Richard E. Hayden, M.D.  ['Otolaryngologist']  Phoenix, AZ
# 1148    Michael L. Hinni, M.D.  ['Otolaryngologist']  Phoenix, AZ
# 1182  Brittany E. Howard, M.D.  ['Otolaryngologist']  Phoenix, AZ
# 1657       David G. Lott, M.D.  ['Otolaryngologist']  Phoenix, AZ
# 1950     Thomas H. Nagel, M.D.  ['Otolaryngologist']  Phoenix, AZ
# 2978  Peter A. Weisskopf, M.D.  ['Otolaryngologist']  Phoenix, AZ

# %%
mayo[mayo['Location']=='Phoenix, AZ'].groupby('Specialty').count().sort_values('Name', ascending = False).head(50)
# Out:
#                                                     Name  Location
# Specialty
# None                                                  61        61
# ['Internist']                                         53        53
# ['Radiologist']                                       39        39
# ['Neurologist']                                       24        24
# ['Anesthesiologist']                                  22        22
# ['Pathologist']                                       19        19
# ['General Surgeon']                                   14        14
# ['Family Physician']                                  14        14
# ['Gastroenterologist']                                12        12
# ['Radiation Oncologist']                              11        11
# ['Urologist']                                         10        10
# ['Radiation Oncology Medical Physicist']               9         9
# ['Internist', 'Oncologist']                            8         8
# ...

# %%
mayo
# Out:
#                                     Name                         Specialty  \
# 0     Christopher (Chris) A. Aakre, M.D.                     ['Internist']
# 1               Ejigayehu G. Abate, M.D.  ['Endocrinologist', 'Internist']
# 2                Charles F. Abboud, M.B.                              None
# 3        Arnoley (Arney) S. Abcejo, M.D.              ['Anesthesiologist']
# 4                 Matthew P. Abdel, M.D.                              None
# ...                                  ...                               ...
# 3145                       Xun Zhu, M.D.              ['Anesthesiologist']
# 3146  Matthew (Matt) J. Ziegelmann, M.D.                              None
# 3147           Martin D. Zielinski, M.D.    ['General Surgeon', 'Surgeon']
# 3148              Scott P. Zietlow, M.D.               ['General Surgeon']
# 3149          Richard S. Zimmerman, M.D.                  ['Neurosurgeon']
#
#               Location
# 0        Rochester, MN
# ...

# %%
def listify(string):
    string_list =string.replace('[','').replace(']','').split("', '")
    return(string_list)

# %%
dict_list =[]
for row in mayo.itertuples():
    new_dict = {'NAME': 'None',
        'SPECIALTY': 'None',
        'SECONDARY_SPECIALTY': 'None',
        'PHONE': 'None',
        'FAX': 'None',
        'LOCATION_NAME': 'None',
        'LOCATION_ADDRESS': 'None',
        'LOCATION_ADDRESS_CITY': 'None',
        'LOCATION_ADDRESS_STATE': 'None',
        'LOCATION_ADDRESS_ZIP': 'None',
        'DEPARTMENT': 'None',
        'PROGRAM': 'None',
        'PARENT_ORG_NAME': 'Mayo Clinic'}
  
    new_dict['LOCATION_ADDRESS_CITY']=row.Location.split(', ')[0]
    if len(row.Location.split(', ')) >1:
        new_dict['LOCATION_ADDRESS_STATE']=row.Location.split(', ')[1] 
            
    new_dict['NAME']=row.Name
        
        
    specialty_list = listify(row.Specialty)
    new_dict['SPECIALTY']=specialty_list[0]
    if len(specialty_list)>1:
        new_dict['SECONDARY_SPECIALTY']=specialty_list[1] 
    dict_list.append(new_dict)

# %%
dict_list
# Out:
# [{'NAME': 'Christopher (Chris) A. Aakre, M.D.',
#   'SPECIALTY': "'Internist'",
#   'SECONDARY_SPECIALTY': 'None',
#   'PHONE': 'None',
#   'FAX': 'None',
#   'LOCATION_NAME': 'None',
#   'LOCATION_ADDRESS': 'None',
#   'LOCATION_ADDRESS_CITY': 'Rochester',
#   'LOCATION_ADDRESS_STATE': 'MN',
#   'LOCATION_ADDRESS_ZIP': 'None',
#   'DEPARTMENT': 'None',
#   'PROGRAM': 'None',
#   'PARENT_ORG_NAME': 'Mayo Clinic'},
#  {'NAME': 'Ejigayehu G. Abate, M.D.',
#   'SPECIALTY': "'Endocrinologist",
#   'SECONDARY_SPECIALTY': "Internist'",
#   'PHONE': 'None',
#   'FAX': 'None',
#   'LOCATION_NAME': 'None',
#   'LOCATION_ADDRESS': 'None',
#   'LOCATION_ADDRESS_CITY': 'Jacksonville',
#   'LOCATION_ADDRESS_STATE': 'FL',
#   'LOCATION_ADDRESS_ZIP': 'None',
#   'DEPARTMENT': 'None',
#   'PROGRAM': 'None',
#   'PARENT_ORG_NAME': 'Mayo Clinic'},
#  {'NAME': 'Charles F. Abboud, M.B.',
#   'SPECIALTY': 'None',
#   'SECONDARY_SPECIALTY': 'None',
#   'PHONE': 'None',
#   'FAX': 'None',
# ...

# %%
henr_df_2 = split_names(henr_df)

# %%
henr_df
# Out:
#                     NAME                  SPECIALTY SECONDARY_SPECIALTY  \
# 0           Saadia Abbas            Family Medicine                None
# 1           Saadia Abbas            Family Medicine                None
# 2           Saadia Abbas            Family Medicine                None
# 3            Sami Abbasi                Dermatology                None
# 4            Sami Abbasi                Dermatology                None
# ...                  ...                        ...                 ...
# 7128      Dace Zvirbulis                  Neurology                None
# 7129  Raimonds Zvirbulis         Orthopedic Surgery                None
# 7130  Raimonds Zvirbulis         Orthopedic Surgery                None
# 7131         Bryan Zweig                 Cardiology                None
# 7132      Michael Zydeck  Radiology, Neuroradiology                None
#
#              PHONE   FAX                                      LOCATION_NAME  \
# ...

# %%
HENR_duplicate_names, HENR_missing_names, HENR_matched = match_ppd(PPD_, henr_df_2)
# Out:
# Approximately 13550 duplicates found
# 2195 duplicates found.
# 4856 names missing.

# %%
HENR_matched.drop_duplicates('ME')[['SPECIALTY','DESC_PRIM']].head(50)
# Out:
#                                             SPECIALTY  \
# 0   Neurology, Neuromuscular Medicine, Neurophysio...
# 1                                   Anesthesia - CRNA
# 2                                   Anesthesia - CRNA
# 3                                   Anesthesia - CRNA
# 4                                   Anesthesia - CRNA
# 5                                   Anesthesia - CRNA
# 6                                   Anesthesia - CRNA
# 7                                   Anesthesia - CRNA
# 8                                   Anesthesia - CRNA
# 9                                   Anesthesia - CRNA
# 10                                  Anesthesia - CRNA
# 11                                  Anesthesia - CRNA
# 12                                  Anesthesia - CRNA
# 13                                  Anesthesia - CRNA
# 14                                  Anesthesia - CRNA
# 15                                  Anesthesia - CRNA
# ...

# %%
HENR_missing_names
# Out:
# ['Muwaffak Abdulhak',
#  'Diane Abel-Williams',
#  'Eva Abiragi',
#  'Joelle Abood',
#  'Iman Abou-Chakra',
#  'Iman Abou-Chakra',
#  'Iman Abou-Chakra',
#  'Iman Abou-Chakra',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Heather Abraam',
#  'Annemarie Abrahamson',
#  'Matthew Abrahamson',
#  'Odaliz Abreu Lanfranco',
#  'Sally Abro',
#  'Alaa Abu Sayf',
#  'Alaa Abu Sayf',
#  'Alaa Abu Sayf',
#  'Alaa Abu Sayf',
#  'Zaid Abu-Seir',
#  'Neelima Acharya',
#  'Mary Achoo',
#  'Kenicia Adams',
#  'Nicole Adams',
#  'Nicole Adams',
#  'Nicole Adams',
#  'Nicole Adams',
#  'Rachel Adler',
#  'Rachel Adler',
#  'Rachel Adler',
#  'Rachel Adler',
#  'Rachel Adler',
#  'Rachel Adler',
#  'Rachel Adler',
#  'Rachel Adler',
# ...

# %%
henr_df_2 = henr_df_2.drop_duplicates('NAME')

# %%
HENR_duplicate_names, HENR_missing_names, HENR_matched = match_ppd(PPD_, henr_df_2)
# Out:
# Approximately 4604 duplicates found
# 699 duplicates found.
# 1766 names missing.

# %%
HENR_matched[HENR_matched['FIRST_NAME']=='SAADIA']
# Out:
#      SPEC_CD_SEC     DESC_SEC SPEC_CD_PRIM        DESC_PRIM            ME  \
# 5835          US  UNSPECIFIED           FM  FAMILY MEDICINE  7.040297e+10
#
#            MAILING_NAME LAST_NAME FIRST_NAME MIDDLE_NAME_x  SUFFIX  ...  \
# 5835  SAADIA R ABBAS MD     ABBAS     SAADIA         REHAN     NaN  ...
#
#              PHONE   FAX                               LOCATION_NAME  \
# 5835  586-421-3052  None  Henry Ford Medical Center Sterling Heights
#
#       LOCATION_ADDRESS LOCATION_ADDRESS_CITY  LOCATION_ADDRESS_STATE  \
# 5835  '3500 15 Mile Rd      Sterling Heights                      MI
#
#       LOCATION_ADDRESS_ZIP DEPARTMENT PROGRAM PARENT_ORG_NAME
# 5835                 48310       None    None            None
#
# [1 rows x 60 columns]

# %%
henr_df_2
# Out:
#                      NAME FIRST_NAME   LAST_NAME MIDDLE_NAME  \
# 0            Saadia Abbas     SAADIA       ABBAS        None
# 9             Sami Abbasi       SAMI      ABBASI        None
# 13       Tariq Abdelkarim      TARIQ  ABDELKARIM        None
# 17         Firas Abdollah      FIRAS    ABDOLLAH        None
# 21      Mayada Abdul-Aziz     MAYADA  ABDUL-AZIZ        None
# ...                   ...        ...         ...         ...
# 14428     Ashley Zuzelski     ASHLEY    ZUZELSKI        None
# 14429      Dace Zvirbulis       DACE   ZVIRBULIS        None
# 14438  Raimonds Zvirbulis   RAIMONDS   ZVIRBULIS        None
# 14442         Bryan Zweig      BRYAN       ZWEIG        None
# 14443      Michael Zydeck    MICHAEL      ZYDECK        None
#
#                        SPECIALTY SECONDARY_SPECIALTY         PHONE   FAX  \
# 0                Family Medicine                None  586-421-3052  None
# 9                    Dermatology                None  734-675-0835  None
# ...

# %%
HENR_matched.drop_duplicates(subset ='NAME', keep=False)
# Out:
#      SPEC_CD_SEC                            DESC_SEC SPEC_CD_PRIM  \
# 0            NMN  NEUROMUSCULAR MEDICINE (NEUROLOGY)           CN
# 284          PME                     PAIN MANAGEMENT           AN
# 318          PME                     PAIN MANAGEMENT           FM
# 359          PME                     PAIN MANAGEMENT           PM
# 360          PME                     PAIN MANAGEMENT          PMM
# ...          ...                                 ...          ...
# 9117         NaN                                 NaN          NaN
# 9118         NaN                                 NaN          NaN
# 9119         NaN                                 NaN          NaN
# 9120         NaN                                 NaN          NaN
# 9121         NaN                                 NaN          NaN
#
#                                  DESC_PRIM            ME  \
# 0                 CLINICAL NEUROPHYSIOLOGY  6.610204e+10
# ...

# %%
HENR_missing_names
# Out:
# ['Muwaffak Abdulhak',
#  'Diane Abel-Williams',
#  'Eva Abiragi',
#  'Joelle Abood',
#  'Iman Abou-Chakra',
#  'Heather Abraam',
#  'Annemarie Abrahamson',
#  'Matthew Abrahamson',
#  'Odaliz Abreu Lanfranco',
#  'Sally Abro',
#  'Alaa Abu Sayf',
#  'Zaid Abu-Seir',
#  'Neelima Acharya',
#  'Mary Achoo',
#  'Kenicia Adams',
#  'Nicole Adams',
#  'Rachel Adler',
#  'Indra Adrianto',
#  'Shana Ageloff-Kupetz',
#  'Anju Aggarwal',
#  'Javier Aguilar Aragon',
#  'Patrick Agunwa',
#  'Hesham Ahmed',
#  'Brian Ahmedani',
#  'Amanda Ahrens',
#  'Arsalan Ahsan',
#  'Heather Ainsworth',
#  'Mohammed Al Hallak',
#  'Saleh Al-Ameen',
#  'Mohammed Al-Ansari',
#  'Majid Al-Zagoum',
#  'Kheir Al-Zouhayli',
#  'Marlon Alafriz',
#  'Maath Alani',
#  'Ronda Albrecht',
#  'Devin Alcala',
#  'Jillian Aldanal',
#  'Patricia Aldridge',
#  'Salah Alenzi',
#  'Gwen Alexander',
#  'Ali Alhimiri',
#  'Meser Ali',
#  'Nour Ali',
#  'Mohammed Samhar Alkhalaf Alali',
#  'Wamidh Alkhoory',
#  'Raad Alkhouri',
# ...

# %%
PPD_[PPD_['FIRST_NAME'] == HENR_missing_names[0].upper().split(' ')[0]]
PPD_[PPD_['LAST_NAME'] == HENR_missing_names[0].upper().split(' ')[1]]['MAILING_NAME']
# Out:
# 347408    ABRAHAM H ABDULHAK MD
# 934068     MUNZER M ABDULHAK MD
# Name: MAILING_NAME, dtype: object

# %%
for name in HENR_missing_names:
    first_match = PPD_[PPD_['FIRST_NAME'] == name.upper().split(' ')[0]]
    last_match = PPD_[PPD_['LAST_NAME'] == name.upper().split(' ')[1]]
    if len(first_match) == 1:
        print(f'{name} : {first_match["MAILING_NAME"]}')
    elif len(last_match) == 1:
        print(f'{name} : {last_match["MAILING_NAME"]}')
# Out:
# Muwaffak Abdulhak : 129640    MUWAFFAK M ABDUL-HAK MD
# Name: MAILING_NAME, dtype: object
# Odaliz Abreu Lanfranco : 663601    ODALIZ E ABREU LANFRANCO MD
# Name: MAILING_NAME, dtype: object
# Kheir Al-Zouhayli : 323956    M K AL-ZOUHAYLI MD
# Name: MAILING_NAME, dtype: object
# Marlon Alafriz : 290813    MANUEL J ALAFRIZ MD
# Name: MAILING_NAME, dtype: object
# Salah Alenzi : 1254664    BADER A ALENZI MD
# Name: MAILING_NAME, dtype: object
# Wamidh Alkhoory : 1183733    WAMIDH L ALKHURRI MD
# Name: MAILING_NAME, dtype: object
# Lisa Allenspach : 1135273    ERIC J ALLENSPACH MD
# Name: MAILING_NAME, dtype: object
# Mohamed-Rida Alsaden : 287560    MUHAMADRIDA A ALSADEN MD
# Name: MAILING_NAME, dtype: object
# Elikem Amable : 1240032    JULIO P AMABLE MD
# Name: MAILING_NAME, dtype: object
# Karthikeyan Ananthasubramaniam : 102843    K ANANTHASUBRAMANIAM MD
# Name: MAILING_NAME, dtype: object
# Angelo Antaran : 1247544    FAUSTO T ANTARAN MD
# Name: MAILING_NAME, dtype: object
# ...

# %%
PPD_.to_csv('ppd_spec.csv', index=False)

# %%
HENR_missing_names[1300:]
# Out:
# ['Nusrat Qayyum',
#  'Zhihua Qi',
#  'Xiaoxi Qiao',
#  'Shijing Qiu',
#  'Linda Quigley',
#  'Sandra Raby',
#  'Thera Radney',
#  'Yaseen Rafee',
#  'Mary Raftery',
#  'Noureyah Rageh',
#  'Reema Rahal',
#  'Naureen Raja-Shafiq',
#  'Sankar Rajan',
#  'Christina Ralko',
#  'Ryan Ramales',
#  'Mayur Ramesh',
#  'Thimmiah Ramesh',
#  'Heidi Ramos',
#  'Rachel Rang',
#  'Sudhaker Rao',
#  'Maria Rapoport',
#  'Rachel Rasmer',
#  'Daniel Rathbun',
#  'Ramandeep Rattan',
#  'None',
#  'Tanya Realy',
#  'Shannon Reaume',
#  'Donna Rebidas',
#  'Jessica Redding',
#  'Madhulata Reddy',
#  'Bobbie Redmile',
#  'Della Rees',
#  'Kimberly Rees',
#  'Erica Reese',
#  'Nicholas Reeser',
#  'Samantha Reidt',
#  'Fay Reis',
#  'Charles Reisdorf',
#  'Ann Marie Rekucki',
#  'Jill Rembinski',
#  'Virginia Remedio',
#  'Patti Renaud',
#  'Sherrie Renaud-Charron',
#  'Priya Renu',
#  'Nicole Reul',
#  'Laura Reule',
#  'Sheri Revell',
#  'Miraflor Reyes-Ganzon',
#  'Nour-Eddine Rhaleb',
# ...

# %%
beth['Address_2']
# Out:
# 0            The Transplant Center
# 1               199 Reedsdale Road
# 2       Outpatient Clinical Center
# 3              464 Hillside Avenue
# 4              275 Sandwich Street
#                    ...
# 2994         1493 Cambridge Street
# 2995              195 Canal Street
# 2996         1493 Cambridge Street
# 2997         1493 Cambridge Street
# 2998         1493 Cambridge Street
# Name: Address_2, Length: 2999, dtype: object

# %%
dict_list =[]
for row in beth.itertuples():
    new_dict = {'NAME': 'None',
        'SPECIALTY': 'None',
        'SECONDARY_SPECIALTY': 'None',
        'PHONE': 'None',
        'FAX': 'None',
        'LOCATION_NAME': 'None',
        'LOCATION_STREET_ADDRESS':'None',
        'LOCATION_ADDRESS': 'None',
        'LOCATION_ADDRESS_CITY': 'None',
        'LOCATION_ADDRESS_STATE': 'MA',
        'LOCATION_ADDRESS_ZIP': 'None',
        'DEPARTMENT': 'None',
        'PROGRAM': 'None',
        'PARENT_ORG_NAME': 'Beth Israel Deaconess Medical Center'}
        
    new_dict['NAME']=row.Name
    new_dict['SPECIALTY']=row.Specialty
    new_dict['PHONE']=row.Phone
    new_dict['FAX']=row.Fax
    new_dict['LOCATION_NAME']=row.Location_Name
    new_dict['LOCATION_ADDRESS_CITY']=row.City
    new_dict['LOCATION_ADDRESS_ZIP']=row.Zipcode
    if 'Department' in row.Address_2:
        new_dict['DEPARTMENT']=str(row.Address_2).replace('Department of ','').replace(' Department','')
    if ',' in row.Address_1:
        new_dict['LOCATION_STREET_ADDRESS'] = row.Address_1.split(',')[0]
    elif row.Address_1.split(' ')[0].isdigit()==True:
        new_dict['LOCATION_STREET_ADDRESS'] = row.Address_1
    else:
        new_dict['LOCATION_STREET_ADDRESS'] = row.Address_2
    new_dict['LOCATION_ADDRESS']=str(row.Address_2 + ', ' + row.Address_1).replace(', None','')
    dict_list.append(new_dict)

# %%
list(pd.DataFrame(dict_list)['LOCATION_ADDRESS_ZIP'].unique())
# Out:
# ['02215-5501',
#  '02186-3926',
#  '02492',
#  '02494-1228',
#  '02360-2183',
#  '02215',
#  '02215-5400',
#  '02150-2247',
#  '02492-2505',
#  '02215-5321',
#  '03874',
#  '02215-5332',
#  '02138',
#  '02122-1817',
#  '02360',
#  '02120',
#  '02481-6202',
#  '01950',
#  '02186',
#  '02186-3884',
#  '02445-7224',
#  '02360-7735',
#  '01550-4051',
#  '02740-3464',
#  '02360-2130',
#  '02446-3806',
#  '02067-2015',
#  '02446-5587',
#  '02026-4530',
#  '02368-4835',
#  '02215-5324',
#  '02139-1047',
#  '02360-2237',
#  '02494-3238',
#  '02186-3874',
#  '02215-5566',
#  '02446',
#  '02124-5520',
#  '01915',
#  '02467-2012',
#  '01778-1824',
#  '02467',
#  '02115-5400',
#  '02467-1710',
#  '02459-1943',
#  '01608-1216',
#  '02130-2061',
#  '02421',
#  '02492-2411',
#  '02359',
#  '02184-6562',
#  '01950-3876',
#  '02186-3801',
#  '03079-5802',
#  '03060',
#  '02052-1654',
#  '02139',
#  '02446-4579',
#  '01890',
#  '02451-7549',
#  '02139-1407',
#  '01844-5802',
#  '01810-3662',
# ...

# %%
pd.DataFrame(dict_list).to_csv('Penn_Medicine_2020-12-30.csv', index=False)

# %%
dict_list =[]
for row in penn.itertuples():
    new_dict = {'NAME': 'None',
        'SPECIALTY': 'None',
        'SECONDARY_SPECIALTY': 'None',
        'PHONE': 'None',
        'FAX': 'None',
        'LOCATION_NAME': 'None',
        'LOCATION_ADDRESS': 'None',
        'LOCATION_ADDRESS_CITY': 'None',
        'LOCATION_ADDRESS_STATE': 'None',
        'LOCATION_ADDRESS_ZIP': 'None',
        'DEPARTMENT': 'None',
        'PROGRAM': 'None',
        'PARENT_ORG_NAME': 'Penn Medicine'}
        
    new_dict['NAME']=row.Name
    new_dict['SPECIALTY']=row.Specialty
    new_dict['PHONE']=row.Phone
    new_dict['PROGRAM']=row.Programs
    new_dict['LOCATION_NAME']=row.Location
    dict_list.append(new_dict)

# %%
num = 2
for row in beth.itertuples():
    print(f'{num} : {row.Name}')
    if ',' in row.Address_1:
        print(row.Address_1.split(',')[0])
    elif row.Address_1.split(' ')[0].isdigit()==True:
        print(row.Address_1)
    else:
        print(row.Address_2)
    print("")
    num+=1
# Out:
# 2 : Amtul Aala, MD
# 110 Francis Street
#
# 3 : Bassima J Abdallah, MD
# 199 Reedsdale Road
#
# 4 : Ayesha Abdeen, MD
# 148 Chestnut Street
#
# 5 : Dorina R. Abdulah, MD
# 464 Hillside Avenue
#
# 6 : Charbel M. Abou Rjeily, MD
# 275 Sandwich Street
#
# 7 : Martin J. Abrahamson, MD
# 110 Francis Street
#
# 8 : Matthew J. Abrams, MD
# 330 Brookline Avenue
#
# 9 : Jose A. Abrego, MD
# 1000 Broadway
#
# 10 : Mahmoud Abu Hazeem, MD
# 330 Brookline Avenue
#
# 11 : Lopamudra Acharya, MD
# 148 Chestnut Street
#
# 12 : Katayun S. Adhami, MD
# 330 Brookline Avenue
#
# 13 : Jamie L. Adler, MD
# 1 Deaconess Road
#
# 14 : Matthew P. Adlestein, MD
# 330 Brookline Avenue
#
# 15 : Souheil W. Adra, MD
# 199 Reedsdale Road
#
# 16 : Nezam H. Afdhal, MD
# 110 Francis Street
#
# 17 : Sangita J Agarwal, MD
# 570 Lafayette Road
#
# 18 : Sarika Aggarwal, MD
# 330 Brookline Avenue
#
# 19 : Nikhil Agrawal, MD
# 171 Pilgrim Road
#
# 20 : Muneeb Ahmed, MD
# 330 Brookline Avenue
#
# 21 : Andrew C. Ahn, MD
# ...

# %%
'1'.isdigit()
# Out:
# True

# %%
zipode = '123456'

# %%
zipode[0:5]
# Out:
# '12345'

# %%
def getState(zipcode): 

    if len(zipcode) < 5:
         print('Must pass a 5-digit zipcode.')
         return

    if len(zipcode)>5:
        zipcode = zipcode[0:5]

    zipcode = int(zipcode)

    if zipcode >= 35000 and zipcode <= 36999 :
        st = 'AL'
        state = 'Alabama'
        
    elif zipcode >= 99500 and zipcode <= 99999 :
        st = 'AK'
        state = 'Alaska'
        
    elif zipcode >= 85000 and zipcode <= 86999 :
        st = 'AZ'
        state = 'Arizona'
        
    elif zipcode >= 71600 and zipcode <= 72999 :
        st = 'AR'
        state = 'Arkansas'
        
    elif zipcode >= 90000 and zipcode <= 96699 :
        st = 'CA'
        state = 'California'
        
    elif zipcode >= 80000 and zipcode <= 81999 :
        st = 'CO'
        state = 'Colorado'
        
    elif zipcode >= 6000 and zipcode <= 6999 :
        st = 'CT'
        state = 'Connecticut'
        
    elif zipcode >= 19700 and zipcode <= 19999 :
        st = 'DE'
        state = 'Delaware'
        
    elif zipcode >= 32000 and zipcode <= 34999 :
        st = 'FL'
        state = 'Florida'
        
    elif zipcode >= 30000 and zipcode <= 31999 :
        st = 'GA'
        state = 'Georgia'
        
    elif zipcode >= 96700 and zipcode <= 96999 :
        st = 'HI'
        state = 'Hawaii'
        
    elif zipcode >= 83200 and zipcode <= 83999 :
        st = 'ID'
        state = 'Idaho'
        
    elif zipcode >= 60000 and zipcode <= 62999 :
        st = 'IL'
        state = 'Illinois'
        
    elif zipcode >= 46000 and zipcode <= 47999 :
        st = 'IN'
        state = 'Indiana'
        
    elif zipcode >= 50000 and zipcode <= 52999 :
        st = 'IA'
        state = 'Iowa'
        
    elif zipcode >= 66000 and zipcode <= 67999 :
        st = 'KS'
        state = 'Kansas'
        
    elif zipcode >= 40000 and zipcode <= 42999 :
        st = 'KY'
        state = 'Kentucky'
        
    elif zipcode >= 70000 and zipcode <= 71599 :
        st = 'LA'
        state = 'Louisiana'
        
    elif zipcode >= 3900 and zipcode <= 4999 :
        st = 'ME'
        state = 'Maine'
        
    elif zipcode >= 20600 and zipcode <= 21999 :
        st = 'MD'
        state = 'Maryland'
        
    elif zipcode >= 1000 and zipcode <= 2799 :
        st = 'MA'
        state = 'Massachusetts'
        
    elif zipcode >= 48000 and zipcode <= 49999 :
        st = 'MI'
        state = 'Michigan'
        
    elif zipcode >= 55000 and zipcode <= 56999 :
        st = 'MN'
        state = 'Minnesota'
        
    elif zipcode >= 38600 and zipcode <= 39999 :
        st = 'MS'
        state = 'Mississippi'
        
    elif zipcode >= 63000 and zipcode <= 65999 :
        st = 'MO'
        state = 'Missouri'
        
    elif zipcode >= 59000 and zipcode <= 59999 :
        st = 'MT'
        state = 'Montana'
        
    elif zipcode >= 27000 and zipcode <= 28999 :
        st = 'NC'
        state = 'North Carolina'
        
    elif zipcode >= 58000 and zipcode <= 58999 :
        st = 'ND'
        state = 'North Dakota'
        
    elif zipcode >= 68000 and zipcode <= 69999 :
        st = 'NE'
        state = 'Nebraska'
        
    elif zipcode >= 88900 and zipcode <= 89999 :
        st = 'NV'
        state = 'Nevada'
        
    elif zipcode >= 3000 and zipcode <= 3899 :
        st = 'NH'
        state = 'New Hampshire'
        
    elif zipcode >= 7000 and zipcode <= 8999 :
        st = 'NJ'
        state = 'New Jersey'
        
    elif zipcode >= 87000 and zipcode <= 88499 :
        st = 'NM'
        state = 'New Mexico'
        
    elif zipcode >= 10000 and zipcode <= 14999 :
        st = 'NY'
        state = 'New York'
        
    elif zipcode >= 43000 and zipcode <= 45999 :
        st = 'OH'
        state = 'Ohio'
        
    elif zipcode >= 73000 and zipcode <= 74999 :
        st = 'OK'
        state = 'Oklahoma'
        
    elif zipcode >= 97000 and zipcode <= 97999 :
        st = 'OR'
        state = 'Oregon'
        
    elif zipcode >= 15000 and zipcode <= 19699 :
        st = 'PA'
        state = 'Pennsylvania'
        
    elif zipcode >= 300 and zipcode <= 999 :
        st = 'PR'
        state = 'Puerto Rico'
        
    elif zipcode >= 2800 and zipcode <= 2999 :
        st = 'RI'
        state = 'Rhode Island'
        
    elif zipcode >= 29000 and zipcode <= 29999 :
        st = 'SC'
        state = 'South Carolina'
        
    elif zipcode >= 57000 and zipcode <= 57999 :
        st = 'SD'
        state = 'South Dakota'
        
    elif zipcode >= 37000 and zipcode <= 38599 :
        st = 'TN'
        state = 'Tennessee'
        
    elif  (zipcode >= 75000 and zipcode <= 79999) or (zipcode >= 88500 and zipcode <= 88599):
        st = 'TX'
        state = 'Texas'
        
    elif zipcode >= 84000 and zipcode <= 84999 :
        st = 'UT'
        state = 'Utah'
        
    elif zipcode >= 5000 and zipcode <= 5999 :
        st = 'VT'
        state = 'Vermont'
        
    elif zipcode >= 22000 and zipcode <= 24699 :
        st = 'VA'
        state = 'Virgina'
        
    elif zipcode >= 20000 and zipcode <= 20599 :
        st = 'DC'
        state = 'Washington DC'
        
    elif zipcode >= 98000 and zipcode <= 99499 :
        st = 'WA'
        state = 'Washington'
        
    elif zipcode >= 24700 and zipcode <= 26999 :
        st = 'WV'
        state = 'West Virginia'
        
    elif zipcode >= 53000 and zipcode <= 54999 :
        st = 'WI'
        state = 'Wisconsin'
        
    elif zipcode >= 82000 and zipcode <= 83199 :
        st = 'WY'
        state = 'Wyoming'
        
    else :
        st = 'none'
        state = 'none'
    

    return st

# %%
getState('1234')
# Out:
# Must pass a 5-digit zipcode.

# %%
for row in beth.itertuples():
    print(getState(row.Zipcode))
# Out:
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# NH
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# MA
# ...

# %%
dict_list
# Out:
# [{'NAME': 'Amtul Aala, MD',
#   'SPECIALTY': 'Nephrology',
#   'SECONDARY_SPECIALTY': 'None',
#   'PHONE': '+1-617-632-9700',
#   'FAX': '+1-617-632-9820',
#   'LOCATION_NAME': 'Beth Israel Deaconess Medical Center',
#   'LOCATION_STREET_ADDRESS': '110 Francis Street',
#   'LOCATION_ADDRESS': 'The Transplant Center, 110 Francis Street, 7th floor',
#   'LOCATION_ADDRESS_CITY': 'Boston',
#   'LOCATION_ADDRESS_STATE': 'None',
#   'LOCATION_ADDRESS_ZIP': '02215-5501',
#   'DEPARTMENT': 'None',
#   'PROGRAM': 'None',
#   'PARENT_ORG_NAME': 'Beth Israel Deaconess Medical Center'},
#  {'NAME': 'Bassima J Abdallah, MD',
#   'SPECIALTY': 'Internal Medicine',
#   'SECONDARY_SPECIALTY': 'None',
#   'PHONE': '+1-617-313-1377',
#   'FAX': '+1-617-754-8632',
#   'LOCATION_NAME': 'Beth Israel Deaconess Hospital - Milton Hospitalists',
#   'LOCATION_STREET_ADDRESS': '199 Reedsdale Road',
#   'LOCATION_ADDRESS': '199 Reedsdale Road',
#   'LOCATION_ADDRESS_CITY': 'Milton',
# ...

# %%
pd.DataFrame(dict_list).to_csv('Beth_Israel_Deaconess_Medical_Center_2020-01-02.csv', index=False)

# %%
penn.head()
# Out:
#    Unnamed: 0                                               Link  \
# 0           0  /providers/profile/nadine-al-naamani?fadf=penn...
# 1           1  /providers/profile/sara-attalla?fadf=pennmedicine
# 2           2  /providers/profile/valerianna-amorosa?fadf=pen...
# 3           3   /providers/profile/nicole-aqui?fadf=pennmedicine
# 4           4  /providers/profile/michael-acker?fadf=pennmedi...
#
#                         Name  \
# 0  Nadine Al-Naamani, MD, MS
# 1           Sara Attalla, MD
# 2  Valerianna K. Amorosa, MD
# 3            Nicole Aqui, MD
# 4       Michael A. Acker, MD
#
#                                                title  \
# 0  Assistant Professor of Medicine at the Hospita...
# 1           Assistant Professor of Clinical Medicine
# 2  Medical Director for Penn Home Infusion Therap...
# 3  Associate Professor of Clinical Pathology and ...
# 4  Chief, Division of Cardiovascular SurgeryDirec...
#
#                            Specialty  \
# ...

# %%
for row in penn.head().itertuples():
    print(row.Link)
# Out:
# /providers/profile/nadine-al-naamani?fadf=pennmedicine
# /providers/profile/sara-attalla?fadf=pennmedicine
# /providers/profile/valerianna-amorosa?fadf=pennmedicine
# /providers/profile/nicole-aqui?fadf=pennmedicine
# /providers/profile/michael-acker?fadf=pennmedicine

# %%
base_url = 'https://www.pennmedicine.org/'

# %%
for row in brig.head().itertuples():
    print (row.link)
# Out:
# https://physiciandirectory.brighamandwomens.org/details/13549/carrie-aaron-pulmonary_and_critical_care-boston?SetSize=48
# https://physiciandirectory.brighamandwomens.org/details/13924/ali-abbas-gastroenterology_hepatology_and_endoscopy-boston?SetSize=48
# https://physiciandirectory.brighamandwomens.org/details/1/reza-abdi-renal_kidney_disease-boston?SetSize=48
# https://physiciandirectory.brighamandwomens.org/details/127/elisa-abdulhayoglu-pediatric_medicine-boston-newton?SetSize=48
# https://physiciandirectory.brighamandwomens.org/details/537/raja-elie-abdulnour-pulmonary_and_critical_care-boston?SetSize=48

# %%
len(beth) + len(brig) + len(clev) + len(cinn) + len(henr) + len(mass) + len(mayo) + len(penn) + len(uthe) + len(utso)
# Out:
# 28689

# %%
28689*1.7
# Out:
# 48771.299999999996

# %%
ohsu
advocate
