# %%
import pandas as pd

# %%
path = "PhysicianProfessionalDataFile_20191012_062051504"
cols = [
        'ME',
        'RECORD_ID',
        'UPDATE_TYPE',
        'ADDRESS_TYPE',
        'MAILING_NAME',
        'LAST_NAME',
        'FIRST_NAME',
        'MIDDLE_NAME',
        'SUFFIX',
        'MAILING_LINE_1',
        'MAILING_LINE_2',
        'CITY',
        'STATE',
        'ZIP',
        'SECTOR',
        'CARRIER_ROUTE',
        'ADDRESS_UNDELIVERABLE_FLAG',
        'FIPS_COUNTY',
        'FIPS_STATE',
        'PRINTER_CONTROL_CODE',
        'PC_ZIP',
        'PC_SECTOR',
        'DELIVERY_POINT_CODE',
        'CHECK_DIGIT',
        'PRINTER_CONTROL_CODE_2',
        'REGION',
        'DIVISION',
        'GROUP',
        'TRACT',
        'SUFFIX_CENSUS',
        'BLOCK_GROUP',
        'MSA_POPULATION_SIZE',
        'MICRO_METRO_IND',
        'CBSA',
        'CBSA_DIV_IND',
        'MD_DO_CODE',
        'BIRTH_YEAR',
        'BIRTH_CITY',
        'BIRTH_STATE',
        'BIRTH_COUNTRY',
        'GENDER',
        'TELEPHONE_NUMBER',
        'PRESUMED_DEAD_FLAG',
        'FAX_NUMBER',
        'TOP_CD',
        'PE_CD',
        'PRIM_SPEC_CD',
        'SEC_SPEC_CD',
        'MPA_CD',
        'PRA_RECIPIENT',
        'PRA_EXP_DT',
        'GME_CONF_FLG',
        'FROM_DT',
        'TO_DT',
        'YEAR_IN_PROGRAM',
        'POST_GRADUATE_YEAR',
        'GME_SPEC_1',
        'GME_SPEC_2',
        'TRAINING_TYPE',
        'GME_INST_STATE',
        'GME_INST_ID',
        'MEDSCHOOL_STATE',
        'MEDSCHOOL_ID',
        'MEDSCHOOL_GRAD_YEAR',
        'NO_CONTACT_IND',
        'NO_WEB_FLAG',
        'PDRP_FLAG',
        'PDRP_START_DT',
        'POLO_MAILING_LINE_1',
        'POLO_MAILING_LINE_2',
        'POLO_CITY',
        'POLO_STATE',
        'POLO_ZIP',
        'POLO_SECTOR',
        'POLO_CARRIER_ROUTE',
        'MOST_RECENT_FORMER_LAST_NAME',
        'MOST_RECENT_FORMER_MIDDLE_NAME',
        'MOST_RECENT_FORMER_FIRST_NAME',
        'NEXT_MOST_RECENT_FORMER_LAST',
        'NEXT_MOST_RECENT_FORMER_MIDDLE',
        'NEXT_MOST_RECENT_FORMER_FIRST'
    ]
ppd = pd.read_csv(path, names=cols, sep='|', encoding='IBM437', index_col=False, dtype=object)
PPD = ppd[['ME',
        'MAILING_NAME',
        'LAST_NAME',
        'FIRST_NAME',
        'MIDDLE_NAME',
        'SUFFIX',
        'MAILING_LINE_1',
        'MAILING_LINE_2',
        'CITY',
        'STATE',
        'ZIP',
        'TELEPHONE_NUMBER',
        'POLO_MAILING_LINE_1',
        'POLO_MAILING_LINE_2',
        'POLO_CITY',
        'POLO_STATE',
        'POLO_ZIP',
        'MEDSCHOOL_GRAD_YEAR'
          ]]

# %%
PPD[PPD['MEDSCHOOL_GRAD_YEAR']=='2019']
# Out:
#                   ME            MAILING_NAME   LAST_NAME FIRST_NAME  \
# 2286     00102140486     ALEXANDER W BRAY MD        BRAY  ALEXANDER
# 2336     00102141024      DANIEL F DITORO MD      DITORO     DANIEL
# 2354     00102141229  JONATHAN R LOCKHART MD    LOCKHART   JONATHAN
# 2385     00102141539         SARA L STONE MD       STONE       SARA
# 2391     00102141598  ALEXANDER P NESMITH MD     NESMITH  ALEXANDER
# ...              ...                     ...         ...        ...
# 1164795  66106190039      CHLOE L BALANDA MD     BALANDA      CHLOE
# 1217075  75918190015  ALEXANDER TSIBULSKI MD   TSIBULSKI  ALEXANDER
# 1217076  75918190023    MICHAEL MALKOWSKI MD   MALKOWSKI    MICHAEL
# 1217490  77201190013      MOAZ ABDELREHIM MD  ABDELREHIM       MOAZ
# 1253985  91511190016   MOHAMED A ELBORAEY MD    ELBORAEY    MOHAMED
#
#          MIDDLE_NAME SUFFIX MAILING_LINE_1                 MAILING_LINE_2  \
# 2286         WENDELL    NaN            NaN                 5 WORTHDALE CT
# 2336         FRANCIS    NaN            NaN                 1700 12TH ST S
# 2354         RUSSELL    NaN            NaN              913 CLEARWOOD AVE
# 2385            LYNN    NaN            NaN                108 ELMWOOD AVE
# 2391          PEYTON    NaN            NaN                1800 ORLEANS ST
# ...              ...    ...            ...                            ...
# 1164795       LEEANN    NaN            NaN  3334 WEATHERFORD DR NW APT 3B
# 1217075          NaN    NaN            NaN               35442 ELMWOOD CT
# 1217076          NaN    NaN            NaN       164 STRATHMORE RD APT 12
# 1217490          NaN    NaN            NaN                  39 SHEPARD ST
# 1253985  AHMED KAMAL    NaN            NaN        4741 MARSH HAMMOCK DR W
#
#                  CITY STATE    ZIP TELEPHONE_NUMBER POLO_MAILING_LINE_1  \
# 2286       GREENSBORO    NC  27408              NaN                 NaN
# 2336       BIRMINGHAM    AL  35205              NaN                 NaN
# 2354        KINGSPORT    TN  37660              NaN                 NaN
# 2385         NARBERTH    PA  19072              NaN                 NaN
# 2391        BALTIMORE    MD  21287              NaN                 NaN
# ...               ...   ...    ...              ...                 ...
# 1164795        WALKER    MI  49544              NaN                 NaN
# 1217075   CLINTON TWP    MI  48035              NaN                 NaN
# 1217076      BRIGHTON    MA  02135              NaN                 NaN
# 1217490      BRIGHTON    MA  02135              NaN                 NaN
# 1253985  JACKSONVILLE    FL  32224              NaN                 NaN
#
#         POLO_MAILING_LINE_2     POLO_CITY POLO_STATE POLO_ZIP  \
# 2286                    NaN           NaN        NaN      NaN
# 2336                    NaN           NaN        NaN      NaN
# 2354                    NaN           NaN        NaN      NaN
# 2385         3400 SPRUCE ST  PHILADELPHIA         PA    19104
# 2391        1800 ORLEANS ST     BALTIMORE         MD    21287
# ...                     ...           ...        ...      ...
# 1164795                 NaN           NaN        NaN      NaN
# 1217075  44405 WOODWARD AVE       PONTIAC         MI    48341
# 1217076                 NaN           NaN        NaN      NaN
# 1217490                 NaN           NaN        NaN      NaN
# 1253985                 NaN           NaN        NaN      NaN
#
#         MEDSCHOOL_GRAD_YEAR
# 2286                   2019
# 2336                   2019
# 2354                   2019
# 2385                   2019
# 2391                   2019
# ...                     ...
# 1164795                2019
# 1217075                2019
# 1217076                2019
# 1217490                2019
# 1253985                2019
#
# [20171 rows x 18 columns]

# %%
PPD['MEDSCHOOL_GRAD_YEAR']
# Out:
# 0          2000
# 1          2001
# 2          2000
# 3          2000
# 4          2000
#            ...
# 1262293    1996
# 1262294    1996
# 1262295    1998
# 1262296    1996
# 1262297    1998
# Name: MEDSCHOOL_GRAD_YEAR, Length: 1262298, dtype: object
