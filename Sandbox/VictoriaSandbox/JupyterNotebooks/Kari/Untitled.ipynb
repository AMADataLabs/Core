# %%
import pandas as pd

# %%
# pd.read_csv('2019-11-01_Entity_Comm_AT.csv'
pd.read_csv('2019-11-01_Entity_Comm_AT.csv', delimiter = ",", index_col = None, header = 0, dtype = str, low_memory =False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-6c6eeee9c8eb> in <module>
#       1 # pd.read_csv('2019-11-01_Entity_Comm_AT.csv'
# ----> 2 pd.read_csv('2019-11-01_Entity_Comm_AT.csv', delimiter = ",", index_col = None, header = 0, dtype = str, low_memory =False)
#
# ...

# %%
pd.read_csv('2019-12-16_Entity_Key_ET.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            key_type_val key_type  entity_id approval_id active_ind  \
# 0           00106950067       ME    1335564           .          Y
# 1           00106950105       ME    1335603           .          Y
# 2           00106950130       ME    1335642           .          Y
# 3           00106950164       ME    1335681           .          Y
# 4           00106951021       ME    1335720           .          Y
# ...                 ...      ...        ...         ...        ...
# 14372307  BP10059153-TX      LIC   47489529           .          Y
# 14372308     1316509854      NPI   48071409           .          Y
# 14372309     1740846815      NPI   48241007           .          Y
# ...

# %%
reader = pd.read_csv('2019-11-01_Entity_Comm_AT.csv',chunksize=1000000,index_col = None, header = 0, dtype = str, low_memory =False)

# %%
for chunk in reader:
    print(chunk)
    pd.DataFrame(chunk)
    new_df = chunk[chunk['comm_cat'] == 'P']
    test.append(new_df)

# %%
reader.get_chunk(10000000).groupby(comm_cat)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-43-b51d084d0bbf> in <module>
# ----> 1 reader.get_chunk(10000000).groupby(comm_cat)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in get_chunk(self, size)
#    1186                 raise StopIteration
#    1187             size = min(size, self.nrows - self._currow)
# -> 1188         return self.read(nrows=size)
#    1189
#    1190
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
# ...

# %%
test.append(reader.get_chunk(2))
# Out:
#           entity_id comm_type comm_cat  seq_nbr   begin_dt   comm_id  \
# 14000002   28272747        HM        A        3  03JUL2012  15856187
# 14000003   13584736        OF        A        7  03JUL2012  15856194
#
#           approval_id     end_dt seasonal_add_ind  chg_rsn_category  ...  \
# 14000002     27014574  27AUG2012                N               NaN  ...
# 14000003     27014588  08JAN2013                N               NaN  ...
#
#           src_category src_cat_code search_city_cd state_cd    zip  plus4  \
# 14000002      SRC-ADDR          ACS       NEW YORK       NY  10028   4028
# 14000003      SRC-ADDR          ACS  FT MONTGOMERY       NY  10922    801
#
#           update_user_id              update_dtm opt_lock  current_ind
# 14000002          jagadm  27AUG2012:12:14:37.459        2            N
# 14000003          jagadm  08JAN2013:22:37:44.229        2            N
#
# [2 rows x 21 columns]

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: [entity_id, comm_type, comm_cat, seq_nbr, begin_dt, comm_id, approval_id, end_dt, seasonal_add_ind, chg_rsn_category, chg_rsn_cat_code, src_category, src_cat_code, search_city_cd, state_cd, zip, plus4, update_user_id, update_dtm, opt_lock, current_ind]
# Index: []
#
# [0 rows x 21 columns]

# %%
reader

# %%
chunk_list = []  # append each chunk df here 
ent_comm_cols = ['entity_id', 'comm_type', 'begin_dt', 'comm_id', 'end_dt', 'src_cat_code']    
# Each chunk is in df format
for chunk in reader:  
    # perform data filtering 
    chunk_filter = chunk[chunk['comm_cat'] == 'P']
    chunk_filter = chunk_filter[ent_comm_cols]
    # Once the data filtering is done, append the chunk to list
    chunk_list.append(chunk_filter)
    
# concat the list into dataframe 
df_concat = pd.concat(chunk_list)

# %%
df_concat
# Out:
#          entity_id comm_type comm_cat seq_nbr   begin_dt  comm_id approval_id  \
# 12527762  10801748        OF        P       1  22JUN1998  1803078         NaN
# 12532680  11683564        OF        P       1  01MAR1997  1795678         NaN
# 12542501  10625026        OF        P       1  01AUG1996  1803655         NaN
# 12549772   7247639        OF        P       1  02JAN1991  1800640         NaN
# 12554419  10802281        OF        P       1  31JUL1996  1793097         NaN
# ...            ...       ...      ...     ...        ...      ...         ...
# 38519617   2831929        OF        P       1  22JUN1998  1802284         NaN
# 38520715   2838689        OF        P       1  22JUN1998  1783306         NaN
# 40500831   9481182        OF        P       1  01AUG1996  1794559         NaN
# 40555834   6546666        OF        P       1  01MAR1997  1781752         NaN
# 40566170  12681704        OF        P       1  22JUN1998  1805483         NaN
#
# ...

# %%
len(chunk_list)
# Out:
# 31

# %%
df_concat.drop([df_concat['comm_id']==1803078])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-b48c2a942790> in <module>
# ----> 1 df_concat.drop([df_concat['comm_id']==1803078])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df_concat.drop(df_concat.loc[df_concat['comm_id']=='1803078'].index, inplace=True)

# %%
df_concat
# Out:
#          entity_id comm_type comm_cat seq_nbr   begin_dt  comm_id approval_id  \
# 12532680  11683564        OF        P       1  01MAR1997  1795678         NaN
# 12542501  10625026        OF        P       1  01AUG1996  1803655         NaN
# 12549772   7247639        OF        P       1  02JAN1991  1800640         NaN
# 12554419  10802281        OF        P       1  31JUL1996  1793097         NaN
# 12564472   6535889        OF        P       1  15DEC1995  1805168         NaN
# ...            ...       ...      ...     ...        ...      ...         ...
# 38519617   2831929        OF        P       1  22JUN1998  1802284         NaN
# 38520715   2838689        OF        P       1  22JUN1998  1783306         NaN
# 40500831   9481182        OF        P       1  01AUG1996  1794559         NaN
# 40555834   6546666        OF        P       1  01MAR1997  1781752         NaN
# 40566170  12681704        OF        P       1  22JUN1998  1805483         NaN
#
# ...
