# %%
import pandas as pd
import useful_functions as use

# %%
ppd = use.get_ppd()
# Out:
# INFO:useful_functions:PPD file from Dec 11 2021
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (13,14,20,21,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
jon = ppd[(ppd.FIRST_NAME=='JON')&(ppd.LAST_NAME=='DYKENS')]

# %%
for col in ppd.columns:
    print(f'{col}: {jon[col]}')
# Out:
# ME: 448498    02803040373
# Name: ME, dtype: object
# RECORD_ID: 448498    A
# Name: RECORD_ID, dtype: object
# UPDATE_TYPE: 448498    1
# Name: UPDATE_TYPE, dtype: int64
# ADDRESS_TYPE: 448498    1.0
# Name: ADDRESS_TYPE, dtype: float64
# MAILING_NAME: 448498    JON A DYKENS MD
# Name: MAILING_NAME, dtype: object
# LAST_NAME: 448498    DYKENS
# Name: LAST_NAME, dtype: object
# FIRST_NAME: 448498    JON
# Name: FIRST_NAME, dtype: object
# MIDDLE_NAME: 448498    ANDREW
# Name: MIDDLE_NAME, dtype: object
# SUFFIX: 448498   NaN
# Name: SUFFIX, dtype: float64
# MAILING_LINE_1: 448498    UNIVERSITY OF ILLINOIS HOSPITA
# Name: MAILING_LINE_1, dtype: object
# MAILING_LINE_2: 448498    820 S WOOD ST
# Name: MAILING_LINE_2, dtype: object
# CITY: 448498    CHICAGO
# Name: CITY, dtype: object
# STATE: 448498    IL
# Name: STATE, dtype: object
# ZIP: 448498    60612
# Name: ZIP, dtype: object
# SECTOR: 448498    4325
# Name: SECTOR, dtype: object
# CARRIER_ROUTE: 448498    C099
# ...

# %%
 'MAILING_LINE_1',
       'MAILING_LINE_2', 'CITY', 'STATE', 'ZIP', 'MD_DO_CODE', 'BIRTH_YEAR',
       'BIRTH_CITY', 'BIRTH_STATE', 'BIRTH_COUNTRY', 'TELEPHONE_NUMBER', 'PRESUMED_DEAD_FLAG', 'FAX_NUMBER', 'TOP_CD',
       'PE_CD', 'PRIM_SPEC_CD', 'SEC_SPEC_CD', 'MPA_CD', 'GME_INST_STATE', 'GME_INST_ID', 'MEDSCHOOL_STATE', 'MEDSCHOOL_ID',
       'MEDSCHOOL_GRAD_YEAR', 'POLO_MAILING_LINE_1', 'POLO_MAILING_LINE_2',
       'POLO_CITY', 'POLO_STATE', 'POLO_ZIP'
