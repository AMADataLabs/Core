# %%
import pandas as pd

# %%
npi = pd.read_csv('../../Data/DataGov.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
new_file[new_file.NPI.isin(npi.NPI)==False].drop_duplicates('NPI')
# Out:
#            prvdr_id    frst_nm   mid_nm         lst_nm  \
# 17         42100430     CARMEN        M        JIMENEZ
# 19         42100463    DANACIA        M          JONES
# 39         42100760       JOHN      NaN         CHIARO
# 40         42100786   JENNIFER        A  CENTORE LOBER
# 65         42101180     WARREN        J        SANDLER
# ...             ...        ...      ...            ...
# 3091803  9931539897      JENNA        M       WILLIAMS
# 3091804  9931539921     LAUREN  ANNETTE        JOHNSON
# 3091808  9931539939  CASSANDRA    MARIE         RIVERS
# 3091809  9931539954   VINNETTE        A         FISHER
# 3091811  9931539970       ERIC      NaN         PETERS
#
#                            adrs_id                  adr_ln_1    adr_ln_2  \
# 17       CO805251542FO1800XSTXX300            1800 STOVER ST         NaN
# 19       OR970801494GR2850XRDXX500  2850 SE POWELL VALLEY RD         NaN
# 39       OH448705390SA2500XRDXX400           2500 W STRUB RD         NaN
# ...

# %%
new_file.columns = [c.replace(' ','') for c in new_file.columns.values]

# %%
len(new_file)
# Out:
# 3091812

# %%
new_file.drop_duplicates('NPI')
# Out:
#            prvdr_id    frst_nm   mid_nm     lst_nm                    adrs_id  \
# 0          42100026      PETER        K       FUNG  CA906404314MO101XXBLVD403
# 2          42100042      BIJAN      NaN   HAGHIGHI  CA926634162NE1XXXXDRXX300
# 3          42100117      DAVID      NaN    GRIFFIN  SC296075253GR104XXDRXX303
# 5          42100133    JEFFREY        M      SPEAR  AR728012724RU1808XSTXX400
# 6          42100190       JOHN        D  VERBRUGGE  MI495032560GR100XXNEXX300
# ...             ...        ...      ...        ...                        ...
# 3091803  9931539897      JENNA        M   WILLIAMS  GA317926676TH100XXDRXX301
# 3091804  9931539921     LAUREN  ANNETTE    JOHNSON  MN553372537BU14101DRXX300
# 3091808  9931539939  CASSANDRA    MARIE     RIVERS  MA010894620WE928XXSTXX300
# 3091809  9931539954   VINNETTE        A     FISHER  NY105301811HA359XXAVEX400
# 3091811  9931539970       ERIC      NaN     PETERS  NY147601100OL1XXXXDRXX401
#
# ...

# %%
new_file.columns
# Out:
# Index(['prvdr_id', 'frst_nm', 'mid_nm', 'lst_nm', 'adrs_id', 'adr_ln_1',
#        'adr_ln_2', 'cty', 'st', 'zip', 'org_pac_id', 'phn_numbr', 'NPI'],
#       dtype='object')
