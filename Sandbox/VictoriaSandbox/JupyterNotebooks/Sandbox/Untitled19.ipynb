# %%
import pandas as pd

# %%
pd.read_csv('../../Data/License/MD Active Type Fixed.txt', sep='\t')
# Out:
#             Last_Name First_Name Middle_Name Suffix  \
# 0       Aachen-Winans      James       Meryl    NaN
# 1               Aalto    Meaghan    Margaret    NaN
# 2               Aaron     Ashley   Elizabeth    NaN
# 3               Aaron      Ronee         NaN    NaN
# 4              Aarons       Alan    Lawrence    NaN
# ...               ...        ...         ...    ...
# 44382            Zwil  Alexander     Stephan    NaN
# 44383           Zwirn      Ilene         NaN    NaN
# 44384  Zwischenberger   Brittany        Anne    NaN
# 44385       Zychowski      Diana        Lynn    NaN
# 44386        Zygowiec   Jonathan       Peter    NaN
#
#                        License_Type License_Number LicenseIssueDate  \
# 0                                MD     2007-01286       07/27/2007
# 1                                MD     2018-02560       10/03/2018
# 2                                MD     2021-02107       06/18/2021
# ...

# %%
pd.read_csv('../../Data/License/MD Active.txt', sep='\t')
# Out:
#             Last_Name First_Name Middle_Name Suffix License_Type  \
# 0       Aachen-Winans      James       Meryl    NaN           MD
# 1               Aalto    Meaghan    Margaret    NaN           MD
# 2               Aaron     Ashley   Elizabeth    NaN           MD
# 3               Aaron      Ronee         NaN    NaN           DO
# 4              Aarons       Alan    Lawrence    NaN           MD
# ...               ...        ...         ...    ...          ...
# 44382            Zwil  Alexander     Stephan    NaN           MD
# 44383           Zwirn      Ilene         NaN    NaN           MD
# 44384  Zwischenberger   Brittany        Anne    NaN           MD
# 44385       Zychowski      Diana        Lynn    NaN           MD
# 44386        Zygowiec   Jonathan       Peter    NaN           DO
#
#       License_Number LicenseIssueDate  LicenseExpDate  Status  \
# 0         2007-01286       07/27/2007             NaN  Active
# ...
