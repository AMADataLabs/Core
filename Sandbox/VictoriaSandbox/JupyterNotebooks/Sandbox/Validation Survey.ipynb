# %%
import pandas as pd

# %%
august_correct = pd.read_excel('../../Data/ValidationSurvey/VALIDATIONS_RETURN_090121.xlsx', sheet_name='Correct')

# %%
august_incorrect = pd.read_excel('../../Data/ValidationSurvey/VALIDATIONS_RETURN_090121.xlsx', sheet_name='Incorrect')

# %%
september_correct = pd.read_excel('../../Data/ValidationSurvey/VALIDATIONS_RETURN_092921.xlsx', sheet_name='ValidatedCorrect')

# %%
september_incorrect = pd.read_excel('../../Data/ValidationSurvey/VALIDATIONS_RETURN_092921.xlsx', sheet_name='ValidatedIncorrect')

# %%
pd.concat([august_correct, august_incorrect]).groupby('CORRECT_PHONE').count()
# Out:
#                SAMPLE_ID  ROW_ID  STUDY_CD  ME_NO  FNAME  MNAME  LNAME  \
# CORRECT_PHONE
# N                    403     403       403    403    403    321    403
# Y                    829     829       829    829    829    687    829
#
#                SUFFIX  DEGREE  LABLE_NAME  ...  CAPTURED_ADD1  CAPTURED_ADD2  \
# CORRECT_PHONE                              ...
# N                  11       0           0  ...              1             38
# Y                  29       0           0  ...              8            116
#
#                CAPTURED_CITY  CAPTURED_STATE  CAPTURED_ZIP  CAPTURED_ZIPEXT  \
# CORRECT_PHONE
# N                         38              38            38                0
# Y                        116             116           116                0
#
#                LASTCALL  ADCID  SECONDATTEMPT  RESULT_OF_CALL
# CORRECT_PHONE
# N                   403    403              0             403
# Y                   829    829              0             829
#
# ...

# %%
pd.concat([september_correct, september_incorrect]).groupby('CORRECT_PHONE').count()
# Out:
#                SAMPLE_ID  ROW_ID  STUDY_CD  ME_NO  FNAME  MNAME  LNAME  \
# CORRECT_PHONE
# N                    420     420       420    420    420    347    420
# Y                    796     796       796    796    796    665    796
#
#                SUFFIX  DEGREE  LABLE_NAME  ...  CAPTURED_ADD1  CAPTURED_ADD2  \
# CORRECT_PHONE                              ...
# N                  11       0           0  ...              0             45
# Y                  26       0           0  ...              9            146
#
#                CAPTURED_CITY  CAPTURED_STATE  CAPTURED_ZIP  CAPTURED_ZIPEXT  \
# CORRECT_PHONE
# N                         45              45            45                0
# Y                        146             146           146                0
#
#                LASTCALL  ADCID  SECONDATTEMPT  RESULT_OF_CALL
# CORRECT_PHONE
# N                   420    420              0             420
# Y                   796    796              0             796
#
# ...

# %%
august_incorrect[['CORRECT_PHONE','REASON_PHONE_INCORRECT','REASON_PHONE_OTHER','CAPTURED_NUMBER','RESULT_OF_CALL']]
# Out:
#     CORRECT_PHONE  REASON_PHONE_INCORRECT  REASON_PHONE_OTHER  \
# 0               N                     1.0                 NaN
# 1               N                     3.0                 NaN
# 2               N                     1.0                 NaN
# 3             NaN                     NaN                 NaN
# 4               N                     1.0                 NaN
# ..            ...                     ...                 ...
# 667             N                     1.0                 NaN
# 668           NaN                     NaN                 NaN
# 669             N                     1.0                 NaN
# 670             N                     1.0                 NaN
# 671           NaN                     NaN                 NaN
#
#      CAPTURED_NUMBER RESULT_OF_CALL
# 0                NaN       Complete
# 1                NaN       Complete
# 2       9.155912e+09       Complete
# 3                NaN     Disconnect
# ...
