# %%
import pandas as pd
wslive_file_location = "../../Data/Scorecard/p-WSLive-Results-2020710.xlsm"

# %%
wslive_table = pd.read_excel(wslive_file_location, sheet_name='Summary Percentage', header=3)
values = list(wslive_table[wslive_table['POLO Address Status'] == 'Confirmed'].iloc[:, -3])
print(values)
values.remove(1)

col_list = ['polo_correct',
                'employment_correct',
                'telephone_correct',
                'telephone_2_correct',
                'fax_correct']

wslive_df = pd.DataFrame({'1':col_list, '2':values})
# Out:
# [0.7302564102564103, 0.7141903171953256, 0.4580191050779286, 0.6033112582781457, 1, 0.7848080133555927]

# %%
wslive_df
# Out:
#                      1         2
# 0         polo_correct  0.730256
# 1   employment_correct  0.714190
# 2    telephone_correct  0.458019
# 3  telephone_2_correct  0.603311
# 4          fax_correct  0.784808

# %%
pd.read_excel(wslive_file_location, sheet_name='Summary Percentage', header=3)
# Out:
#    POLO Address Status    Jul-17    Aug-17   Sep-17    Oct-17    Nov-17  \
# 0            Confirmed  0.878686  0.876518  0.84986  0.878716  0.881472
# 1              Updated  0.121314  0.123482  0.15014  0.121284  0.118528
# 2          Grand Total         1         1        1         1         1
# 3                  NaN       NaN       NaN      NaN       NaN       NaN
# 4                  NaN       NaN       NaN      NaN       NaN       NaN
# ..                 ...       ...       ...      ...       ...       ...
# 58       Confirmed (1)       NaN       NaN      NaN       NaN       NaN
# 59         Updated (2)       NaN       NaN      NaN       NaN       NaN
# 60        Inconclusive       NaN       NaN      NaN       NaN       NaN
# 61           Known Bad       NaN       NaN      NaN       NaN       NaN
# 62         Grand Total       NaN       NaN      NaN       NaN       NaN
#
#       Dec-17 2018-01-18 00:00:00     Feb-18     Mar-18  ...  \
# ...

# %%
wslive_table[wslive_table['POLO Address Status'] == 'Confirmed']
# Out:
#    POLO Address Status    Jul-17    Aug-17    Sep-17    Oct-17    Nov-17  \
# 0            Confirmed  0.878686  0.876518   0.84986  0.878716  0.881472
# 6            Confirmed  0.944557  0.945494  0.899163  0.926754  0.940736
# 12           Confirmed  0.753124  0.825793  0.176237   0.33442  0.396265
# 20           Confirmed  0.809239  0.825901  0.761334  0.793062  0.881983
# 26           Confirmed  0.977418   0.97151  0.971442  0.975505  0.974215
# 32           Confirmed  0.878469  0.879617  0.795885  0.883455  0.902139
#
#       Dec-17 2018-01-18 00:00:00    Feb-18    Mar-18  ... 2019-11-18 00:00:00  \
# 0   0.875895            0.868774  0.883962  0.866184  ...            0.916235
# 6   0.942896            0.891008  0.887824  0.722222  ...            0.688216
# 12  0.472738            0.552095  0.558476  0.542585  ...            0.473553
# 20  0.824226            0.682603  0.692615     0.722  ...            0.619452
# ...
