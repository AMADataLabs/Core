# %%
import pandas as pd
import useful_functions as use
import random

# %%
gov = pd.read_csv(use.get_newest('../../Data/DataGov','All_Data'))
ppd = use.get_ppd()
# Out:
# C:/Users/vigrose/Data/PPD\ppd_data_20210612.csv
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (13,14,20,21,42,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
gov = gov[gov.phn_numbr!='None']

# %%
no_dupes = gov.drop_duplicates('ME',keep=False)

# %%
dupes = gov[gov.ME.isin(no_dupes.ME)==False]

# %%
dupes = dupes.sort_values('ME')

# %%
dupes['TELEPHONE_NUMBER'] = [str(x).replace('.0','')[:10] for x in dupes.phn_numbr]

# %%
OKAY = dupes.drop_duplicates(['ME','TELEPHONE_NUMBER','adrs_id'])

# %%
no_dupes_OKAY = OKAY.drop_duplicates('ME',keep=False)

# %%
OKAY_dupes = OKAY[OKAY.ME.isin(no_dupes_OKAY.ME)==False]

# %%
OKAY_dupes
# Out:
#           frst_nm mid_nm           lst_nm                    adrs_id  \
# 570341   NADHIWAN   None  SAKARIN-MAISIAK  AZ853755282SU14502BLVD400
# 570342   NADHIWAN   None  SAKARIN-MAISIAK  AZ853513004SU10401BLVD400
# 570340   NADHIWAN   None  SAKARIN-MAISIAK  AZ850062612PH1111XRDXX400
# 1920646     RAJIV      B             GALA  LA701212429NE1514XHWYX300
# 1173707     RAJIV      B             GALA  LA701156969NE2820XAVEX300
# ...           ...    ...              ...                        ...
# 562769     GEORGE      N          MWANDIA  OH452552439CI7500XRDXX300
# 2790987    GEORGE      N          MWANDIA  OH447082614CA1320XNWXX400
# 562771     GEORGE      N          MWANDIA  OH452552439CI7500XRDXX300
# 562773     GEORGE      N          MWANDIA  OH454092939DA30XXXSTXX404
# 2790988    GEORGE      N          MWANDIA  OH452111103CI3300XBLVD400
#
#                          adr_ln_1    adr_ln_2          cty  st        zip  \
# ...

# %%
mes = random.sample(list(this_dupes.ME.unique()),17000)

# %%
MAYBE = this_dupes[this_dupes.ME.isin(mes)].drop_duplicates('TELEPHONE_NUMBER')

# %%
this_dict = {}
adds = []
phones = []
for row in OKAY_dupes.itertuples():
    if row.ME in this_dict.keys():
        if row.adrs_id in this_dict[row.ME]:
            REPEATED_ADDRESS == True
        else:
            this_dict[row.ME].append(row.adrs_id)
            REPEATED_ADDRESS = False
        if row.TELEPHONE_NUMBER in this_dict[row.ME]:
            REPEATED_PHONE == True
        else:
            this_dict[row.ME].append(row.TELEPHONE_NUMBER)
            REPEATED_PHONE = False
    else:
        this_dict[row.ME] = [row.adrs_id,row.TELEPHONE_NUMBER]

# %%
unique_add = OKAY_dupes.drop_duplicates(['ME','adrs_id'], keep=False)

# %%
unique_phone = OKAY_dupes.drop_duplicates(['ME','TELEPHONE_NUMBER'], keep=False)

# %%
just_this = unique_phone.drop_duplicates(['ME','adrs_id'], keep=False)

# %%
no_dupes_this = just_this.drop_duplicates('ME',keep=False)
this_dupes = just_this[just_this.ME.isin(no_dupes_this.ME)==False]

# %%
no_dupes_this
# Out:
#              frst_nm mid_nm               lst_nm                    adrs_id  \
# 1346421      REBECCA      M                 SUGG  AL366172300MO2451XDRXX401
# 1168446        DAVID      C                PRICE  NC287394137HE805XXWXXX400
# 2584178       DONALD      E            YARBROUGH  OR973303737CO3600XDRXX400
# 2100012      SANDEEP      D                 SULE  TX752512272DA12221DRXX301
# 2293989    CATHERINE      A              SKINNER  AL354763270NO1325XNXXX401
# ...              ...    ...                  ...                        ...
# 384703      SLOBODAN   None               KALABA  UT846315137FI700XX99XX401
# 303310        RENATA   None      SELAK STANKOVIC  CA904042139SA2020XBLVD404
# 649536        MILICA   None  BOGDANOVIC STARCEVC  FL333162510FO1600XBLDG600
# 1639182         RAME   DEME            IBERDEMAJ  CA936375693MA1000XAVEX400
# 1423740  JAYESHKUMAR      A                PATEL  TX770301501HO6431XSTXX304
#
# ...

# %%
no_dupes_MAYBE = MAYBE.drop_duplicates('ME',keep=False)
dupes_MAYBE = MAYBE[MAYBE.ME.isin(no_dupes_MAYBE.ME)==False]
dupes_MAYBE
# Out:
#          frst_nm mid_nm       lst_nm                    adrs_id  \
# 1920646    RAJIV      B         GALA  LA701212429NE1514XHWYX300
# 1173707    RAJIV      B         GALA  LA701156969NE2820XAVEX300
# 1723381    BYRON   None       COLLEY  MS392164606JA969XXDRXX300
# 1723382    BYRON   None       COLLEY  MS392164634JA970XXDRXX305
# 451110   MELINDA      B         HART  AL350580689CU1890X300X500
# ...          ...    ...          ...                        ...
# 729857    OLGICA   None  LABAN GRANT  NY125241883FI21XXXSTXX402
# 718093    MARIJA   None     PETROVIC  MI498541234MA125XXSTXX400
# 718092    MARIJA   None     PETROVIC  MI497839286SA3865XTRLX400
# 721217     CIRIL      J        GODEC  NY112235940BR260XXXXXX300
# 721216     CIRIL      J        GODEC  NY112192916BR4802XAVEX300
#
#                     adr_ln_1   adr_ln_2                 cty  st        zip  \
# 1920646   1514 JEFFERSON HWY       None         NEW ORLEANS  LA  701212429
# ...

# %%
dupes_MAYBE.columns
# Out:
# Index(['frst_nm', 'mid_nm', 'lst_nm', 'adrs_id', 'adr_ln_1', 'adr_ln_2', 'cty',
#        'st', 'zip', 'org_pac_id', 'phn_numbr', 'NPI', 'ME',
#        'TELEPHONE_NUMBER'],
#       dtype='object')

# %%
COLS = {'adr_ln_1':'POLO_MAILING_LINE_2', 'adr_ln_2':'POLO_MAILING_LINE_1', 'cty':'POLO_CITY',
       'st':'POLO_STATE', 'description':'DESCRIPTION'}

# %%
dupes_MAYBE['ME'] = use.fix_me(dupes_MAYBE.ME)
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mwah = pd.merge(ppd[['ME','FIRST_NAME','MIDDLE_NAME','LAST_NAME','SUFFIX','PRIM_SPEC_CD','PE_CD','FAX_NUMBER','TOP_CD']], dupes_MAYBE, on='ME')
pe_cd = pd.read_excel('../../Data/AMAIA/PRESENT_EMPLOYMENT_CODE_KEY.xlsx')
mwah = pd.merge(mwah, pe_cd, left_on='PE_CD', right_on='present_emp_cd')

# %%
pe_cd = pd.read_excel('../../Data/AMAIA/PRESENT_EMPLOYMENT_CODE_KEY.xlsx')
mwah = pd.merge(mwah, pe_cd, left_on='PE_CD', right_on='present_emp_cd')

# %%
mwah = pd.merge(mwah, pe_cd, left_on='PE_CD', right_on='present_emp_cd')

# %%
mwah = mwah.rename(columns = COLS)

# %%
bolo = pd.read_excel(use.get_newest('../../Data/PhoneAppend/','Bing_BOLO'))

# %%
mwah['POLO_ZIP'] = [use.fix_zipcode(x) for x in mwah.zip]

# %%
mwah.to_excel('../../Data/DataGov/DataGov_Multiples.xlsx', index=False)

# %%
mwah[:18000]
# Out:
#                 ME FIRST_NAME MIDDLE_NAME LAST_NAME  SUFFIX PRIM_SPEC_CD  \
# 0      00102000226      WAYNE           C  ANDERSON     NaN           FM
# 1      00102000226      WAYNE           C  ANDERSON     NaN           FM
# 2      00102000251     ROBERT      PEARCE   BOLLING     NaN           PS
# 3      00102000251     ROBERT      PEARCE   BOLLING     NaN           PS
# 4      00102010116      MERLE       LINDY      WADE     NaN            U
# ...            ...        ...         ...       ...     ...          ...
# 17995  03501000611     YVONNE    MARGARET   SAENGER     NaN           HO
# 17996  03501000611     YVONNE    MARGARET   SAENGER     NaN           HO
# 17997  03501850437     ROBERT        JOHN    DOWNEY     NaN           TS
# 17998  03501850437     ROBERT        JOHN    DOWNEY     NaN           TS
# 17999  03503030526       SETH         NaN    MENSAH     NaN           IM
#
#        PE_CD    FAX_NUMBER frst_nm mid_nm  ...    POLO_CITY POLO_STATE  \
# ...

# %%
len(mwah)
# Out:
# 19539

# %%
mwah.groupby('TOP_CD').count()
# Out:
#            ME  FIRST_NAME  MIDDLE_NAME  LAST_NAME  SUFFIX  PRIM_SPEC_CD  \
# TOP_CD
# 12        247         247          198        247       2           247
# 20      18329       18329        15306      18329     594         18329
# 30         78          78           72         78       4            78
# 40        136         136          114        136       2           136
# 50         48          48           35         48       0            48
# 62         33          33           29         33       0            33
# 71        223         223          204        223      12           223
# 72        177         177          157        177      11           177
# 74         24          24           20         24       0            24
# 75         34          34           34         34       0            34
# 100       898         898          634        898      14           898
#
#         PE_CD  FAX_NUMBER  frst_nm  mid_nm  ...  adrs_id  adr_ln_1  adr_ln_2  \
# ...

# %%
mwah = mwah[mwah.TOP_CD==20]

# %%
list(bolo.columns)
# Out:
# ['ME',
#  'FIRST_NAME',
#  'MIDDLE_NAME',
#  'LAST_NAME',
#  'SUFFIX',
#  'POLO_MAILING_LINE_1',
#  'POLO_MAILING_LINE_2',
#  'POLO_CITY',
#  'POLO_STATE',
#  'POLO_ZIP',
#  'TELEPHONE_NUMBER',
#  'PRIM_SPEC_CD',
#  'DESCRIPTION',
#  'PE_CD',
#  'FAX_NUMBER']
