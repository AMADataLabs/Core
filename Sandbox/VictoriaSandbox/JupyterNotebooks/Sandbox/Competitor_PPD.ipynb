# %%
import pandas as pd

# %%
Accuracy Metric	Formula		
Phone	Confirmed / (Confirmed + Updated + Known Bad + Inconclusive + No Contact)		
Address	Confirmed / (Confirmed + Updated)		
Fax	Confirmed / (Confirmed + Updated)		
PE Status	Confirmed / (Confirmed + Updated)		
Primary Specialty	Confirmed / (Confirmed + Updated)

# %%
all_thing = pd.read_csv('../../Data/Humach/wslive_with_results_2020-06-05_to_2020-07-03.csv')

# %%
all_thing = wslive_date_df.drop_duplicates()

# %%
#29911
#28355
len(sy)
# Out:
# 2014

# %%
iq = all_thing[all_thing.SOURCE=='Q']
sy = all_thing[all_thing.SOURCE=='S']

# %%
get_accuracy(iq)
# Out:
# {'Phone': 0.37939958592132506,
#  'Phone_2': 0.37939958592132506,
#  'Address': 0.7619834710743801,
#  'Fax': 0.5349862258953169,
#  'PE': 0.46225895316804405,
#  'Spec': 1.0}

# %%
iq.groupby(['phone_status','addr_status']).count()
# Out:
#                            PHYSICIAN_ME_NUMBER  PHYSICIAN_FIRST_NAME  \
# phone_status addr_status
# Confirmed    Confirmed                    1188                  1188
#              Updated                       278                   278
# Inconclusive Inconclusive                  410                   410
# Known Bad    Known Bad                    1639                  1639
# Updated      Confirmed                     195                   195
#              Updated                       154                   154
#
#                            PHYSICIAN_MIDDLE_NAME  PHYSICIAN_LAST_NAME  SUFFIX  \
# phone_status addr_status
# Confirmed    Confirmed                       951                 1188      31
#              Updated                         221                  278      12
# Inconclusive Inconclusive                    322                  410      13
# Known Bad    Known Bad                      1313                 1639      54
# Updated      Confirmed                       147                  195       3
#              Updated                         111                  154       2
#
#                            DEGREE  OFFICE_ADDRESS_LINE_1  \
# phone_status addr_status
# Confirmed    Confirmed          0                    489
#              Updated            0                    144
# Inconclusive Inconclusive       0                     70
# Known Bad    Known Bad          0                    329
# Updated      Confirmed          0                     29
#              Updated            0                     44
#
#                            OFFICE_ADDRESS_LINE_2  OFFICE_ADDRESS_CITY  \
# phone_status addr_status
# Confirmed    Confirmed                      1188                 1188
#              Updated                         278                  278
# Inconclusive Inconclusive                    410                  410
# Known Bad    Known Bad                      1639                 1639
# Updated      Confirmed                       195                  195
#              Updated                         154                  154
#
#                            OFFICE_ADDRESS_STATE  ...  COMMENTS  SOURCE  \
# phone_status addr_status                         ...
# Confirmed    Confirmed                     1188  ...      1188    1188
#              Updated                        278  ...       278     278
# Inconclusive Inconclusive                   410  ...       410     410
# Known Bad    Known Bad                     1639  ...      1639    1639
# Updated      Confirmed                      195  ...       195     195
#              Updated                        154  ...       154     154
#
#                            SOURCE_DATE  SAMPLE_ID  ROW_ID  WSLIVE_SOURCE  \
# phone_status addr_status
# Confirmed    Confirmed            1188       1188    1188           1188
#              Updated               278        278     278            278
# Inconclusive Inconclusive          410        410     410            410
# Known Bad    Known Bad            1639       1639    1639           1639
# Updated      Confirmed             195        195     195            195
#              Updated               154        154     154            154
#
#                            new_metric  pe_status  fax_status  spec_status
# phone_status addr_status
# Confirmed    Confirmed           1188       1188        1188         1188
#              Updated              278        278         278          278
# Inconclusive Inconclusive         410        410         410          410
# Known Bad    Known Bad           1639       1639        1639         1639
# Updated      Confirmed            195        195         195          195
#              Updated              154        154         154          154
#
# [6 rows x 30 columns]

# %%
len(iq.addr_status=='Confirmed')
# Out:
# 3864

# %%
def get_accuracy(table):
    a = {}
    a['Phone'] = len(table[table.phone_status=='Confirmed'])/len(table)
    a['Phone_2'] = len(table[table.phone_status=='Confirmed'])/len(table[table.phone_status!='No Contact'])
    a['Address'] = len(table[table.addr_status=='Confirmed'])/len(table[(table.addr_status=='Confirmed')|(table.addr_status=='Updated')])
    a['Fax'] = len(table[table.fax_status=='Confirmed'])/len(table[(table.fax_status=='Confirmed')|(table.fax_status=='Updated')])
    a['PE'] = len(table[table.pe_status=='Confirmed'])/len(table[(table.pe_status=='Confirmed')|(table.pe_status=='Updated')])
    a['Spec'] = len(table[table.spec_status=='Confirmed'])/len(table[(table.spec_status=='Confirmed')|(table.spec_status=='Updated')])
    return a

# %% [markdown]
# all_thing.drop_duplicates()

# %%
other_1 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_040921_OTHER.xls')
other_2 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_040221_OTHER.xls')
other_7 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_040121_OTHER.xls')
other_3 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_032621_OTHER.xls')
other_4 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_031921_OTHER.xls')
other_5 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_031221_OTHER.xls')
other_6 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_030521_OTHER.xls')
other = pd.concat([other_1, other_2,other_3,other_4,other_5,other_6, other_7])
other['WSLIVE_SOURCE'] = 'OTHERS'
updated_1 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_040921_UPDATED.xls')
updated_2 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_040121_UPDATED.xls')
updated_8 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_040221_UPDATED.xls')
updated_3 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_032621_UPDATED.xls')
updated_4 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_031921_UPDATED.xls')
updated_5 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_031221_UPDATED.xls')
updated_6 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_030521_UPDATED.xls')
updated_7 = pd.read_excel('../../Data/Humach/AMA_PHYSICIAN_NEW_SURVEY_040121-040221_UPDATED.xls')
updated = pd.concat([updated_1, updated_2,updated_3,updated_4,updated_5,updated_6, updated_7, updated_8])
updated['WSLIVE_SOURCE'] = 'UPDATED'
wslive_date_df = pd.concat([updated, other])
# Out:
# WARNING *** file size (516032) not 512 + multiple of sector size (512)
# WARNING *** file size (516032) not 512 + multiple of sector size (512)
# WARNING *** file size (1572800) not 512 + multiple of sector size (512)
# WARNING *** file size (573376) not 512 + multiple of sector size (512)
# WARNING *** file size (753600) not 512 + multiple of sector size (512)
# WARNING *** file size (581568) not 512 + multiple of sector size (512)
# WARNING *** file size (155584) not 512 + multiple of sector size (512)
# WARNING *** file size (1245120) not 512 + multiple of sector size (512)
# WARNING *** file size (1073088) not 512 + multiple of sector size (512)

# %%
wslive_date_df.columns = [c.replace(' ','_').replace('/','_') for c in wslive_date_df.columns.values]

# %%
wslive_date_df.dtypes
# Out:
# PHYSICIAN_ME_NUMBER                  int64
# PHYSICIAN_FIRST_NAME                object
# PHYSICIAN_MIDDLE_NAME               object
# PHYSICIAN_LAST_NAME                 object
# SUFFIX                              object
# DEGREE                             float64
# OFFICE_ADDRESS_LINE_1               object
# OFFICE_ADDRESS_LINE_2               object
# OFFICE_ADDRESS_CITY                 object
# OFFICE_ADDRESS_STATE                object
# OFFICE_ADDRESS_ZIP                  object
# OFFICE_ADDRESS_VERIFIED_UPDATED      int64
# OFFICE_TELEPHONE                   float64
# OFFICE_PHONE_VERIFIED_UPDATED        int64
# OFFICE_FAX                         float64
# OFFICE_FAX_VERIFIED_UPDATED          int64
# SPECIALTY                           object
# SPECIALTY_UPDATED                    int64
# PRESENT_EMPLOYMENT_CODE              int64
# PRESENT_EMPLOYMENT_UPDATED           int64
# COMMENTS                            object
# SOURCE                              object
# SOURCE_DATE                         object
# SAMPLE_ID                            int64
# ROW_ID                               int64
# WSLIVE_SOURCE                       object
# dtype: object

# %%
wslive_date_df['new_metric'] = 'Inconclusive'

update_ndx = wslive_date_df['WSLIVE_SOURCE'] == 'UPDATED'
kd_ndx = (wslive_date_df['WSLIVE_SOURCE'] == 'OTHERS') & (wslive_date_df['COMMENTS'].isin(['DISCONNECT', 'NOT IN SERVICE', 
                           'WRONG NUMBER', 'RETIRED', 'DECEASED', 'FAX MODEM', 'FAX OR MODEM LINE', 'MOVED, NO FORWARDING INFO']))
nc_ndx = wslive_date_df['WSLIVE_SOURCE'] == 'FAIL'

wslive_date_df.loc[update_ndx, 'new_metric'] = 'Updated'
wslive_date_df.loc[kd_ndx, 'new_metric'] = 'Known Bad'
wslive_date_df.loc[nc_ndx, 'new_metric'] = 'No Contact'


wslive_date_df['addr_status'] = wslive_date_df['new_metric']
addr_conf_ndx = (wslive_date_df['addr_status'] == 'Updated') & (wslive_date_df['OFFICE_ADDRESS_VERIFIED_UPDATED'] == 1)
wslive_date_df.loc[addr_conf_ndx, 'addr_status'] = 'Confirmed'

wslive_date_df['pe_status'] = wslive_date_df['new_metric']
pe_conf_ndx = (wslive_date_df['pe_status'] == 'Updated') & (wslive_date_df['PRESENT_EMPLOYMENT_UPDATED'] == 1)
wslive_date_df.loc[pe_conf_ndx, 'pe_status'] = 'Confirmed'

wslive_date_df['phone_status'] = wslive_date_df['new_metric']
phone_conf_ndx = (wslive_date_df['phone_status'] == 'Updated') & (wslive_date_df['OFFICE_PHONE_VERIFIED_UPDATED'] == 1)
wslive_date_df.loc[phone_conf_ndx, 'phone_status'] = 'Confirmed'

wslive_date_df['fax_status'] = wslive_date_df['new_metric']
fax_conf_ndx = (wslive_date_df['fax_status'] == 'Updated') & (wslive_date_df['OFFICE_FAX_VERIFIED_UPDATED'] == 1)
wslive_date_df.loc[fax_conf_ndx, 'fax_status'] = 'Confirmed'

wslive_date_df['spec_status'] = wslive_date_df['new_metric']
spec_conf_ndx = (wslive_date_df['spec_status'] == 'Updated') & (wslive_date_df['SPECIALTY_UPDATED'] == 1)
wslive_date_df.loc[spec_conf_ndx, 'spec_status'] = 'Confirmed'

# %%
APRIL_TEST = wslive_date_df[['PHYSICIAN_ME_NUMBER','SOURCE','OFFICE_ADDRESS_VERIFIED_UPDATED','OFFICE_PHONE_VERIFIED_UPDATED', 
       'OFFICE_FAX_VERIFIED_UPDATED', 'PRESENT_EMPLOYMENT_UPDATED', 'COMMENTS', 
       'SPECIALTY_UPDATED', 'COMMENTS','addr_status', 'pe_status', 'phone_status',
       'fax_status', 'spec_status']]

# %%
wslive_date_df.groupby(['addr_status', 'COMMENTS']).count()
# Out:
#                                         PHYSICIAN_ME_NUMBER  \
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                                  5
#              ANSWERING SERVICE                            6
#              LANGUAGE/HEARING                            10
#              REFUSAL                                    208
# Known Bad    DECEASED                                     4
#              FAX MODEM                                    7
#              MOVED, NO FORWARDING INFO                  701
#              NOT IN SERVICE                             108
#              RETIRED                                     59
#              WRONG NUMBER                                22
# Updated      COMPLETE                                  1264
#
#                                         PHYSICIAN_FIRST_NAME  \
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                                   5
#              ANSWERING SERVICE                             6
#              LANGUAGE/HEARING                             10
#              REFUSAL                                     208
# Known Bad    DECEASED                                      4
#              FAX MODEM                                     7
#              MOVED, NO FORWARDING INFO                   701
#              NOT IN SERVICE                              108
#              RETIRED                                      59
#              WRONG NUMBER                                 22
# Updated      COMPLETE                                   1264
#
#                                         PHYSICIAN_MIDDLE_NAME  \
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                                    3
#              ANSWERING SERVICE                              2
#              LANGUAGE/HEARING                              10
#              REFUSAL                                      174
# Known Bad    DECEASED                                       4
#              FAX MODEM                                      6
#              MOVED, NO FORWARDING INFO                    586
#              NOT IN SERVICE                                85
#              RETIRED                                       47
#              WRONG NUMBER                                  19
# Updated      COMPLETE                                    1020
#
#                                         PHYSICIAN_LAST_NAME  SUFFIX  DEGREE  \
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                                  5       1       0
#              ANSWERING SERVICE                            6       0       0
#              LANGUAGE/HEARING                            10       0       0
#              REFUSAL                                    208       4       0
# Known Bad    DECEASED                                     4       1       0
#              FAX MODEM                                    7       0       0
#              MOVED, NO FORWARDING INFO                  701      12       0
#              NOT IN SERVICE                             108       4       0
#              RETIRED                                     59       3       0
#              WRONG NUMBER                                22       0       0
# Updated      COMPLETE                                  1264      20       0
#
#                                         OFFICE_ADDRESS_LINE_1  \
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                                    3
#              ANSWERING SERVICE                              3
#              LANGUAGE/HEARING                               4
#              REFUSAL                                       32
# Known Bad    DECEASED                                       1
#              FAX MODEM                                      3
#              MOVED, NO FORWARDING INFO                    160
#              NOT IN SERVICE                                33
#              RETIRED                                       21
#              WRONG NUMBER                                  10
# Updated      COMPLETE                                     488
#
#                                         OFFICE_ADDRESS_LINE_2  \
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                                    5
#              ANSWERING SERVICE                              6
#              LANGUAGE/HEARING                              10
#              REFUSAL                                      208
# Known Bad    DECEASED                                       4
#              FAX MODEM                                      7
#              MOVED, NO FORWARDING INFO                    701
#              NOT IN SERVICE                               108
#              RETIRED                                       59
#              WRONG NUMBER                                  22
# Updated      COMPLETE                                    1264
#
#                                         OFFICE_ADDRESS_CITY  \
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                                  5
#              ANSWERING SERVICE                            6
#              LANGUAGE/HEARING                            10
#              REFUSAL                                    208
# Known Bad    DECEASED                                     4
#              FAX MODEM                                    7
#              MOVED, NO FORWARDING INFO                  701
#              NOT IN SERVICE                             108
#              RETIRED                                     59
#              WRONG NUMBER                                22
# Updated      COMPLETE                                  1264
#
#                                         OFFICE_ADDRESS_STATE  ...  SOURCE  \
# addr_status  COMMENTS                                         ...
# Inconclusive 2ND ATTEMPT                                   5  ...       5
#              ANSWERING SERVICE                             6  ...       6
#              LANGUAGE/HEARING                             10  ...      10
#              REFUSAL                                     208  ...     208
# Known Bad    DECEASED                                      4  ...       4
#              FAX MODEM                                     7  ...       7
#              MOVED, NO FORWARDING INFO                   701  ...     701
#              NOT IN SERVICE                              108  ...     108
#              RETIRED                                      59  ...      59
#              WRONG NUMBER                                 22  ...      22
# Updated      COMPLETE                                   1264  ...    1264
#
#                                         SOURCE_DATE  SAMPLE_ID  ROW_ID  \
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                          5          5       5
#              ANSWERING SERVICE                    6          6       6
#              LANGUAGE/HEARING                    10         10      10
#              REFUSAL                            208        208     208
# Known Bad    DECEASED                             4          4       4
#              FAX MODEM                            7          7       7
#              MOVED, NO FORWARDING INFO          701        701     701
#              NOT IN SERVICE                     108        108     108
#              RETIRED                             59         59      59
#              WRONG NUMBER                        22         22      22
# Updated      COMPLETE                          1264       1264    1264
#
#                                         WSLIVE_SOURCE  new_metric  pe_status  \
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                            5           5          5
#              ANSWERING SERVICE                      6           6          6
#              LANGUAGE/HEARING                      10          10         10
#              REFUSAL                              208         208        208
# Known Bad    DECEASED                               4           4          4
#              FAX MODEM                              7           7          7
#              MOVED, NO FORWARDING INFO            701         701        701
#              NOT IN SERVICE                       108         108        108
#              RETIRED                               59          59         59
#              WRONG NUMBER                          22          22         22
# Updated      COMPLETE                            1264        1264       1264
#
#                                         phone_status  fax_status  spec_status
# addr_status  COMMENTS
# Inconclusive 2ND ATTEMPT                           5           5            5
#              ANSWERING SERVICE                     6           6            6
#              LANGUAGE/HEARING                     10          10           10
#              REFUSAL                             208         208          208
# Known Bad    DECEASED                              4           4            4
#              FAX MODEM                             7           7            7
#              MOVED, NO FORWARDING INFO           701         701          701
#              NOT IN SERVICE                      108         108          108
#              RETIRED                              59          59           59
#              WRONG NUMBER                         22          22           22
# Updated      COMPLETE                           1264        1264         1264
#
# [11 rows x 30 columns]

# %%
get_accuracy(all_thing[all_thing.Source=='CR'])
# Out:
# {'Phone': 0.37312182866151045,
#  'Phone_2': 0.6000158440941139,
#  'Address': 0.773916292974589,
#  'Fax': 0.7863726955655207,
#  'PE': 0.7156203288490284,
#  'Spec': 1.0}

# %%
things[things.ws_month==6]
# Out:
#        PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 0             4.120201e+10              ADIKUOR               OHENEWA
# 1             4.964096e+10                ASMAT                 ZEHRA
# 2             1.720081e+09                 ADAM               MICHAEL
# 3             8.019512e+08                 AMOS               OLABISI
# 4             4.953202e+10                 AMIT                   NaN
# ...                    ...                  ...                   ...
# 48204         1.611761e+09                 JOHN                   JOS
# 48205         5.605821e+09                 JOHN                     B
# 48206         1.104810e+09                 JOHN                 IMLAY
# 48207         4.019603e+08                 JOHN               CHARLES
# 48208                  NaN                  NaN                   NaN
#
#       PHYSICIAN_LAST_NAME  SUFFIX  DEGREE  OFFICE_ADDRESS_LINE_1  \
# 0                 ADJETEY     NaN     NaN                    NaN
# 1                   JAFRY     NaN     NaN                    NaN
# 2                   WERNE     NaN     NaN                    NaN
# 3                    DARE     NaN     NaN                STE 310
# 4                  TODANI     NaN     NaN                    NaN
# ...                   ...     ...     ...                    ...
# 48204             MANGONI     NaN     NaN                    NaN
# 48205            MITCHELL     4.0     NaN                    NaN
# 48206               BENET     NaN     NaN  KAISER MEDICAL CENTER
# 48207              WEBBER     NaN     NaN         YOUTH HOME INC
# 48208                 NaN     NaN     NaN                    NaN
#
#           OFFICE_ADDRESS_LINE_2 OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE  ...  \
# 0             3435 S ALAMEDA ST        CORP CHRISTI                   TX  ...
# 1          1112 S WASHINGTON ST          NAPERVILLE                   IL  ...
# 2          8333 NAAB RD STE 400        INDIANAPOLIS                   IN  ...
# 3               644 CESERY BLVD        JACKSONVILLE                   FL  ...
# 4                170 DRAPER AVE         N ATTLEBORO                   MA  ...
# ...                         ...                 ...                  ...  ...
# 48204  1311 N SAN FERNANDO BLVD             BURBANK                   CA  ...
# 48205            2025 MORSE AVE          SACRAMENTO                   CA  ...
# 48206              26 TOPAZ WAY       SAN FRANCISCO                   CA  ...
# 48207    20400 COLONEL GLENN RD         LITTLE ROCK                   AR  ...
# 48208                       NaN                 NaN                  NaN  ...
#
#       SPECIALTY_UPDATED  SOURCE_FILE_DT  ws_month  ws_year    new_metric  \
# 0                   1.0      2020-04-28         6     2020       Updated
# 1                   1.0      2020-04-28         6     2020       Updated
# 2                   1.0      2020-04-28         6     2020       Updated
# 3                   1.0      2020-04-28         6     2020       Updated
# 4                   1.0      2020-04-28         6     2020       Updated
# ...                 ...             ...       ...      ...           ...
# 48204               1.0      2020-05-22         6     2020     Known Bad
# 48205               1.0      2020-05-22         6     2020     Known Bad
# 48206               1.0      2020-05-22         6     2020     Known Bad
# 48207               1.0      2020-05-22         6     2020     Known Bad
# 48208               NaN             NaN         6     2020  Inconclusive
#
#         addr_status     pe_status  phone_status    fax_status   spec_status
# 0         Confirmed     Confirmed     Confirmed     Confirmed     Confirmed
# 1         Confirmed       Updated     Confirmed     Confirmed     Confirmed
# 2         Confirmed       Updated     Confirmed     Confirmed     Confirmed
# 3           Updated     Confirmed     Confirmed     Confirmed     Confirmed
# 4         Confirmed       Updated     Confirmed     Confirmed     Confirmed
# ...             ...           ...           ...           ...           ...
# 48204     Known Bad     Known Bad     Known Bad     Known Bad     Known Bad
# 48205     Known Bad     Known Bad     Known Bad     Known Bad     Known Bad
# 48206     Known Bad     Known Bad     Known Bad     Known Bad     Known Bad
# 48207     Known Bad     Known Bad     Known Bad     Known Bad     Known Bad
# 48208  Inconclusive  Inconclusive  Inconclusive  Inconclusive  Inconclusive
#
# [27079 rows x 38 columns]

# %%
all_thing_2 = pd.read_csv('../../Data/Humach/wslive_with_results_2020-05-01_to_2020-06-05.csv')

# %%
things = pd.concat([all_thing, all_thing_2])

# %%
things[things.Source=='C']
# Out:
# Empty DataFrame
# Columns: [PHYSICIAN_ME_NUMBER, PHYSICIAN_FIRST_NAME, PHYSICIAN_MIDDLE_NAME, PHYSICIAN_LAST_NAME, SUFFIX, DEGREE, OFFICE_ADDRESS_LINE_1, OFFICE_ADDRESS_LINE_2, OFFICE_ADDRESS_CITY, OFFICE_ADDRESS_STATE, OFFICE_ADDRESS_ZIP, OFFICE_ADDRESS_VERIFIED_UPDATED, OFFICE_TELEPHONE, OFFICE_PHONE_VERIFIED_UPDATED, OFFICE_FAX, OFFICE_FAX_VERIFIED_UPDATED, EMAIL_ADDRESS, EMAIL_ADDRESS_VERIFIED_UPDATED, PRESENT_EMPLOYMENT_CODE, PRESENT_EMPLOYMENT_UPDATED, COMMENTS, Source, WSLIVE_SOURCE, WSLIVE_FILE_DT, MATCH_ADDR, MATCH_PHONE, MATCH_ADDR_LONG, SPECIALTY, SPECIALTY_UPDATED, SOURCE_FILE_DT, ws_month, ws_year, new_metric, addr_status, pe_status, phone_status, fax_status, spec_status]
# Index: []
#
# [0 rows x 38 columns]

# %%
len(things)
# Out:
# 78506
