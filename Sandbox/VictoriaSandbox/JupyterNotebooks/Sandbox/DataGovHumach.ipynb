# %%
import pandas as pd
import useful_functions as use

# %%
humach = pd.read_csv('../../Data/PhoneAppend/humach_results.csv')

# %%
og_bolo_sample = pd.read_excel('../../Data/DataGov/National_Downloadable_FIle_BOLO_Humach_Sample_25-05-21.xlsx')

# %%
og_sample = pd.read_excel('../../Data/DataGov/National_Downloadable_File_Humach_Random_Sample_25-05-21.xlsx')

# %%
og_sample
# Out:
#                ME    LAST_NAME FIRST_NAME MIDDLE_NAME  SUFFIX  \
# 0     02576971209          RAO      MADHU         NaN     NaN
# 1     69005890152       MBAERI   CHINYERE       CHRIS     NaN
# 2     05404790368     COULSTON     DANIEL        ROBT     NaN
# 3     49529840097       SEKHON   JATINDER           S     NaN
# 4     60501970118       LAKKIS        JAY         IAN     NaN
# ...           ...          ...        ...         ...     ...
# 9995  64935980028         NOEL        MAX         NaN     NaN
# 9996  93503010087         NOEL        AMY           L     NaN
# 9997  49501000166      MALEKAR     SHILPA        ARUN     NaN
# 9998  00301991002  ZZIWAMBAZZA     NATHAN       ZZIWA     NaN
# 9999  00515140735      SALAZAR     KARINA        INEZ     NaN
#
#       POLO_MAILING_ADDRESS_2 POLO_MAILING_ADDRESS_1     POLO_CITY POLO_STATE  \
# 0              1904 LAKE AVE                    NaN      PLYMOUTH         IN
# ...

# %%
og_bolo_sample['ME']=use.fix_me(og_bolo_sample.ME)
og_sample['ME']=use.fix_me(og_sample.ME)

# %%
ppd = use.get_ppd()
# Out:
# C:/Users/vigrose/Data/PPD\ppd_data_20210612.csv
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (13,14,20,21,42,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
humach['ME']=use.fix_me(humach.PHYSICIAN_ME_NUMBER)

# %%
len(humach[(humach.Source=='NR')|(humach.Source=='NB')])
# Out:
# 2736

# %%
random = humach[(humach.Source=='NR')]

# %%
humach[(humach.Source=='NB')].groupby(['COMMENTS','OFFICE_ADDRESS_VERIFIED_UPDATED']).count()
# Out:
#                                                            PHYSICIAN_ME_NUMBER  \
# COMMENTS                  OFFICE_ADDRESS_VERIFIED_UPDATED
# 2ND ATTEMPT               1                                                  3
# ANSWERING SERVICE         1                                                  7
# COMPLETE                  1                                                474
#                           2                                                 84
# DECEASED                  1                                                  1
# DO NOT CALL               1                                                  1
# FAX MODEM                 1                                                  6
# LANGUAGE/HEARING          1                                                  1
# MOVED, NO FORWARDING INFO 1                                                 90
# NOT IN SERVICE            1                                                 88
# ...

# %%
humach[(humach.Source=='BB')]
# Out:
#       PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 7              1720112490                 ADAM               CHARLES
# 10             4301970493                 ADAM                     M
# 13            13202000058              ADRIANA                LORENA
# 17             3519061707                AHMED                     I
# 24             3840820598                 ALAN           CHRISTOPHER
# ...                   ...                  ...                   ...
# 3545            518990039                EMILY                     C
# 3546           2307060895                 ERIC                THOMAS
# 3552           1803990693                HEIDI                  GAYE
# 3554            401720839                HENRY                  LYLE
# 3556           4177940921               EUGENE                     S
#
#      PHYSICIAN_LAST_NAME  SUFFIX  DEGREE             OFFICE_ADDRESS_LINE_1  \
# ...

# %%
humach[humach.WSLIVE_SOURCE=='FAIL'][['Source','COMMENTS']]
# Out:
#      Source     COMMENTS
# 843      NB  2ND ATTEMPT
# 844      NR  2ND ATTEMPT
# 845      BB  2ND ATTEMPT
# 846      NB  2ND ATTEMPT
# 847      NR  2ND ATTEMPT
# 2284     NB  2ND ATTEMPT
# 2285     BB  2ND ATTEMPT
# 2286     BB  2ND ATTEMPT

# %%
len(humach[(humach.Source=='NR')])
# Out:
# 1867

# %%
humach[(humach.Source=='NR')].groupby(['COMMENTS','OFFICE_ADDRESS_VERIFIED_UPDATED']).count()
# Out:
#                                                            PHYSICIAN_ME_NUMBER  \
# COMMENTS                  OFFICE_ADDRESS_VERIFIED_UPDATED
# 2ND ATTEMPT               1                                                  2
# ANSWERING SERVICE         1                                                  7
#                           2                                                  1
# COMPLETE                  1                                                691
#                           2                                                535
# DECEASED                  1                                                  2
# FAX MODEM                 1                                                 22
# LANGUAGE/HEARING          1                                                 21
# MOVED, NO FORWARDING INFO 1                                                251
# NOT IN SERVICE            1                                                159
# ...

# %%
691/(535+691)
# Out:
# 0.5636215334420881

# %%
OG_SPREAD[(OG_SPREAD.OFFICE_ADDRESS_VERIFIED_UPDATED==2)&(OG_SPREAD.COMMENTS=='COMPLETE')][['COMMENTS','OFFICE_ADDRESS_VERIFIED_UPDATED','OFFICE_ADDRESS_LINE_1','POLO_MAILING_ADDRESS_1','OFFICE_ADDRESS_LINE_2','POLO_MAILING_ADDRESS_2', 'OFFICE_ADDRESS_CITY','POLO_CITY_GOV','OFFICE_ADDRESS_STATE','POLO_STATE_GOV','OFFICE_ADDRESS_ZIP','POLO_ZIP_GOV']]
# Out:
#       COMMENTS  OFFICE_ADDRESS_VERIFIED_UPDATED OFFICE_ADDRESS_LINE_1  \
# 0     COMPLETE                                2             SUITE 201
# 1     COMPLETE                                2                   NaN
# 4     COMPLETE                                2                   NaN
# 11    COMPLETE                                2  108 MEDICAL CTR BLVD
# 14    COMPLETE                                2                 STE A
# ...        ...                              ...                   ...
# 1841  COMPLETE                                2             SUITE 103
# 1845  COMPLETE                                2                   NaN
# 1847  COMPLETE                                2                   NaN
# 1870  COMPLETE                                2                   NaN
# 1872  COMPLETE                                2                   NaN
#
#      POLO_MAILING_ADDRESS_1       OFFICE_ADDRESS_LINE_2  \
# 0                 SUITE 201               1022 1ST ST N
# ...

# %%
og_bolo_sample['POLO_MAILING_LINE_2']
# Out:
# 0               675 W North Ave
# 1               3401 North Blvd
# 2       1020 S State Highway 16
# 3                  179 North St
# 4                  14943 Hgy 14
#                  ...
# 4995           315 W Dalton Ave
# 4996               300 S 8th St
# 4997      300 S 8th St Ste 182W
# 4998               300 S 8th St
# 4999        3443 Dickerson Pike
# Name: POLO_MAILING_LINE_2, Length: 5000, dtype: object

# %%
#Confirmed / (Confirmed + Updated + Known Bad + Inconclusive + No Contact)
522/869
# Out:
# 0.6006904487917146

# %%
474/(474+84)
# Out:
# 0.8494623655913979

# %%
ALL = pd.merge(ppd, humach, on='ME')

# %%
OG_SPREAD = pd.merge(ALL, og_sample, on='ME', suffixes = ['_PPD','_GOV'])

# %%
for col in OG_SPREAD.columns:
    print(col)
# Out:
# ME
# RECORD_ID
# UPDATE_TYPE
# ADDRESS_TYPE
# MAILING_NAME
# LAST_NAME_PPD
# FIRST_NAME_PPD
# MIDDLE_NAME_PPD
# SUFFIX_x
# MAILING_LINE_1
# MAILING_LINE_2
# CITY
# STATE
# ZIP
# SECTOR
# CARRIER_ROUTE
# ADDRESS_UNDELIVERABLE_FLAG
# FIPS_COUNTY
# FIPS_STATE
# PRINTER_CONTROL_CODE
# PC_ZIP
# PC_SECTOR
# DELIVERY_POINT_CODE
# CHECK_DIGIT
# PRINTER_CONTROL_CODE_2
# REGION
# DIVISION
# GROUP
# TRACT
# SUFFIX_CENSUS
# BLOCK_GROUP
# MSA_POPULATION_SIZE
# MICRO_METRO_IND
# CBSA
# CBSA_DIV_IND
# MD_DO_CODE
# BIRTH_YEAR
# BIRTH_CITY
# BIRTH_STATE
# BIRTH_COUNTRY
# GENDER
# TELEPHONE_NUMBER_PPD
# PRESUMED_DEAD_FLAG
# FAX_NUMBER_PPD
# TOP_CD
# PE_CD_PPD
# PRIM_SPEC_CD_PPD
# SEC_SPEC_CD
# MPA_CD
# PRA_RECIPIENT
# PRA_EXP_DT
# GME_CONF_FLG
# FROM_DT
# TO_DT
# YEAR_IN_PROGRAM
# POST_GRADUATE_YEAR
# GME_SPEC_1
# GME_SPEC_2
# TRAINING_TYPE
# GME_INST_STATE
# GME_INST_ID
# MEDSCHOOL_STATE
# MEDSCHOOL_ID
# MEDSCHOOL_GRAD_YEAR
# NO_CONTACT_IND
# NO_WEB_FLAG
# PDRP_FLAG
# PDRP_START_DT
# ...

# %%
RANDOM = pd.merge(ppd, random, on='ME')

# %%
RANDOM = RANDOM.fillna('None')
RANDOM[RANDOM.TELEPHONE_NUMBER=='None'].groupby('COMMENTS').count()
# Out:
#                             ME  RECORD_ID  UPDATE_TYPE  ADDRESS_TYPE  \
# COMMENTS
# ANSWERING SERVICE            3          3            3             3
# COMPLETE                   113        113          113           113
# DECEASED                     1          1            1             1
# FAX MODEM                    4          4            4             4
# LANGUAGE/HEARING             1          1            1             1
# MOVED, NO FORWARDING INFO   53         53           53            53
# NOT IN SERVICE              23         23           23            23
# REFUSAL                     14         14           14            14
# RETIRED                      4          4            4             4
# WRONG NUMBER                 3          3            3             3
#
#                            MAILING_NAME  LAST_NAME  FIRST_NAME  MIDDLE_NAME  \
# COMMENTS
# ANSWERING SERVICE                     3          3           3            3
# ...

# %%
RANDOM[['TELEPHONE_NUMBER','OFFICE_TELEPHONE','POLO_MAILING_LINE_1','OFFICE_ADDRESS_LINE_1', 'POLO_MAILING_LINE_2','OFFICE_ADDRESS_LINE_2','COMMENTS','OFFICE_ADDRESS_VERIFIED_UPDATED']]
# Out:
#      TELEPHONE_NUMBER  OFFICE_TELEPHONE     POLO_MAILING_LINE_1  \
# 0         2.05622e+09        2056219500                    None
# 1         9.01449e+09        3347496523  DIVISION OF NEPHROLOGY
# 2                None        2569742200                    None
# 3         2.05487e+09        2054865234                    None
# 4         8.50437e+09        7278675480                    None
# ...               ...               ...                     ...
# 1862      6.18328e+09        6183278236                    None
# 1863      3.05666e+09        3055951594                    None
# 1864      7.13955e+09        7139553919                    None
# 1865      2.05935e+09        3027331980                    None
# 1866      3.05576e+09        3059941825                    None
#
#        OFFICE_ADDRESS_LINE_1                POLO_MAILING_LINE_2  \
# 0                  SUITE 201              1022 1ST ST N STE 201
# 1                       None                777 WELCH RD STE DE
# ...
