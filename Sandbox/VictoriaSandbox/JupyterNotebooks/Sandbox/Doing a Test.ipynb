# %%
import pandas as pd
import pyodbc
import useful_functions as use

# %%
ppd = use.get_ppd()
# Out:
# C:/Users/vigrose/Data/PPD\ppd_data_20210731.csv
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (13,14,20,21,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
username = 'vigrose'
password = 'Ravenclaw~10946'
s = "DSN=PRDDW; UID={}; PWD={}".format(username, password)
AMAEDW = pyodbc.connect(s)

# %%
query = \
    """
    SELECT
    PARTY_ID,
    ACTIVE_IND,
    DEATH_DT,
    UPDATE_TMSTP
    FROM
    AMAEDW.PERSON
    WHERE
    ACTIVE_IND = 'N'
    ;
    """
CHECK = pd.read_sql(con=AMAEDW, sql=query)
CHECK.head()
# Out:
#    PARTY_ID ACTIVE_IND DEATH_DT        UPDATE_TMSTP
# 0   3709005          N     None 2012-12-20 22:36:20
# 1   3709006          N     None 2006-06-23 09:34:18
# 2   3709007          N     None 2008-02-13 22:23:09
# 3   3709009          N     None 2006-08-22 19:35:14
# 4   3709011          N     None 2012-12-04 23:48:39

# %%
len(CHECK)
# Out:
# 33627

# %%
ppd.groupby('TOP_CD').count()
# Out:
#             ME  RECORD_ID  UPDATE_TYPE  ADDRESS_TYPE  MAILING_NAME  LAST_NAME  \
# TOP_CD
# 12      144352     144352       144352        141887        144352     144343
# 20      817592     817592       817592        808355        817592     817579
# 30       13067      13067        13067         12820         13067      13067
# 40       12294      12294        12294         12075         12294      12293
# 50       12617      12617        12617         12316         12617      12617
# 62        4684       4684         4684          4608          4684       4684
# 71      168579     168579       168579        163922        168579     168576
# 72       19504      19504        19504         19271         19504      19504
# 74        3992       3992         3992          3929          3992       3992
# 75       14159      14159        14159         13547         14159      14158
# 100      91154      91154        91154         88313         91154      91151
#
# ...

# %%
ppd[(ppd.TOP_CD==71)&(ppd.PRESUMED_DEAD_FLAG!='D')]
# Out:
#                   ME RECORD_ID  UPDATE_TYPE  ADDRESS_TYPE  \
# 519      00102030451         A            1           2.0
# 692      00102040627         A            1           2.0
# 1123     00102070305         A            1           2.0
# 1291     00102080386         A            1           1.0
# 1555     00102091591         A            1           2.0
# ...              ...       ...          ...           ...
# 1301690  95708760073         A            1           2.0
# 1301802  95708880150         A            1           2.0
# 1301850  95709760018         A            1           2.0
# 1301924  96501760037         A            1           1.0
# 1301930  96501780011         A            1           1.0
#
#                   MAILING_NAME LAST_NAME FIRST_NAME MIDDLE_NAME  SUFFIX  \
# 519      SUMMERPAL S KAHLON MD    KAHLON  SUMMERPAL       SINGH     NaN
# 692       JEFFERY L WALDING MD   WALDING    JEFFERY    LAWRENCE     NaN
# ...
