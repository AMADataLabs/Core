# %%
import pandas as pd
import useful_functions as use
import numpy as np

# %%
ppd = use.get_ppd()
# Out:
# INFO:useful_functions:PPD file from Mar 05 2022
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (13,14,20,21,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
ppd[(ppd.SUFFIX.isna())]
# Out:
#                   ME RECORD_ID  UPDATE_TYPE  ADDRESS_TYPE  \
# 0        00102000013         A            1           2.0
# 1        00102000021         A            1           3.0
# 2        00102000030         A            1           1.0
# 3        00102000048         A            1           2.0
# 4        00102000056         A            1           2.0
# ...              ...       ...          ...           ...
# 1308622  96501960028         A            1           2.0
# 1308623  96501960036         A            1           2.0
# 1308624  96501960044         A            1           2.0
# 1308625  96501960052         A            1           2.0
# 1308626  96501980029         A            1           1.0
#
#                     MAILING_NAME    LAST_NAME FIRST_NAME MIDDLE_NAME  SUFFIX  \
# 0          MICHAEL J STANFORD MD     STANFORD    MICHAEL       JAMES     NaN
# 1               MERI K MARTIN MD       MARTIN       MERI        KING     NaN
# ...

# %%
#109108
#334722
#56364

# %%
len(ppd[ppd.MD_DO_CODE==2])
# Out:
# 100482

# %%
notes_2 = pd.read_excel('../../Data/Scorecard/v-Masterfile-Scorecard_January_2022_02_11.xlsx', sheet_name='Notes_2')
standard_devs = []
for num in list(range(0, 24)):
    standard_devs.append(np.std(notes_2.iloc[[num], 2:15].values, dtype=np.float64))

# %%
standard_devs
# Out:
# [0.002764805009557464,
#  0.006140801209535603,
#  0.011867214984544065,
#  0.0011040560467643658,
#  0.0006406450752169392,
#  0.001940693995821728,
#  0.005698115737846425,
#  0.023451655711572775,
#  0.02242711908487918,
#  0.011327326758528334,
#  0.02463495472570425,
#  0.007116969237096863,
#  18334.440131317086,
#  8239.327722905782,
#  13841.4661257195,
#  30514.756776810937,
#  0.022800556246042936,
#  0.010112920832192123,
#  0.016635911919071142,
#  0.021180695184125683,
#  1699.3002249272702,
#  2381.0958518340462,
#  10690.896817817988,
#  1458.7180438182515]

# %%
ppd_old = pd.read_csv('../../Data/Scorecard/ppd_data_20220205.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,14,20,21,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(ppd_old[ppd_old.MD_DO_CODE==2])
# Out:
# 100434

# %%
ppd[~(ppd.PRESUMED_DEAD_FLAG.isna())&(ppd.MD_DO_CODE==2)][['BIRTH_YEAR','MAILING_NAME']]
# Out:
#         BIRTH_YEAR           MAILING_NAME
# 16955       1954.0     ALBERTA R JONES DO
# 81205       1915.0  DONALD CURRY-ALLEN DO
# 81206       1920.0    EARL CHAPPELL JR DO
# 84092       1957.0  STEPHEN D DOCHERTY DO
# 84471       1947.0     KENNETH S YOUNG DO
# ...            ...                    ...
# 785747      1953.0  SILVIO J ZAPPASODI DO
# 788373      1964.0    JOHN S FLUBACHER DO
# 904790      1985.0         ATEFA NAYEB DO
# 960310      1945.0       MARION WATSON DO
# 960458      1955.0        STEVEN SMITH DO
#
# [364 rows x 2 columns]

# %%
ppd[~(ppd.NO_CONTACT_IND.isna())&(ppd.TOP_CD==20)]
# Out:
#                   ME RECORD_ID  UPDATE_TYPE  ADDRESS_TYPE  \
# 61       00102000650         A            1           1.0
# 125      00102001869         A            1           2.0
# 160      00102010060         A            1           1.0
# 197      00102010442         A            1           2.0
# 211      00102010582         A            1           2.0
# ...              ...       ...          ...           ...
# 1308186  95705850055         A            1           2.0
# 1308300  95707980037         A            1           2.0
# 1308404  95708870049         A            1           1.0
# 1308463  95708930033         A            1           2.0
# 1308589  96501830051         A            1           2.0
#
#                       MAILING_NAME   LAST_NAME   FIRST_NAME MIDDLE_NAME  \
# 61               DAVID I GAINES MD      GAINES        DAVID       ISAAC
# 125               RONALD M ROAN MD        ROAN       RONALD      MCCUEN
# ...

# %%
ppd_old[(ppd_old.NO_CONTACT_IND.isna())&(ppd_old.TOP_CD==20)]
# Out:
#                   ME RECORD_ID  UPDATE_TYPE  ADDRESS_TYPE  \
# 0          102000013         A            1           2.0
# 2          102000030         A            1           1.0
# 3          102000048         A            1           2.0
# 4          102000056         A            1           2.0
# 5          102000064         A            1           2.0
# ...              ...       ...          ...           ...
# 1308695  96501940019         A            1           1.0
# 1308696  96501950014         A            1           2.0
# 1308700  96501960036         A            1           2.0
# 1308701  96501960044         A            1           2.0
# 1308702  96501960052         A            1           2.0
#
#                     MAILING_NAME    LAST_NAME FIRST_NAME MIDDLE_NAME  SUFFIX  \
# 0          MICHAEL J STANFORD MD     STANFORD    MICHAEL       JAMES     NaN
# 2              MARK T JACKSON MD      JACKSON       MARK      THOMAS     NaN
# ...
