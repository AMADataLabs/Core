# %%
import pandas as pd
import pyodbc
from datamart import fix_me

# %%
username = 'vigrose'
password_edw = 'Gryffindor~10946'
w = "DSN=PRDDW; UID={}; PWD={}".format(username, password_edw)
AMAEDW = pyodbc.connect(w)

# %%
filtered_polos = pd.read_csv('../../Data/POLO_Filter/Filtered_POLOs.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,23,28,29,30,114) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sql_query = \
    """
    SELECT DISTINCT
    L.PARTY_ID,
    S.SRC_STATE_CD AS STATE_CD,
    L.LIC_NBR,
    L.FROM_DT,
    L.ISS_DT,
    L.AS_OF_DT
    FROM
    AMAEDW.LIC L, AMAEDW.STATE S
    WHERE
    L.THRU_DT IS NULL
    AND
    L.STATE_ID = S.STATE_ID
    AND
    L.STS_TYPE_ID = 40
    AND
    L.DELETE_IND = 'N';
    """
license = pd.read_sql(con=AMAEDW, sql=sql_query)

# %%
license.head()
# Out:
#    PARTY_ID STATE_CD     LIC_NBR             FROM_DT      ISS_DT    AS_OF_DT
# 0   2715442       GU    M00-1484 2005-06-15 08:22:49  2005-02-16  2005-06-15
# 1   3496718       DE   C70002806 2005-10-19 11:56:38  2003-07-28  2005-09-26
# 2   3579207       VT  0600003338 2006-02-14 09:32:16  2005-08-03  2006-02-08
# 3   3451654       AK      R03301 2006-02-16 16:02:19  2005-02-08  2006-02-09
# 4   3688725       PR      015511 2006-05-01 15:37:09  2004-07-21  2006-03-28

# %%
filtered_polos['ME']=fix_me(filtered_polos.ME)

# %%
CHECKIN = pd.merge(filtered_polos, license, on='PARTY_ID', suffixes = ['_PPD',''])

# %%
for col in filtered_polos.columns:
    print(col)
# Out:
# ME
# RECORD_ID
# UPDATE_TYPE
# ADDRESS_TYPE
# MAILING_NAME
# LAST_NAME
# FIRST_NAME
# MIDDLE_NAME
# SUFFIX_POLO
# MAILING_LINE_1
# MAILING_LINE_2
# CITY
# STATE
# ZIP
# SECTOR
# CARRIER_ROUTE
# ADDRESS_UNDELIVERABLE_FLAG
# FIPS_COUNTY
# FIPS_STATE
# PRINTER_CONTROL_CODE
# PC_ZIP
# PC_SECTOR
# DELIVERY_POINT_CODE
# CHECK_DIGIT
# PRINTER_CONTROL_CODE_2
# REGION
# DIVISION
# GROUP
# TRACT
# SUFFIX_CENSUS
# BLOCK_GROUP
# MSA_POPULATION_SIZE
# MICRO_METRO_IND
# CBSA
# CBSA_DIV_IND
# MD_DO_CODE
# BIRTH_YEAR
# BIRTH_CITY
# BIRTH_STATE
# BIRTH_COUNTRY
# GENDER
# TELEPHONE_NUMBER
# PRESUMED_DEAD_FLAG
# FAX_NUMBER
# TOP_CD
# PE_CD
# PRIM_SPEC_CD
# SEC_SPEC_CD
# MPA_CD
# PRA_RECIPIENT
# PRA_EXP_DT
# GME_CONF_FLG
# FROM_DT
# TO_DT
# YEAR_IN_PROGRAM
# POST_GRADUATE_YEAR
# GME_SPEC_1
# GME_SPEC_2
# TRAINING_TYPE
# GME_INST_STATE
# GME_INST_ID
# MEDSCHOOL_STATE
# MEDSCHOOL_ID
# MEDSCHOOL_GRAD_YEAR
# NO_CONTACT_IND
# NO_WEB_FLAG
# PDRP_FLAG
# PDRP_START_DT
# POLO_MAILING_LINE_1
# ...

# %%
count = 0
this_count = 0 
other_count = 0
what = 0
for row in BOP.itertuples():
    if row.ADDRESS_TYPE == '1.0' & row.STATE_POLO in LIC_DIC[row.ME]:

    elif row.STATE_POLO in LIC_DIC[row.ME] & row.STATE_PPMA not in LIC_DIC[row.ME]:

# %%
len(BOP)
# Out:
# 18475

# %%
len(filtered_polos)
# Out:
# 19520

# %%
filtered_polos.groupby('ADDRESS_TYPE').count()
# Out:
#                 ME  RECORD_ID  UPDATE_TYPE  MAILING_NAME  LAST_NAME  \
# ADDRESS_TYPE
# 1.0           9687       9687         9687          9687       9687
# 2.0           9547       9547         9547          9547       9547
# 3.0             38         38           38            38         38
# None           248        248          248           248        248
#
#               FIRST_NAME  MIDDLE_NAME  SUFFIX_POLO  MAILING_LINE_1  \
# ADDRESS_TYPE
# 1.0                 9687         9687         9687            9687
# 2.0                 9547         9547         9547            9547
# 3.0                   38           38           38              38
# None                 248          248          248             248
#
#               MAILING_LINE_2  ...  WSLIVE_SOURCE  WSLIVE_FILE_DT  MATCH_ADDR  \
# ADDRESS_TYPE                  ...
# 1.0                     9687  ...           9687            9687        9687
# ...

# %%
BOP['LICENSE_STATE_MATCH']=lic_matches
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# 1,045 do not have an active license in EDW
# 5,464 PPMAs to be replaced are Office Addresses and the Individual associated with POLO has an active license in the POLO state
# 1,242 POLOs are replacing home PPMAs but the individual associated with POLO has an active license in the POLO state and does not have an active license in the PPMA state
# 2,016 have licenses in both PPMA and POLO state

# %%
BOP[BOP.LICENSE_STATE_MATCH == True]
# Out:
#                 ME RECORD_ID  UPDATE_TYPE ADDRESS_TYPE           MAILING_NAME  \
# 0      01003120208         A            1          1.0     DARIUS P FELTON MD
# 1      01201090446         A            1          1.0       ERIK B PERSON MD
# 2      03548090694         A            1          2.0    KARL C SCHLOBOHM MD
# 3      61001870032         A            1          2.0      MAUD O NICOLAS MD
# 4      02312020931         A            1          2.0    CHRISTINE A LAKY MD
# ...            ...       ...          ...          ...                    ...
# 19514  04501161441         A            1          1.0       JOHN T EPTING MD
# 19515  70433050051         A            1          1.0     MUHAMMAD SHAHID MD
# 19517  04501900031         A            1          1.0  RICHARD E AKERS II MD
# 19518  01606141978         A            1          2.0   JARRETT J FAILING MD
# 19519  04814021659         A            1          1.0  JOHN D MIDDLEBROOK MD
#
# ...

# %%
len(filtered_polos)
# Out:
# 19520

# %%
LIC_DIC = {}
for row in CHECKIN.itertuples():
    if row.ME in LIC_DIC.keys():
        LIC_DIC[row.ME].append(row.STATE_CD)
    else:
        LIC_DIC[row.ME] = [row.STATE_CD]

# %%
BOP = filtered_polos[filtered_polos.ME.isin(CHECKIN.ME)]

# %%
count
# Out:
# 12406

# %%
CHECKIN[['STATE_CD','STATE_POLO','STATE_PPMA','STATE', 'AS_OF_DT','FROM_DT_POLO', 'ME']]
# Out:
#       STATE_CD STATE_POLO STATE_PPMA STATE    AS_OF_DT  \
# 0           NY         NY         MI    MI  2021-04-09
# 1           GA         GA         MD    MD  2021-05-17
# 2           NJ         NJ         MA    MA  2021-05-04
# 3           GA         FL         FL    FL  2021-05-17
# 4           MI         FL         FL    FL  2021-05-12
# ...        ...        ...        ...   ...         ...
# 28865       SC         NC         SC    SC  2021-05-04
# 28866       NC         NC         SC    SC  2021-05-12
# 28867       MN         MN         MN    MN  2021-05-04
# 28868       TX         TX         TX    TX  2021-05-10
# 28869       CO         TX         TX    TX  2021-05-07
#
#                      FROM_DT_POLO           ME
# 0      2018-05-11 20:51:12.192391   1003120208
# 1      2018-05-11 20:51:41.048978   1201090446
# 2      2018-05-04 20:52:49.100535   3548090694
# 3      2018-05-11 20:51:06.370570  61001870032
# 4      2018-05-11 20:51:06.370570  61001870032
# ...

# %%
len(filtered_polos)
# Out:
# 19520

# %%
filtered_polos.ADDRESS_TYPE
# Out:
# 0        1.0
# 1        1.0
# 2        2.0
# 3        2.0
# 4        2.0
#         ...
# 19515    1.0
# 19516    2.0
# 19517    1.0
# 19518    2.0
# 19519    1.0
# Name: ADDRESS_TYPE, Length: 19520, dtype: object

# %%
LIC_DIC
# Out:
# {1003120208: ['NY'],
#  1201090446: ['GA'],
#  3548090694: ['NJ'],
#  61001870032: ['GA', 'MI', 'FL'],
#  2312020931: ['VA', 'MD', 'TX', 'ID'],
#  2002960659: ['PA'],
#  2879850153: ['OH'],
#  30501136332: ['GA'],
#  1175050601: ['FL'],
#  1720082990: ['IN', 'IL', 'GA', 'IA', 'SC'],
#  3844951034: ['NC'],
#  3844110412: ['OH'],
#  2105953561: ['NY'],
#  3843110117: ['FL'],
#  1606060498: ['OH'],
#  2105041163: ['LA'],
#  30501111151: ['IN', 'OH'],
#  3841041274: ['NY'],
#  3840130664: ['IN'],
#  2878991861: ['IN', 'MI'],
#  4113071406: ['NY', 'PA'],
#  1104121612: ['FL'],
#  1104131201: ['FL'],
#  16002830322: ['NY'],
#  42201060227: ['NY'],
#  3305111430: ['FL'],
#  2878811049: ['CA', 'CO'],
#  2507071786: ['NY'],
#  2879750264: ['IN'],
#  4178060240: ['NY'],
#  42201042440: ['WV'],
#  30501102373: ['VA'],
#  58306010016: ['NY'],
#  1611101216: ['NM', 'CO'],
#  4901111036: ['UT'],
#  5104820427: ['FL'],
#  64914002352: ['AZ', 'OK', 'OH'],
#  30501064439: ['WI', 'GA'],
# ...
