# %%
import pandas as pd
import os
import useful_functions as use
import psycopg2
import pyodbc
import datetime

# %%
#License
x = os.path.getmtime(path)
dt = datetime.datetime.fromtimestamp(x)
print(dt)
# Out:
# 2022-08-15 09:19:18.670937

# %%
path = "../../Data/Alabama/"
x = os.path.getctime(path) 
dt = datetime.datetime.fromtimestamp(x)
print(dt)
# Out:
# 2022-08-15 09:19:16.282389

# %%
dict_list = []
for directory in os.listdir('../../Data/'):
    path = f'../../Data/{directory}'
    x = os.path.getctime(path) 
    dt = datetime.datetime.fromtimestamp(x)
    new_dict = {
        'STATE': directory,
        'CREATION_DT': dt
    }
    dict_list.append(new_dict)

# %%
dict_list
# Out:
# [{'STATE': 'access.txt',
#   'CREATION_DT': datetime.datetime(2022, 3, 4, 13, 18, 51, 711974)},
#  {'STATE': 'Address_APIs.csv',
#   'CREATION_DT': datetime.datetime(2021, 3, 9, 13, 50, 3, 568761)},
#  {'STATE': 'Alabama',
#   'CREATION_DT': datetime.datetime(2022, 8, 15, 9, 19, 16, 282389)},
#  {'STATE': 'AMAIA',
#   'CREATION_DT': datetime.datetime(2020, 3, 27, 9, 19, 45, 79472)},
#  {'STATE': 'Asks',
#   'CREATION_DT': datetime.datetime(2022, 2, 23, 13, 8, 2, 116952)},
#  {'STATE': 'BeckerReview',
#   'CREATION_DT': datetime.datetime(2020, 4, 23, 16, 6, 47, 460979)},
#  {'STATE': 'code.txt',
#   'CREATION_DT': datetime.datetime(2022, 4, 22, 13, 25, 45, 131886)},
#  {'STATE': 'counts.csv',
#   'CREATION_DT': datetime.datetime(2021, 4, 12, 12, 19, 24, 775614)},
#  {'STATE': 'CPT_Company_Segmentation',
#   'CREATION_DT': datetime.datetime(2022, 7, 29, 14, 33, 19, 487208)},
#  {'STATE': 'CPT_Dashboard',
#   'CREATION_DT': datetime.datetime(2020, 4, 2, 11, 14, 14, 696701)},
#  {'STATE': 'CPT_Panel',
#   'CREATION_DT': datetime.datetime(2020, 9, 16, 8, 9, 2, 336)},
#  {'STATE': 'Credentialling',
#   'CREATION_DT': datetime.datetime(2020, 4, 30, 9, 47, 46, 614876)},
#  {'STATE': 'DataGov',
#   'CREATION_DT': datetime.datetime(2021, 3, 10, 11, 16, 42, 634539)},
#  {'STATE': 'DataGov.csv',
#   'CREATION_DT': datetime.datetime(2021, 3, 15, 11, 13, 49, 132056)},
#  {'STATE': 'DEA',
#   'CREATION_DT': datetime.datetime(2020, 12, 17, 9, 35, 47, 554975)},
#  {'STATE': 'DHC',
#   'CREATION_DT': datetime.datetime(2020, 3, 9, 11, 21, 1, 224664)},
#  {'STATE': 'Email',
#   'CREATION_DT': datetime.datetime(2020, 3, 5, 9, 1, 43, 554499)},
#  {'STATE': 'Full Source Files - August',
#   'CREATION_DT': datetime.datetime(2021, 8, 2, 13, 49, 46, 708081)},
#  {'STATE': 'Full Source Files - MD Active Type Fixed.txt',
#   'CREATION_DT': datetime.datetime(2021, 8, 2, 13, 56, 22, 515495)},
#  {'STATE': 'Gap_Analysis',
#   'CREATION_DT': datetime.datetime(2021, 7, 21, 11, 3, 28, 535087)},
#  {'STATE': 'geocodes.xlsb.xlsx',
#   'CREATION_DT': datetime.datetime(2021, 4, 16, 10, 54, 38, 947196)},
#  {'STATE': 'geocodes.xlsx',
#   'CREATION_DT': datetime.datetime(2020, 12, 21, 11, 59, 0, 351939)},
#  {'STATE': 'GetPhone',
#   'CREATION_DT': datetime.datetime(2020, 5, 14, 20, 20, 54, 555761)},
#  {'STATE': 'Google',
#   'CREATION_DT': datetime.datetime(2020, 5, 14, 20, 20, 59, 388524)},
#  {'STATE': 'HealthPlans',
#   'CREATION_DT': datetime.datetime(2020, 4, 15, 9, 8, 1, 3617)},
#  {'STATE': 'Humach',
#   'CREATION_DT': datetime.datetime(2020, 3, 4, 15, 6, 16, 574331)},
#  {'STATE': 'IQVia',
#   'CREATION_DT': datetime.datetime(2022, 1, 25, 8, 30, 5, 438510)},
#  {'STATE': 'License',
#   'CREATION_DT': datetime.datetime(2020, 7, 21, 13, 21, 38, 844620)},
#  {'STATE': 'Martketing',
#   'CREATION_DT': datetime.datetime(2020, 3, 3, 9, 29, 23, 136617)},
#  {'STATE': 'MasterfileCore',
#   'CREATION_DT': datetime.datetime(2020, 7, 16, 15, 17, 51, 155893)},
#  {'STATE': 'MD Active.xlsx',
#   'CREATION_DT': datetime.datetime(2021, 8, 2, 13, 48, 37, 500548)},
#  {'STATE': 'Measurement',
#   'CREATION_DT': datetime.datetime(2022, 2, 22, 10, 50, 51, 860035)},
#  {'STATE': 'Medscape',
#   'CREATION_DT': datetime.datetime(2020, 4, 7, 11, 25, 32, 919955)},
#  {'STATE': 'Medscape2020-05-14',
#   'CREATION_DT': datetime.datetime(2020, 5, 14, 14, 41, 8, 242152)},
#  {'STATE': 'Medscape2020-07-01',
#   'CREATION_DT': datetime.datetime(2020, 7, 1, 9, 45, 1, 589795)},
#  {'STATE': 'Misc',
#   'CREATION_DT': datetime.datetime(2022, 2, 1, 16, 21, 32, 336998)},
#  {'STATE': 'NC_License_Status_2020-09-12.xlsx',
#   'CREATION_DT': datetime.datetime(2020, 9, 14, 7, 57, 21, 959779)},
#  {'STATE': 'NC_License_Status_2021-01-09.xlsx',
#   'CREATION_DT': datetime.datetime(2021, 1, 11, 8, 7, 26, 395110)},
#  {'STATE': 'NC_License_Status_2021-08-06.csv',
#   'CREATION_DT': datetime.datetime(2021, 8, 6, 16, 37, 0, 919709)},
#  {'STATE': 'New_Products',
#   'CREATION_DT': datetime.datetime(2021, 6, 1, 11, 13, 3, 278071)},
#  {'STATE': 'NPI',
#   'CREATION_DT': datetime.datetime(2020, 3, 4, 10, 19, 20, 368979)},
#  {'STATE': 'OLD_FILES',
#   'CREATION_DT': datetime.datetime(2022, 6, 6, 16, 45, 12, 315512)},
#  {'STATE': 'OneView_Testing',
#   'CREATION_DT': datetime.datetime(2021, 10, 12, 16, 42, 38, 465575)},
#  {'STATE': 'OneView_Testing.csv',
#   'CREATION_DT': datetime.datetime(2021, 10, 12, 16, 43, 7, 289167)},
#  {'STATE': 'Osteopathic_Counts_2021.xlsx',
#   'CREATION_DT': datetime.datetime(2022, 1, 4, 15, 24, 17, 292776)},
#  {'STATE': 'PhoneAppend',
#   'CREATION_DT': datetime.datetime(2021, 3, 29, 10, 52, 55, 584219)},
#  {'STATE': 'PhoneAppend.csv',
#   'CREATION_DT': datetime.datetime(2021, 4, 2, 9, 3, 18, 775810)},
#  {'STATE': 'POLO_Filter',
#   'CREATION_DT': datetime.datetime(2021, 5, 13, 9, 13, 47, 113396)},
#  {'STATE': 'POLO_Filter_older_matches.csv',
#   'CREATION_DT': datetime.datetime(2021, 6, 14, 13, 55, 17, 413465)},
#  {'STATE': 'PPD',
#   'CREATION_DT': datetime.datetime(2020, 3, 4, 14, 58, 45, 849812)},
#  {'STATE': 'ppd_sampl.csv',
#   'CREATION_DT': datetime.datetime(2021, 1, 14, 7, 40, 36, 524622)},
#  {'STATE': 'ppd_sample_2.csv',
#   'CREATION_DT': datetime.datetime(2021, 1, 14, 23, 37, 5, 505157)},
#  {'STATE': 'Regina_Chennault.csv',
#   'CREATION_DT': datetime.datetime(2022, 1, 19, 18, 51, 11, 778857)},
#  {'STATE': 'Results',
#   'CREATION_DT': datetime.datetime(2020, 3, 10, 11, 13, 39, 206348)},
#  {'STATE': 'Rosters',
#   'CREATION_DT': datetime.datetime(2020, 4, 17, 8, 31, 36, 83396)},
#  {'STATE': 'Sales_Ops',
#   'CREATION_DT': datetime.datetime(2020, 8, 18, 8, 19, 28, 719033)},
#  {'STATE': 'Scorecard',
#   'CREATION_DT': datetime.datetime(2020, 3, 4, 15, 40, 49, 553990)},
#  {'STATE': 'Scorecardoutput.xlsx',
#   'CREATION_DT': datetime.datetime(2020, 5, 20, 13, 16, 24, 598229)},
#  {'STATE': 'SFMC',
#   'CREATION_DT': datetime.datetime(2020, 5, 4, 12, 6, 53, 877959)},
#  {'STATE': 'SRS',
#   'CREATION_DT': datetime.datetime(2020, 9, 16, 13, 26, 57, 648297)},
#  {'STATE': 'SRSSchool_List_2021-07-27.txt',
#   'CREATION_DT': datetime.datetime(2021, 7, 27, 13, 55, 29, 17824)},
#  {'STATE': 'SRSSchool_List_2021-08-23.txt',
#   'CREATION_DT': datetime.datetime(2021, 8, 23, 8, 44, 38, 877978)},
#  {'STATE': 'SRSSchool_List_2021-10-26.txt',
#   'CREATION_DT': datetime.datetime(2021, 10, 26, 11, 1, 35, 380503)},
#  {'STATE': 'SRSSchool_List_2021-11-30.txt',
#   'CREATION_DT': datetime.datetime(2021, 11, 30, 9, 11, 5, 4713)},
#  {'STATE': 'SRSSchool_List_2022-01-06.txt',
#   'CREATION_DT': datetime.datetime(2022, 1, 6, 9, 37, 25, 374706)},
#  {'STATE': 'SRSSchool_List_2022-01-28.txt',
#   'CREATION_DT': datetime.datetime(2022, 1, 28, 8, 9, 37, 756405)},
#  {'STATE': 'SRSSchool_List_2022-03-03.txt',
#   'CREATION_DT': datetime.datetime(2022, 3, 3, 8, 53, 28, 725021)},
#  {'STATE': 'SRSSchool_List_2022-03-29.txt',
#   'CREATION_DT': datetime.datetime(2022, 3, 29, 13, 1, 29, 751375)},
#  {'STATE': 'SRSSchool_List_2022-05-02.txt',
#   'CREATION_DT': datetime.datetime(2022, 5, 2, 12, 43, 40, 697885)},
#  {'STATE': 'SRSSchool_List_2022-06-01.txt',
#   'CREATION_DT': datetime.datetime(2022, 6, 1, 14, 21, 13, 953062)},
#  {'STATE': 'SRSSchool_List_2022-06-28.txt',
#   'CREATION_DT': datetime.datetime(2022, 6, 28, 11, 12, 55, 557396)},
#  {'STATE': 'SRSSchool_List_2022-07-27.txt',
#   'CREATION_DT': datetime.datetime(2022, 7, 27, 8, 3, 24, 11261)},
#  {'STATE': 'SRSSRS_Scraped_New_2021-07-27.csv',
#   'CREATION_DT': datetime.datetime(2021, 7, 27, 15, 57, 30, 430554)},
#  {'STATE': 'SRS_Scrape_2021-06-03.csv',
#   'CREATION_DT': datetime.datetime(2021, 6, 3, 8, 8, 59, 690046)},
#  {'STATE': 'SRS_Scrape_2021-09-27.xlsx',
#   'CREATION_DT': datetime.datetime(2021, 9, 27, 16, 0, 5, 228302)},
#  {'STATE': 'Triangulation',
#   'CREATION_DT': datetime.datetime(2020, 5, 14, 20, 20, 49, 343811)},
#  {'STATE': 'Undeliverable_POLOs_220509.xlsx',
#   'CREATION_DT': datetime.datetime(2022, 5, 17, 8, 31, 31, 902584)},
#  {'STATE': 'Unverified_DEA_Sourced_POLOs.xlsx',
#   'CREATION_DT': datetime.datetime(2022, 2, 8, 14, 27, 51, 540742)},
#  {'STATE': 'v-Masterfile-Scorecard-August_2020-09-15.xlsx',
#   'CREATION_DT': datetime.datetime(2020, 9, 15, 13, 3, 55, 677858)},
#  {'STATE': 'v-Masterfile-Scorecard-August_2020-09-16.xlsx',
#   'CREATION_DT': datetime.datetime(2020, 9, 16, 12, 34, 28, 905391)},
#  {'STATE': 'v-Masterfile-Scorecard-August_2020-09-18.xlsx',
#   'CREATION_DT': datetime.datetime(2020, 9, 18, 9, 58, 10, 43664)},
#  {'STATE': 'ValidationSurvey',
#   'CREATION_DT': datetime.datetime(2021, 11, 9, 10, 4, 52, 800700)},
#  {'STATE': 'with_iqvia.xlsx',
#   'CREATION_DT': datetime.datetime(2022, 5, 17, 8, 32, 46, 461624)},
#  {'STATE': 'wordcloud.png',
#   'CREATION_DT': datetime.datetime(2022, 2, 1, 16, 14, 32, 810173)},
#  {'STATE': '~$Osteopathic_Counts_2021.xlsx',
#   'CREATION_DT': datetime.datetime(2022, 2, 11, 7, 39, 40, 780780)}]
