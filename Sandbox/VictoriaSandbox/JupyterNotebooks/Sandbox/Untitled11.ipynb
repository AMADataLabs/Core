# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vigrose\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vigrose\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\vigrose\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-60bc3c174852> in <module>
#       7 nltk.download('averaged_perceptron_tagger')
#       8 from PIL import Image
# ----> 9 from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#      10 from nltk.corpus import stopwords
# ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vigrose\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vigrose\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\vigrose\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt

from wordcloud import WordCloud

# %%
rotten_urls=['https://www.rottentomatoes.com/m/interstellar_2014/reviews?type=&sort=']*23

# %%
page=2
while (page<=23):
    url_pos = page-1
    rotten_urls[url_pos] = rotten_urls[url_pos]+'&page='+ str(page)
    page = page + 1

# %%
response = requests.get('https://www.rottentomatoes.com/m/interstellar_2014/reviews?')
soup = BeautifulSoup(response.content, 'html.parser')
soup

# %%
rotten_urls[1]

# %%
soup.find('class'='the_review')

# %%
reviews=[]
for url in rotten_urls:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    page_soup = soup(page_html,"html.parser")
    reviews = reviews + [review.text for review in page_soup.find_all("div", {"class": "the_review"})]

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
from selenium.webdriver.common.by import By

# %%
from driver_test import get_site

# %%
def wait(browser):
    return WebDriverWait(browser, 60)

# %%
driver = webdriver.Chrome(executable_path='C:/Users/vigrose/Jupyter Notebooks/chromedriver.exe')

# %%
driver.get('https://www.rottentomatoes.com/m/interstellar_2014/reviews')

# %%
reviews = driver.find_elements(By.CLASS_NAME, 'the_review')
reviews[0].text
# Out:
# 'The inherent message of the film brings hope, but it can definitely get waterlogged by intellectual speak and long-winded scenes.'

# %%
audience_review_list = []

# %%
testy = driver.find_elements(By.CLASS_NAME, 'review_icon')

# %%
<div class="review_icon icon small fresh">
            
        </div>

# %%
gah = []
for icon in testy:
    gah.append(icon.get_attribute('class'))

# %%
[x.split(' ')[-1] for x in gah]
# Out:
# ['fresh',
#  'fresh',
#  'fresh',
#  'rotten',
#  'fresh',
#  'fresh',
#  'fresh',
#  'rotten',
#  'fresh',
#  'fresh',
#  'fresh',
#  'fresh',
#  'fresh',
#  'fresh',
#  'fresh',
#  'rotten',
#  'fresh',
#  'rotten',
#  'fresh',
#  'fresh']

# %%
import time

# %%
gah = []

# %%
for i in list(range(1,30)):
    review_1 = wait(driver).until(presence_of_element_located((By.CLASS_NAME, 'review_icon')))
    testy = driver.find_elements(By.CLASS_NAME, 'review_icon')
    for icon in testy:
        gah.append(icon.get_attribute('class'))
    time.sleep(2)
    button_xpath = '//*[@id="content"]/div/div/div/nav[1]/button[2]'
    button = driver.find_element(By.XPATH, button_xpath)
    button.click()
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-128-b5618ce5b033> in <module>
#       7     button_xpath = '//*[@id="content"]/div/div/div/nav[1]/button[2]'
#       8     button = driver.find_element(By.XPATH, button_xpath)
# ----> 9     button.click()
#      10     time.sleep(2)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
# ...

# %%
fresh_list = [x.split(' ')[-1] for x in gah]

# %%
fresh_list[:10]
# Out:
# ['fresh',
#  'fresh',
#  'fresh',
#  'rotten',
#  'fresh',
#  'fresh',
#  'fresh',
#  'rotten',
#  'fresh',
#  'fresh']

# %%
review_df = pd.DataFrame(review_list).drop_duplicates()

# %%
review_df = review_df.rename(columns = {0:'REVIEW'})

# %%
review_df['JUDGEMENT']=fresh_list

# %%
for i in list(range(1,30)):
    review_1 = wait(driver).until(presence_of_element_located((By.CLASS_NAME, 'the_review')))
    reviews = driver.find_elements(By.CLASS_NAME, 'the_review')
    for review in reviews:
        review_list.append(review.text)
    button_xpath = '//*[@id="content"]/div/div/div/nav[1]/button[2]'
    button = driver.find_element(By.XPATH, button_xpath)
    button.click()
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-31-454d42c8955f> in <module>
#       1 for i in list(range(1,30)):
# ----> 2     review_1 = wait(driver).until(presence_of_element_located((By.CLASS_NAME, 'the_review')))
#       3     reviews = driver.find_elements(By.CLASS_NAME, 'the_review')
#       4     for review in reviews:
#       5         audience_review_list.append(review.text)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\support\wait.py in until(self, method, message)
#      78             if time.time() > end_time:
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#      82     def until_not(self, method, message=''):
#
# TimeoutException: Message:

# %%
for i in list(range(1,30)):
    class_ = "audience-reviews__review js-review-text clamp clamp-8 js-clamp"
    review_1 = wait(driver).until(presence_of_element_located((By.CLASS_NAME, class_)))
    reviews = driver.find_elements(By.CLASS_NAME, class_)
    for review in reviews:
        review_list.append(review.text)
    button_xpath = '//*[@id="content"]/div/div/div/nav[1]/button[2]'
    button = driver.find_element(By.XPATH, button_xpath)
    button.click()
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-33-01cf5b145147> in <module>
#       1 for i in list(range(1,30)):
#       2     class_ = "audience-reviews__review js-review-text clamp clamp-8 js-clamp"
# ----> 3     review_1 = wait(driver).until(presence_of_element_located((By.CLASS_NAME, class_)))
#       4     reviews = driver.find_elements(By.CLASS_NAME, class_)
#       5     for review in reviews:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\support\wait.py in until(self, method, message)
#      78             if time.time() > end_time:
#      79                 break
# ---> 80         raise TimeoutException(message, screen, stacktrace)
#      81
#      82     def until_not(self, method, message=''):
#
# TimeoutException: Message:

# %%
//*[@id="movieUserReviewsContent"]/ul/li[2]/div[2]/p[1]
<p class="audience-reviews__review js-review-text clamp clamp-8 js-clamp" data-qa="review-text">i couldnt finish this film as something was off something wasnt sitting right with me i mean i wasnt that happy with the story but i liked everything else but still i feel like as if there is something that needs to be done but i cant put my finger on what it is.</p>

# %%
review_list_2 = []

# %%
for i in list(range(1,30)):
    review_1 = wait(driver).until(presence_of_element_located((By.CLASS_NAME, 'the_review')))
    reviews = driver.find_elements(By.CLASS_NAME, 'the_review')
    for review in reviews:
        review_list_2.append(review.text)
    button_xpath = '//*[@id="content"]/div/div/div/nav[1]/button[2]'
    button = driver.find_element(By.XPATH, button_xpath)
    button.click()
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-82-952d82697538> in <module>
#       6     button_xpath = '//*[@id="content"]/div/div/div/nav[1]/button[2]'
#       7     button = driver.find_element(By.XPATH, button_xpath)
# ----> 8     button.click()
#       9     time.sleep(2)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
# ...

# %%
good_reviews = list(sharks[sharks.JUDGEMENT=='fresh'].REVIEW)

# %%
current_release_info = wait(driver).until(presence_of_element_located((By.XPATH, release_xpath))).text

# %%
pd.DataFrame(review_list).to_csv('../../Data/Misc/Interstellar_Reviews.csv', index=False)

# %%
text = ''
for review in review_list:
    text+=' ' + review

# %%
text = text.replace('Nolan','').replace('Christopher','').replace('Interstellar','').replace('movie','').replace('film','')

# %%
# #Importing Dataset
# df = pd.read_csv("android-games.csv")
# #Checking the Data
# df.head()
# #Checking for NaN values
# df.isna().sum()
# #Removing NaN Values
# #df.dropna(inplace = True)
# #Creating the text variable
# text = " ".join(cat.split()[1] for cat in df.category)
# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(all_summary)
# Display the generated Word Cloud

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
stop_words=set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
stop_words.append('christopher')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-5af13e4732bd> in <module>
# ----> 1 stop_words.append('christopher')
#
# AttributeError: 'set' object has no attribute 'append'

# %%
bad_reviews
# Out:
# ['Audiences are sure to lose their suspensions of disbelief over the nearly impenetrable climax.',
#  "None of these characters feel fully-fledged... for a film so rife with schmaltzy musings on the meaning of life, it's alarming how lacking it is in this department.",
#  'Interstellar is 120 minutes of good movie stuffed into 170 minutes.',
#  'Overall, Interstellar looks nice but ultimately lacks substance. Nolan essentially loses his way by going to space.',
#  'Preposterous, pseudointellectual, poorly constructed, clichéd, impenetrably masculine, goofy and possessed of an indecipherable ending, Interstellar is the mother of all misfires.',
#  'A contrived science fiction film without authenticity, emotionally and narratively.',
#  "Literally reaches for the stars -- and comes up short. Despite the best efforts of a talented cast and writer/director Christopher Nolan, this film just can't overcome a script with black hole-size plot craters.",
# ...

# %%
word_tokens=[]
for review in good_reviews:
    word_tokens=word_tokens+word_tokenize(review)

filtered_word_3 = [w for w in word_tokens if not w in stop_words]

# %%
all_summary_3 = " ".join(s for s in filtered_word_3)

# %%
all_summary_3 = all_summary_3.replace('Nolan','').replace('Christopher','').replace('Interstellar','').replace('movie','').replace('film','').replace("'s",'').replace('director','').replace("n't",'')

# %%
word_cloud.to_file("../../Data/wordcloud.png")

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()

plt.imshow(wordcloud);

# %%
adjs=[word for (word,pos) in nltk.pos_tag(filtered_word_3)if(pos[:2]== 'JJ')]
print(adjs)
palavras = " ".join(s for s in adjs)
# Out:
# ['hilarious', 'best', 'bloody', 'good', 'bad', 'good', 'terrible', 'fine', 'stupid', 'like', 'worth', 'sure', 'easy', 'possible', 'take', 'whole', 'fabulous', 'in-home', 'cheesy', 'humorous', 'social', 'puts', 'skip', 'lucky', 'list', 'hysterical', 'brainless', 'well-spent', 'perfect', 'pop', 'ever-popular', 'shark-as-adversary', 'awesome', 'immersive', 'ludicrous', 'draw', 'looky-lous', 'dumb', 'outrageous']

# %%
all_summary_3 = all_summary_3.replace("'s",'').replace("n't",'').replace(" s ",'')

# %%
wordcloud = WordCloud(background_color="white").generate(palavras)
# mostrar a imagem final
fig, ax = plt.subplots(figsize=(20,15))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()

plt.imshow(wordcloud)

# %%
wordcloud.to_file("wordcloud_good_sharks_adjectives.png")

# %%
len(review_list_2)
# Out:
# 19

# %%
all_summary = all_summary.replace("n't",'').replace(" s ",'').replace("one",'')

# %%
review_df.to_csv('../../Data/Misc/InterstellarReviews.csv', index=False)

# %%
len(review_list_2)
# Out:
# 19

# %%
fresh_2 = ['rotten','rotten','fresh','fresh','fresh','rotten','rotten','fresh','fresh','fresh','fresh','fresh','fresh','fresh','fresh','fresh','fresh','rotten','fresh']

# %%
sharks = pd.DataFrame({'REVIEW':review_list_2,'JUDGEMENT':fresh_2})

# %%
sharks.to_csv('../../Data/Misc/SharknadoReviews.csv', index=False)

# %%
len(fresh_list)
# Out:
# 368
