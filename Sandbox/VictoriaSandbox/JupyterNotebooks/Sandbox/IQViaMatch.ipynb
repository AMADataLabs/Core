# %%
import pandas as pd
import pyodbc

# %%
username = 'vigrose'
password = 'Gryffindor~10946'
q = "DSN=eprdods; UID={}; PWD={}".format(username, password)
ODS = pyodbc.connect(q)

# %%
new_file = pd.read_csv('../../Data/DataGov/DAC_NationalDownloadableFile_210326.csv')
ppd = pd.read_csv('../../Data/PPD/ppd_data_20210410.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (14,15,17,25,29,31,33,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,20,42,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
iqvia_query =   """ 
        SELECT DISTINCT 
        B.BUSINESS_NAME,
        B.DBA_NAME,
        B.PHONE,
        B.PHYSICAL_ADDR_1,
        B.PHYSICAL_ADDR_2,
        B.PHYSICAL_CITY,
        B.PHYSICAL_STATE,
        B.PHYSICAL_ZIP,
        B.POSTAL_ADDR_1,
        B.POSTAL_ADDR_2,
        B.POSTAL_CITY,
        B.POSTAL_STATE,
        B.POSTAL_ZIP,
        P.ME,
        T.AFFIL_TYPE_DESC,
        A.AFFIL_IND,
        A.AFFIL_RANK
        FROM 
        ODS.ODS_IMS_BUSINESS B, ODS.SAS_ODS_IMS_PROVIDER_AFFIL A, ODS.ODS_IMS_PROFESSIONAL P, ODS.ODS_IMS_AFFILIATION_TYPE T
        WHERE  
        B.IMS_ORG_ID = A.IMS_ORG_ID
        AND
        A.PROFESSIONAL_ID = P.PROFESSIONAL_ID
        AND
        A.AFFIL_TYPE_ID = T.AFFIL_TYPE_ID
        AND
        P.CURRENT_BATCH_FLAG='Y'
        AND
        A.CURRENT_BATCH_FLAG='Y'
        AND
        B.CURRENT_BATCH_FLAG='Y'
        """

# %%
iqvia = pd.read_sql(con=ODS, sql=iqvia_query)
iqvia.head()
# Out:
#                            BUSINESS_NAME  \
# 0  SOUTH BALDWIN REGIONAL MEDICAL CENTER
# 1                   LARGO MEDICAL CENTER
# 2             MISSION HEALTH SYSTEM, INC
# 3                         MISSION HEALTH
# 4       BANNER DEL E WEBB MEDICAL CENTER
#
#                                DBA_NAME           PHONE      PHYSICAL_ADDR_1  \
# 0                                  None  2519493400       1613 N MCKENZIE ST
# 1                                  None  7275885200           201 14TH ST SW
# 2  MISSION HOSPITAL SAINT JOSEPH CAMPUS  8282131111         428 BILTMORE AVE
# 3      MISSION HOSPITAL MEMORIAL CAMPUS  8282131111         509 BILTMORE AVE
# 4                                  None  6235244000      14502 W MEEKER BLVD
#
#   PHYSICAL_ADDR_2  PHYSICAL_CITY PHYSICAL_STATE     PHYSICAL_ZIP  \
# 0            None          FOLEY             AL  36535-2247
# 1            None          LARGO             FL  33770-3133
# 2            None      ASHEVILLE             NC  28801-4502
# 3            None      ASHEVILLE             NC  28801-4601
# 4            None  SUN CITY WEST             AZ  85375-5282
#
#          POSTAL_ADDR_1 POSTAL_ADDR_2    POSTAL_CITY POSTAL_STATE  \
# 0   1613 N MCKENZIE ST          None          FOLEY           AL
# 1       201 14TH ST SW          None          LARGO           FL
# 2     428 BILTMORE AVE          None      ASHEVILLE           NC
# 3     509 BILTMORE AVE          None      ASHEVILLE           NC
# 4  14502 W MEEKER BLVD          None  SUN CITY WEST           AZ
#
#         POSTAL_ZIP          ME AFFIL_TYPE_DESC AFFIL_IND  AFFIL_RANK
# 0  36535-2247       0010200001       Admitting         A           6
# 1  33770-3133       0010200001       Admitting         A           6
# 2  28801-4502       0010200003       Admitting         A           6
# 3  28801-4601       0010200003       Admitting         A           6
# 4  85375-5282       0010200004       Attending         P          10

# %%
NEW_FILE.

# %%
pd.merge(new_file, ppd, on='NPI')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-441deb2f6a17> in <module>
# ----> 1 pd.merge(new_file, ppd, on='NPI')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     624             self.right_join_keys,
#     625             self.join_names,
# --> 626         ) = self._get_merge_keys()
#     627
#     628         # validate the merge keys dtypes. We may need to coerce
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     973                     if not is_rkey(rk):
#     974                         if rk is not None:
# --> 975                             right_keys.append(right._get_label_or_level_values(rk))
#     976                         else:
#     977                             # work-around for merge_asof(right_index=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'NPI'
