# %%
import pandas as pd
import useful_functions as use
import datacompy

# %%
race_1 = pd.read_csv('../../Data/MasterfileCore/PhysicianRaceEthnicity_2_2022-02-01.csv')
race_2 = pd.read_csv('../../Data/MasterfileCore/PhysicianRaceEthnicity_2_2022-03-01.csv')

# %%
race_compare = datacompy.Compare(race_1, race_2, join_columns='medical_education_number', df1_name = 'February', df2_name = 'March')

# %%
print(race_compare.report())
# Out:
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns     Rows
# 0  February        2  1724938
# 1     March        2  1725249
#
# Column Summary
# --------------
#
# Number of columns in common: 2
# Number of columns in February but not in March: 0
# Number of columns in March but not in February: 0
#
# Row Summary
# -----------
#
# Matched on: medical_education_number
# Any duplicates on match values: No
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 1,724,938
# Number of rows in February but not in March: 0
# Number of rows in March but not in February: 311
#
# Number of rows with some compared columns unequal: 105
# Number of rows with all compared columns equal: 1,724,833
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 1
# Number of columns compared with all values equal: 1
# Total number of values which compare unequal: 105
#
# ...

# %%
race_compare.sample_mismatch(column="race_ethnicity", sample_count=106)
# Out:
#          medical_education_number    race_ethnicity_df1  \
# 1675474                 102170903    Tribal Affiliation
# 1675450                3503171375    Tribal Affiliation
# 1675471                3901170940    Tribal Affiliation
# 1675500                4101171863    Tribal Affiliation
# 1724574                3401170838  Mixed Race/Ethnicity
# ...                           ...                   ...
# 1675468                3605171060    Tribal Affiliation
# 1675486                 702170648    Tribal Affiliation
# 1724567                3845170818  Mixed Race/Ethnicity
# 1675460                3901171300    Tribal Affiliation
# 1675502                 702171466    Tribal Affiliation
#
#                         race_ethnicity_df2
# 1675474  American Indian or Alaskan Native
# 1675450  American Indian or Alaskan Native
# 1675471  American Indian or Alaskan Native
# 1675500  American Indian or Alaskan Native
# 1724574  American Indian or Alaskan Native
# ...

# %%
product_compare.sample_mismatch(column="description", sample_count=315)

# %%
ppd = use.get_ppd()
# Out:
# INFO:useful_functions:PPD file from Feb 19 2022
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (13,14,20,21,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
ppd[~ppd.NO_CONTACT_IND.isna()]
# Out:
#                   ME RECORD_ID  UPDATE_TYPE  ADDRESS_TYPE  \
# 61       00102000650         A            1           1.0
# 125      00102001869         A            1           2.0
# 160      00102010060         A            1           1.0
# 197      00102010442         A            1           2.0
# 211      00102010582         A            1           2.0
# ...              ...       ...          ...           ...
# 1308214  95707980037         A            1           2.0
# 1308318  95708870049         A            1           1.0
# 1308377  95708930033         A            1           2.0
# 1308476  96501770059         A            1           2.0
# 1308503  96501830051         A            1           2.0
#
#                       MAILING_NAME   LAST_NAME   FIRST_NAME MIDDLE_NAME  \
# 61               DAVID I GAINES MD      GAINES        DAVID       ISAAC
# 125               RONALD M ROAN MD        ROAN       RONALD      MCCUEN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-69381186b16a> in <module>
# ----> 1 ppd.columns
#
# NameError: name 'ppd' is not defined
