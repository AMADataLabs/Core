# %%
import pandas as pd
import useful_functions as use

# %%
old = pd.read_csv('../../Data/DHC/DHC_2021-11.csv')
new = pd.read_csv('../../Data/DHC/DHC_2022-04.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(new) - len(old)
# Out:
# 1557608

# %%
new[new.ME.isna()]
# Out:
#                 NPI  ME Additional Office Locations  Phone Number Zip Code  \
# 921728   1619503406 NaN                         NaN           NaN    99508
# 921729   1538713482 NaN                         NaN           NaN    85015
# 921730   1356428510 NaN                         NaN           NaN    85381
# 921731   1780658039 NaN                         NaN           NaN    85022
# 921732   1740741867 NaN                         NaN           NaN    72202
# ...             ...  ..                         ...           ...      ...
# 2458469  1407808728 NaN                         NaN  509.701.4231    99163
# 2458470  1821142738 NaN                         NaN  360.816.0277    98683
# 2458471  1295847002 NaN                         NaN  414.476.8183    53226
# 2458472  1275147704 NaN                         NaN           NaN    98520
# 2458473  1275086548 NaN                         NaN  608.263.8100    53792
#
#         State         City                    Address First Name  \
# 921728     AK    Anchorage             4020 Folker St    Faitupe
# 921729     AZ      Phoenix     1607 W Bethany Home Rd     Rooney
# 921730     AZ       Peoria      7616 W Thunderbird Rd      Bruce
# 921731     AZ      Phoenix              706 E Bell Rd  Alexandre
# 921732     AR  Little Rock            1 Childrens Way     Lauren
# ...       ...          ...                        ...        ...
# 2458469    WA      Pullman             252 Brayton Rd    Lennard
# 2458470    WA    Vancouver  406 Se 131st Ave Ste C305       Lisa
# 2458471    WI    Wauwatosa          2525 N Mayfair Rd       Marc
# 2458472    WA     Aberdeen                1006 N H St     Rachel
# 2458473    WI      Madison           600 Highland Ave    Michael
#
#           Physician Name    Middle Name  \
# 921728     Faitupe A'asa              M
# 921729       Rooney Aago  Batrus Yousif
# 921730     Bruce Aahrens         Thomas
# 921731   Alexandre Aalam            NaN
# 921732     Lauren Aamoth       Michelle
# ...                  ...            ...
# 2458469  Lennard Zylstra              P
# 2458470     Lisa Zylstra              D
# 2458471     Marc Zylstra              W
# 2458472     Rachel Zynda              C
# 2458473  Michael Zywicki        Francis
#
#                                        Primary Specialty  \
# 921728                                             Other
# 921729                                             Other
# 921730                                             Other
# 921731                                             Other
# 921732                                             Other
# ...                                                  ...
# 2458469  Social Worker - Licensed Clinical Social Worker
# 2458470                              Physician Assistant
# 2458471               Psychology - Clinical Psychologist
# 2458472                     Therapy - Physical Therapist
# 2458473                       Nurse - Nurse Practitioner
#
#                               Primary Hospital Affiliation Last Name Address1
# 921728                                                 NaN     A'asa      NaN
# 921729                                                 NaN      Aago      NaN
# 921730                                                 NaN   Aahrens      NaN
# 921731                                                 NaN     Aalam      NaN
# 921732                                                 NaN    Aamoth      NaN
# ...                                                    ...       ...      ...
# 2458469  Walla Walla VA Medical Center (AKA Jonathan Wa...   Zylstra      NaN
# 2458470  PeaceHealth Southwest Medical Center (Vancouve...   Zylstra      NaN
# 2458471                                                NaN   Zylstra      #80
# 2458472  Harbor Regional Health Community Hospital (FKA...     Zynda      NaN
# 2458473                                                NaN   Zywicki      NaN
#
# [1536746 rows x 15 columns]

# %%
old[old.ME.isna()]
# Out:
# Empty DataFrame
# Columns: [Additional_Office_Locations, Phone_Number, Zip_Code, State, City, Address, First_Name, Physician_Name, Middle_Name, Primary_Specialty, NPI, Primary_Hospital_Affiliation, Last_Name, Address1, ME]
# Index: []

# %%
npi_phones = pd.read_csv('../../Data/NPI/NPI_PHONES_TO_TRIANGULATE_041922.csv')
npi_phones['ME'] = use.fix_me(npi_phones.medical_education_number)
npi_phones['IQVIA_ME'] = [x[0:10] for x in npi_phones.ME]
npi_phones['PHONE_NPI'] = [use.fix_phone(x) for x in npi_phones.PHONE]
npi_phones.head()
# Out:
#    medical_education_number       PHONE SOURCE           ME    IQVIA_ME  \
# 0                 102000323  4783014111      B  00102000323  0010200032
# 1                 102000439  2655355972      B  00102000439  0010200043
# 2                 102000510  8038029488      B  00102000510  0010200051
# 3                 102000561  4178310150      B  00102000561  0010200056
# 4                 102000676  3032864560      B  00102000676  0010200067
#
#     PHONE_NPI
# 0  4783014111
# 1  2655355972
# 2  8038029488
# 3  4178310150
# 4  3032864560

# %%
testing = list(npi_phones[npi_phones.SOURCE!='B'].ME)

# %%
npi_phones[npi_phones.ME.isin(testing)]
# Out:
#        medical_education_number       PHONE SOURCE           ME    IQVIA_ME  \
# 12115                1611152228  7737021150      M  01611152228  0161115222
# 15160                1803000359  3192353697      M  01803000359  0180300035
# 17445                2012710774  3864923243      M  02012710774  0201271077
# 23722                2512160908  8592124700      M  02512160908  0251216090
# 36031                3575980201  8567166598      M  03575980201  0357598020
# 43867                4113780288  4073037283      M  04113780288  0411378028
# 45716                4178181209  7195957585      M  04178181209  0417818120
# 58170               13002171095  9259170964      M  13002171095  1300217109
# 64267               49521020694  9898391644      M  49521020694  4952102069
# 76211               91504120118  8573181460      M  91504120118  9150412011
#
#         PHONE_NPI
# 12115  7737021150
# 15160  3192353697
# 17445  3864923243
# 23722  8592124700
# 36031  8567166598
# 43867  4073037283
# 45716  7195957585
# 58170  9259170964
# 64267  9898391644
# 76211  8573181460
