# %%
import pandas as pd
import pyodbc
from fuzzywuzzy import fuzz
import datetime as dt
from nameparser import HumanName

# %%
#PPD Directory
PPD = pd.read_csv('../../Data/PPD/ppd_data_20200404.csv')

#Out Directory
medscape = pd.read_csv('../../Data/Medscape/2020-07-01/Memorium_USA_2020-07-01.csv')
twitter = pd.read_csv('../../Data/Medscape/2020-07-01/Twitter_Doctors_2020-07-01.csv')
heroes = pd.read_excel('../../Data/Medscape/2020-07-01/Heroes_Physicians_2020-07-01.xlsx')

#Specialty Table
SPEC_FILE = pd.read_csv('../../Data/PPD/speciality_id.csv')

# %%
def get_processed_list():
    '''Get latest processed ME list from EDW'''
    username = 'vigrose'
    password = 'Hufflepuff10946'
    sql_query = \
        """
        SELECT DISTINCT
        M.MED_EDU_NBR
        FROM
        AMAEDW.PERSON M
        WHERE
        M.MORTALITY_STS_CD ='C'
        OR
        M.MORTALITY_STS_CD ='P';
        """
    s = "DSN=PRDDW; UID={}; PWD={}".format(username, password)
    AMAEDW = pyodbc.connect(s)
    known_mortality_status = pd.read_sql(con=AMAEDW, sql=sql_query)

    processed_mes = list(known_mortality_status.MED_EDU_NBR)

    return processed_mes

def remove_processed_mes(physicians):
    '''Remove physicians whose ME numbers are already processed'''
    processed_list = get_processed_list()
    unprocessed_physicians = physicians[physicians.ME.isin(processed_list) == False]

    return unprocessed_physicians

def match_spec(ppd_df, specialty, spec_table):
    '''Checks fuzzy matching on specialty'''
    mf_spec_cd = ppd_df.iloc[0]['PRIM_SPEC_CD']
    specialty_og = specialty.title()
    specialty = specialty_og.replace('Doctor ', '')
    mf_spec = spec_table[spec_table.SPEC_CD == mf_spec_cd].iloc[0]['DESC'].title()
    specialty = specialty.replace('Primary Care', 'Family Medicine')
    specialty = specialty.replace('Ob-Gyn', 'Obstetrics & Gynecology')
    specialty = specialty.replace('Ob/Gyn', 'Obstetrics & Gynecology')
    specialty = specialty.replace('trist', 'try').replace('gist', 'gy')
    specialty = specialty.replace('eon', 'ery').replace('cian', 's')
    if mf_spec in specialty:
        return True
    elif fuzz.ratio(mf_spec, specialty) > 40:
        return True
    elif mf_spec == 'Unspecified' and 'Resident' in specialty:
        return True
    elif mf_spec == 'Unspecified':
        return True
    elif 'Physician' in specialty_og or specialty_og == 'Doctor':
        return True
    elif 'Family Medicine' in specialty_og and mf_spec == 'Pediatrics':
        return True
    else:
        return False

# %%
def fix_me(me_list):
    '''Add leading zeroes to ME numbers'''
    nums = []
    for num in me_list:
        num = str(num)
        num = num.replace('.0', '')
        if len(num) == 10:
            num = '0' + num
        elif len(num) == 9:
            num = '00' + num
        elif len(num) == 8:
            num = '000' + num
        nums.append(num)
    return nums

# %%
def split_names(roster_df):
    '''Splits name column into components'''
    roster_df = roster_df.drop_duplicates()
    dict_list = []
    for row in roster_df.itertuples():
        name_parsed = HumanName(row.NAME)
        name_dict = {
            'NAME': row.NAME,
            'FIRST_NAME': name_parsed.first.upper(),
            'LAST_NAME': name_parsed.last.upper(),
            'MIDDLE_NAME': name_parsed.middle.upper(),
            'SUFFIX': name_parsed.suffix.upper(),
            'NICKNAME': name_parsed.nickname.upper(),
            'TITLE': name_parsed.title.upper(),
        }
        dict_list.append(name_dict)
    name_df = pd.DataFrame(dict_list)
    new_df = pd.merge(name_df, roster_df, on='NAME')
    return new_df

def append_me(roster_df, spec_df):
    potential = []
    '''Matches to PPD and appends ME'''
    from_twitter = False
    if 'DATE' in roster_df.columns or 'Date' in roster_df.columns:
        from_twitter = True
        data_split = roster_df
    else:
        data_split = split_names(roster_df)

    bad_spec_words = [
        'NURS',
        'VET',
        'TRANSPORT',
        'ASSISTANT',
        'RECEPTIONIST',
        'TECHNICIAN',
        'PARAMEDIC',
        'AIDE',
        'SOCIAL WORKER',
        'ENTREPRENEUR',
        'SERVICES',
        'GROUPHOME',
        'SECURITY',
        'PHARMACIST',
        'FIRE',
        'EMPLOYEE',
        'DEVELOPER',
        'ADMINISTRATOR',
        'LEADER',
        'LPN',
        'THERAPIST',
        'CLERK',
        'COUNSELOR',
        'ATTENDANT',
        'ADMIN',
        'SUPPLY',
        'CLEAN',
        'PRIEST',
        'STAFF',
        'INVESTIGATOR',
        'MRI',
        'EDUCATOR',
        'OFFICER',
        'MAINTENANCE',
        'CNA',
        'SUPERVISOR',
        'COORDINATOR',
        'SUPERVISOR',
        'TECHNOLOGIST',
        'MECHANIC',
        'EMT'
    ]
    mes = []
    for row in data_split.itertuples():
        physician_me = 'None'
        keep = True
        if from_twitter == False:
            for word in bad_spec_words:
                if word in row.SPECIALTY.upper():
                    keep = False
#         if keep == False:
#             print('---')
#             print(row.NAME)
#             print(row.SPECIALTY)
        if keep:
            print('---')
            print(row.NAME)
            new_df = PPD[(PPD.FIRST_NAME == row.FIRST_NAME) & (PPD.LAST_NAME == row.LAST_NAME)]
            try:
                years = [2019.0 - int(row.AGE), 2020.0 - int(row.AGE)]
            except ValueError:
                years = []
                if len(new_df)>1:
                    if row.STATE == "New York":
                        new_df = new_df[new_df.POLO_STATE == 'NY']
                    elif from_twitter == False:
                        new_df = new_df[new_df.POLO_CITY == row.CITY.upper()]
                    else:
                        new_df = new_df[new_df.STATE == row.STATE]
            if len(new_df) == 0 and len(years) > 0:
                if '-' in row.LAST_NAME:
                    last = row.LAST_NAME.replace('-', ' ')
                elif ' ' in row.LAST_NAME:
                    last = row.LAST_NAME.replace(' ', '')
                else:
                    last = row.LAST_NAME.replace('J', 'G')
                    print(last)
                new_df = PPD[(PPD.LAST_NAME == last) & (PPD.BIRTH_YEAR.isin(years))]
                if len(new_df) == 0:
                    pass
                if len(new_df) > 1:
                    if from_twitter:
                        print(f'{row.NAME} potentially matched to multiple ME numbers.')
                    else:
                        new_df = new_df[new_df.CITY == row.CITY.upper()]
            elif len(new_df) > 1 and len(years) > 0:
                new_df = new_df[new_df.BIRTH_YEAR.isin(years)]
                if len(new_df) > 1 and not from_twitter:
                    new_df = new_df[new_df.CITY == row.CITY.upper()]   
            if len(new_df) == 1:
                if from_twitter:
                    physician_me = new_df.iloc[0]['ME']
                else:
                    if match_spec(new_df, row.SPECIALTY, spec_df):
                        physician_me = new_df.iloc[0]['ME']
            elif len(new_df) > 1:
                print(f'{row.NAME} potentially matched to multiple ME numbers.')
        mes.append(physician_me)
        if keep==True:
            print(physician_me)
            potential.append(row.NAME)

    data_split['ME'] = fix_me(mes)
    data_me = data_split[data_split.ME != 'None']
    return data_split, data_me, potential

# %%
ALL_MED, MED_ME, name_list = append_me(medscape, SPEC_FILE)
# Out:
# ---
# Ashraf Abdo
# General Practitioner
# 91502920371
# ---
# Nancy Ajemian
# Family Medicine
# 42201850562
# ---
# Niaz Ali
# Pediatrics
# 30810840192
# ---
# Nerissa Armesto
# Nephrology Renal Dietician Hemodialysis
# ARMESTO
# None
# ---
# Glenn Barquet
# Physician Invasive Cardiologist
# 01103970403
# ---
# Doug Bass
# Medical Director
# BASS
# None
# ---
# Joseph A. Bonjiorno
# Psychiatrist
# BONGIORNO
# 05605670093
# ---
# James Boudwin
# Family Practice Physician
# 03306800069
# ---
# Kenneth Bradshaw
# Director of Facilities (retired)
# None
# ---
# Irving Buterman
# OB-GYN
# 66001710037
# ---
# Luis Caldera-Nieves
# OB-GYN
# 04201831399
# ---
# John P. Careccia
# Chief and Training Director
# None
# ---
# Evelyn Caro
# Holy Cross Hospital
# None
# ---
# Ricardo Castaneda
# Psychiatrist
# 42901790064
# ---
# Sudheer Chauhan
# Internal Medicine Chief of Medicine
# 49541720081
# ---
# Charlie Chin Song Chen
# Family Medicine/General Practitioner
# 02878920972
# ---
# Reza Chowdhury
# Internist and Infectious Diseases Physician,Westchester Medical Healthcare
# 16004870089
# ---
# Kenneth Conte
# Family Medicine/General practitioner
# None
# ---
# Jeannie Danker
# Director of Radiology
# DANKER
# None
# ---
# Leo dela Cruz
# Geriatric Psychiatrist,Carepoint Hospital
# 74809860012
# ---
# Ernesto "Audie" DeLeon
# ADN
# None
# ---
# Elizabeth Edwards
# Phlebotomist
# None
# ---
# Norman Einhorn
# Other Optometrist Neuro Optometry
# EINHORN
# None
# ---
# Jeffrey Escher
# Physician Geriatrician
# 16501800035
# ---
# Orlando Espinoza
# Family Practitioner
# 30813980637
# ---
# Jessie Ferreras
# Primary Care Physician
# 74801820887
# ---
# Chris Firlit
# PGY6 Oral-Maxillofacial Surgery Chief Resident (presumed)
# FIRLIT
# 02507173333
# ---
# Louis Edouard Fontaine
# Doctor
# None
# ---
# James Footit
# Radiology
# FOOTIT
# None
# ---
# Frank Gabrin
# Emergency Medicine Physician
# 04177851693
# ---
# Jay Galst
# Ophthamologist
# 03501760446
# ---
# Dulce Garcia
# Interpreter
# GARCIA
# None
# ---
# Deborah Gatewood
# Phlebotomist
# None
# ---
# Michael Giuliano
# Doctor
# 04177811080
# ---
# James T. Goodrich
# Neurosurgeon Director of the Division of Pediatric Neurosurgery at Montefiore Health System Professor of Clinical Neurological Surgery
# 03501801606
# ---
# Sam Green
# Radiology
# GREEN
# None
# ---
# Harvey Hirsch
# Pediatrics
# 64914790091
# ---
# Mitchell Horowitz
# Physician
# 04101830646
# ---
# Alex Hsu
# Internal Medicine
# 01401820236
# ---
# 01002821971
# ---
# David Wolin
# Radiologist Mammography and Breast Imaging
# 03005731398
# ---
# Sina Zaim
# Physician,Electrophysiology,Hackensack University Medical Center
# 03520811361
# ---
# Jesus Zambrano
# Pediatrician,Mt. Sinai South NassauOceanside,
# 30801900221
# ---
# Jack Zoller
# OB-GYN
# 02105500664
# ---
# Anonymous Healthcare Worker
# Hartford
# None
# ---
# Anonymous Healthcare Worker
# John D. Dingell VA Medical Center
# WORKER
# None
# ---
# Anonymous Healthcare Worker
# Hartford
# None
# ---
# Anonymous Healthcare Worker
# John D. Dingell VA Medical Center
# WORKER
# None
# ---
# Anonymous Nurse
# Atlanta
# None
# ---
# Anonymous Pharmacy Technician
# San Diego County
# TECHNICIAN
# None

# %%
me_name = list(MED_ME['NAME'])

# %%
MED_ME[60:]
# Out:
#                NAME FIRST_NAME LAST_NAME MIDDLE_NAME SUFFIX NICKNAME TITLE  \
# 278  Ronald Verrier     RONALD   VERRIER
# 287    Barry Webber      BARRY    WEBBER
# 291     David Wolin      DAVID     WOLIN
# 294       Sina Zaim       SINA      ZAIM
# 295  Jesus Zambrano      JESUS  ZAMBRANO
# 297     Jack Zoller       JACK    ZOLLER
#
#     AGE                                          SPECIALTY         CITY  \
# 278  59                                     Trauma Surgeon        Bronx
# 287  67                                    General Surgery       Queens
# 291  74         Radiologist Mammography and Breast Imaging     Piermont
# 294  68  Physician,Electrophysiology,Hackensack Univers...   Hackensack
# 295  54      Pediatrician,Mt. Sinai South NassauOceanside,    Oceanside
# 297  91                                             OB-GYN  New Orleans
#
#           STATE COUNTRY                  LOCATION  \
# 278    New York     USA                      None
# 287    New York     USA      Mount Sinai Hospital
# 291    New York     USA  Brooklyn Hospital Center
# 294  New Jersey     USA                      None
# 295    New York     USA                      None
# 297   Louisiana     USA                      None
#
#                                                   LINK           ME
# 278  https://twitter.com/DoctorChrys/status/1248015...  44001860078
# 287  https://www.facebook.com/1053125492/posts/1021...  01002821971
# 291  https://www.legacy.com/obituaries/nytimes/obit...  03005731398
# 294  https://www.legacy.com/amp/obituaries/nytimes/...  03520811361
# 295  https://www.liherald.com/stories/three-employe...  30801900221
# 297  https://obits.nola.com/obituaries/nola/obituar...  02105500664

# %%
bad_spec_words = ['NURS',
        'VET',
        'TRANSPORT',
        'ASSISTANT',
        'RECEPTIONIST',
        'TECHNICIAN',
        'PARAMEDIC',
        'AIDE',
        'SOCIAL WORKER',
        'ENTREPRENEUR',
        'SERVICES',
        'GROUPHOME',
        'RN',
        'SECURITY',
        'PHARMACIST',
        'FIRE',
        'EMPLOYEE',
        'DEVELOPER',
        'ADMINISTRATOR',
        'LEADER',
        'LPN',
        'THERAPIST',
        'CLERK',
        'COUNSELOR',
        'ATTENDANT',
        'ADMIN',
        'SUPPLY',
        'CLEAN',
        'PRIEST',
        'STAFF',
        'INVESTIGATOR',
        'MRI',
        'EDUCATOR',
        'OFFICER',
        'MAINTENANCE',
        'CNA',
        'SUPERVISOR',
        'COORDINATOR',
        'SUPERVISOR',
        'TECHNOLOGIST',
        'MECHANIC',
        'EMT'
    ]

# %%
sp = 'Internal Medicine Chief of Medicine'
for word in bad_spec_words:
    if word in sp.upper():
        print(word)
# Out:
# RN

# %%
len(name_list)
# Out:
# 95

# %%
beep = medscape[(medscape.NAME.isin(name_list))&(medscape.NAME.isin(me_name)==False)]

# %%
len(MED_ME)
# Out:
# 66

# %%
len(beep)
# Out:
# 33

# %%
zz = pd.merge(beep, MED_ME, on='NAME', how='left')

# %%
PPD['ME']=fix_me(PPD['ME'])

# %%
ppd = PPD[['ME','POLO_CITY','POLO_STATE','MAILING_NAME','LAST_NAME','FIRST_NAME','MIDDLE_NAME','BIRTH_YEAR','PRIM_SPEC_CD']]

# %%
ppd = pd.merge(ppd, SPEC_FILE, left_on='PRIM_SPEC_CD', right_on='SPEC_CD')

# %%
pd.merge(zz, ppd, on='ME', how='left')
# Out:
#                              NAME        AGE_x  \
# 0                 Nerissa Armesto           64
# 1                       Doug Bass           64
# 2                Kenneth Bradshaw           64
# 3                John P. Careccia  age unknown
# 4                     Evelyn Caro           69
# 5                   Kenneth Conte           75
# 6                  Jeannie Danker           60
# 7          Ernesto "Audie" DeLeon           61
# 8               Elizabeth Edwards  age unknown
# 9                  Norman Einhorn           69
# 10         Louis Edouard Fontaine         None
# 11                   James Footit           56
# 12                   Dulce Garcia           29
# 13               Deborah Gatewood         None
# 14                      Sam Green           57
# 15                Steven J. Huber           62
# 16                   Albasha Hume           63
# 17                Victor de Jesus           58
# 18                Stephan Kamholz           72
# 19           Rabbi Mordechai Katz  age unknown
# 20                  DonaldKennedy           88
# 21                      John Lara           40
# 22                Elizabeth Levan           45
# 23                 Adan Maldonado           39
# 24                    Sal Mancuso           66
# 25                John Mutah Mbah           55
# 26             Ferdinando Moretti           73
# 27        Sandra "Sandy" Oldfield           53
# 28             Robert V. Piemonte           86
# 29    Anonymous Healthcare Worker  age unknown
# 30    Anonymous Healthcare Worker           70
# 31                Anonymous Nurse  age unknown
# 32  Anonymous Pharmacy Technician           25
#
#                                           SPECIALTY_x             CITY_x  \
# 0             Nephrology Renal Dietician Hemodialysis           Brooklyn
# 1                                    Medical Director      New York City
# 2                    Director of Facilities (retired)            Memphis
# 3                         Chief and Training Director         Woodbridge
# 4                                 Holy Cross Hospital      Silver Spring
# 5                Family Medicine/General practitioner           Garfield
# 6                               Director of Radiology           Columbus
# 7                                                 ADN      New York City
# 8                                        Phlebotomist           New Bern
# 9                   Other Optometrist Neuro Optometry             Belmar
# 10                                             Doctor           Brooklyn
# 11                                          Radiology        Springfield
# 12                                        Interpreter        Chapel Hill
# 13                                       Phlebotomist   Farmington Hills
# 14                                          Radiology      New York City
# 15                                        Orthodonist     Jefferson City
# 16    Men's Health Director,Open Cities Health Center           St. Paul
# 17                                       Pediatrician             Caguas
# 18  Pulmonary Medicine Critical Care Medicine Inte...           Brooklyn
# 19                                  Hospital Medicine      New York City
# 20          Neurobiologist (retired) Former President       Redwood City
# 21  Emergency Dept Tech,Clara Maass Medical Center...         Belleville
# 22                                          Caregiver  Bensalem Township
# 23                                    Medical Imaging          El Centro
# 24                                Ambulance Volunteer     Blooming Grove
# 25                                          Radiology           Cheverly
# 26                              Painting Crew Foreman          Oceanside
# 27                                          Telemetry             Fresno
# 28                      Former President and Director      New York City
# 29                                           Hartford               None
# 30                  John D. Dingell VA Medical Center            Detroit
# 31                                            Atlanta               None
# 32                                   San Diego County               None
#
#            STATE_x COUNTRY_x                                    LOCATION_x  \
# 0         New York       USA           Rogosin Institute NFB Brooklyn East
# 1         New York       USA                                          None
# 2        Tennessee       USA          University of  Health Science Center
# 3       New Jersey       USA  Woodbridge Township Ambulance & Rescue Squad
# 4         Maryland       USA                                          None
# 5       New Jersey       USA                                          None
# 6             Ohio       USA                     OSU Wexner Medical Center
# 7         New York       USA                                          None
# 8   North Carolina       USA                   CarolinaEast Medical Center
# 9       New Jersey       USA              Center for Visual Rehabilitation
# 10        New York       USA                                          None
# 11   Massachusetts       USA                             Baystate Hospital
# 12  North Carolina       USA                       University of  Hospital
# 13        Michigan       USA              Beaumont Health Farmington Hills
# 14        New York       USA                              X-ray Technician
# 15        Missouri       USA                                          None
# 16       Minnesota       USA                                          None
# 17     Puerto Rico       USA                                 Hospital HIMA
# 18        New York       USA                     Maimonides Medical Center
# 19        New York       USA                                      Chaplain
# 20      California       USA   Stanford University; Former Chief of US FDA
# 21      New Jersey       USA                                          None
# 22    Pennsylvania       USA                      The Birches Nursing Home
# 23      California       USA             El Centro Regional Medical Center
# 24        New York       USA      Blooming Grove Volunteer Ambulance Corps
# 25        Maryland       USA               Prince George's Hospital Center
# 26        New York       USA                        Mt. Sinai South Nassau
# 27      California       USA                             Kaiser Permanente
# 28        New York       USA      Chief Nurse of the 8th Army Medical Unit
# 29     Connecticut       USA                                          None
# 30        Michigan       USA                                          None
# 31         Georgia       USA                                          None
# 32      California       USA                                          None
#
#                                                LINK_x FIRST_NAME_x  \
# 0   https://www.gofundme.com/f/nerissa-armesto-mem...      NERISSA
# 1   https://abc7ny.com/doctor-dead-doug-bass-kille...          NaN
# 2   https://www.legacy.com/obituaries/commercialap...      KENNETH
# 3   https://www.firehouse.com/safety-health/news/2...          NaN
# 4   https://www.baltimoresun.com/coronavirus/bs-md...       EVELYN
# 5   https://www.northjersey.com/story/news/bergen/...      KENNETH
# 6   https://www.dispatch.com/news/20200331/coronav...          NaN
# 7   https://www.dignitymemorial.com/obituaries/new...      ERNESTO
# 8   https://www.newbernsj.com/news/20200416/craven...          NaN
# 9   https://www.dignitymemorial.com/obituaries/oce...          NaN
# 10  https://twitter.com/ClaireZebra/status/1253121...          NaN
# 11  https://obits.masslive.com/obituaries/masslive...          NaN
# 12  https://www.facebook.com/COVID19MedicalMemoria...          NaN
# 13  https://www.fox2detroit.com/news/beaumont-work...          NaN
# 14                                               None          NaN
# 15  https://www.dulletrimble.com/obituaries/Dr-Ste...          NaN
# 16  https://kstp.com/coronavirus/st-paul-health-ca...          NaN
# 17  https://www.elnuevodia.com/noticias/locales/no...          NaN
# 18  https://collive.com/chief-doctor-at-maimonides...      STEPHAN
# 19            https://matzav.com/rabbi-motti-katz-zl/          NaN
# 20  https://www.latimes.com/obituaries/story/2020-...          NaN
# 21       https://www.facebook.com/groups/61237398056/          NaN
# 22  https://www.legacy.com/obituaries/buckscountyc...          NaN
# 23  https://calexicochronicle.com/2020/06/covid-19...          NaN
# 24  https://www.ems1.com/coronavirus-covid-19/arti...          NaN
# 25  https://www.forevermissed.com/john-mutah-mbah/...          NaN
# 26  https://www.liherald.com/stories/three-employe...          NaN
# 27  https://www.nationalnursesunited.org/press/can...          NaN
# 28  https://www.legacy.com/obituaries/name/robert-...          NaN
# 29  https://www.wfsb.com/news/hartford-healthcare-...          NaN
# 30  https://www.michiganradio.org/post/va-employee...          NaN
# 31  https://www.georgiahealthnews.com/2020/04/geor...          NaN
# 32  https://www.recordgazette.net/news/breaking/co...          NaN
#
#    LAST_NAME_x  ... POLO_STATE           MAILING_NAME LAST_NAME_y  \
# 0      ARMESTO  ...         PA     DAVID M ARMESTO MD     ARMESTO
# 1          NaN  ...        NaN                    NaN         NaN
# 2     BRADSHAW  ...        NaN  KENNETH G BRADSHAW DO    BRADSHAW
# 3          NaN  ...        NaN                    NaN         NaN
# 4         CARO  ...         CA       EVELYN A CARO MD        CARO
# 5        CONTE  ...         NJ     KENNETH S CONTE DO       CONTE
# 6          NaN  ...        NaN                    NaN         NaN
# 7       DELEON  ...        NaN      ERNESTO DELEON MD      DELEON
# 8          NaN  ...        NaN                    NaN         NaN
# 9          NaN  ...        NaN                    NaN         NaN
# 10         NaN  ...        NaN                    NaN         NaN
# 11         NaN  ...        NaN                    NaN         NaN
# 12         NaN  ...        NaN                    NaN         NaN
# 13         NaN  ...        NaN                    NaN         NaN
# 14         NaN  ...        NaN                    NaN         NaN
# 15         NaN  ...        NaN                    NaN         NaN
# 16         NaN  ...        NaN                    NaN         NaN
# 17         NaN  ...        NaN                    NaN         NaN
# 18     KAMHOLZ  ...         NY   STEPHAN L KAMHOLZ MD     KAMHOLZ
# 19         NaN  ...        NaN                    NaN         NaN
# 20         NaN  ...        NaN                    NaN         NaN
# 21         NaN  ...        NaN                    NaN         NaN
# 22         NaN  ...        NaN                    NaN         NaN
# 23         NaN  ...        NaN                    NaN         NaN
# 24         NaN  ...        NaN                    NaN         NaN
# 25         NaN  ...        NaN                    NaN         NaN
# 26         NaN  ...        NaN                    NaN         NaN
# 27         NaN  ...        NaN                    NaN         NaN
# 28         NaN  ...        NaN                    NaN         NaN
# 29         NaN  ...        NaN                    NaN         NaN
# 30         NaN  ...        NaN                    NaN         NaN
# 31         NaN  ...        NaN                    NaN         NaN
# 32         NaN  ...        NaN                    NaN         NaN
#
#    FIRST_NAME_y MIDDLE_NAME_y BIRTH_YEAR PRIM_SPEC_CD SPEC_CD SPEC_ID  \
# 0         DAVID       MICHAEL     1955.0          OPH     OPH  1783.0
# 1           NaN           NaN        NaN          NaN     NaN     NaN
# 2       KENNETH             G     1955.0           FM      FM  1691.0
# 3           NaN           NaN        NaN          NaN     NaN     NaN
# 4        EVELYN             A     1937.0            P       P  1793.0
# 5       KENNETH             S     1941.0            R       R  1853.0
# 6           NaN           NaN        NaN          NaN     NaN     NaN
# 7       ERNESTO           NaN     1969.0           EM      EM  1682.0
# 8           NaN           NaN        NaN          NaN     NaN     NaN
# 9           NaN           NaN        NaN          NaN     NaN     NaN
# 10          NaN           NaN        NaN          NaN     NaN     NaN
# 11          NaN           NaN        NaN          NaN     NaN     NaN
# 12          NaN           NaN        NaN          NaN     NaN     NaN
# 13          NaN           NaN        NaN          NaN     NaN     NaN
# 14          NaN           NaN        NaN          NaN     NaN     NaN
# 15          NaN           NaN        NaN          NaN     NaN     NaN
# 16          NaN           NaN        NaN          NaN     NaN     NaN
# 17          NaN           NaN        NaN          NaN     NaN     NaN
# 18      STEPHAN       LEONARD     1947.0          MDM     MDM  1733.0
# 19          NaN           NaN        NaN          NaN     NaN     NaN
# 20          NaN           NaN        NaN          NaN     NaN     NaN
# 21          NaN           NaN        NaN          NaN     NaN     NaN
# 22          NaN           NaN        NaN          NaN     NaN     NaN
# 23          NaN           NaN        NaN          NaN     NaN     NaN
# 24          NaN           NaN        NaN          NaN     NaN     NaN
# 25          NaN           NaN        NaN          NaN     NaN     NaN
# 26          NaN           NaN        NaN          NaN     NaN     NaN
# 27          NaN           NaN        NaN          NaN     NaN     NaN
# 28          NaN           NaN        NaN          NaN     NaN     NaN
# 29          NaN           NaN        NaN          NaN     NaN     NaN
# 30          NaN           NaN        NaN          NaN     NaN     NaN
# 31          NaN           NaN        NaN          NaN     NaN     NaN
# 32          NaN           NaN        NaN          NaN     NaN     NaN
#
#                   DESC
# 0        OPHTHALMOLOGY
# 1                  NaN
# 2      FAMILY MEDICINE
# 3                  NaN
# 4           PSYCHIATRY
# 5            RADIOLOGY
# 6                  NaN
# 7   EMERGENCY MEDICINE
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18  MEDICAL MANAGEMENT
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                 NaN
#
# [33 rows x 33 columns]

# %%
ppd[(ppd.LAST_NAME=='BASS')&(ppd.FIRST_NAME=='DOUGLAS')]
# Out:
#                  ME POLO_CITY POLO_STATE       MAILING_NAME LAST_NAME  \
# 820920  03503830077   ASTORIA         NY  DOUGLAS H BASS MD      BASS
#
#        FIRST_NAME MIDDLE_NAME  BIRTH_YEAR PRIM_SPEC_CD SPEC_CD  SPEC_ID  \
# 820920    DOUGLAS      HOWARD      1956.0           AN      AN     1639
#
#                   DESC
# 820920  ANESTHESIOLOGY

# %%
ppd[(ppd.LAST_NAME=='MBAH')]
# Out:
#                   ME   POLO_CITY POLO_STATE           MAILING_NAME LAST_NAME  \
# 16073    02002141259  PITTSBURGH         PA  NSEHNIITOOH A MBAH MD      MBAH
# 44836    04802182151     HOUSTON         TX        BRIAN N MBAH MD      MBAH
# 278671   69012970013      NEWARK         OH          MAY U MBAH MD      MBAH
# 348943   69007940092   GREEN BAY         WI        NGOZI N MBAH MD      MBAH
# 573770   04814100109       PLANO         TX        LYNDA E MBAH MD      MBAH
# 1147637  69014980041         NaN        NaN       ENJONG M MBAH MD      MBAH
#
#           FIRST_NAME   MIDDLE_NAME  BIRTH_YEAR PRIM_SPEC_CD SPEC_CD  SPEC_ID  \
# 16073    NSEHNIITOOH  APPOLINARISE      1980.0           EM      EM     1682
# 44836          BRIAN        NNAMDI      1991.0           EM      EM     1682
# 278671           MAY      UZOAMAKA      1971.0           IM      IM     1724
# 348943         NGOZI       NWAMAKA      1966.0          OBG     OBG     1769
# 573770         LYNDA         EBERE      1975.0           FM      FM     1691
# 1147637       ENJONG          MARY      1970.0           US      US     1883
#
#                             DESC
# 16073         EMERGENCY MEDICINE
# 44836         EMERGENCY MEDICINE
# 278671         INTERNAL MEDICINE
# 348943   OBSTETRICS & GYNECOLOGY
# 573770           FAMILY MEDICINE
# 1147637              UNSPECIFIED

# %%
ppd[(ppd.LAST_NAME=='CONTE')&(ppd.FIRST_NAME=='KENNETH')]
# Out:
#                  ME POLO_CITY POLO_STATE        MAILING_NAME LAST_NAME  \
# 945129  02878660733  GARFIELD         NJ  KENNETH S CONTE DO     CONTE
#
#        FIRST_NAME MIDDLE_NAME  BIRTH_YEAR PRIM_SPEC_CD SPEC_CD  SPEC_ID  \
# 945129    KENNETH           S      1941.0            R       R     1853
#
#              DESC
# 945129  RADIOLOGY

# %%
MED_ME
# Out:
#                            NAME FIRST_NAME       LAST_NAME MIDDLE_NAME SUFFIX  \
# 0                   Ashraf Abdo     ASHRAF            ABDO
# 5                 Nancy Ajemian      NANCY         AJEMIAN
# 9                      Niaz Ali       NIAZ             ALI
# 21                Glenn Barquet      GLENN         BARQUET
# 38          Joseph A. Bonjiorno     JOSEPH       BONJIORNO          A.
# 39                James Boudwin      JAMES         BOUDWIN
# 51              Irving Buterman     IRVING        BUTERMAN
# 55          Luis Caldera-Nieves       LUIS  CALDERA-NIEVES
# 63            Ricardo Castaneda    RICARDO       CASTANEDA
# 66              Sudheer Chauhan    SUDHEER         CHAUHAN
# 67       Charlie Chin Song Chen    CHARLIE            CHEN   CHIN SONG
# 69               Reza Chowdhury       REZA       CHOWDHURY
# 80                Leo dela Cruz        LEO       DELA CRUZ
# 97               Jeffrey Escher    JEFFREY          ESCHER
# 99             Orlando Espinoza    ORLANDO        ESPINOZA
# 103             Jessie Ferreras     JESSIE        FERRERAS
# 106                Chris Firlit      CHRIS          FIRLIT
# 115                Frank Gabrin      FRANK          GABRIN
# 116                   Jay Galst        JAY           GALST
# 121            Michael Giuliano    MICHAEL        GIULIANO
# 122           James T. Goodrich      JAMES        GOODRICH          T.
# 134               Harvey Hirsch     HARVEY          HIRSCH
# 137           Mitchell Horowitz   MITCHELL        HOROWITZ
# 139                    Alex Hsu       ALEX             HSU
# 150              Jay Alan Kavet        JAY           KAVET        ALAN
# 154                Priya Khanna      PRIYA          KHANNA
# 155        Satyender Dev Khanna  SATYENDER          KHANNA         DEV
# 161            Robert Lancaster     ROBERT       LANCASTER
# 165              Mortimer Levin   MORTIMER           LEVIN
# 174               James Mahoney      JAMES         MAHONEY
# 191                 Sydney Mehl     SYDNEY            MEHL
# 201  Francis "Frankie" Molinari    FRANCIS        MOLINARI
# 203              Nola Mae Moore       NOLA           MOORE         MAE
# 207              John F. Murray       JOHN          MURRAY          F.
# 210            Darioush Nasseri   DARIOUSH         NASSERI
# 223             Angelo Patsalis     ANGELO        PATSALIS
# 224            Tomas Pattugalan      TOMAS      PATTUGALAN
# 226                Steven Perez     STEVEN           PEREZ
# 228          Bredy Pierre-Louis      BREDY    PIERRE-LOUIS
# 233              Nisar Quraishi      NISAR        QURAISHI
# 238                Mark Respler       MARK         RESPLER
# 240            Victor C. Rivera     VICTOR          RIVERA          C.
# 245           Burton "Bud" Rose     BURTON            ROSE
# 251              Charlie Safley    CHARLIE          SAFLEY
# 253              Barry Sakowitz      BARRY        SAKOWITZ
# 255               Elliott Samet    ELLIOTT           SAMET
# 257               Eugene Sayfie     EUGENE          SAYFIE
# 260            Stephen Schwartz    STEPHEN        SCHWARTZ
# 261                  Gary Sclar       GARY           SCLAR
# 266               Javier Sloyer     JAVIER          SLOYER
# 267        Charles Rodney Smith    CHARLES           SMITH      RODNEY
# 270               Joshua Suzuki     JOSHUA          SUZUKI
# 273      Arthur Sydeco Tayengco     ARTHUR        TAYENGCO      SYDECO
# 277             Arthur Turetsky     ARTHUR        TURETSKY
# 278              Ronald Verrier     RONALD         VERRIER
# 287                Barry Webber      BARRY          WEBBER
# 291                 David Wolin      DAVID           WOLIN
# 294                   Sina Zaim       SINA            ZAIM
# 295              Jesus Zambrano      JESUS        ZAMBRANO
# 297                 Jack Zoller       JACK          ZOLLER
#
#     NICKNAME TITLE          AGE  \
# 0                            60
# 5                            60
# 9                            71
# 21                           50
# 38                           78
# 39                           67
# 51                           78
# 55                           63
# 63                           64
# 66                  age unknown
# 67                  age unknown
# 69                           58
# 80                  age unknown
# 97                           72
# 99                           53
# 103                          52
# 106                          37
# 115                          60
# 116                 age unknown
# 121                          64
# 122                          73
# 134                          68
# 137                        None
# 139                          67
# 150                          72
# 154                          43
# 155                          78
# 161                          98
# 165                          99
# 174                 age unknown
# 191                          72
# 201  FRANKIE                 70
# 203                          88
# 207                          92
# 210                        None
# 223                          63
# 224                          70
# 226                          68
# 228                          74
# 233                          74
# 238                          66
# 240                          77
# 245      BUD                 77
# 251                          78
# 253                          75
# 255                          69
# 257                          85
# 260                          78
# 261                          66
# 266                          71
# 267                          92
# 270                          78
# 273                          81
# 277                        None
# 278                          59
# 287                          67
# 291                          74
# 294                          68
# 295                          54
# 297                          91
#
#                                              SPECIALTY                CITY  \
# 0                                 General Practitioner       New York City
# 5                                      Family Medicine       Grosse Pointe
# 9                                           Pediatrics            Red Bank
# 21                     Physician Invasive Cardiologist               Miami
# 38                                        Psychiatrist             Chicago
# 39                           Family Practice Physician       New Brunswick
# 51                                              OB-GYN       New York City
# 55                                              OB-GYN               Miami
# 63                                        Psychiatrist       New York City
# 66                 Internal Medicine Chief of Medicine              Queens
# 67                Family Medicine/General Practitioner       New York City
# 69   Internist and Infectious Diseases Physician,We...               Bronx
# 80           Geriatric Psychiatrist,Carepoint Hospital         Jersey City
# 97                              Physician Geriatrician  Westchester County
# 99                                 Family Practitioner      Broward County
# 103                             Primary Care Physician            Waldwick
# 106  PGY6 Oral-Maxillofacial Surgery Chief Resident...             Detroit
# 115                       Emergency Medicine Physician       New York City
# 116                                     Ophthamologist       New York City
# 121                                             Doctor              Nutley
# 122  Neurosurgeon Director of the Division of Pedia...       New York City
# 134                                         Pediatrics            Lakewood
# 137                                          Physician       New York City
# 139                                  Internal Medicine             Margate
# 150                                  Internal Medicine       New York City
# 154                                       Nephrologist          Glen Ridge
# 155                                    General Surgery          Belleville
# 161                                       Psychiatrist         New Orleans
# 165                                          Physician             Detroit
# 174            Doctor Pulmonary/Critical Care Medicine            Brooklyn
# 191                                         Cardiology       New York City
# 201                         Internal MedicinePhysician          Belleville
# 203                                          Physician           Shoreline
# 207              Pulmonary and Critical Care Physician       San Francisco
# 210                       Orthopedic Surgeon (retired)           Baltimore
# 223          Family Physician,Henry Ford Medical Group             Detroit
# 224                        Internal Medicine Physician              Queens
# 226                 Internal MedicineMedical Center of           Annandale
# 228               Family Medicine/General Practitioner            Brooklyn
# 233                                  Internal Medicine       New York City
# 238                                          Urologist            Brooklyn
# 240                                      Pediatrician,           Langhorne
# 245         Nephrologist (retired) Creator of UpToDate              Boston
# 251                                      Dermatologist             Memphis
# 253                    Internal and Pulmonary Medicine             Paramus
# 255                                      Pediatrician,             Passaic
# 257                                         Cardiology               Miami
# 260                                        Pathologist             Seattle
# 261                                        Neurologist       New York City
# 266                         Physician Anesthesiologist       New York City
# 267                                       Psychiatrist         New Orleans
# 270                                             OB-GYN             Seattle
# 273                                             OB-GYN           Las Vegas
# 277                        Pulmonary and Critical Care          Bridgeport
# 278                                     Trauma Surgeon               Bronx
# 287                                    General Surgery              Queens
# 291         Radiologist Mammography and Breast Imaging            Piermont
# 294  Physician,Electrophysiology,Hackensack Univers...          Hackensack
# 295      Pediatrician,Mt. Sinai South NassauOceanside,           Oceanside
# 297                                             OB-GYN         New Orleans
#
#              STATE COUNTRY                                           LOCATION  \
# 0         New York     USA                                               None
# 5         Michigan     USA                                  Beaumont Hospital
# 9       New Jersey     USA                           Riverview Medical Center
# 21         Florida     USA            Mercy Hospital and South Miami Hospital
# 38        Illinois     USA                   St. Joseph Hospital (affiliated)
# 39      New Jersey     USA            Robert Wood Johnson University Hospital
# 51        New York     USA                                               None
# 55         Florida     USA                                               None
# 63        New York     USA                                               None
# 66        New York     USA                    Jamaica Hospital Medical Center
# 67        New York     USA                                               None
# 69        New York     USA                                               None
# 80      New Jersey     USA                                               None
# 97        New York     USA                                                NaN
# 99         Florida     USA                                               None
# 103     New Jersey     USA                                               None
# 106       Michigan     USA                                               None
# 115       New York     USA                                               None
# 116       New York     USA                                               None
# 121     New Jersey     USA                         Mountainside Medical Group
# 122       New York     USA                                         Pediatrics
# 134     New Jersey     USA                                             CHEMED
# 137       New York     USA                                        Radiologist
# 139        Florida     USA                           Northwest Medical Center
# 150       New York     USA                                               None
# 154     New Jersey     USA                                  Khanna Nephrology
# 155     New Jersey     USA                               Clara Maass Hospital
# 161      Louisiana     USA                                               None
# 165       Michigan     USA                                               None
# 174       New York     USA  University Hospital of Brooklyn/SUNY Downstate...
# 106     Dr. Ashraf Metwally     ASHRAF   METWALLY         NaN    NaN      NaN
# 108  Dr. Mark Allen Respler       MARK    RESPLER       ALLEN    NaN      NaN
# 109        Dr. Frank Gabrin      FRANK     GABRIN         NaN    NaN      NaN
# 110    Dr. Stephen Schwartz    STEPHEN   SCHWARTZ         NaN    NaN      NaN
# 111            Dr. Alex Hsu       ALEX        HSU         NaN    NaN      NaN
#
#     TITLE   AGE                       DATE STATE  \
# 1     DR.    79  2020-06-27 00:39:00+00:00  None
# 2     DR.    91  2020-06-26 23:29:00+00:00  None
# 3     DR.    80  2020-06-25 00:37:00+00:00    OK
# 4     DR.    84  2020-06-24 23:01:00+00:00  None
# 7     DR.    78  2020-06-13 13:40:09+00:00    CA
# ..    ...   ...                        ...   ...
# 106   DR.  None  2020-04-05 11:59:10+00:00  None
# 108   DR.    66  2020-04-03 02:58:13+00:00  None
# 109   DR.  None  2020-04-01 13:19:36+00:00  None
# 110   DR.    78  2020-04-01 01:38:07+00:00  None
# 111   DR.    67  2020-03-31 23:15:17+00:00    FL
#
#                                                   LINK           ME
# 1    https://www.pleasantmanorfh.com/obituary/Guido...  78101620041
# 2    https://www.legacy.com/obituaries/nytimes/obit...  51701560764
# 3    http://totallytahlequah.blogspot.com/2020/04/o...  03901680727
# 4    https://ryortho.com/2020/06/renowned-orthopedi...  03841610490
# 7    https://www.google.com/amp/s/www.legacy.com/ob...  01002670662
# ..                                                 ...          ...
# 106                                               None  91503870156
# 108  https://hamodia.com/2020/03/27/bde-dr-mark-all...  03508801512
# 109                                               None  04177851693
# 110                                               None  02405670502
# 111                                               None  01401820236
#
# [78 rows x 12 columns]

# %%
xx = pd.merge(T_ME, heroes, on='ME', how='outer', suffixes=('_twitter','_hero'))

# %%
heroes['ME']=fix_me(heroes['ME'])

# %%
remove_processed_mes(xx)
# Out:
#                 NAME_twitter FIRST_NAME_twitter LAST_NAME_twitter  \
# 0        Dr. Guido Volcovici              GUIDO         VOLCOVICI
# 1      Dr. Hooshang Behroozi           HOOSHANG          BEHROOZI
# 2        Dr. Robert Oglesbee             ROBERT          OGLESBEE
# 3            Dr. John Makley               JOHN            MAKLEY
# 27         Dr. Richard Miles            RICHARD             MILES
# 32         Dr. Richard Mills            RICHARD             MILLS
# 42               Dr. Sol Dan                SOL               DAN
# 56  Dr. Jacob Zeiger Slepian              JACOB           SLEPIAN
# 72     Dr. Gregory V. Miller            GREGORY            MILLER
# 73       Dr. Ashraf Metwally             ASHRAF          METWALLY
#
#    MIDDLE_NAME_twitter SUFFIX_twitter NICKNAME_twitter TITLE_twitter  \
# 0                  NaN            NaN              NaN           DR.
# 1                  NaN            NaN              NaN           DR.
# 2                  NaN            NaN              NaN           DR.
# 3                  NaN            NaN              NaN           DR.
# 27                 NaN            NaN              NaN           DR.
# 32                 NaN            NaN              NaN           DR.
# 42                 NaN            NaN              NaN           DR.
# 56              ZEIGER            NaN              NaN           DR.
# 72                  V.            NaN              NaN           DR.
# 73                 NaN            NaN              NaN           DR.
#
#    AGE_twitter                       DATE STATE_twitter  ... SUFFIX_hero  \
# 0           79  2020-06-27 00:39:00+00:00          None  ...         NaN
# 1           91  2020-06-26 23:29:00+00:00          None  ...         NaN
# 2           80  2020-06-25 00:37:00+00:00            OK  ...         NaN
# 3           84  2020-06-24 23:01:00+00:00          None  ...         NaN
# 27        None  2020-05-20 19:08:35+00:00            MI  ...         NaN
# 32        None  2020-05-12 14:28:13+00:00            WA  ...         NaN
# 42          70  2020-05-02 17:55:29+00:00            NY  ...         NaN
# 56          82  2020-04-18 12:46:48+00:00            MA  ...         NaN
# 72        None  2020-04-05 19:34:48+00:00            GA  ...         NaN
# 73        None  2020-04-05 11:59:10+00:00          None  ...         NaN
#
#    NICKNAME_hero TITLE_hero AGE_hero SPECIALTY CITY  STATE_hero  COUNTRY  \
# 0            NaN        NaN      NaN       NaN  NaN         NaN      NaN
# 1            NaN        NaN      NaN       NaN  NaN         NaN      NaN
# 2            NaN        NaN      NaN       NaN  NaN         NaN      NaN
# 3            NaN        NaN      NaN       NaN  NaN         NaN      NaN
# 27           NaN        NaN      NaN       NaN  NaN         NaN      NaN
# 32           NaN        NaN      NaN       NaN  NaN         NaN      NaN
# 42           NaN        NaN      NaN       NaN  NaN         NaN      NaN
# 56           NaN        NaN      NaN       NaN  NaN         NaN      NaN
# 72           NaN        NaN      NaN       NaN  NaN         NaN      NaN
# 73           NaN        NaN      NaN       NaN  NaN         NaN      NaN
#
#    LOCATION LINK_hero
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 27      NaN       NaN
# 32      NaN       NaN
# 42      NaN       NaN
# 56      NaN       NaN
# 72      NaN       NaN
# 73      NaN       NaN
#
# [10 rows x 26 columns]

# %%
xx = xx.drop_duplicates()

# %%
med_me['ME']=fix_me(med_me['ME'])

# %%
remove_processed_mes(med_me)
# Out:
# Empty DataFrame
# Columns: [NAME, FIRST_NAME, LAST_NAME, MIDDLE_NAME, SUFFIX, NICKNAME, TITLE, AGE, SPECIALTY, CITY, STATE, COUNTRY, LOCATION, LINK, ME]
# Index: []

# %%
remove_processed_mes(VV).to_excel('../../Data/Medscape/2020-07-01/Other_Unprocessed_2020-07-01.xlsx')

# %%
ppd[ppd['ME']=='56101680474']
# Out:
#                  ME POLO_CITY POLO_STATE        MAILING_NAME LAST_NAME  \
# 444246  56101680474     AKRON         OH  JACOB Z SLEPIAN MD   SLEPIAN
#
#        FIRST_NAME MIDDLE_NAME  BIRTH_YEAR PRIM_SPEC_CD SPEC_CD  SPEC_ID  \
# 444246      JACOB      ZEIGER      1938.0          OTO     OTO     1791
#
#                                         DESC
# 444246  OTOLARYNGOLOGY-HEAD AND NECK SURGERY

# %%
MED_ME.to_excel('../../Data/Medscape/2020-07-01/Memorium_USA_Physicians_2020-07-01.xlsx')

# %%
med_me = pd.read_excel('../../Data/Medscape/2020-07-01/Memorium_USA_Physicians_2020-07-01.xlsx')

# %%
medscape[medscape['NAME']=='Kenneth Conte']
# Out:
#              NAME AGE                             SPECIALTY      CITY  \
# 74  Kenneth Conte  75  Family Medicine/General practitioner  Garfield
#
#          STATE COUNTRY LOCATION  \
# 74  New Jersey     USA     None
#
#                                                  LINK
# 74  https://www.northjersey.com/story/news/bergen/...

# %%
xx = xx.fillna('None')

# %%
def clean_other(xx):
    xx = xx.fillna('None')
    xx = xx.drop_duplicates()
    YY = xx[['ME','DATE']]
    dict__list = []
    for row in xx.itertuples():
        me=row.ME
        if row.NAME_twitter=='None':
            name = row.NAME_hero
            first_name = row.FIRST_NAME_hero
            middle_name = row.MIDDLE_NAME_hero
            title = row.TITLE_hero
            nickname = row.NICKNAME_hero
            last_name = row.LAST_NAME_hero
            age = row.AGE_hero
            state = row.STATE_hero
        else:
            name = row.NAME_twitter
            first_name = row.FIRST_NAME_twitter
            middle_name = row.MIDDLE_NAME_twitter
            title = row.TITLE_twitter
            nickname = row.NICKNAME_twitter
            last_name = row.LAST_NAME_twitter
            age = row.AGE_twitter
            state = row.STATE_twitter
        if row.LINK_twitter =='None':
            link = row.LINK_hero
        else:
            link = row.LINK_twitter
        new_dict = {
            'NAME':name,
            'FIRST_NAME':first_name,
            'MIDDLE_NAME': middle_name,
            'LAST_NAME': last_name,
            'NICKNAME': nickname,
            'TITLE': title,
            'AGE': age,
            'STATE': state,
            'LINK': link,
            'ME':me
        }
        dict__list.append(new_dict)
    WW = pd.DataFrame(dict__list)
    VV = pd.merge(YY, WW, on='ME')
    return('VV')

# %%
WW = pd.DataFrame(dict__list)

# %%
xx.columns
# Out:
# Index(['NAME_twitter', 'FIRST_NAME_twitter', 'LAST_NAME_twitter',
#        'MIDDLE_NAME_twitter', 'SUFFIX_twitter', 'NICKNAME_twitter',
#        'TITLE_twitter', 'AGE_twitter', 'DATE', 'STATE_twitter', 'LINK_twitter',
#        'ME', 'NAME_hero', 'FIRST_NAME_hero', 'LAST_NAME_hero',
#        'MIDDLE_NAME_hero', 'SUFFIX_hero', 'NICKNAME_hero', 'TITLE_hero',
#        'AGE_hero', 'SPECIALTY', 'CITY', 'STATE_hero', 'COUNTRY', 'LOCATION',
#        'LINK_hero'],
#       dtype='object')

# %%
YY = xx[['ME','CITY','COUNTRY','LOCATION','DATE']]

# %%
VV = pd.merge(YY, WW, on='ME')

# %%
VV[['ME', 'DATE', 'NAME', 'FIRST_NAME',
       'MIDDLE_NAME', 'LAST_NAME', 'NICKNAME', 'TITLE', 'AGE', 'STATE',
       'LINK']].to_excel('../../Data/Medscape/2020-07-01/Other_Physicians_2020-07-01.xlsx')

# %%
VV['DATE'][0].strftime("%m-%d-%Y")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-170-fb56995efbff> in <module>
# ----> 1 VV['DATE'][0].strftime("%b %d %Y %H:%M:%S")
#
# AttributeError: 'str' object has no attribute 'strftime'

# %%
ppd[ppd.ME=='00801680518']
# Out:
#                  ME POLO_CITY POLO_STATE        MAILING_NAME LAST_NAME  \
# 637880  00801680518       NaN        NaN  RICHARD P MILLS MD     MILLS
#
#        FIRST_NAME MIDDLE_NAME  BIRTH_YEAR PRIM_SPEC_CD SPEC_CD  SPEC_ID  \
# 637880    RICHARD       PENCE      1943.0          OPH     OPH     1783
#
#                  DESC
# 637880  OPHTHALMOLOGY
