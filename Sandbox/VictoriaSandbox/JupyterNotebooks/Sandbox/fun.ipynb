# %%
import pandas as pd
from datamart import fix_me

# %%
ppd = pd.read_csv('../../Data/PPD/ppd_data_20210501.csv')
cred = pd.read_csv('../../Data/Credentialling/addresses_20210526.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,14,20,21,42,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cred_2 = pd.read_csv('../../Data/Credentialling/Credentialing_Addresses_1_2021-05-26.csv')

# %%
cred_2['ME']=fix_me(cred_2.ME)
cred_2 = cred_2.fillna('None')
cred_2_phones = cred_2[cred_2.PHONE_NUMBER!='None']

# %%
ppd['ME']=fix_me(ppd.ME)
cred['ME']=fix_me(cred.ME)

# %%
cred = cred.fillna('None')

# %%
cred_phones = cred[cred.PHONE_NUMBER!='None']

# %%
FOR_FUN = pd.merge(cred_2_phones, ppd, on='ME', suffixes =['_ppd','_cred'])
FOR_FUN = FOR_FUN.fillna('None')

# %%
# count =0
# matches = []
count =0
for row in FOR_FUN.itertuples():
    if row.PHONE_NUMBER == row.TELEPHONE_NUMBER:
        count += 1
        print(f'PHONE: {row.ADDRESS_LINE_1} {row.POLO_MAILING_LINE_2}')
        print('')
#     matches.append(is_a_match(str(row.ZIPCODE), str(row.POLO_ZIP)))
#         other_count+= 1
#         print(f'ZIP: {row.ADDRESS_LINE_1} {row.POLO_MAILING_LINE_2}')
#         print('------')
# Out:
# PHONE: 1855 E Southern Ave 1855 E SOUTHERN AVE STE 1
#
# PHONE: 13737 Noel Rd Ste 1600 13737 NOEL RD STE 1600
#
# PHONE: 13737 Noel Rd Ste 1600 13737 NOEL RD
#
# PHONE: 7165 E University Dr Ste 183 7165 E UNIVERSITY DR STE 183
#
# PHONE: 7165 E University Dr Ste 183 7165 E UNIVERSITY DR STE 183
#
# PHONE: 13737 Noel Rd Ste 1600 13737 NOEL RD STE 1600
#
# PHONE: 935 State Route 28 2131 GATEWAY DR
#
# PHONE: 935 State Route 28 2131 GATEWAY DR
#
# PHONE: 11995 Singletree Ln Ste 500 11995 SINGLETREE LN STE 500
#
# PHONE: 11995 Singletree Ln Ste 500 11995 SINGLETREE LN STE 500
#
# PHONE: 11995 Singletree Ln Ste 500 11995 SINGLETREE LN STE 500
#
# PHONE: 11995 Singletree Ln Ste 500 11995 SINGLETREE LN STE 500
#
# PHONE: 11995 Singletree Ln Ste 500 1720 ESPLANADE
#
# PHONE: 11995 Singletree Ln Ste 500 1720 ESPLANADE
#
# PHONE: 88 Martin Luther King Jr Dr 88 MARTIN LUTHER KING JR DR
#
# PHONE: 88 Martin Luther King Jr Dr 88 MARTIN LUTHER KING JR DR
#
# ...

# %%
count
# Out:
# 1895

# %%
def is_a_match(thing_1, thing_2):
    if thing_1 == thing_2:
        match = True
    elif thing_1 in thing_2:
        match = True
    elif thing_2 in thing_1:
        match = True
    else:
        match = False
    return(match)

# %%
FOR_FUN['ZIP_MATCH']=matches

# %%
FOR_FUN[(FOR_FUN.TELEPHONE_NUMBER=='None')&(FOR_FUN.ZIP_MATCH==True)][['ME','ORG_ID','ADDRESS_LINE_1','ADDRESS_LINE_2','PHONE_NUMBER','POLO_MAILING_LINE_2','TELEPHONE_NUMBER','ZIPCODE','POLO_ZIP']]
# Out:
#                  ME  ORG_ID                  ADDRESS_LINE_1    ADDRESS_LINE_2  \
# 1831    00102101006    2316                4000 Highway 9 E              None
# 2277    02301860741    5081       1065 Senator Keating Blvd              None
# 2590    02576130859    1020          19601 W Bluemound Road         Suite 130
# 4101    42201071172     641  Hillcrest Medical Staff Office  1120 S Utica Ave
# 4102    42201071172     641  Hillcrest Medical Staff Office  1120 S Utica Ave
# ...             ...     ...                             ...               ...
# 737716  04705871006    7572            5430 Distinction Way              None
# 737946  05605920022    7659          1125 SE Washington Ave     PO Box 642302
# 737950  03503070196    7659          1125 SE Washington Ave     PO Box 642302
# 738026  49508830121    7609          3305 S 20th St Ste 150              None
# 738104  02802821002    7983          1979 Snyder St Ste 150              None
#
# ...

# %%
ppd = ppd.fillna('None')
ppd[(ppd.POLO_MAILING_STATE!='None')&(ppd.TELEPHONE_NUMBER=='None')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-a2bb69bd490e> in <module>
#       1 ppd = ppd.fillna('None')
# ----> 2 ppd[(ppd.POLO_MAILING_STATE!='None')&(ppd.TELEPHONE_NUMBER=='None')]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'POLO_MAILING_STATE'

# %%
ppd[(ppd.TOP_CD==20)]
# Out:
#                   ME RECORD_ID  UPDATE_TYPE ADDRESS_TYPE  \
# 0        00102000013         A            1            2
# 2        00102000030         A            1            1
# 3        00102000048         A            1            2
# 4        00102000056         A            1            2
# 5        00102000064         A            1            2
# ...              ...       ...          ...          ...
# 1281045  96501940019         A            1            1
# 1281046  96501950014         A            1            2
# 1281050  96501960036         A            1            2
# 1281051  96501960044         A            1            2
# 1281052  96501960052         A            1            2
#
#                     MAILING_NAME    LAST_NAME FIRST_NAME MIDDLE_NAME SUFFIX  \
# 0          MICHAEL J STANFORD MD     STANFORD    MICHAEL       JAMES   None
# 2              MARK T JACKSON MD      JACKSON       MARK      THOMAS   None
# ...

# %%
111719/819579
# Out:
# 0.1363126678453206

# %%
276,991

# %%
len(cred.drop_duplicates('ORG_ID'))
# Out:
# 3566

# %%
len(cred_phones.drop_duplicates('ORG_ID'))
# Out:
# 2298

# %%
2298/3566
# Out:
# 0.6444195176668536

# %%
len(FOR_FUN.drop_duplicates('ME'))
# Out:
# 365177

# %%
There are ~112K DPCs that have POLOs but no phone numbers on the ppd which is ~14% of DPCs

# %%
check = 15
string_check = 'Victoria {check}'
print(f'{string_check}')
# Out:
# Victoria {check}
