# %%
import pandas as pd
from nameparser import HumanName

# %%
yale = pd.read_csv('../../Data/Rosters/Yale_New_Haven_Health_2020-11-01.csv')
ucla = pd.read_csv('../../Data/Rosters/UCLA_Health_2020-11-01.csv')
orla = pd.read_csv('../../Data/Rosters/Orlando_Health_2020-11-01.csv')
nsuh = pd.read_csv('../../Data/Rosters/North_Shore_University_Health_2020-11-01.csv')
memo = pd.read_csv('../../Data/Rosters/Memorial_HealthCare_2020-11-01.csv')
lijm = pd.read_csv('../../Data/Rosters/Long_Island_jewish_Medical_2020-11-01.csv')
inno = pd.read_csv('../../Data/Rosters/Innova_Medical_2020-11-01.csv')
chri = pd.read_csv('../../Data/Rosters/Christiana_Care_2020-11-01.csv')
template = pd.read_excel('../../Data/Rosters/SIngle_Record_Roster_Template.xlsx')

# %%
template.columns
# Out:
# Index(['NAME', 'SPECIALTY', 'SECONDARY_SEPECIALTY', 'PHONE', 'FAX', 'EMAIL',
#        'LOCATION_NAME', 'LOCATION_ADDRESS', 'LOCATION_ADDRESS_CITY',
#        'LOCATION_ADDRESS_STATE', 'LOCATION_ADDRESS_ZIP', 'DEPARTMENT',
#        'PROGRAM', 'PARENT_ORG_NAME', 'TITLE', 'MED_SCHOOL_GRADUATION_YEAR',
#        'MED_SCHOOL', 'RESIDENCY_PROGRAM', 'DEGREE', 'LINK'],
#       dtype='object')

# %%
ppd = pd.read_csv('../../Data/PPD/ppd_data_20201107.csv', low_memory=False)

# %%
uthe['PARENT_ORG_NAME'] = 'UTHeath'
uthe = uthe.rename(columns={'LOCATION':'LOCATION_NAME'})

# %%
upmc = upmc.rename(columns = {'location':'LOCATION_NAME', 'address':'LOCATION_ADDRESS', 'address_2':'LOCATION_ADDRESS_2','city':'LOCATION_ADDRESS_CITY', 'zipcode':'LOCATION_ADDRESS_ZIPCODE'})

# %%
ohsu = ohsu.rename(columns = {'location':'LOCATION_NAME', 'address':'LOCATION_ADDRESS', 'city':'LOCATION_ADDRESS_CITY', 'zipcode':'LOCATION_ADDRESS_ZIP', 'specialities':'SPECIALTY'})

# %%
nych = nych.rename(columns = {'address':'LOCATION_ADDRESS', 'Specialty2':'SECONDARY_SPECIALTY'})

# %%
mayo = mayo.rename(columns = {'0':'LINK','1':'NAME','2':'SPECIALTY','3':'LOCATION_ADDRESS_CITY','4':'DATE'})
mayo
# Out:
#                                                    LINK  \
# 0     /biographies/aakre-christopher-chris-a-m-d/bio...
# 1       /biographies/abate-ejigayehu-g-m-d/bio-20055425
# 2        /biographies/abboud-charles-f-m-b/bio-20053030
# 3     /biographies/abcejo-arnoley-arney-s-m-d/bio-20...
# 4         /biographies/abdel-matthew-p-m-d/bio-20087325
# ...                                                 ...
# 1985     /biographies/neisen-melissa-j-m-d/bio-20089091
# 1986        /biographies/nelson-chad-r-m-d/bio-20055720
# 1987     /biographies/nelson-darlene-r-m-d/bio-20055652
# 1988         /biographies/nelson-heidi-m-d/bio-20053829
# 1989        /biographies/nelson-kent-d-m-d/bio-20053830
#
#                               NAME           SPECIALTY LOCATION_ADDRESS_CITY  \
# 0     Christopher (Chris) A. Aakre                 NaN         Rochester, MN
# 1               Ejigayehu G. Abate     Endocrinologist      Jacksonville, FL
# ...

# %%
mass = mass.rename(columns = {'0':'LINK','1':'NAME','2':'LOCATION_ADDRESS_CITY','3':'SPECIALTY','4':'PHONE','5':'LOCATION_NAME','6':'DATE'})

# %%
cinc = cinc.rename(columns = {'0':'LINK','1':'NAME','2':'PHONE','3':'TITLE','4':'LOCATION_NAME','5':'DATE'})

# %%
brig = brig.rename(columns = {'location':'LOCATION_NAME', 'address':'LOCATION_ADDRESS','FROM_DT':'date'})

# %%
beth = beth.rename(columns = {'0':'LINK','1':'NAME','2':'SPECIALTY','3':'PHONE','4':'FAX','5':'LOCATION_NAME','6':'LOCATION_ADDRESS','7':'DATE'})

# %%
ROSTERS = [uthe, upmc, ohsu, nort,
nych,
mayo,
mass,
hefo,
cinc,
brig,
lahe,
beth]

# %%
for roster in ROSTERS:
    roster.columns = [c.upper() for c in roster.columns.values]
    if 'FROM_DT' in list(roster.columns):
        roster['DATE'] = roster.FROM_DT

# %%
upmc = upmc.rename(columns = {'ADDRESS2':'LOCATION_ADDRESS_2'})

# %%
ohsu = ohsu.rename(columns = {'STATE':'LOCATION_ADDRESS_STATE'})
ohsu['PARENT_ORG_NAME']='OHSU'

# %%
nych['PARENT_ORG_NAME']='NYC Health'

# %%
mayo['PARENT_ORG_NAME']='MAYO'

# %%
mass['PARENT_ORG_NAME']='Massachusetts General Hospital'

# %%
cinc['PARENT_ORG_NAME']='Cincinnati Childrens Hospital'

# %%
brig['PARENT_ORG_NAME']='Brigham and Womens Health'

# %%
beth['PARENT_ORG_NAME']='Beth Israel Deaconess Medical Center'

# %%
nych = nych.rename(columns = {'ADDRESS':'LOCATION_ADDRESS'})

# %%
mayo['LOCATION_ADDRESS_STATE'] = [str(x)[-2:] for x in mayo.LOCATION_ADDRESS_CITY]
mayo['LOCATION_ADDRESS_CITY'] = [x.split(', ')[0] for x in mayo.LOCATION_ADDRESS_CITY]

# %%
dict_list =[]
for row in hefo.itertuples():
    office_index = 0
    office_list =row.OFFICES.replace('[','').replace(']','').split("', '")
    for office in office_list:
        print(office)
        new_dict = {'NAME': 'None',
        'SPECIALTY': 'None',
        'SECONDARY_SPECIALTY': 'None',
        'PHONE': 'None',
        'FAX': 'None',
        'LOCATION_NAME': 'None',
        'LOCATION_ADDRESS': 'None',
        'LOCATION_ADDRESS_CITY': 'None',
        'LOCATION_ADDRESS_STATE': 'None',
        'LOCATION_ADDRESS_ZIP': 'None',
        'DEPARTMENT': 'None',
        'PROGRAM': 'None',
        'PARENT_ORG_NAME': 'Henry Ford'}
        
        new_dict['LOCATION_NAME'] = office.replace("'","")
        address_list = row.ADDRESSES.replace('[','').replace(']','').split("', '")
        split_addresses = address_list[office_index].split(',')
        print(split_addresses)
        if len(split_addresses) == 3:
            new_dict['LOCATION_ADDRESS']=split_addresses[0].replace("'","")       
            new_dict['LOCATION_ADDRESS_CITY']=split_addresses[1]  
            new_dict['LOCATION_ADDRESS_STATE']=split_addresses[2].split(' ')[1]  
            new_dict['LOCATION_ADDRESS_ZIP']=split_addresses[2].split(' ')[2]  
            
        if len(split_addresses) == 4:
            new_dict['LOCATION_ADDRESS']=(split_addresses[0] + ',' + split_addresses[1]).replace("'","")    
            new_dict['LOCATION_ADDRESS_CITY']=split_addresses[2]  
            new_dict['LOCATION_ADDRESS_STATE']=split_addresses[3].split(' ')[1]  
            new_dict['LOCATION_ADDRESS_ZIP']=split_addresses[3].split(' ')[2]  
            
        new_dict['NAME']=row.NAME
        new_dict['SPECIALTY']=row.SPECIALTY
        new_dict['PHONE']=row.PHONE
        
        office_index += 1
        dict_list.append(new_dict)
# Out:
# 'Henry Ford Medical Center Sterling Heights
# ["'3500 15 Mile Rd", ' Sterling Heights', ' MI 48310 ']
# HFM Urgent Care - Bruce Twp
# ['80650 Van Dyke', ' Bruce Township', ' MI 48065 ']
# HFM Urgent Care - Chesterfield
# ['30795 23 Mile Rd', ' Chesterfield', ' MI 48047 ']
# HFM Urgent Care - Fraser'
# ['15717 15 Mile Rd', ' Clinton Township', " MI 48035 '"]
# 'None
# ["'133 W Main St", ' Ste 251', ' Northville', ' MI 48167 ']
# Abbasi Dermatology'
# ['21401 Allen Road', ' Woodhaven', " MI 48183 '"]
# 'Hillsdale Pulmonary Critical Care &
# ["'Sleep Medicine", ' 3271 W. Carleton Rd', ' Hillsdale', ' MI 49242 ']
# Tariq H. Abdelkarim, MD'
# ['605 W. Chicago Street', ' Coldwater', " MI 49036 '"]
# 'Henry Ford Medical Center - Fairlane
# ["'19401 Hubbard Dr", ' Dearborn', ' MI 48126 ']
# Henry Ford Medical Center - Lakeside'
# ['14500 Hall Rd', ' Sterling Hgts', " MI 48313 '"]
# 'Henry Ford Medical Center - Taylor'
# ["'24555 Haig Rd", ' Taylor', " MI 48180 '"]
# ...

# %%
hefo = pd.DataFrame(dict_list)

# %%
uthe['PHONE']=uthe['TELEPHONE']

# %%
all_info = pd.DataFrame()
for roster in ROSTERS:
    for col in template.columns:
        if col not in list(roster.columns):
            roster[col] = 'None'
    print(roster.columns)
    roster_2 = roster[list(template.columns)]
    all_info = pd.concat([all_info, roster_2])
# Out:
# Index(['LINK', 'NAME', '2', '3', 'LOCATION_NAME', 'TELEPHONE', 'DATE',
#        'PARENT_ORG_NAME', 'SPECIALTY', 'SECONDARY_SEPECIALTY', 'PHONE', 'FAX',
#        'EMAIL', 'LOCATION_ADDRESS', 'LOCATION_ADDRESS_CITY',
#        'LOCATION_ADDRESS_STATE', 'LOCATION_ADDRESS_ZIP', 'DEPARTMENT',
#        'PROGRAM', 'TITLE', 'MED_SCHOOL_GRADUATION_YEAR', 'MED_SCHOOL',
#        'RESIDENCY_PROGRAM', 'DEGREE'],
#       dtype='object')
# Index(['LINK', 'NAME', 'SPECIALTY', 'LOCATION_NAME', 'LOCATION_ADDRESS',
#        'LOCATION_ADDRESS_2', 'LOCATION_ADDRESS_CITY',
#        'LOCATION_ADDRESS_ZIPCODE', 'PHONE', 'SECONDARY_SEPECIALTY', 'FAX',
#        'EMAIL', 'LOCATION_ADDRESS_STATE', 'LOCATION_ADDRESS_ZIP', 'DEPARTMENT',
#        'PROGRAM', 'PARENT_ORG_NAME', 'TITLE', 'MED_SCHOOL_GRADUATION_YEAR',
#        'MED_SCHOOL', 'RESIDENCY_PROGRAM', 'DEGREE'],
#       dtype='object')
# Index(['LINK', 'NAME', 'SPECIALTY', 'FOCUS', 'LOCATION_NAME', 'PHONE',
# ...

# %%
BOPBOP = ALL_INFO.drop_duplicates(['NAME','LOCATION_ADDRESS','LOCATION_NAME','PHONE','LINK'])

# %%
def split_names(roster_df):
    '''Splits name column into components'''
    roster_df = roster_df.drop_duplicates()
    roster_df.columns = [c.upper() for c in roster_df.columns.values]
    dict_list = []
    for row in roster_df.itertuples():
        name_parsed = HumanName(row.NAME)
        name_dict = {
            'NAME': row.NAME,
            'FIRST_NAME': name_parsed.first.upper(),
            'LAST_NAME': name_parsed.last.upper(),
            'MIDDLE_NAME': name_parsed.middle.upper(),
            'SUFFIX': name_parsed.suffix.upper(),
            'NICKNAME': name_parsed.nickname.upper(),
            'TITLE': name_parsed.title.upper(),
        }
        dict_list.append(name_dict)
    name_df = pd.DataFrame(dict_list)
    new_df = pd.merge(name_df, roster_df, on='NAME', how='right')
    return new_df

# %%
ALL_INFO = split_names(all_info)

# %%
ppd = pd.read_csv('../../Data/PPD/ppd_data_20201010.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,20,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
PPD = ppd[['ME', 'MAILING_NAME',
       'LAST_NAME', 'FIRST_NAME', 'MIDDLE_NAME', 'SUFFIX', 'MAILING_LINE_1',
       'MAILING_LINE_2', 'CITY', 'STATE', 'ZIP' ,'MD_DO_CODE' ,'GENDER',
       'TELEPHONE_NUMBER' ,'MEDSCHOOL_STATE', 'MEDSCHOOL_ID',
       'MEDSCHOOL_GRAD_YEAR' ,'POLO_MAILING_LINE_1', 'POLO_MAILING_LINE_2',
       'POLO_CITY', 'POLO_STATE', 'POLO_ZIP']]

# %%
all_matches = pd.merge(PPD, ALL_INFO, on = ['LAST_NAME','FIRST_NAME'])

# %%
perfect = all_matches.drop_duplicates('NAME', keep=False)

# %%
perfect = perfect.fillna('None')
perfect[(perfect.TELEPHONE_NUMBER=='None')&(perfect.PHONE!='None')][['POLO_MAILING_LINE_2','POLO_CITY','LOCATION_ADDRESS_CITY','LOCATION_ADDRESS']]
# Out:
#             POLO_MAILING_LINE_2   POLO_CITY LOCATION_ADDRESS_CITY  \
# 4036     571 S FLOYD ST STE 300  LOUISVILLE            Louisville
# 4283             6431 FANNIN ST     HOUSTON                  None
# 4416              4401 PENN AVE  PITTSBURGH            Pittsburgh
# 14737              3459 5TH AVE  PITTSBURGH            Pittsburgh
# 14938                      None        None                  None
# ...                         ...         ...                   ...
# 111684  8708 JUSTICE AVE STE 1B    ELMHURST                  None
# 111690                     None        None                  None
# 111694                     None        None                  None
# 111708            3959 BROADWAY    NEW YORK                  None
# 111764       1111 AMSTERDAM AVE    NEW YORK                  None
#
#                                          LOCATION_ADDRESS
# 4036                           9880 Angies Way, Suite 330
# ...

# %%
perfect[(perfect.POLO_MAILING_LINE_2=='None')&(perfect.LOCATION_ADDRESS!='None')][['POLO_MAILING_LINE_2','POLO_CITY','LOCATION_ADDRESS_CITY','LOCATION_ADDRESS']]
# Out:
#        POLO_MAILING_LINE_2 POLO_CITY LOCATION_ADDRESS_CITY  \
# 8423                  None      None                  None
# 14938                 None      None                  None
# 19360                 None      None          Williamsport
# 19488                 None      None              Portland
# 19915                 None      None                  None
# ...                    ...       ...                   ...
# 111536                None      None               Melrose
# 111560                None      None                  None
# 111690                None      None                  None
# 111694                None      None                  None
# 111723                None      None                  None
#
#                                          LOCATION_ADDRESS
# 8423    NYC Health + Hospitals/Coney Island 2601 Ocean...
# 14938   NYC Health + Hospitals/Queens 82-68 164th Stre...
# 19360                                     700 High Street
# ...

# %%
ALL_INFO[ALL_INFO.PARENT_ORG_NAME=='None']
# Out:
#                           NAME FIRST_NAME   LAST_NAME MIDDLE_NAME SUFFIX  \
# 720                 Bela Patel       BELA       PATEL
# 721                 Bela Patel       BELA       PATEL
# 722                 Bela Patel       BELA       PATEL
# 723                 Bela Patel       BELA       PATEL
# 724                 Bela Patel       BELA       PATEL
# ...                        ...        ...         ...         ...    ...
# 55414          Craig Alexander      CRAIG   ALEXANDER
# 55415   Elizabeth A. Alexander  ELIZABETH   ALEXANDER          A.
# 55416     Eirene G. Alexandrou     EIRENE  ALEXANDROU          G.
# 55417                Faiza Ali      FAIZA         ALI
# 55418            Amil H. Allen       AMIL       ALLEN          H.
#
#       NICKNAME TITLE_x        SPECIALTY SECONDARY_SEPECIALTY         PHONE  \
# 720                     Family Medicine                 None  724-933-7117
# 721                     Family Medicine                 None  724-933-7117
# ...

# %%
mass
# Out:
#                                                 LINK                  NAME  \
# 0  https://www.massgeneral.org/doctors/20205/Emil...        Emily-Aaronson
# 1  https://www.massgeneral.org/doctors/20845/Matt...        Matthew-Abadir
# 2  https://www.massgeneral.org/doctors/17130/Laur...         Lauren-Abbate
# 3  https://www.massgeneral.org/doctors/17947/Gera...         Gerald-Abbott
# 4  https://www.massgeneral.org/doctors/20820/Shad...  Shadi-Abdar-Esfahani
# 5  https://www.massgeneral.org/doctors/18674/John...            John-Ablon
# 6  https://www.massgeneral.org/doctors/17107/Dian...    Diane-Abraczinskas
# 7  https://www.massgeneral.org/doctors/18015/Meli...       Melissa-Abraham
# 8  https://www.massgeneral.org/doctors/16829/Step...       Stephen-Abraham
# 9  https://www.massgeneral.org/doctors/17070/Anna...          Annah-Abrams
#
#   LOCATION_ADDRESS_CITY                                          SPECIALTY  \
# ...

# %%
mass_2 = pd.read_csv('../../Data/Rosters/Massachusetts_Scrape_2020-10-15.csv')

# %%
mass_2
# Out:
#                                                    0                     1  \
# 0  https://www.massgeneral.org/doctors/20205/Emil...        Emily-Aaronson
# 1  https://www.massgeneral.org/doctors/20845/Matt...        Matthew-Abadir
# 2  https://www.massgeneral.org/doctors/17130/Laur...         Lauren-Abbate
# 3  https://www.massgeneral.org/doctors/17947/Gera...         Gerald-Abbott
# 4  https://www.massgeneral.org/doctors/20820/Shad...  Shadi-Abdar-Esfahani
# 5  https://www.massgeneral.org/doctors/18674/John...            John-Ablon
# 6  https://www.massgeneral.org/doctors/17107/Dian...    Diane-Abraczinskas
# 7  https://www.massgeneral.org/doctors/18015/Meli...       Melissa-Abraham
# 8  https://www.massgeneral.org/doctors/16829/Step...       Stephen-Abraham
# 9  https://www.massgeneral.org/doctors/17070/Anna...          Annah-Abrams
#
#         2                                                  3             4  \
# ...

# %%
len(cinc)
# Out:
# 140

# %%
cinc
# Out:
#                                                   LINK  \
# 0    https://www.cincinnatichildrens.org/bio/a/juan...
# 1    https://www.cincinnatichildrens.org/bio/a/mich...
# 2    https://www.cincinnatichildrens.org/bio/a/mais...
# 3    https://www.cincinnatichildrens.org/bio/a/robi...
# 4    https://www.cincinnatichildrens.org/bio/a/heid...
# ..                                                 ...
# 135  https://www.cincinnatichildrens.org/bio/a/crai...
# 136  https://www.cincinnatichildrens.org/bio/a/eliz...
# 137  https://www.cincinnatichildrens.org/bio/a/eire...
# 138  https://www.cincinnatichildrens.org/bio/a/faiz...
# 139  https://www.cincinnatichildrens.org/bio/a/amil...
#
#                         NAME         PHONE  \
# 0            J. Pablo Abonia  513-636-6771
# 1         Michael J. Absalon  513-636-3200
# 2     Maisam A. Abu-El-Haija  513-636-3200
# 3             Robin J. Adams  513-636-3200
# 4            Heidi R. Adkins  513-636-3200
# ...

# %%
for roster in ROSTERS:
    print(len(roster))
# Out:
# 1042
# 30202
# 790
# 2844
# 395540
# 1990
# 10
# 774
# 140
# 192
# 1644
# 2880

# %%
[uthe, upmc, ohsu, nort,
nych,
mayo,
mass,
hefo,
cinc,
brig,
lahe,
beth]

# %%
BOP = pd.read_csv('../../Data/Rosters/NYC_Healthplus_2020-10-15.csv')
len(BOP)
# Out:
# 395540

# %%
uthe[['NAME', 'SPECIALTY', 'PHONE', 'LOCATION_NAME',
       'LOCATION_ADDRESS', 'SECONDARY_SEPECIALTY', 
       'DEPARTMENT',
       'PROGRAM', 'TITLE', 'MED_SCHOOL_GRADUATION_YEAR', 'MED_SCHOOL',
       'RESIDENCY_PROGRAM', 'DEGREE']]
# Out:
#                        NAME SPECIALTY PHONE  \
# 0            Aamir A. Abbas      None  None
# 1     Lourice K. Abdelmelek      None  None
# 2              Humaira Abid      None  None
# 3           Cilymol Abraham      None  None
# 4           Simi M. Abraham      None  None
# ...                     ...       ...   ...
# 1037        Jay-Jiguang Zhu      None  None
# 1038        Hallie A. Zietz      None  None
# 1039           Amina Zubair      None  None
# 1040         Amber Zulfiqar      None  None
# 1041   Giovana Zunta-Soares      None  None
#
#                                           LOCATION_NAME LOCATION_ADDRESS  \
# 0     Center for Advanced Heart Failure – Texas Medi...             None
# 1              UT Physicians Family Practice – Bellaire             None
# 2                 UT Physicians Multispecialty – Greens             None
# 3                 UT Physicians Multispecialty – Greens             None
# ...

# %%
mayo
# Out:
#                                                    LINK  \
# 0     /biographies/aakre-christopher-chris-a-m-d/bio...
# 1       /biographies/abate-ejigayehu-g-m-d/bio-20055425
# 2        /biographies/abboud-charles-f-m-b/bio-20053030
# 3     /biographies/abcejo-arnoley-arney-s-m-d/bio-20...
# 4         /biographies/abdel-matthew-p-m-d/bio-20087325
# ...                                                 ...
# 1985     /biographies/neisen-melissa-j-m-d/bio-20089091
# 1986        /biographies/nelson-chad-r-m-d/bio-20055720
# 1987     /biographies/nelson-darlene-r-m-d/bio-20055652
# 1988         /biographies/nelson-heidi-m-d/bio-20053829
# 1989        /biographies/nelson-kent-d-m-d/bio-20053830
#
#                               NAME           SPECIALTY LOCATION_ADDRESS_CITY  \
# 0     Christopher (Chris) A. Aakre                 NaN             Rochester
# 1               Ejigayehu G. Abate     Endocrinologist          Jacksonville
# ...

# %%
for roster in ROSTERS:
    roster_2 = split_names(roster)
    print(len(pd.merge(PPD, roster_2, on = ['LAST_NAME','FIRST_NAME']).drop_duplicates('NAME')))
# Out:
# 734
# 3264
# 458
# 640
# 5694
# 1677
# 0
# 304
# 15
# 162
# 1170
# 43

# %%
uthe.drop_duplicates('NAME')
# Out:
#                                                    LINK  \
# 0     https://www.utphysicians.com/provider/aamir-a-...
# 1     https://www.utphysicians.com/provider/lourice-...
# 2     https://www.utphysicians.com/provider/humaira-...
# 3     https://www.utphysicians.com/provider/cilymol-...
# 4     https://www.utphysicians.com/provider/simi-m-a...
# ...                                                 ...
# 1037  https://www.utphysicians.com/provider/jay-jigu...
# 1038  https://www.utphysicians.com/provider/hallie-a...
# 1039  https://www.utphysicians.com/provider/amina-zu...
# 1040  https://www.utphysicians.com/provider/amber-zu...
# 1041  https://www.utphysicians.com/provider/giovana-...
#
#                        NAME     2     3  \
# 0            Aamir A. Abbas  None  None
# 1     Lourice K. Abdelmelek  None  None
# 2              Humaira Abid  None  None
# 3           Cilymol Abraham  None  None
# 4           Simi M. Abraham  None  None
# ...                     ...   ...   ...
# ...

# %%
mass['NAME']=[x.replace('-',' ') for x in mass.NAME]

# %%
roster_2 = split_names(mass)
print(len(pd.merge(PPD, roster_2, on = ['LAST_NAME','FIRST_NAME']).drop_duplicates('NAME')))
# Out:
# 7

# %%
roster_2
# Out:
#                    NAME FIRST_NAME     LAST_NAME MIDDLE_NAME SUFFIX NICKNAME  \
# 0        Emily Aaronson      EMILY      AARONSON
# 1        Matthew Abadir    MATTHEW        ABADIR
# 2         Lauren Abbate     LAUREN        ABBATE
# 3         Gerald Abbott     GERALD        ABBOTT
# 4  Shadi Abdar Esfahani      SHADI      ESFAHANI       ABDAR
# 5            John Ablon       JOHN         ABLON
# 6    Diane Abraczinskas      DIANE  ABRACZINSKAS
# 7       Melissa Abraham    MELISSA       ABRAHAM
# 8       Stephen Abraham    STEPHEN       ABRAHAM
# 9          Annah Abrams      ANNAH        ABRAMS
#
#   TITLE_x                                               LINK  \
# 0          https://www.massgeneral.org/doctors/20205/Emil...
# 1          https://www.massgeneral.org/doctors/20845/Matt...
# 2          https://www.massgeneral.org/doctors/17130/Laur...
# 3          https://www.massgeneral.org/doctors/17947/Gera...
# 4          https://www.massgeneral.org/doctors/20820/Shad...
# ...

# %%
perfect
# Out:
#                  ME              MAILING_NAME     LAST_NAME  FIRST_NAME  \
# 192       102020693  KRISTOPHER W CUMMINGS MD      CUMMINGS  KRISTOPHER
# 209       102021231           JILL ADAMSKI MD       ADAMSKI        JILL
# 3460      102061268        MATTHEW N ALDER MD         ALDER     MATTHEW
# 4035      102090365    ERIK H MIDDLEBROOKS MD  MIDDLEBROOKS        ERIK
# 4036      102090829       DANIELLE M GRAFF MD         GRAFF    DANIELLE
# ...             ...                       ...           ...         ...
# 111758  95708870022           OGNJEN GAJIC MD         GAJIC      OGNJEN
# 111763  95708890066       NERMICA SARCEVIC MD      SARCEVIC     NERMICA
# 111764  95708890074    GORDANA STJEPANOVIC MD   STJEPANOVIC     GORDANA
# 111765  95708900088           AMELA BLEKIC MD        BLEKIC       AMELA
# 111766  95708940012            EMIR FESTIC MD        FESTIC        EMIR
#
#        MIDDLE_NAME_x SUFFIX_x               MAILING_LINE_1  \
# ...

# %%
all_matches.drop_duplicates('NAME')
# Out:
#                  ME            MAILING_NAME    LAST_NAME FIRST_NAME  \
# 0         102010396          AMIT K SHAH MD         SHAH       AMIT
# 96        102010655      LISA H WILLIAMS MD     WILLIAMS       LISA
# 132       102011112         ERIC S MOORE MD        MOORE       ERIC
# 138       102011121     CHARLES M GRAHAM MD       GRAHAM    CHARLES
# 149       102011627    JENNIFER A GEIGER MD       GEIGER   JENNIFER
# ...             ...                     ...          ...        ...
# 111759  95708870162          NAGIB MANOV MD        MANOV      NAGIB
# 111763  95708890066     NERMICA SARCEVIC MD     SARCEVIC    NERMICA
# 111764  95708890074  GORDANA STJEPANOVIC MD  STJEPANOVIC    GORDANA
# 111765  95708900088         AMELA BLEKIC MD       BLEKIC      AMELA
# 111766  95708940012          EMIR FESTIC MD       FESTIC       EMIR
#
#        MIDDLE_NAME_x  SUFFIX_x MAILING_LINE_1              MAILING_LINE_2  \
# 0         KIRITKUMAR       NaN            NaN               512 GARDEN DR
# ...

# %%
ppd = pd.read_csv('../../Data/PPD/ppd_data_20200201.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (13,20,42,49,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ppd[(ppd.FIRST_NAME=='SIDDHARTH')&(ppd.BIRTH_YEAR==1963.0)][['ME','MAILING_NAME',
       'LAST_NAME', 'FIRST_NAME', 'MIDDLE_NAME', 'SUFFIX', 'MD_DO_CODE', 'BIRTH_YEAR',
       'POLO_MAILING_LINE_1', 'POLO_MAILING_LINE_2',
       'POLO_CITY', 'POLO_STATE']]
# Out:
#                   ME         MAILING_NAME LAST_NAME FIRST_NAME MIDDLE_NAME  \
# 177893    1601901036   SIDDHARTH SINGH MD     SINGH  SIDDHARTH         NaN
# 1055218  49516880138  SIDDHARTH G JAIN MD      JAIN  SIDDHARTH           G
#
#          SUFFIX  MD_DO_CODE  BIRTH_YEAR        POLO_MAILING_LINE_1  \
# 177893      NaN           1      1963.0                 BASS MD PA
# 1055218     NaN           1      1963.0  TEXAS UROLOGY SPECIALISTS
#
#             POLO_MAILING_LINE_2     POLO_CITY POLO_STATE
# 177893          1257 NE 94TH ST  MIAMI SHORES         FL
# 1055218  2705 PRINCE GEORGE AVE        DESOTO         TX

# %%
ppd.columns
# Out:
# Index(['ME', 'RECORD_ID', 'UPDATE_TYPE', 'ADDRESS_TYPE', 'MAILING_NAME',
#        'LAST_NAME', 'FIRST_NAME', 'MIDDLE_NAME', 'SUFFIX', 'MAILING_LINE_1',
#        'MAILING_LINE_2', 'CITY', 'STATE', 'ZIP', 'SECTOR', 'CARRIER_ROUTE',
#        'ADDRESS_UNDELIVERABLE_FLAG', 'FIPS_COUNTY', 'FIPS_STATE',
#        'PRINTER_CONTROL_CODE', 'PC_ZIP', 'PC_SECTOR', 'DELIVERY_POINT_CODE',
#        'CHECK_DIGIT', 'PRINTER_CONTROL_CODE_2', 'REGION', 'DIVISION', 'GROUP',
#        'TRACT', 'SUFFIX_CENSUS', 'BLOCK_GROUP', 'MSA_POPULATION_SIZE',
#        'MICRO_METRO_IND', 'CBSA', 'CBSA_DIV_IND', 'MD_DO_CODE', 'BIRTH_YEAR',
#        'BIRTH_CITY', 'BIRTH_STATE', 'BIRTH_COUNTRY', 'GENDER',
#        'TELEPHONE_NUMBER', 'PRESUMED_DEAD_FLAG', 'FAX_NUMBER', 'TOP_CD',
#        'PE_CD', 'PRIM_SPEC_CD', 'SEC_SPEC_CD', 'MPA_CD', 'PRA_RECIPIENT',
#        'PRA_EXP_DT', 'GME_CONF_FLG', 'FROM_DT', 'TO_DT', 'YEAR_IN_PROGRAM',
#        'POST_GRADUATE_YEAR', 'GME_SPEC_1', 'GME_SPEC_2', 'TRAINING_TYPE',
# ...

# %%
beth.columns
# Out:
# Index(['LINK', 'NAME', 'SPECIALTY', 'PHONE', 'FAX', 'LOCATION_NAME',
#        'LOCATION_ADDRESS', 'DATE', '8', '9', '10', 'PARENT_ORG_NAME',
#        'SECONDARY_SEPECIALTY', 'EMAIL', 'LOCATION_ADDRESS_CITY',
#        'LOCATION_ADDRESS_STATE', 'LOCATION_ADDRESS_ZIP', 'DEPARTMENT',
#        'PROGRAM', 'TITLE', 'MED_SCHOOL_GRADUATION_YEAR', 'MED_SCHOOL',
#        'RESIDENCY_PROGRAM', 'DEGREE'],
#       dtype='object')

# %%
beth['LOCATION_ADDRESS_ZIP']=beth['9']

# %%
beth[['DATE','LOCATION_NAME','LOCATION_ADDRESS','LOCATION_ADDRESS_CITY',
       'LOCATION_ADDRESS_STATE', 'LOCATION_ADDRESS_ZIP', 'DEPARTMENT']][5:20]
# Out:
#                                     DATE  \
# 5                    275 Sandwich Street
# 6                     110 Francis Street
# 7       Department of Radiation Oncology
# 8                          1000 Broadway
# 9           Division of General Medicine
# 10                   148 Chestnut Street
# 11      Department of Emergency Medicine
# 12          Division of General Medicine
# 13          Division of General Medicine
# 14             Center for Specialty Care
# 15                    110 Francis Street
# 16                    570 Lafayette Road
# 17  Beth Israel Deaconess Medical Center
# 18                      185 Pilgrim Road
# 19  Division of Interventional Radiology
#
#                                         LOCATION_NAME  \
# 5         Beth Israel Deaconess HealthCare - Plymouth
# 6                   BIDMC - Division of Endocrinology
# 7                Beth Israel Deaconess Medical Center
# 8   Beth Israel Deaconess HealthCare Chelsea - Adu...
# ...

# %%
beth_list = []
for entry in beth.DATE:
    loc_name = 'None'
    add_2 = 'None'
    dept = 'None'
    add_1 = 'None'
    if 'Beth Israel Deaconess Medical Center' in entry:
        loc_name = entry
    elif 'Center' in entry:
        add_2 = entry
    elif 'Division' in entry:
        add_2 = entry
    elif 'Department' in entry:
        dept = entry
    elif entry.split(' ')[0].isnumeric():
        add_1 = entry
    else:
        add_2 = entry
    new_dict = {
        'LOCATION_NAME': loc_name,
        'LOCATION_ADDRESS_2': add_2,
        'LOCATION_ADDRESS': add_1,
        'DEPARTMENT': dept
    }
    beth_list.append(new_dict)

# %%
beth.columns
# Out:
# Index(['LINK', 'NAME', 'SPECIALTY', 'PHONE', 'FAX', 'LOCATION_NAME',
#        'LOCATION_ADDRESS', 'DATE', '8', '9', '10', 'PARENT_ORG_NAME',
#        'SECONDARY_SEPECIALTY', 'EMAIL', 'LOCATION_ADDRESS_CITY',
#        'LOCATION_ADDRESS_STATE', 'LOCATION_ADDRESS_ZIP', 'DEPARTMENT',
#        'PROGRAM', 'TITLE', 'MED_SCHOOL_GRADUATION_YEAR', 'MED_SCHOOL',
#        'RESIDENCY_PROGRAM', 'DEGREE'],
#       dtype='object')

# %%
beth_list = []
for row in beth.itertuples():
    entry = row.DATE
    loc_name = row.LOCATION_NAME
    add_2 = 'None'
    dept = row.DEPARTMENT
    add_1 = row.LOCATION_ADDRESS
    if 'Beth Israel Deaconess Medical Center' in entry:
        print(loc_name)
        loc_name = entry
    elif 'Center' in entry:
        add_2 = entry
    elif 'Division' in entry:
        add_2 = entry
    elif 'Department' in entry:
        print(dept)
        dept = entry
    elif entry.split(' ')[0].isnumeric():
        if '\n' not in add_1:
            add_2 = add_1
        add_1 = entry
    else:
        add_2 = entry
    new_dict = {
        'LOCATION_NAME': loc_name,
        'LOCATION_ADDRESS_2': add_2,
        'LOCATION_ADDRESS': add_1,
        'DEPARTMENT': dept
    }
    beth_list.append(new_dict)
# Out:
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# Healthcare Associates
# None
# None
# None
# None
# ...

# %%
beth_list[0:60]
# Out:
# [{'LOCATION_NAME': 'Beth Israel Deaconess Medical Center',
#   'LOCATION_ADDRESS_2': 'The Transplant Center',
#   'LOCATION_ADDRESS': '110 Francis Street, 7th floor',
#   'DEPARTMENT': 'None'},
#  {'LOCATION_NAME': 'Beth Israel Deaconess Medical Center',
#   'LOCATION_ADDRESS_2': 'Division of General Medicine',
#   'LOCATION_ADDRESS': '330 Brookline Avenue, W/SPAN-2',
#   'DEPARTMENT': 'None'},
#  {'LOCATION_NAME': 'Beth Israel Deaconess Medical Center',
#   'LOCATION_ADDRESS_2': 'Division of General Medicine',
#   'LOCATION_ADDRESS': '330 Brookline Avenue, W/SPAN-2',
#   'DEPARTMENT': 'None'},
#  {'LOCATION_NAME': 'Beth Israel Deaconess Medical Center',
#   'LOCATION_ADDRESS_2': 'None',
#   'LOCATION_ADDRESS': '330 Brookline Avenue, Shapiro 2',
#   'DEPARTMENT': 'Department of Orthopaedics'},
#  {'LOCATION_NAME': 'BIDHC Extended Care Community Program',
#   'LOCATION_ADDRESS_2': 'Suite 304',
#   'LOCATION_ADDRESS': '464 Hillside Avenue',
#   'DEPARTMENT': 'None'},
# ...

# %%
x = '\nPlymouth,\r\n\r\n\t\t\t\t\tMA\xa0\r\n\r\n\t\t\t\t02360-2183\n'
str(x.replace('\n','').replace('\r','').replace('\t','')).split('x')
# Out:
# ['Plymouth,MA\xa002360-2183']

# %%
beth = beth[['LINK', 'NAME', 'SPECIALTY', 'PHONE', 'FAX', 'PARENT_ORG_NAME',
       'SECONDARY_SEPECIALTY', 'EMAIL', 'LOCATION_ADDRESS_CITY',
       'LOCATION_ADDRESS_STATE', 'LOCATION_ADDRESS_ZIP', 
       'PROGRAM', 'TITLE', 'MED_SCHOOL_GRADUATION_YEAR', 'MED_SCHOOL',
       'RESIDENCY_PROGRAM', 'DEGREE']]

# %%
beth = beth.drop_duplicates('NAME')

# %%
beth[beth['NAME']=='Alexander P. Abadir, MD']
# Out:
#                                                    LINK  \
# 1     https://findadoc.bidmc.org/details/4353/alexan...
# 49    https://findadoc.bidmc.org/details/4353/alexan...
# 97    https://findadoc.bidmc.org/details/4353/alexan...
# 145   https://findadoc.bidmc.org/details/4353/alexan...
# 193   https://findadoc.bidmc.org/details/4353/alexan...
# 241   https://findadoc.bidmc.org/details/4353/alexan...
# 289   https://findadoc.bidmc.org/details/4353/alexan...
# 337   https://findadoc.bidmc.org/details/4353/alexan...
# 385   https://findadoc.bidmc.org/details/4353/alexan...
# 433   https://findadoc.bidmc.org/details/4353/alexan...
# 481   https://findadoc.bidmc.org/details/4353/alexan...
# 529   https://findadoc.bidmc.org/details/4353/alexan...
# 577   https://findadoc.bidmc.org/details/4353/alexan...
# 625   https://findadoc.bidmc.org/details/4353/alexan...
# 673   https://findadoc.bidmc.org/details/4353/alexan...
# 721   https://findadoc.bidmc.org/details/4353/alexan...
# ...

# %%
beth.groupby(['NAME','LOCATION_ADDRESS']).count()
# Out:
#                                                                                    LINK  \
# NAME                           LOCATION_ADDRESS
# Alexander P. Abadir, MD        330 Brookline Avenue, W/SPAN-2                        60
# Alyaa Al-Ibraheemi, MD         330 Brookline Avenue, E106                            60
# Amanda Kindred Anastasi, MD    330 Brookline Avenue, Yamins 2                        60
# Amtul Aala, MD                 110 Francis Street, 7th floor                         60
# Andrew C. Ahn, MD              330 Brookline Avenue, W/SPAN-2                        60
# Anjali P. Ahn, MD              330 Brookline Avenue, Shapiro 7                       60
# Anne-Marie Anagnostopoulos, MD Shapiro 7                                             60
# Asha M. Anandaiah, MD          330 Brookline Avenue, Shapiro 7                       60
# Asimenia Angelidou, MD         \nBoston,\r\n\r\n\t\t\t\t\tMA \r\n\r\n\t\t\t\t0...    60
# ...

# %%
pd.DataFrame(beth_list)[0:48]
# Out:
#                                         LOCATION_NAME  \
# 0                Beth Israel Deaconess Medical Center
# 1                Beth Israel Deaconess Medical Center
# 2                Beth Israel Deaconess Medical Center
# 3                Beth Israel Deaconess Medical Center
# 4               BIDHC Extended Care Community Program
# 5         Beth Israel Deaconess HealthCare - Plymouth
# 6                   BIDMC - Division of Endocrinology
# 7                Beth Israel Deaconess Medical Center
# 8   Beth Israel Deaconess HealthCare Chelsea - Adu...
# 9                Beth Israel Deaconess Medical Center
# 10  Beth Israel Deaconess Hospital - Needham Hospi...
# 11               Beth Israel Deaconess Medical Center
# 12               Beth Israel Deaconess Medical Center
# 13               Beth Israel Deaconess Medical Center
# 14            Beth Israel Deaconess Hospital - Milton
# 15  BIDMC - Division of Gastroenterology/Liver Center
# ...

# %%
beth[['LOCATION_NAME','LOCATION_ADDRESS_2','LOCATION_ADDRESS','DEPARTMENT']] = pd.DataFrame(beth_list)[0:48]

# %%
beth
# Out:
#                                                  LINK  \
# 0   https://findadoc.bidmc.org/details/3480/amtul-...
# 1   https://findadoc.bidmc.org/details/4353/alexan...
# 2   https://findadoc.bidmc.org/details/2627/bassim...
# 3   https://findadoc.bidmc.org/details/1/ayesha-ab...
# 4   https://findadoc.bidmc.org/details/2/dorina-ab...
# 5   https://findadoc.bidmc.org/details/2248/charbe...
# 6   https://findadoc.bidmc.org/details/3/martin-ab...
# 7   https://findadoc.bidmc.org/details/2601/matthe...
# 8   https://findadoc.bidmc.org/details/5/jose-abre...
# 9   https://findadoc.bidmc.org/details/3481/mahmou...
# 10  https://findadoc.bidmc.org/details/1869/lopamu...
# 11  https://findadoc.bidmc.org/details/2891/jamie-...
# 12  https://findadoc.bidmc.org/details/4354/jason-...
# 13  https://findadoc.bidmc.org/details/2674/matthe...
# 14  https://findadoc.bidmc.org/details/2837/souhei...
# 15  https://findadoc.bidmc.org/details/9/nezam-afd...
# ...

# %%
beth.to_csv('../../Data/Rosters/beth_israel_cleaned.csv',index=False)

# %%
beth = split_names(beth)

# %%
PPD = ppd[['ME', 'MAILING_NAME',
       'LAST_NAME', 'FIRST_NAME', 'MIDDLE_NAME', 'SUFFIX', 'MAILING_LINE_1',
       'MAILING_LINE_2', 'CITY', 'STATE', 'ZIP', 'MD_DO_CODE', 
       'TELEPHONE_NUMBER',  'PRIM_SPEC_CD', 'SEC_SPEC_CD', 
       'MEDSCHOOL_GRAD_YEAR',  'POLO_MAILING_LINE_1', 'POLO_MAILING_LINE_2',
       'POLO_CITY', 'POLO_STATE', 'POLO_ZIP', 'POLO_SECTOR']]

# %%
spec = pd.read_csv('../../Data/PPD/speciality_id.csv')

# %%
ppd_spec = pd.merge(PPD, spec, left_on='PRIM_SPEC_CD', right_on='SPEC_CD')
ppd_spec = pd.merge(ppd_spec, spec, left_on='SEC_SPEC_CD', right_on='SPEC_CD', suffixes = ['_PRIM', '_SEC'])

# %%
ppd_spec['DEGREE']=['MD' if x==1 else 'DO' for x in ppd_spec.MD_DO_CODE]

# %%
yale=split_names(yale)

# %%
pd.merge(yale, ppd_spec, on=['FIRST_NAME','LAST_NAME','DEGREE'])
# Out:
#                       NAME FIRST_NAME   LAST_NAME MIDDLE_NAME_x SUFFIX_x  \
# 0      Susan Gail M. Parke      SUSAN       PARKE       GAIL M.
# 1            Haddon Pantel     HADDON      PANTEL
# 2            Haddon Pantel     HADDON      PANTEL
# 3            Haddon Pantel     HADDON      PANTEL
# 4            Haddon Pantel     HADDON      PANTEL
# ...                    ...        ...         ...           ...      ...
# 26496     Nina R. Horowitz       NINA    HOROWITZ            R.
# 26497    Mustafa K. Khokha    MUSTAFA      KHOKHA            K.
# 26498   Timothy Van Deusen    TIMOTHY  VAN DEUSEN
# 26499    Mark T. Silvestri       MARK   SILVESTRI            T.
# 26500         Jack Porrino       JACK     PORRINO
#
#       NICKNAME TITLE                                               LINK  \
# 0                     https://www.ynhh.org:443/physicians/susan-gail...
# 1                     https://www.ynhh.org:443/physicians/haddon-pan...
# ...

# %%
yale.MED_SCHOOL_GRAD_YEAR
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 13458    None
# 13459    None
# 13460    None
# 13461    None
# 13462    None
# Name: MED_SCHOOL_GRAD_YEAR, Length: 13463, dtype: object

# %%
ppd_spec['MEDSCHOOL_GRAD_YEAR']
# Out:
# 0          2000
# 1          1970
# 2          1970
# 3          1971
# 4          1974
#            ...
# 1281356    1992
# 1281357    1999
# 1281358    2007
# 1281359    1976
# 1281360    2003
# Name: MEDSCHOOL_GRAD_YEAR, Length: 1281361, dtype: int64

# %%
chri = split_names(chri)
pd.merge(chri, ppd_spec, left_on=['FIRST_NAME','LAST_NAME','DEGREE','MED_SCHOOL_GRAD_YEAR'], right_on = ['FIRST_NAME','LAST_NAME','DEGREE','MEDSCHOOL_GRAD_YEAR'])
# Out:
#                      NAME FIRST_NAME    LAST_NAME MIDDLE_NAME_x SUFFIX_x  \
# 0      Nicole L. Aaronson     NICOLE     AARONSON            L.
# 1      Madeel A. Abdullah     MADEEL     ABDULLAH            A.
# 2         Ari Daniel Abel        ARI         ABEL        DANIEL
# 3     Rebecca A Achterhof    REBECCA    ACHTERHOF             A
# 4             Pablo Adler      PABLO        ADLER
# ...                   ...        ...          ...           ...      ...
# 3732    Pawel Pomianowski      PAWEL  POMIANOWSKI
# 3733    Pawel Pomianowski      PAWEL  POMIANOWSKI
# 3734    Pawel Pomianowski      PAWEL  POMIANOWSKI
# 3735    Pawel Pomianowski      PAWEL  POMIANOWSKI
# 3736    Pawel Pomianowski      PAWEL  POMIANOWSKI
#
#      NICKNAME TITLE                                               LINK DEGREE  \
# 0                    https://doctors.christianacare.org/provider/Ni...     MD
# 1                    https://doctors.christianacare.org/provider/Ma...     MD
# ...

# %%
ppd_spec['MEDSCHOOL_GRAD_YEAR'] = [str(x) for x in ppd_spec.MEDSCHOOL_GRAD_YEAR]

# %%
len(chri)
# Out:
# 7153

# %%
chri.drop_duplicates('NAME')
# Out:
#                        NAME FIRST_NAME     LAST_NAME MIDDLE_NAME SUFFIX  \
# 0           Joshua N. Aaron     JOSHUA         AARON          N.
# 4        Nicole L. Aaronson     NICOLE      AARONSON          L.
# 5     Raafat Z. Abdel-Misih     RAAFAT   ABDEL-MISIH          Z.
# 6        Peter Abdelmessieh      PETER  ABDELMESSIEH
# 7        Madeel A. Abdullah     MADEEL      ABDULLAH          A.
# ...                     ...        ...           ...         ...    ...
# 7137         Elise C. Hogan      ELISE         HOGAN          C.
# 7138          Vanessa Patel    VANESSA         PATEL
# 7139      Pawel Pomianowski      PAWEL   POMIANOWSKI
# 7148   Marybeth Rizzo Moore   MARYBETH         MOORE       RIZZO
# 7152   Shanthi P. Shakamuri    SHANTHI     SHAKAMURI          P.
#
#      NICKNAME TITLE                                               LINK DEGREE  \
# 0                    https://doctors.christianacare.org/provider/Jo...     MD
# ...

# %%
linko = chri.drop_duplicates('LINK')

# %%
quest = linko.drop_duplicates('NAME', keep=False)

# %%
linko[linko.LINK.isin(quest.LINK)==False]['LINK']
# Out:
# 294     https://doctors.christianacare.org/provider/Da...
# 296     https://doctors.christianacare.org/provider/Da...
# 352     https://doctors.christianacare.org/provider/Br...
# 370     https://doctors.christianacare.org/provider/Br...
# 408     https://doctors.christianacare.org/provider/Lo...
#                               ...
# 7078    https://doctors.christianacare.org/provider/Yu...
# 7080    https://doctors.christianacare.org/provider/Yi...
# 7082    https://doctors.christianacare.org/provider/Yi...
# 7096    https://doctors.christianacare.org/provider/Ma...
# 7114    https://doctors.christianacare.org/provider/Ma...
# Name: LINK, Length: 474, dtype: object

# %%
2019-00825
