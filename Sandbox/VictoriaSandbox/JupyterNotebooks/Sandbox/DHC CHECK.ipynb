# %%
import pandas as pd
import useful_functions as use

# %%
# dhc_file = use.get_newest('../../Data/DHC/','DHC_2')
# dhc = pd.read_csv(dhc_file, low_memory=False)
# dhc = dhc.fillna('None')
# dhc['ME'] = use.fix_me(dhc.ME)

other_dhc_file = use.get_newest('../../Data/DHC/','DHC_P')
other_dhc = pd.read_csv(other_dhc_file, low_memory=False)
other_dhc = other_dhc.fillna('None')
other_dhc['ME'] = use.fix_me(other_dhc.ME)

# %%
dhc = dhc[dhc.ME!='None']

# %%
other_dhc = other_dhc[other_dhc.ME!='None']

# %%
dhc[~dhc.ME.isin(other_dhc.ME)]
# Out:
#                NPI           ME Additional Office Locations  Phone Number  \
# 1583    1457519126  03575080234                        None          None
# 2451    1477525970  02002111121                        None  256.533.1600
# 2460    1477642841  04804090440         Charlottesville, VA  540.332.4329
# 3118    1487784534  66103070059                        None  203.288.5278
# 3667    1497733075  16001920107                  Lorain, OH  440.414.9260
# ...            ...          ...                         ...           ...
# 921700  1619396108  04501140894                        None          None
# 921703  1932561081  03840161977                        None          None
# 921711  1740840776  49521180101                        None          None
# 921718  1649730722  70437130122                        None          None
# 921726  1982137204  01105170161                        None          None
#
#         Zip Code State          City                         Address  \
# ...

# %%
ppd = use.get_ppd()
# Out:
# INFO:useful_functions:PPD file from Mar 05 2022
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: DtypeWarning: Columns (13,14,20,21,49,56,57,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
ppd[ppd.ME=='02002111121']
# Out:
#                  ME RECORD_ID  UPDATE_TYPE  ADDRESS_TYPE  \
# 288564  02002111121         A            1           2.0
#
#                  MAILING_NAME LAST_NAME FIRST_NAME MIDDLE_NAME  SUFFIX  \
# 288564  STEPHEN E SANDWELL MD  SANDWELL    STEPHEN      EDWARD     NaN
#
#        MAILING_LINE_1  ... POLO_STATE POLO_ZIP POLO_SECTOR POLO_CARRIER_ROUTE  \
# 288564            NaN  ...         AL    35801      5171.0               C013
#
#        MOST_RECENT_FORMER_LAST_NAME MOST_RECENT_FORMER_MIDDLE_NAME  \
# 288564                          NaN                            NaN
#
#        MOST_RECENT_FORMER_FIRST_NAME  NEXT_MOST_RECENT_FORMER_LAST  \
# 288564                           NaN                           NaN
#
#         NEXT_MOST_RECENT_FORMER_MIDDLE NEXT_MOST_RECENT_FORMER_FIRST
# 288564                             NaN                           NaN
#
# [1 rows x 81 columns]

# %%
other_dhc
# Out:
#                NPI           ME   Credentials   Age  Gender Middle Name  \
# 0       1528265030  04201040791            MD    43    Male          A.
# 1       1447466313  49575000010            MD    50  Female        None
# 2       1447468301  02106050565            MD    44  Female           M
# 3       1447468970  04113040195            MD    46  Female        None
# 4       1447469382  03575010503            DO  None  Female        None
# ...            ...          ...           ...   ...     ...         ...
# 918452  1073001921  70425150632          MBBS  None    Male        None
# 918453  1649806613  02701200325            MD  None    Male     Douglas
# 918454  1992366264  13002181007            MD  None    Male        None
# 918455  1649841909  00476210623            DO  None    Male      Robert
# 918456  1942819404  60501100539  MD, MPH, MSC  None    Male      Mounir
#
#        First Name Last Name  Physician Name
# 0          Elfren     Colon    Elfren Colon
# ...
