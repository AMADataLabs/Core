# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
npi = pd.read_csv('ALL_NPI_NEW.csv')

# %%
npi[npi.MAILING_ADDRESS_1=='2301 MARSH LN']
# Out:
# Empty DataFrame
# Columns: [NPI, Taxonomies, NAME, OTHER_NAME, MAILING_ADDRESS_1, MAILING_ADDRESS_2, MAILING_CITY, MAILING_STATE, MAIING_ZIP, MAILING_PHONE, LOCATION_ADDRESS_1, LOCATION_ADDRESS_2, LOCATION_CITY, LOCATION_STATE, LOCATION_ZIP, LOCATION_PHONE, LAST_UPDATE_DATE]
# Index: []

# %%
npi.columns
# Out:
# Index(['NPI', 'Taxonomies', 'NAME', 'OTHER_NAME', 'MAILING_ADDRESS_1',
#        'MAILING_ADDRESS_2', 'MAILING_CITY', 'MAILING_STATE', 'MAIING_ZIP',
#        'MAILING_PHONE', 'LOCATION_ADDRESS_1', 'LOCATION_ADDRESS_2',
#        'LOCATION_CITY', 'LOCATION_STATE', 'LOCATION_ZIP', 'LOCATION_PHONE',
#        'LAST_UPDATE_DATE'],
#       dtype='object')

# %%
all_names = list(npi.NAME)+list(npi.OTHER_NAME.dropna())

# %%
new_name = 'ALTACARE OF MONTANA'
for name in all_names:
    if fuzz.ratio(new_name, name)>80:
        print(name)

# %%
pd.read_csv('NPI_with_Taxonomy.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (9,12,17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                 NPI    Taxonomy           Other  \
# 0        1003000118  208000000X  ['208000000X']
# 1        1003000209  111N00000X  ['111N00000X']
# 2        1003000217  152W00000X  ['152W00000X']
# 3        1003000233  122300000X  ['122300000X']
# 4        1003000258  3336C0003X  ['3336C0003X']
# ...             ...         ...             ...
# 1327685  1992999767  103G00000X  ['103G00000X']
# 1327686  1992999775  261QA1903X  ['261QA1903X']
# 1327687  1992999809  251E00000X  ['251E00000X']
# 1327688  1992999841  1223G0001X  ['1223G0001X']
# 1327689  1992999890  152W00000X  ['152W00000X']
#
#                                 Prov_Org_Nm__Legal_Bus_Nm_  \
# ...

# %%
for gm_chunk in pd.read_csv('NPI_DATA_ALL.csv', engine='python',encoding='utf-8', error_bad_lines=False,chunksize=500):
    pd.concat(gm_chunk)
# Out:
#             NPI  Entity Type Code  Replacement NPI  \
# 0    1679576722               1.0              NaN
# 1    1588667638               1.0              NaN
# 2    1497758544               2.0              NaN
# 3    1306849450               1.0              NaN
# 4    1215930367               1.0              NaN
# ..          ...               ...              ...
# 495  1861495053               NaN              NaN
# 496  1770586968               2.0              NaN
# 497  1689677874               1.0              NaN
# 498  1902809395               1.0              NaN
# 499  1306849591               1.0              NaN
#
#     Employer Identification Number (EIN)  \
# 0                                    NaN
# 1                                    NaN
# 2                              <UNAVAIL>
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 495                                  NaN
# ...

# %%
pd.read_csv('NPI_DATA_ALL.csv', engine='python',encoding='utf-8', error_bad_lines=False,chunksize=500)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-2cd2fdf52908> in <module>
# ----> 1 pd.read_csv('NPI_DATA_ALL.csv', engine='python',encoding='utf-8', error_bad_lines=False,chunksize=500)()
#
# TypeError: 'TextFileReader' object is not callable

# %%
npi
# Out:
#                NPI                                  Taxonomies  \
# 0       1346258928                              ['111N00000X']
# 1       1326056904                              ['261QP2300X']
# 2       1952319535                              ['314000000X']
# 3       1770591356                              ['332B00000X']
# 4       1659389237  ['207Q00000X', '207QA0401X', '207R00000X']
# ...            ...                                         ...
# 241400  1184632754                              ['1223P0221X']
# 241401  1992713564                ['3336I0012X', '282E00000X']
# 241402  1174531743                              ['207L00000X']
# 241403  1891703468                              ['208600000X']
# 241404  1619985280                              ['332B00000X']
#
#                                                   NAME  \
# 0                CHIROPRACTIC ASSOCIATES, INCORPORATED
# 1                             F DANIEL JACKSON, MD, PA
# ...
