# %%
import pandas as pd

# %%
pd.read_csv('Google_Results.csv')
# Out:
#         Unnamed: 0                                            Address  \
# 0                0     13601 Preston Rd # 900W, Dallas, TX 75240, USA
# 1                1     13601 Preston View Blvd, Dallas, TX 75240, USA
# 2                2    1400 I-20 Frontage Rd, Arlington, TX 76018, USA
# 3                3    1400 I-20 Frontage Rd, Arlington, TX 76018, USA
# 4                4    1400 I-20 Frontage Rd, Arlington, TX 76018, USA
# 5                5    1400 I-20 Frontage Rd, Arlington, TX 76018, USA
# 6                6  13601 Preston View Blvd #1000w, Dallas, TX 752...
# 7                7     13601 Preston View Blvd, Dallas, TX 75240, USA
# 8                8  13601 Preston View Blvd #1000w, Dallas, TX 752...
# 9                9         8200 Walnut Hill Ln, Dallas, TX 75231, USA
# 10              10         1600 Hospital Pkwy, Bedford, TX 76022, USA
# 11              11         1600 Hospital Pkwy, Bedford, TX 76022, USA
# ...
