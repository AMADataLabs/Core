# %%
def getState(zipcode): 

    

    if len(zipcode) < 5:
         console.log('Must pass a 5-digit zipcode.')
         return('Try Again')

    if len(zipcode)>5:
        zipcode = zipcode[0:5]

    zipcode = int(zipcode)

    if zipcode >= 35000 & zipcode <= 36999 :
        st = 'AL'
        state = 'Alabama'
        
    elif zipcode >= 99500 & zipcode <= 99999 :
        st = 'AK'
        state = 'Alaska'
        
    elif zipcode >= 85000 & zipcode <= 86999 :
        st = 'AZ'
        state = 'Arizona'
        
    elif zipcode >= 71600 & zipcode <= 72999 :
        st = 'AR'
        state = 'Arkansas'
        
    elif zipcode >= 90000 & zipcode <= 96699 :
        st = 'CA'
        state = 'California'
        
    elif zipcode >= 80000 & zipcode <= 81999 :
        st = 'CO'
        state = 'Colorado'
        
    elif zipcode >= 6000 & zipcode <= 6999 :
        st = 'CT'
        state = 'Connecticut'
        
    elif zipcode >= 19700 & zipcode <= 19999 :
        st = 'DE'
        state = 'Delaware'
        
    elif zipcode >= 32000 & zipcode <= 34999 :
        st = 'FL'
        state = 'Florida'
        
    elif zipcode >= 30000 & zipcode <= 31999 :
        st = 'GA'
        state = 'Georgia'
        
    elif zipcode >= 96700 & zipcode <= 96999 :
        st = 'HI'
        state = 'Hawaii'
        
    elif zipcode >= 83200 & zipcode <= 83999 :
        st = 'ID'
        state = 'Idaho'
        
    elif zipcode >= 60000 & zipcode <= 62999 :
        st = 'IL'
        state = 'Illinois'
        
    elif zipcode >= 46000 & zipcode <= 47999 :
        st = 'IN'
        state = 'Indiana'
        
    elif zipcode >= 50000 & zipcode <= 52999 :
        st = 'IA'
        state = 'Iowa'
        
    elif zipcode >= 66000 & zipcode <= 67999 :
        st = 'KS'
        state = 'Kansas'
        
    elif zipcode >= 40000 & zipcode <= 42999 :
        st = 'KY'
        state = 'Kentucky'
        
    elif zipcode >= 70000 & zipcode <= 71599 :
        st = 'LA'
        state = 'Louisiana'
        
    elif zipcode >= 3900 & zipcode <= 4999 :
        st = 'ME'
        state = 'Maine'
        
    elif zipcode >= 20600 & zipcode <= 21999 :
        st = 'MD'
        state = 'Maryland'
        
    elif zipcode >= 1000 & zipcode <= 2799 :
        st = 'MA'
        state = 'Massachusetts'
        
    elif zipcode >= 48000 & zipcode <= 49999 :
        st = 'MI'
        state = 'Michigan'
        
    elif zipcode >= 55000 & zipcode <= 56999 :
        st = 'MN'
        state = 'Minnesota'
        
    elif zipcode >= 38600 & zipcode <= 39999 :
        st = 'MS'
        state = 'Mississippi'
        
    elif zipcode >= 63000 & zipcode <= 65999 :
        st = 'MO'
        state = 'Missouri'
        
    elif zipcode >= 59000 & zipcode <= 59999 :
        st = 'MT'
        state = 'Montana'
        
    elif zipcode >= 27000 & zipcode <= 28999 :
        st = 'NC'
        state = 'North Carolina'
        
    elif zipcode >= 58000 & zipcode <= 58999 :
        st = 'ND'
        state = 'North Dakota'
        
    elif zipcode >= 68000 & zipcode <= 69999 :
        st = 'NE'
        state = 'Nebraska'
        
    elif zipcode >= 88900 & zipcode <= 89999 :
        st = 'NV'
        state = 'Nevada'
        
    elif zipcode >= 3000 & zipcode <= 3899 :
        st = 'NH'
        state = 'New Hampshire'
        
    elif zipcode >= 7000 & zipcode <= 8999 :
        st = 'NJ'
        state = 'New Jersey'
        
    elif zipcode >= 87000 & zipcode <= 88499 :
        st = 'NM'
        state = 'New Mexico'
        
    elif zipcode >= 10000 & zipcode <= 14999 :
        st = 'NY'
        state = 'New York'
        
    elif zipcode >= 43000 & zipcode <= 45999 :
        st = 'OH'
        state = 'Ohio'
        
    elif zipcode >= 73000 & zipcode <= 74999 :
        st = 'OK'
        state = 'Oklahoma'
        
    elif zipcode >= 97000 & zipcode <= 97999 :
        st = 'OR'
        state = 'Oregon'
        
    elif zipcode >= 15000 & zipcode <= 19699 :
        st = 'PA'
        state = 'Pennsylvania'
        
    elif zipcode >= 300 & zipcode <= 999 :
        st = 'PR'
        state = 'Puerto Rico'
        
    elif zipcode >= 2800 & zipcode <= 2999 :
        st = 'RI'
        state = 'Rhode Island'
        
    elif zipcode >= 29000 & zipcode <= 29999 :
        st = 'SC'
        state = 'South Carolina'
        
    elif zipcode >= 57000 & zipcode <= 57999 :
        st = 'SD'
        state = 'South Dakota'
        
    elif zipcode >= 37000 & zipcode <= 38599 :
        st = 'TN'
        state = 'Tennessee'
        
    elif  (zipcode >= 75000 & zipcode <= 79999) or (zipcode >= 88500 & zipcode <= 88599):
        st = 'TX'
        state = 'Texas'
        
    elif zipcode >= 84000 & zipcode <= 84999 :
        st = 'UT'
        state = 'Utah'
        
    elif zipcode >= 5000 & zipcode <= 5999 :
        st = 'VT'
        state = 'Vermont'
        
    elif zipcode >= 22000 & zipcode <= 24699 :
        st = 'VA'
        state = 'Virgina'
        
    elif zipcode >= 20000 & zipcode <= 20599 :
        st = 'DC'
        state = 'Washington DC'
        
    elif zipcode >= 98000 & zipcode <= 99499 :
        st = 'WA'
        state = 'Washington'
        
    elif zipcode >= 24700 & zipcode <= 26999 :
        st = 'WV'
        state = 'West Virginia'
        
    elif zipcode >= 53000 & zipcode <= 54999 :
        st = 'WI'
        state = 'Wisconsin'
        
    elif zipcode >= 82000 & zipcode <= 83199 :
        st = 'WY'
        state = 'Wyoming'
        
    else :
        st = 'none'
        state = 'none'
    

    return st
