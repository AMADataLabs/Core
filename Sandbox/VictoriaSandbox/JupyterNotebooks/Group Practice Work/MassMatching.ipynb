# %%
import pandas as pd

# %%
mass = pd.read_csv('mass_work.csv')

# %%
for col in mass.columns: 
    print(col)
# Out:
# Department
# Name
# Practice
# Telephone
# FIRST_NAME
# LAST_NAME
# MIDDLE_NAME_x
# ME
# MAILING_NAME
# MIDDLE_NAME_y
# SUFFIX
# MAILING_LINE_1
# MAILING_LINE_2
# CITY
# STATE
# ZIP
# TELEPHONE_NUMBER
# POLO_MAILING_LINE_1
# POLO_MAILING_LINE_2
# POLO_CITY
# POLO_STATE
# POLO_ZIP

# %%
mass = mass.fillna('None')
dict_list =[]
for row in mass.itertuples():
    if (row.MIDDLE_NAME_y == row.MIDDLE_NAME_x) or (row.MIDDLE_NAME_x == str(row.MIDDLE_NAME_y)[0]):
        new_dict = {}
        new_dict['ME'] = row.ME
        new_dict['Name'] = row.Name
        dict_list.append(new_dict)
middles = pd.DataFrame(dict_list)

# %%
df_all = mass.merge(middles.drop_duplicates(), on=['ME'], 
                   how='left', indicator=True)
df_all[df_all['_merge'] == 'left_only']
# Out:
#                                              Department  \
# 8                               Department of Pathology
# 15                                          Hospitalist
# 16                                           Cardiology
# 18                             Department of Pediatrics
# 19                                         Primary Care
# 20                                           Cardiology
# 21    Department of Anesthesia, Critical Care and Pa...
# 27                                         Primary Care
# 32                                          Hospitalist
# 33                                Department of Urology
# 35                               Allergy and Immunology
# 36                              Department of Neurology
# 37                            Obstetrics and Gynecology
# 38                              Department of Neurology
# 39                             Department of Pediatrics
# 40                                       Otolaryngology
# ...

# %%
middles
# Out:
#                ME                          Name
# 0       702640121         A Benedict Cosimi, MD
# 1       514020671      Aalok Vijay Agarwala, MD
# 2       802020074          Aaron L. Baggish, MD
# 3      2401081804     Aaron D. Aguirre, MD, PhD
# 4      4177120583     Aaron R. Hoffman, DO, MPH
# 5     51708930168      Abdolnabi S. Sabouri, MD
# 6      2802020735            Abena O. Ofori, MD
# 7       801030122    Abigail Louise Donovan, MD
# 8      3520010822     Abner Louissaint, MD, PhD
# 9      2416000452   Adam Scott Feldman, MD, MPH
# 10      511100208          Adam S. Tenforde, MD
# 11      514091285            Adam R. Miller, MD
# 12     1720133349            Adam R. Miller, MD
# 13     1720150626            Adam R. Miller, MD
# 14     3501081107    Adeline A. Boatin, MD, MPH
# 15     1001141607             Adith Sekaran, MD
# 16     6501930812         Adrian J. Priesol, MD
# 17     2407100711       Aferdita Spahillari, MD
# 18     3508100450         Agnieszka Lesicka, MD
# ...

# %%
mass_test = pd.merge(mass, middles, on=['ME', 'Name'], how='right')

# %%
potential = pd.read_csv('potential_mass.csv')

# %%
no_phone = pd.read_csv('no_phone_mass.csv')

# %%
pd.merge(no_phone, mass_test, on='ME', suffixes =['_PPD','_Mass'])
# Out:
#               ME          MAILING_NAME_PPD   LAST_NAME_PPD FIRST_NAME_PPD  \
# 0      102141822        JAMES C SIMPSON MD         SIMPSON          JAMES
# 1      301071078          LIDA P HARIRI MD          HARIRI           LIDA
# 2      301131011            ANNA M WARD MD            WARD           ANNA
# 3      502030957         ERICA J WILSON MD          WILSON          ERICA
# 4      502080113             PUJA KOHLI MD           KOHLI           PUJA
# 5      502120239          CRYSTAL E TAN MD             TAN        CRYSTAL
# 6      502801406         JOHNSON T WONG MD            WONG        JOHNSON
# 7      511080835           KEYAN SALARI MD          SALARI          KEYAN
# 8      511110238               XIAO TAN MD             TAN           XIAO
# 9      514050171             AMY M YULE MD            YULE            AMY
# 10     514071543           RUPA NARAYAN MD         NARAYAN           RUPA
# 11     514110891         MARVIN G CHANG MD           CHANG         MARVIN
# ...

# %%
pd.merge(potential, mass_test, on='ME', how='left',suffixes =['_PPD','_Mass'])
# Out:
#                ME                  MAILING_NAME_PPD       LAST_NAME_PPD  \
# 0       102020910                   ALVIN V SHIH MD                SHIH
# 1       102031091                      LONG P LE MD                  LE
# 2       102121066            SUZANNE M MCCLUSKEY MD           MCCLUSKEY
# 3       102131134                TRAVIS D HULL I MD                HULL
# 4       102141822                JAMES C SIMPSON MD             SIMPSON
# 5       102931301                  JORDAN T SHIN MD                SHIN
# 6       106130361              PATRICIA L HUDSON MD              HUDSON
# 7       106940720                BRENNA C BOUNDS MD              BOUNDS
# 8       301020635                  SEAN B POCOCK MD              POCOCK
# 9       301070462                   SARAH CHIANG MD              CHIANG
# 10      301071078                  LIDA P HARIRI MD              HARIRI
# 11      301131011                    ANNA M WARD MD                WARD
# ...

# %%
pd.merge(nums, mass, on='ME',suffixes =['_PPD','_Mass'])[['TELEPHONE_NUMBER_PPD','Telephone']]
# Out:
#     TELEPHONE_NUMBER_PPD   Telephone
# 0             6177262967  6177268173
# 1             6177263030  6177263030
# 2             6037402887  6177244000
# 3             6177262740  6177262740
# 4             6177263093  6177263093
# 5             6177262000  6177245600
# 6             6177243257  6177243257
# 7             6177950492  6177245600
# 8             6177249040  6177249040
# 9             6177265155  6177265155
# 10            6179653098  6179653098
# 11            6177247738  6177247738
# 12            6177262728  6177262728
# 13            6177262748  6177262590
# 14            6177242183  8572388496
# 15            6177243252  6177243252
# 16            6035773070  6177263567
# 17            6177265117  6177264700
# 18            6177264422  6177264422
# 19            6176434723  6176434723
# 20            6177263877  6177263877
# 21            6177243289  6177243289
# 22            5135851300  6177244800
# 23            9788826767  9788826767
# ...

# %%
nums = potential[potential['TELEPHONE_NUMBER']!='None']

# %%
nums
# Out:
#                ME                 MAILING_NAME       LAST_NAME  FIRST_NAME  \
# 1       102031091                 LONG P LE MD              LE        LONG
# 5       102931301             JORDAN T SHIN MD            SHIN      JORDAN
# 7       106940720           BRENNA C BOUNDS MD          BOUNDS      BRENNA
# 14      502030507           BRINDA B KAMDAR MD          KAMDAR      BRINDA
# 16      502040057            CESAR M CASTRO MD          CASTRO       CESAR
# 18      502071718         ZACHARY S PEACOCK MD         PEACOCK     ZACHARY
# 20      502080181         PRADEEP NATARAJAN MD       NATARAJAN     PRADEEP
# 22      502090348              MANISHA BAHL MD            BAHL     MANISHA
# 23      502100661          LAURA A PETRILLO MD        PETRILLO       LAURA
# 26      502110209         ANTHONY D SOSSONG MD         SOSSONG     ANTHONY
# 31      502140698            LAUREN E SMITH MD           SMITH      LAUREN
# ...

# %%
mass_test
# Out:
#                                              Department  \
# 0                                    Transplant Surgery
# 1     Department of Anesthesia, Critical Care and Pa...
# 2                                            Cardiology
# 3                                            Cardiology
# 4                                          Primary Care
# 5     Department of Anesthesia, Critical Care and Pa...
# 6                             Department of Dermatology
# 7                              Department of Psychiatry
# 8                               Department of Pathology
# 9                                 Department of Urology
# 10     MGH Physical Medicine and Rehabilitation Service
# 11                                  Hematology/Oncology
# 12                                  Hematology/Oncology
# 13                                  Hematology/Oncology
# 14                            Obstetrics and Gynecology
# 15                                          Hospitalist
# ...
