# %%
import pandas as pd

# %%
owners = pd.read_csv('owners.csv')

# %%
ppd = pd.read_csv('PPD.csv')

# %%
pd.merge(owners, ppd, left_on=['Authorized_Official_Last_Nm','Authorized_Official_1st_Nm', 'Authorized_Official_Middle_Nm'], right_on=['FIRST_NAME','LAST_NAME','MIDDLE_NAME'])
# Out:
#                            Prov_Org_Nm__Legal_Bus_Nm_  \
# 0                           IMEDIX TRANSPORTATION INC
# 1                                RIGLEYS PHARMACY LLC
# 2   DAVID PHYSICAL THERAPY AND SPORTS MEDICINE CEN...
# 3                         MOHAMMAD ASHRAF, M.D., INC.
# 4                                VERICARE VISION PLLC
# 5                                   MANARAH CARE PLLC
# 6                              ST. THOMAS MANOR, INC.
# 7                              ST. THOMAS MANOR, INC.
# 8                              ST. THOMAS MANOR, INC.
# 9                              ST. THOMAS MANOR, INC.
# 10                 INFECTION PREVENTION MEDICINE PLLC
# 11                                 MUNE GOWDA MD PLLC
# 12        FLORIDA PAIN & REHABILITATION INSTITUTE INC
# 13                       LEE PROFESSIONAL DENTAL CORP
# 14                              EHC INSTITUTIONAL LLC
# 15                           KANDASWAMY JAYARAJ MD PA
# ...

# %%
all_groups=pd.read_csv('npi_groups.csv')
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.merge(ppd, dorted_groups, left_on='POLO_MAILING_LINE_2',right_on='Prov_1st_Line_Bus_Mail_Addr')
# Out:
#                  ME           MAILING_NAME  LAST_NAME FIRST_NAME MIDDLE_NAME  \
# 0         102000081   ANDREA B MCMURPHY MD   MCMURPHY     ANDREA      BARBER
# 1         102070291     JOSEPH R TURNER MD     TURNER     JOSEPH        RYAN
# 2         102110307       RYAN C BURTON MD     BURTON       RYAN      CURTIS
# 3         102110692    BRIAN P SULLIVAN MD   SULLIVAN      BRIAN     PATRICK
# 4         102680731        TOM M WALKER MD     WALKER        TOM      MORROW
# ...             ...                    ...        ...        ...         ...
# 327919  95702540136   DUSHAN R KOSOVICH MD   KOSOVICH     DUSHAN           R
# 327920  95702760021     DUSAN I PEKOVIC MD    PEKOVIC      DUSAN           I
# 327921  95702960062   MOHAMMAD J KHAMIS MD     KHAMIS   MOHAMMAD       JALAL
# 327922  95704720018  NIKOLA A BOSKOVSKI MD  BOSKOVSKI     NIKOLA           A
# 327923  96501820013        ANIL C PATEL MD      PATEL       ANIL  CHHOTUBHAI
#
# ...

# %%
sorted_groups = all_groups.sort_values('Last_Update_Date')
dorted_groups = sorted_groups.drop_duplicates('Prov_Org_Nm__Legal_Bus_Nm_', keep='last')

# %%
dorted_groups
# Out:
#                   Prov_Org_Nm__Legal_Bus_Nm_  \
# 117845             J. MICHAEL OAKS, DO, INC.
# 86818                   MIDWEST HEALTH, INC.
# 85724          COMPASSIONATE DENTISTRY, P.C.
# 58949    ZENITH REHABILITATION SERVICES INC.
# 97785               THE SERENITY HOUSE, INC.
# ...                                      ...
# 33189           INDEPENDENT PHYSICAL THERAPY
# 54524   SAMARITAN HOSPITAL OF TROY, NEW YORK
# 82940      BUFFALO NIAGARA ENDODONTICS, P.C.
# 94777          HEART CENTER USA INCORPORATED
# 8912                ALABAMA CVS PHARMACY LLC
#
#                              Prov_Other_Org_Nm Prov_1st_Line_Bus_Mail_Addr  \
# 117845                                     NaN                 933 HIGH ST
# 86818                       BOYER CHIROPRACTIC             9770 QUIVIRA RD
# 85724                      SCOTT B. BOLTZ, DDS             604 E BOULEVARD
# 58949                                      NaN      323 PARKWOOD DR APT R8
# ...
