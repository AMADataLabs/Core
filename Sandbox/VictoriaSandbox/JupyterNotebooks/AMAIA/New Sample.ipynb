# %%
import pandas as pd

# %%
new = pd.read_csv('../additional_sample_2019-09-24.csv')

# %%
untest = pd.read_csv('../Phone API Work/GetPhoneInfo/untested_with_wslive_results.csv')

# %%
new.dtypes
# Out:
# OFFICE_TELEPHONE                     int64
# PHYSICIAN_ME_NUMBER                  int64
# PHYSICIAN_FIRST_NAME                object
# PHYSICIAN_MIDDLE_NAME               object
# PHYSICIAN_LAST_NAME                 object
# OFFICE_ADDRESS_LINE_1               object
# OFFICE_ADDRESS_LINE_2               object
# OFFICE_ADDRESS_CITY                 object
# OFFICE_ADDRESS_STATE                object
# OFFICE_ADDRESS_ZIP                 float64
# OFFICE_ADDRESS_VERIFIED_UPDATED      int64
# COMMENTS                            object
# WSLIVE_FILE_DT                      object
# SPECIALTY                           object
# pred_recall                        float64
# dtype: object

# %%
untest.dtypes
# Out:
# PHYSICIAN_ME_NUMBER                float64
# PHYSICIAN_FIRST_NAME                object
# PHYSICIAN_MIDDLE_NAME               object
# PHYSICIAN_LAST_NAME                 object
# SUFFIX                             float64
# DEGREE                             float64
# OFFICE_ADDRESS_LINE_1               object
# OFFICE_ADDRESS_LINE_2               object
# OFFICE_ADDRESS_CITY                 object
# OFFICE_ADDRESS_STATE                object
# OFFICE_ADDRESS_ZIP                 float64
# OFFICE_ADDRESS_VERIFIED_UPDATED    float64
# OFFICE_TELEPHONE                   float64
# OFFICE_PHONE_VERIFIED_UPDATED      float64
# OFFICE_FAX                         float64
# OFFICE_FAX_VERIFIED_UPDATED        float64
# EMAIL_ADDRESS                      float64
# EMAIL_ADDRESS_VERIFIED_UPDATED     float64
# PRESENT_EMPLOYMENT_CODE            float64
# PRESENT_EMPLOYMENT_UPDATED         float64
# COMMENTS_x                          object
# Source                              object
# ...

# %%
model = pd.read_csv('../Phone API Work/model_results.csv')

# %%
model = model.sort_values('pred_recall')
model = model.drop_duplicates('ppd_telephone_number', keep='first')

# %%
with_model = pd.merge(untest,model, left_on='OFFICE_TELEPHONE',right_on='ppd_telephone_number')

# %%
with_model = with_model.rename(columns={'COMMENTS_y':'COMMENTS'})

# %%
all_nums = pd.concat([with_model, new],join='inner')

# %%
with_model.groupby(['COMMENTS']).count()
# Out:
#                            PHYSICIAN_ME_NUMBER  PHYSICIAN_FIRST_NAME  \
# COMMENTS
# 2ND ATTEMPT                                 43                    43
# COMPLETE                                    83                    83
# FAIL                                         4                     4
# FAX MODEM                                    7                     7
# LANGUAGE/HEARING                             1                     1
# MOVED, NO FORWARDING INFO                   24                    24
# NOT IN SERVICE                              57                    57
# REFUSAL                                      4                     4
# RETIRED                                      5                     5
# WRONG NUMBER                                15                    15
#
#                            PHYSICIAN_MIDDLE_NAME  PHYSICIAN_LAST_NAME  SUFFIX  \
# COMMENTS
# 2ND ATTEMPT                                   35                   43       3
# ...

# %%
with_model = with_model.sort_values('COMMENTS')

# %%
with_model.drop(v)
# Out:
#      PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 35          5.280103e+10                 EHAB                MASOOD
# 36          3.607711e+09                 ERIC               WEBSTER
# 37          4.113821e+09               ERNEST                ROBERT
# 38          4.952101e+10              IBRAHIM                   NaN
# 39          5.029703e+08             JENNIFER                  MARY
# 40          6.491482e+10                 JOHN               MICHAEL
# 41          3.080380e+10                 JUAN                     N
# 34          4.113852e+09               EDWARD                 KOWAL
# 33          4.707851e+09                 EARL                     R
# 32          4.114861e+09                DAVID                PHILIP
# 31          1.645831e+09                ADELE                 MARIE
# 7           2.106760e+09                HAYES                TAYLOR
# 25          4.102981e+09                BRIAN                SAMUEL
# ...

# %%
v = list(range(43,126))

# %%
all_nums.to_csv('GetPhoneInfo_batch_sample.csv',index=False)
