# %% [markdown]
# # Disconnect Model with RPV + GPI

# %%
import pandas as pd
import pickle as pk
import numpy as np

from datetime import datetime
from dateutil.parser import parse

from med_words import med_words

from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB


import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# ### Import WSLive Results

# %%
wslive_path = 'U:\\Source Files\\Data Analytics\\Derek\\SAS_DATA\\SURVEY\\wslive_results.sas7bdat'

wslive_df = pd.read_sas(wslive_path, encoding='latin')

wslive_2019 = wslive_df[wslive_df['WSLIVE_FILE_DT'] >= '2019-01-01']

# save off 2019 WSLive results for easier retrieval later
with open('wslive_2019.pk','wb') as f:
    pk.dump(wslive_2019, f)

# %%
# if starting new, just load 2019 wslive results here
wslive_2019 = pk.load(open('U:\\Source Files\\Data Analytics\\Data-Science\\Data\\Get_Phone_Info\\wslive_2019.pk','rb'))

# %%
# scope of this modeling data
wsl = wslive_2019[wslive_2019['WSLIVE_FILE_DT'] >= '2019-07-01']

wsl = wsl[['OFFICE_ADDRESS_LINE_1', 
           'OFFICE_ADDRESS_LINE_2', 
           'OFFICE_ADDRESS_VERIFIED_UPDATED',
           'COMMENTS',
           'OFFICE_TELEPHONE',
           'OFFICE_ADDRESS_CITY', 
           'OFFICE_ADDRESS_STATE',
           'OFFICE_ADDRESS_ZIP',]]

wsl.rename(columns={'OFFICE_TELEPHONE': 'phone',
                    'OFFICE_ADDRESS_CITY': 'wsl_city',
                    'OFFICE_ADDRESS_STATE':'wsl_state',
                    'OFFICE_ADDRESS_ZIP': 'wsl_zip',
                    }, inplace=True)

for col in wsl.columns:
    wsl[col] = wsl[col].astype(str)
    
    
wsl['isDisconnected'] = wsl['COMMENTS'].apply(lambda x: 1 if x == 'NOT IN SERVICE' else 0)
wsl['isWrong'] = [1 if com=='COMPLETE' and v=='1' else 0 for com, v in zip(wsl['COMMENTS'], wsl['OFFICE_ADDRESS_VERIFIED_UPDATED'])]

wsl.drop(columns=['COMMENTS','OFFICE_ADDRESS_VERIFIED_UPDATED'],
         axis=1, 
         inplace=True)

# %% [markdown]
# ### Import GPI Results

# %%
# all GPI results
#gpi = pd.read_csv('U:\\Source Files\\Data Analytics\\Data-Science\\Data\\Get_Phone_Info\\gpi_all.csv', dtype=object)
gpi = pd.read_csv('gpi_all.csv', dtype=object)

keep = [
    'phone',
    'ProviderNameOut',
    'LineTypeOut',
    'ContactNameOut',
    'ContactAddressOut',
    'ContactCityOut',
    'ContactStateOut',
    'ContactZipOut',
    'ContactPhoneType',
    'ContactQualityScore',
    'DateOfPorting',
    'NoteDescriptions'
]
gpi = gpi[keep]
for col in gpi:
    gpi[col] = gpi[col].astype(str)

# %%
print('GPI Results:', len(gpi))
# Out:
# GPI Results: 1459

# %% [markdown]
# ### Import RPV Results

# %%
rpv_archive=pd.read_csv('U:\\Source Files\\Data Analytics\\Data-Science\\Data\\RPV\output\\_archive\\RPV_archive.csv', 
                        dtype=object).drop_duplicates()

# %% [markdown]
# ### Merge

# %%
gpi = gpi.merge(rpv_archive, on='phone', how='inner')
print(len(gpi))
gpi = gpi.merge(wsl, on='phone', how='inner')
print(len(gpi))
# Out:
# 1412
# 1846

# %% [markdown]
# ### Observing duplication

# %%
gpi[gpi['phone'].duplicated()].sort_values(by='phone')
# Out:
#            phone       ProviderNameOut LineTypeOut  \
# 1251  2014883131      AIRUS, INC. - NJ         nan
# 1256  2027458000    CAVALIER TELEPHONE         nan
# 1257  2027458000    CAVALIER TELEPHONE         nan
# 1258  2027458000    CAVALIER TELEPHONE         nan
# 1259  2027458000    CAVALIER TELEPHONE         nan
# 1255  2027458000    CAVALIER TELEPHONE         nan
# 581   2028776429      PAETEC COMM - DC    LANDLINE
# 361   2029943893     LEVEL 3 COMM - MD        VOIP
# 169   2032352505    FRONTIER COMM - CT    LANDLINE
# 456   2032842800    FRONTIER COMM - CT    LANDLINE
# 324   2037852956    BANDWIDTH.COM - CT        VOIP
# 1125  2058792276  CHARTER FIBERLINK AL    LANDLINE
# 1267  2059393361     BELLSOUTH SO CNTL         nan
# 1266  2059393361     BELLSOUTH SO CNTL         nan
# 1270  2067445100            MAGNA5 LLC         nan
# 1273  2076261000       CONSOLIDATED NE         nan
# 1274  2076261000       CONSOLIDATED NE         nan
# 878   2077754151  CRC COMMS MAINE - ME    LANDLINE
# 942   2094686820          PACIFIC BELL    LANDLINE
# 1118  2105677410     SOUTHWESTERN BELL    LANDLINE
# 1119  2105677410     SOUTHWESTERN BELL    LANDLINE
# 1120  2105677410     SOUTHWESTERN BELL    LANDLINE
# 471   2106167700   TW TELECOM OF TEXAS    LANDLINE
# 757   2122634661      PAETEC COMM - NY    LANDLINE
# 543   2127462962     LEVEL 3 COMM - NY        VOIP
# 1328  2128295581  VERIZON NEW YORK INC         nan
# 1320  2128295581  VERIZON NEW YORK INC         nan
# 1321  2128295581  VERIZON NEW YORK INC         nan
# 1322  2128295581  VERIZON NEW YORK INC         nan
# 1323  2128295581  VERIZON NEW YORK INC         nan
# ...          ...                   ...         ...
# 1015  9202888350   AMERITECH WISCONSIN    LANDLINE
# 501   9202888400  TELEPORT COM AM - WI    LANDLINE
# 177   9209828300   AMERITECH WISCONSIN    LANDLINE
# 1816  9253705110          PACIFIC BELL         nan
# 1822  9373997021   CINCINNATI BELL EXT         nan
# 627   9375470107   TELEPORT COMM AM-OH    LANDLINE
# 1048  9376413350  LEVEL3 TELECOM OF OH    LANDLINE
# 698   9419172342     LEVEL 3 COMM - FL        VOIP
# 220   9419539080   FRONTIER COMM OF FL    LANDLINE
# 934   9496007864     LEVEL 3 COMM - CA        VOIP
# 933   9496007864     LEVEL 3 COMM - CA        VOIP
# 935   9496007864     LEVEL 3 COMM - CA        VOIP
# 920   9513532000          PACIFIC BELL    LANDLINE
# 923   9513532000          PACIFIC BELL    LANDLINE
# 922   9513532000          PACIFIC BELL    LANDLINE
# 921   9513532000          PACIFIC BELL    LANDLINE
# 919   9513532000          PACIFIC BELL    LANDLINE
# 918   9513532000          PACIFIC BELL    LANDLINE
# 917   9513532000          PACIFIC BELL    LANDLINE
# 1827  9544736344    CBEYOND COMMS - FL         nan
# 1829  9544935065  INTERMEDIA COMM - FL         nan
# 1832  9549877512  INTERMEDIA COMM - FL         nan
# 694   9564215521     LEVEL 3 COMM - TX        VOIP
# 1095  9566475144  TIME WARNER CABLE TX    LANDLINE
# 388   9722555588   FRONTIER COMM OF TX    LANDLINE
# 497   9725602667   TELEPORT COM DALLAS    LANDLINE
# 496   9725602667   TELEPORT COM DALLAS    LANDLINE
# 1841  9739725672  MCI WORLDCOM COMM NJ         nan
# 1842  9739725672  MCI WORLDCOM COMM NJ         nan
# 973   9782879400  BROADVIEW NTWKS - MA    LANDLINE
#
#                                          ContactNameOut  \
# 1251                 ANDREW FINK MD PHYSICIANS SURGEONS
# 1256     ERDULFO ANTONIO ROMERO JR MD INTERNAL MEDICINE
# 1257     ERDULFO ANTONIO ROMERO JR MD INTERNAL MEDICINE
# 1258     ERDULFO ANTONIO ROMERO JR MD INTERNAL MEDICINE
# 1259     ERDULFO ANTONIO ROMERO JR MD INTERNAL MEDICINE
# 1255     ERDULFO ANTONIO ROMERO JR MD INTERNAL MEDICINE
# 581                          WASHINGTON HOSPITAL CENTER
# 361                                                 GWU
# 169                                    HORTON PAUL C MD
# 456                          GAYLORD HOSPITAL HOSPITALS
# 324                  YALE UNIVERSITY SCHOOL OF MEDICINE
# 1125                               FRANCES C CHAIPRAKOB
# 1267                                                UAB
# 1266                                                UAB
# 1270                                             UW MED
# 1273           CHENG H C MD DOCTORS PHYSICIANS SURGEONS
# 1274           CHENG H C MD DOCTORS PHYSICIANS SURGEONS
# 878                                      LAURA SCHWINDT
# 942                SAN JOAQUIN COUNTY OF MEDICAL CLINIC
# 1118   UNIVERSITY OF TEXAS HEALTH SCIENCE CENTER AT SAN
# 1119   UNIVERSITY OF TEXAS HEALTH SCIENCE CENTER AT SAN
# 1120   UNIVERSITY OF TEXAS HEALTH SCIENCE CENTER AT SAN
# 471      SOUTH TEXAS RADIOLOGY GROUP PA PATIENT ACCOUNT
# 757                                     NYU MEDICAL CTR
# 543                                     NY PRESBYTERIAN
# 1328                               HQ GLOBAL WORKPLACES
# 1320                               HQ GLOBAL WORKPLACES
# 1321                               HQ GLOBAL WORKPLACES
# 1322                               HQ GLOBAL WORKPLACES
# 1323                               HQ GLOBAL WORKPLACES
# ...                                                 ...
# 1015                                      WESLY GRIFFIT
# 501                                   RICHARD L SHAFFER
# 177                                        DALE SCHLAIS
# 1816        CONTRA COSTA COUNTY OF MEDICAL STAFF OFFICE
# 1822   SAS SURGERY VEIN SPECIALISTS PHYSICIANS SURGEONS
# 627            REISS MD ALISHA FACS PHYSICIANS SURGEONS
# 1048       DAYTON CHILDREN S OUTPATIENT TESTING CENTERS
# 698   SARASOTA MEMORIAL HOSPITAL AND HEALTH CARE SYSTEM
# 220                  LERNERCOHEN HEALTHCARE HEALTH CARE
# 934                     ANESTHESIA BUSINESS CONSULTANTS
# 933                     ANESTHESIA BUSINESS CONSULTANTS
# 935                     ANESTHESIA BUSINESS CONSULTANTS
# 920              KAISER PERMANENTE MEDICAL CARE PROGRAM
# 923              KAISER PERMANENTE MEDICAL CARE PROGRAM
# 922              KAISER PERMANENTE MEDICAL CARE PROGRAM
# 921              KAISER PERMANENTE MEDICAL CARE PROGRAM
# 919              KAISER PERMANENTE MEDICAL CARE PROGRAM
# 918              KAISER PERMANENTE MEDICAL CARE PROGRAM
# 917              KAISER PERMANENTE MEDICAL CARE PROGRAM
# 1827      ORTHOPEDIC CENTER OF SOUTH FLORIDA PHYSICIANS
# 1829                                          AMERIPATH
# 1832                                      NORMAN MINARS
# 694                                       ST OF TX HHSC
# 1095         RUIZ LLANES JORGE MD PA PHYSICIANS GENERAL
# 388       WON DOUGLAS PHYSICIANS SURGEONS LASER SURGERY
# 497   COOPER AEROBICS CENTER COOPER CLINIC HEALTH CLUBS
# 496   COOPER AEROBICS CENTER COOPER CLINIC HEALTH CLUBS
# 1841            UNIVERSITY OF MEDICINE AND DENTISTRY OF
# 1842            UNIVERSITY OF MEDICINE AND DENTISTRY OF
# 973                                     HARVARD VANGUAR
#
#                   ContactAddressOut   ContactCityOut ContactStateOut  \
# 1251                            nan       HACKENSACK              NJ
# 1256                            nan       WASHINGTON              DC
# 1257                            nan       WASHINGTON              DC
# 1258                            nan       WASHINGTON              DC
# 1259                            nan       WASHINGTON              DC
# 1255                            nan       WASHINGTON              DC
# 581                             nan       WASHINGTON              DC
# 361                             nan       WASHINGTON              DC
# 169       321 RESEARCH PKWY STE 106          MERIDEN              CT
# 456              50 GAYLORD FARM RD      WALLINGFORD              CT
# 324                 266 WHITNEY AVE        NEW HAVEN              CT
# 1125               1605 ROSELAND DR       BIRMINGHAM              AL
# 1267                            nan       BIRMINGHAM              AL
# 1266                            nan       BIRMINGHAM              AL
# 1270                            nan          SEATTLE              WA
# 1273                            nan          AUGUSTA              ME
# 1274                            nan          AUGUSTA              ME
# 878       75 JOHN ROBERTS RD BLDG B   SOUTH PORTLAND              ME
# 942               500 W HOSPITAL RD      FRENCH CAMP              CA
# 1118                4201 MEDICAL DR      SAN ANTONIO              TX
# 1119                4201 MEDICAL DR      SAN ANTONIO              TX
# 1120                4201 MEDICAL DR      SAN ANTONIO              TX
# 471       8401 DATAPOINT DR STE 600      SAN ANTONIO              TX
# 757                     550 1ST AVE         NEW YORK              NY
# 543                             nan         NEW YORK              NY
# 1328                            nan         NEW YORK              NY
# 1320                            nan         NEW YORK              NY
# 1321                            nan         NEW YORK              NY
# 1322                            nan         NEW YORK              NY
# 1323                            nan         NEW YORK              NY
# ...                             ...              ...             ...
# 1015             2845 GREENBRIER RD        GREEN BAY              WI
# 501              2845 GREENBRIER RD        GREEN BAY              WI
# 177                  1420 ALGOMA ST       NEW LONDON              WI
# 1816                            nan         MARTINEZ              CA
# 1822                            nan      SPRINGFIELD              OH
# 627                 804 CENTRAL AVE       GREENVILLE              OH
# 1048                1 CHILDRENS PLZ           DAYTON              OH
# 698              1700 S TAMIAMI TRL         SARASOTA              FL
# 220       1921 WALDEMERE ST STE 814         SARASOTA              FL
# 934                26522 LA ALAMEDA    MISSION VIEJO              CA
# 933                26522 LA ALAMEDA    MISSION VIEJO              CA
# 935                26522 LA ALAMEDA    MISSION VIEJO              CA
# 920              10800 MAGNOLIA AVE        RIVERSIDE              CA
# 923              10800 MAGNOLIA AVE        RIVERSIDE              CA
# 922              10800 MAGNOLIA AVE        RIVERSIDE              CA
# 921              10800 MAGNOLIA AVE        RIVERSIDE              CA
# 919              10800 MAGNOLIA AVE        RIVERSIDE              CA
# 918              10800 MAGNOLIA AVE        RIVERSIDE              CA
# 917              10800 MAGNOLIA AVE        RIVERSIDE              CA
# 1827                            nan       PLANTATION              FL
# 1829                            nan  FORT LAUDERDALE              FL
# 1832                            nan        HOLLYWOOD              FL
# 694                             nan              nan             nan
# 1095                  1412 E 8TH ST          WESLACO              TX
# 388   4301 N MACARTHUR BLVD STE 101           IRVING              TX
# 497                12200 PRESTON RD           DALLAS              TX
# 496                12200 PRESTON RD           DALLAS              TX
# 1841                            nan           NEWARK              NJ
# 1842                            nan           NEWARK              NJ
# 973                             nan          CONCORD              MA
#
#      ContactZipOut ContactPhoneType ContactQualityScore   ...   iscell  \
# 1251          7601         BUSINESS                 nan   ...        N
# 1256    20422-0001         BUSINESS                 nan   ...        N
# 1257    20422-0001         BUSINESS                 nan   ...        N
# 1258    20422-0001         BUSINESS                 nan   ...        N
# 1259    20422-0001         BUSINESS                 nan   ...        N
# 1255    20422-0001         BUSINESS                 nan   ...        N
# 581          20024         BUSINESS                 LOW   ...        N
# 361          20036         BUSINESS                 LOW   ...        N
# 169     06450-8341         BUSINESS                HIGH   ...        N
# 456     06492-2828         BUSINESS                HIGH   ...        N
# 324     06511-8902         BUSINESS                 LOW   ...        N
# 1125    35209-3935      RESIDENTIAL                HIGH   ...        N
# 1267         35233         BUSINESS                 nan   ...        N
# 1266         35233         BUSINESS                 nan   ...        N
# 1270         98101         BUSINESS                 nan   ...        N
# 1273          4330         BUSINESS                 nan   ...        N
# 1274          4330         BUSINESS                 nan   ...        N
# 878     04106-6967      RESIDENTIAL                HIGH   ...        N
# 942     95231-9693         BUSINESS                HIGH   ...        N
# 1118    78229-5656         BUSINESS                 LOW   ...        N
# 1119    78229-5656         BUSINESS                 LOW   ...        N
# 1120    78229-5656         BUSINESS                 LOW   ...        N
# 471     78229-5907         BUSINESS                HIGH   ...        N
# 757     10016-6402         BUSINESS                 LOW   ...        N
# 543          10021         BUSINESS                 LOW   ...        N
# 1328         10022         BUSINESS                 nan   ...        N
# 1320         10022         BUSINESS                 nan   ...        N
# 1321         10022         BUSINESS                 nan   ...        N
# 1322         10022         BUSINESS                 nan   ...        N
# 1323         10022         BUSINESS                 nan   ...        N
# ...            ...              ...                 ...   ...      ...
# 1015    54311-6519      RESIDENTIAL                HIGH   ...        N
# 501     54311-6519      RESIDENTIAL                HIGH   ...        N
# 177     54961-2104      RESIDENTIAL                HIGH   ...        N
# 1816    94553-3156         BUSINESS                 nan   ...        N
# 1822    45504-2581         BUSINESS                 nan   ...        N
# 627     45331-1206         BUSINESS                HIGH   ...        N
# 1048    45404-1873         BUSINESS                 LOW   ...        N
# 698     34239-3509         BUSINESS                 LOW   ...        N
# 220     34239-2913         BUSINESS                HIGH   ...        N
# 934     92691-6330         BUSINESS                 LOW   ...        N
# 933     92691-6330         BUSINESS                 LOW   ...        N
# 935     92691-6330         BUSINESS                 LOW   ...        N
# 920     92505-3043         BUSINESS                 LOW   ...        N
# 923     92505-3043         BUSINESS                 LOW   ...        N
# 922     92505-3043         BUSINESS                 LOW   ...        N
# 921     92505-3043         BUSINESS                 LOW   ...        N
# 919     92505-3043         BUSINESS                 LOW   ...        N
# 918     92505-3043         BUSINESS                 LOW   ...        N
# 917     92505-3043         BUSINESS                 LOW   ...        N
# 1827         33324         BUSINESS                 nan   ...        N
# 1829         33308         BUSINESS                 nan   ...        N
# 1832         33021      RESIDENTIAL                 nan   ...        N
# 694            nan         BUSINESS                 MED   ...        N
# 1095    78596-6639         BUSINESS                HIGH   ...        V
# 388     75038-6497         BUSINESS                HIGH   ...        N
# 497     75230-2223         BUSINESS                HIGH   ...        N
# 496     75230-2223         BUSINESS                HIGH   ...        N
# 1841          7107         BUSINESS                 nan   ...        N
# 1842          7107         BUSINESS                 nan   ...        N
# 973           1742         BUSINESS                 LOW   ...        N
#
#                           carrier date_checked  \
# 1251                  Airus, Inc.   2019-09-04
# 1256           Cavalier Telephone   2019-09-04
# 1257           Cavalier Telephone   2019-09-04
# 1258           Cavalier Telephone   2019-09-04
# 1259           Cavalier Telephone   2019-09-04
# 1255           Cavalier Telephone   2019-09-04
# 581                        PAETEC   2019-09-25
# 361                       Level 3   2019-09-25
# 169       Frontier Communications   2019-09-04
# 456       Frontier Communications   2019-09-25
# 324                 BANDWIDTH.COM   2019-09-25
# 1125                Charter Fiber   2019-09-25
# 1267                    BellSouth   2019-09-04
# 1266                    BellSouth   2019-09-04
# 1270             X5Solutions-ATLC   2019-09-04
# 1273     FairPoint Communications   2019-09-04
# 1274     FairPoint Communications   2019-09-04
# 878   CRC Communications of Maine   2019-09-25
# 942    Pacific Bell - Nevada Bell   2019-09-25
# 1118            SouthWestern Bell   2019-09-25
# 1119            SouthWestern Bell   2019-09-25
# 1120            SouthWestern Bell   2019-09-25
# 471                    tw telecom   2019-09-25
# 757                        PAETEC   2019-09-25
# 543                       Level 3   2019-09-25
# 1328                      Verizon   2019-09-04
# 1320                      Verizon   2019-09-04
# 1321                      Verizon   2019-09-04
# 1322                      Verizon   2019-09-04
# 1323                      Verizon   2019-09-04
# ...                           ...          ...
# 1015                    Ameritech   2019-09-25
# 501                           TCG   2019-09-25
# 177                     Ameritech   2019-09-04
# 1816   Pacific Bell - Nevada Bell   2019-09-04
# 1822          Cincinnati Bell Tel   2019-09-04
# 627                           TCG   2019-09-25
# 1048                   tw telecom   2019-09-25
# 698                       Level 3   2019-09-25
# 220            Frontier Rochester   2019-09-25
# 934                       Level 3   2019-09-25
# 933                       Level 3   2019-09-25
# 935                       Level 3   2019-09-25
# 920    Pacific Bell - Nevada Bell   2019-09-25
# 923    Pacific Bell - Nevada Bell   2019-09-25
# 922    Pacific Bell - Nevada Bell   2019-09-25
# 921    Pacific Bell - Nevada Bell   2019-09-25
# 919    Pacific Bell - Nevada Bell   2019-09-25
# 918    Pacific Bell - Nevada Bell   2019-09-25
# 917    Pacific Bell - Nevada Bell   2019-09-25
# 1827                      Cbeyond   2019-09-04
# 1829   MCImetro Former Intermedia   2019-09-04
# 1832   MCImetro Former Intermedia   2019-09-04
# 694                       Level 3   2019-09-25
# 1095              TimeWarnerCable   2019-09-25
# 388            Frontier Rochester   2019-09-25
# 497                           TCG   2019-09-25
# 496                           TCG   2019-09-25
# 1841     MCImetro Former Worldcom   2019-09-04
# 1842     MCImetro Former Worldcom   2019-09-04
# 973            Broadview Networks   2019-09-25
#
#                          OFFICE_ADDRESS_LINE_1         OFFICE_ADDRESS_LINE_2  \
# 1251                                       nan     385 PROSPECT AVE  STE 200
# 1256                                       nan          3800 RESERVOIR RD NW
# 1257                                       nan               50 IRVING ST NW
# 1258           VETERNAS AFFAIRS MEDICAL CENTER               50 IRVING ST NW
# 1259                                       nan               50 IRVING ST NW
# 1255                         VETERANS HOSPITAL               50 IRVING ST NW
# 581                                        BA2              110 IRVING ST NW
# 361                GEORGE WASHINGTON UNIV HOSP                900 23RD ST NW
# 169                                    STE 106             321 RESEARCH PKWY
# 456                                        nan            50 GAYLORD FARM RD
# 324   YALE UNIVERSITY SCHOOL OF MEDICINE - END                  333 CEDAR ST
# 1125                                       nan              1605 ROSELAND DR
# 1267                                       UAB                 619 19TH ST S
# 1266                                  JT N 266                 619 19TH ST S
# 1270                                       nan                           nan
# 1273                                       nan      6 E CHESTNUT ST  STE 340
# 1274                                       nan              15 E CHESTNUT ST
# 878        MAINE MEDICAL PARTNERS - PEDIATRICS     75 JOHN ROBERTS RD STE B8
# 942               SAN JOAQUIN GENERAL HOSPITAL             500 W HOSPITAL RD
# 1118            CENTRAL COUNTIES SERVICES MHMR                 304 S 22ND ST
# 1119                DEPT OF EMERGENCY MEDICINE            7703 FLOYD CURL DR
# 1120                          2ND FLOOR MS 722               6600 MADISON ST
# 471                                 POBOX29407   155 E SONTERRA BLVD STE 100
# 757                 BALLARD COMMUNITY HOSPITAL              15001 59TH PL NE
# 543                              525 E 68TH ST                       BOX 124
# 1328                                       nan         82 PATTON AVE STE 510
# 1320                                       nan                 502 ELM ST NE
# 1321                                       nan              3904 CORTEZ RD W
# 1322                                       nan              23625 HOLMAN HWY
# 1323                      SANTA CLARA MED OFCS                2885 KAISER DR
# ...                                        ...                           ...
# 1015                                   STE 360            2845 GREENBRIER RD
# 501                                      # 430            2845 GREENBRIER RD
# 177                                        nan                1420 ALGOMA ST
# 1816          CONTRA COSTA REGIONAL MED CENTER             2500 ALHAMBRA AVE
# 1822                                   STE 220          30 WARDER ST STE 220
# 627                                        nan               804 CENTRAL AVE
# 1048                    DEPT OF ANESTHESIOLOGY               1 CHILDRENS PLZ
# 698                                        nan  3901 COCONUT PALM DR STE 120
# 220                                        nan     1921 WALDEMERE ST STE 814
# 934                                        nan      26522 LA ALAMEDA STE 370
# 933                                        nan      26522 LA ALAMEDA STE 370
# 935                                        nan      26522 LA ALAMEDA STE 370
# 920                  KAISER PERMANENTE MED CTR            10800 MAGNOLIA AVE
# 923                                        nan            10800 MAGNOLIA AVE
# 922                                        nan            10800 MAGNOLIA AVE
# 921            MEDICAL GROUP-RIVERSIDE MED CTR            10800 MAGNOLIA AVE
# 919                                        nan            10800 MAGNOLIA AVE
# 918                                        nan            10800 MAGNOLIA AVE
# 917     RIVERSIDE MEDICAL CENTER - ORTHOPEDICS            10800 MAGNOLIA AVE
# 1827                                       nan              11401 NW 19TH ST
# 1829                                       nan       895 SW 30TH AVE STE 101
# 1832                                     STE C          4060 SHERIDAN STREET
# 694                                        nan               601 W SESAME DR
# 1095                                       nan            1526 N EDGEMONT ST
# 388                                        nan    4090 MAPLESHADE LN STE 100
# 497                              COOPER CLINIC              12200 PRESTON RD
# 496                              COOPER CLINIC              12200 PRESTON RD
# 1841                                       nan        150 BERGEN ST STE H245
# 1842                        8TH FL TEAM HEALTH                912 GESSNER RD
# 973                                        nan                 330 BAKER AVE
#
#            wsl_city wsl_state wsl_zip isDisconnected isWrong
# 1251           HACK        NJ   07601              0       0
# 1256     WASHINGTON        DC   20007              0       0
# 1257     WASHINGTON        DC   20422              0       0
# 1258     WASHINGTON        DC   20422              0       0
# 1259     WASHINGTON        DC   20422              0       0
# 1255     WASHINGTON        DC   20422              0       0
# 581      WASHINGTON        DC   20010              0       0
# 361      WASHINGTON        DC   20037              1       0
# 169         MERIDEN        CT   06450              1       0
# 456     WALLINGFORD        CT   06492              0       1
# 324       NEW HAVEN        CT   06510              0       0
# 1125     BIRMINGHAM        AL   35209              1       0
# 1267     BIRMINGHAM        AL   35233              1       0
# 1266     BIRMINGHAM        AL   35233              1       0
# 1270            nan       nan     nan              0       0
# 1273        AUGUSTA        ME   04330              0       0
# 1274        AUGUSTA        ME   04330              0       0
# 878      S PORTLAND        ME   04106              0       1
# 942     FRENCH CAMP        CA   95231              0       1
# 1118         TEMPLE        TX   76501              1       0
# 1119    SAN ANTONIO        TX   78229              1       0
# 1120   NEW PRT RCHY        FL   34652              1       0
# 471     SAN ANTONIO        TX   78229              0       0
# 757         KENMORE        WA   98028              1       0
# 543        NEW YORK        NY   10065              0       1
# 1328      ASHEVILLE        NC   28801              1       0
# 1320    ALBUQUERQUE        NM   87102              1       0
# 1321      BRADENTON        FL   34210              1       0
# 1322       MONTEREY        CA   93940              1       0
# 1323    SANTA CLARA        CA   95051              1       0
# ...             ...       ...     ...            ...     ...
# 1015       BELLEVUE        WI   54311              0       0
# 501       GREEN BAY        WI   54311              0       1
# 177      NEW LONDON        WI   54961              0       0
# 1816       MARTINEZ        CA   94553              0       1
# 1822    SPRINGFIELD        OH   45504              0       1
# 627      GREENVILLE        OH   45331              0       0
# 1048         DAYTON        OH   45404              0       0
# 698           TAMPA        FL   33619              1       0
# 220        SARASOTA        FL   34239              0       1
# 934   MISSION VIEJO        CA   92691              0       1
# 933   MISSION VIEJO        CA   92691              0       0
# 935   MISSION VIEJO        CA   92691              0       1
# 920       RIVERSIDE        CA   92505              0       0
# 923       RIVERSIDE        CA   92505              0       1
# 922       RIVERSIDE        CA   92505              0       0
# 921       RIVERSIDE        CA   92505              0       0
# 919       RIVERSIDE        CA   92505              0       0
# 918       RIVERSIDE        CA   92505              0       0
# 917       RIVERSIDE        CA   92505              0       0
# 1827     PLANTATION        FL   33323              0       0
# 1829  POMPANO BEACH        FL   33069              1       0
# 1832      HOLLYWOOD        FL   33021              0       0
# 694       HARLINGEN        TX   78550              1       0
# 1095    LOS ANGELES        CA   90027              1       0
# 388           PLANO        TX   75093              1       0
# 497          DALLAS        TX   75230              0       1
# 496          DALLAS        TX   75230              0       1
# 1841         NEWARK        NJ   07103              0       1
# 1842        HOUSTON        TX   77024              0       0
# 973         CONCORD        MA   01742              0       0
#
# [434 rows x 24 columns]

# %%
gpi = gpi.groupby('phone').first().reset_index() # remove duplicates (typically differing address)
len(gpi)  # should be back to value on first merge
# Out:
# 1412

# %% [markdown]
# ### Save Intermediate data

# %%
gpi.to_csv('U:\\Source Files\\Data Analytics\\Data-Science\\Data\\Get_Phone_Info\\gpi_merged.csv', index=False)
#gpi.to_csv('U:\\Source Files\\Data Analytics\\Data-Science\\Data\\Get_Phone_Info\\gpi_merged.csv', index=False)

# %% [markdown]
# # Data transformation

# %%
addr_translate = {
    'DR': 'DRIVE',
    'PKWY': 'PARKWAY',
    'RD': 'ROAD',
    'ST': 'STREET',
    'STE': 'SUITE',
    'N': 'NORTH',
    'S': 'SOUTH',
    'E': 'EAST',
    'W': 'WEST',
    'LN': 'LANE',
    'CTR': 'CENTER',
    'CT': 'COURT',
    'BLVD': 'BOULEVARD',
    'CIR': 'CIRCLE',
    'HTS': 'HEIGHTS',
    'AVE': 'AVENUE',
    'HWY': 'HIGHWAY',
    'JCT': 'JUNCTION',
    'LK': 'LAKE',
    'MTN': 'MTN',
    'APT': 'APARTMENT',
    'RM': 'ROOM',
    'PL': 'PLACE',
    'PLZ': 'PLACA',
    'RDG': 'RIDGE',
    'SQ': 'SQUARE',
    'STA': 'STATION',
    'TER': 'TERRACE',
    'TRL': 'TRAIL',
    'TPKE': 'TURNPIKE',
    'VLY': 'VALLEY',
    'IS': 'ISLAND'
}

# returns a standardized address string. Extends abbreviations to full words.
def translate_addr(addr_string):
    addr_string = addr_string.upper()
    new_addr = []
    
    tokens = addr_string.split()
    
    for t in tokens:
        if t in addr_translate:
            new_addr.append(addr_translate[t])
        else:
            new_addr.append(t)
    
    return ' '.join(new_addr)

# %%
def addr_potential_match(addr1, addr2):
    return addr1==addr2 or addr1 in addr2 or addr2 in addr1

# %%
to_del = []  # list of columns to delete after transformation


##############################################################################
############################ WSLive ########################################


# Translating WSLive address

gpi['OFFICE_ADDRESS_LINE_1'] = gpi['OFFICE_ADDRESS_LINE_1'].apply(lambda x: ' '.join([t if t not in ['nan', 'NAN'] else '' for t in str(x).split()]))
gpi['OFFICE_ADDRESS_LINE_2'] = gpi['OFFICE_ADDRESS_LINE_2'].apply(lambda x: ' '.join([t if t not in ['nan', 'NAN'] else '' for t in str(x).split()]))

gpi['OFFICE_ADDRESS_LINE_1'] = gpi['OFFICE_ADDRESS_LINE_1'].apply(translate_addr)
gpi['OFFICE_ADDRESS_LINE_2'] = gpi['OFFICE_ADDRESS_LINE_2'].apply(translate_addr)
gpi['wsl_address'] = gpi['OFFICE_ADDRESS_LINE_1'] + gpi['OFFICE_ADDRESS_LINE_2']

to_del.append('OFFICE_ADDRESS_LINE_1')
to_del.append('OFFICE_ADDRESS_LINE_2')



##############################################################################
############################ GPI ########################################


# Translating GetPhoneInfo address and name
gpi['ContactAddressOut'] = gpi['ContactAddressOut'].apply(lambda x: ' '.join([t if t not in ['nan', 'NAN'] else '' for t in str(x).split()]))
gpi['gpi_address']       = gpi['ContactAddressOut'].apply(translate_addr)
gpi['ContactNameOut']    = gpi['ContactNameOut'].apply(lambda x: ' '.join([t if t not in ['nan', 'NAN'] else '' for t in str(x).split()]))
gpi['gpi_name']          = gpi['ContactNameOut'].apply(translate_addr)
to_del.append('ContactAddressOut')
to_del.append('ContactNameOut')

# encoding GetPhoneInfo 'Notes'

gpi['gpi_isConnected'] = gpi['NoteDescriptions'].apply(lambda x: 1 if 'IsConnected' in x else 0)
gpi['gpi_isPorted']    = gpi['NoteDescriptions'].apply(lambda x: 1 if 'IsPorted' in x else 0)
gpi['gpi_isMailable']  = gpi['NoteDescriptions'].apply(lambda x: 1 if 'IsMailable' in x else 0)
gpi['gpi_isWireless']  = gpi['NoteDescriptions'].apply(lambda x: 1 if 'IsWireless' in x else 0)
gpi['gpi_isPossibleDisconnected'] = gpi['NoteDescriptions'].apply(lambda x: 1 if 'IsPossibleDisconnected' in x else 0)
gpi['gpi_isPossiblePortableVOIP'] = gpi['NoteDescriptions'].apply(lambda x: 1 if 'IsPossiblePortableVOIP' in x else 0)
gpi['gpi_INF'] = gpi['NoteDescriptions'].apply(lambda x: 1 if 'INF' in x else 0)

to_del.append('NoteDescriptions')


# encoding GetPhoneInfo 'QualityScore'
quality = {
    'HIGH': 3,
    'MED': 2,
    'LOW': 1,
    'nan': 1,
    None: 1
}
gpi['gpi_qs_null'] = gpi['ContactQualityScore'].apply(lambda x: 1 if x in ['nan', None] else 0)
gpi['gpi_qs']      = gpi['ContactQualityScore'].apply(lambda x: quality[x] if x in quality else 1)

to_del.append('ContactQualityScore')


# encoding GetPhoneInfo name
med_terms = list(set([t.upper() for t in med_words]))

gpi['ContactNameOut'] = gpi['ContactNameOut'].apply(lambda x: ' '.join([t if t not in ['nan', 'NAN'] else '' for t in str(x).split()]))
gpi['gpi_name_meddy'] = gpi['ContactNameOut'].apply(lambda x: 1 if any([t in x for t in med_terms]) else 0)



# standardizing Zipcode to first 5 digits

gpi['gpi_zip'] = gpi['ContactZipOut'].apply(lambda x: x[:5] if len(x)>=5 else x)  # reduce extended Zipcodes
gpi['gpi_zip'] = gpi['gpi_zip'].apply(lambda x: ('000' + x)[-5:] if x.isdigit() else x)

to_del.append('ContactZipOut')


# standardizing PhoneType

gpi['gpi_phonetype'] = gpi['ContactPhoneType'].apply(lambda x: x if x in ['BUSINESS', 'RESIDENTIAL'] else 'UNKNOWN')

to_del.append('ContactPhoneType')


# parse 'Date' as Datetime Date
gpi['gpi_date'] = gpi['DateOfPorting'].apply(lambda x: parse(x) if x not in ['nan', 'None', None] else x)
to_del.append('DateOfPorting')
# get date diff
gpi['gpi_date_diff']    = gpi['gpi_date'].apply(lambda x: (datetime.now() - x).days if x not in ['nan','None'] else x)
notnull_date_diffs      = [d for d in gpi['gpi_date_diff'].values if d not in ['nan', 'None', None]]
gpi['gpi_date_diff']    = gpi['gpi_date_diff'].apply(lambda x: x if x not in ['nan', 'None', None] else 2*max(notnull_date_diffs))
gpi['gpi_date_missing'] = gpi['gpi_date'].apply(lambda x: 1 if x in ['nan', 'None', None] else 0)

to_del.append('gpi_date')

# Line type
gpi['gpi_linetype_m'] = gpi['LineTypeOut'].apply(lambda x: 1 if x=='WIRELESS' else 0)  # wireless - mobile
gpi['gpi_linetype_v'] = gpi['LineTypeOut'].apply(lambda x: 1 if x=='VOIP' else 0)
gpi['gpi_linetype_l'] = gpi['LineTypeOut'].apply(lambda x: 1 if x=='LANDLINE' else 0)

to_del.append('LineTypeOut')


##############################################################################
############################ AREA CODE #######################################


gpi.drop(columns=to_del, axis=1, inplace=True)


# area and prefix features
gpi['gpi_area_code']   = gpi['phone'].apply(lambda x: x[:3])
gpi['gpi_area+prefix'] = gpi['phone'].apply(lambda x: x[:6])


# renaming address fields
gpi.rename(columns={'ContactCityOut': 'gpi_city',
                    'ContactStateOut':'gpi_state',
                    'ProviderNameOut': 'gpi_provider'}, inplace=True)


##############################################################################
############################ GPI CATEGORICALS ################################


# categorize
gpi_categoricals = [
    'gpi_city',
    'gpi_provider',
    'gpi_state',
    'gpi_zip',
    'gpi_phonetype',
    'gpi_area_code',
    'gpi_area+prefix'
]

for col in gpi_categoricals:
    gpi[col] = gpi[col].astype('category')
    
#########################################################################
############################ RPV ########################################


# encode RPV status
rpv_statuses = {
    'disconnected': 4,
    'disconnected-70': 3,
    'connected-75': 2,
    'connected': 1
}
gpi['rpv_status'] = gpi['status'].apply(lambda x: rpv_statuses[x] if x in rpv_statuses else 0)

# encode rpv iscell
gpi['rpv_iscell_V'] = gpi['iscell'].apply(lambda x: 1 if x=='V' else 0)
gpi['rpv_iscell_Y'] = gpi['iscell'].apply(lambda x: 1 if x=='Y' else 0)

# categorize carrier
gpi['carrier'] = gpi['carrier'].astype('category')

# drop unnecessary columns after transformation
gpi.drop(columns=['status','error_text','iscell','date_checked'], axis=1, inplace=True)

# rename carrier
gpi.rename(columns={'carrier': 'rpv_carrier'},inplace=True)


##############################################################################
############################ MATCHING ########################################

# finding potential provider matches (gpi_provder and rpv_carrier) -- different naming conventions so it's a little tricky
gpi['match_provider'] = [1 if any([t in g for t in r.split()]) else 0 for r, g in zip(gpi['rpv_carrier'], gpi['gpi_provider'])]
# WSLive city match GPI
gpi['match_city']     = [1 if r==g else 0 for r, g in zip(gpi['gpi_city'], gpi['wsl_city'])] 
# WSLive state match GPI
gpi['match_state']    = [1 if r==g else 0 for r, g in zip(gpi['gpi_state'], gpi['wsl_state'])] 
# WSLive ZIP match GPI
gpi['match_zip']      = [1 if r==g else 0 for r, g in zip(gpi['gpi_zip'], gpi['wsl_zip'])] 
# WSLive Address match GPI
gpi['match_address']  = [1 if any([t in g for t in r.split()]) else 0 for r, g in zip(gpi['wsl_address'], gpi['gpi_address'])]

to_del = [
    'gpi_city',
    'gpi_state',
    'gpi_zip',
    'gpi_provider',
    'wsl_city',
    'wsl_state',
    'wsl_zip',
    'rpv_carrier',
    'wsl_address',
    'gpi_address',
    'gpi_name'
]

gpi.drop(columns=to_del, axis=1, inplace=True)


##############################################################################
############################ GPI PHONE TYPE AND BUSINESS #####################


gpi['gpi_type_business']    = gpi['gpi_phonetype'].apply(lambda x: 1 if x=='BUSINESS' else 0)
gpi['gpi_type_residential'] = gpi['gpi_phonetype'].apply(lambda x: 1 if x=='RESIDENTIAL' else 0)

gpi.drop(columns='gpi_phonetype', axis=1, inplace=True)

##############################################################################
############################ MATCH GPI RPV LINE TYPE#### #####################
gpi['match_linetype_voip']   = [1 if r==g else 0 for r, g in zip(gpi['gpi_linetype_v'], gpi['rpv_iscell_V'])]
gpi['match_linetype_mobile'] = [1 if r==g else 0 for r, g in zip(gpi['gpi_linetype_m'], gpi['rpv_iscell_Y'])]

# %%
gpi.dtypes
# Out:
# phone                           object
# isDisconnected                   int64
# isWrong                          int64
# gpi_isConnected                  int64
# gpi_isPorted                     int64
# gpi_isMailable                   int64
# gpi_isWireless                   int64
# gpi_isPossibleDisconnected       int64
# gpi_isPossiblePortableVOIP       int64
# gpi_INF                          int64
# gpi_qs_null                      int64
# gpi_qs                           int64
# gpi_name_meddy                   int64
# gpi_date_diff                    int64
# gpi_date_missing                 int64
# gpi_linetype_m                   int64
# gpi_linetype_v                   int64
# gpi_linetype_l                   int64
# gpi_area_code                 category
# gpi_area+prefix               category
# rpv_status                       int64
# rpv_iscell_V                     int64
# rpv_iscell_Y                     int64
# match_provider                   int64
# match_city                       int64
# match_state                      int64
# match_zip                        int64
# match_address                    int64
# gpi_type_business                int64
# gpi_type_residential             int64
# match_linetype_voip              int64
# match_linetype_mobile            int64
# dtype: object

# %%
savepath = 'U:\\Source Files\\Data Analytics\\Data-Science\\Data\\Get_Phone_Info\\gpi_merged_processed.csv'

# %%
### Saving off data
gpi.to_csv(savepath, index=False)

# %%
### loading data above
#gpi = pk.load(open('savepath', 'rb'))

# %% [markdown]
# # Done transforming.
#
# .
#
# .
#
# .
#
# # Setting X and y for dataset

# %% [markdown]
# #### All data

# %%
Xy = gpi.set_index('phone')
target = gpi['isDisconnected']
#target = gpi['isWrong']

del Xy['isWrong']
del Xy['isDisconnected']

# %% [markdown]
# #### Only records RPV says are "disconnected"

# %%
Xy_dc = gpi[gpi['rpv_status'] == 4].copy().set_index('phone')
target_dc = gpi[gpi['rpv_status'] == 4]['isDisconnected']
del Xy_dc['isDisconnected']
del Xy_dc['isWrong']

# %% [markdown]
# #### Only records says are "disconnected" or "disconnected-70"

# %%
Xy_dc70 = gpi[gpi['rpv_status'] >=3].copy().set_index('phone')
target_dc70 = gpi[gpi['rpv_status'] >= 3]['isDisconnected']
del Xy_dc70['isDisconnected']
del Xy_dc70['isWrong']

# %%
data = {
    'all': {
        'X': Xy,
        'y': target
    },
    'dc': {
        'X': Xy_dc,
        'y': target_dc
    },
    'dc70': {
        'X': Xy_dc70,
        'y': target_dc70
    }
}

# %%
Xy.dtypes
# Out:
# gpi_isConnected                  int64
# gpi_isPorted                     int64
# gpi_isMailable                   int64
# gpi_isWireless                   int64
# gpi_isPossibleDisconnected       int64
# gpi_isPossiblePortableVOIP       int64
# gpi_INF                          int64
# gpi_qs_null                      int64
# gpi_qs                           int64
# gpi_name_meddy                   int64
# gpi_date_diff                    int64
# gpi_date_missing                 int64
# gpi_linetype_m                   int64
# gpi_linetype_v                   int64
# gpi_linetype_l                   int64
# gpi_area_code                 category
# gpi_area+prefix               category
# rpv_status                       int64
# rpv_iscell_V                     int64
# rpv_iscell_Y                     int64
# match_provider                   int64
# match_city                       int64
# match_state                      int64
# match_zip                        int64
# match_address                    int64
# gpi_type_business                int64
# gpi_type_residential             int64
# match_linetype_voip              int64
# match_linetype_mobile            int64
# dtype: object

# %%
for dataset in data:
    
    X = data[dataset]['X']
    y = data[dataset]['y']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    train_dataset = lgb.Dataset(X_train, y_train)
    test_dataset = lgb.Dataset(X_test, y_test)


    # T - no. of total samples
    # P - no. of positive samples
    T = len(target)
    P = sum(target)
    pos = ((1.0 * T)/P) - 1


    # experiment with different parameters
    param = {
        'num_leaves': 31, 
        'objective': 'binary',
        'metric': 'auc',
        'learning_rate': 0.1,
        'scale_pos_weight': pos
    }
    n_iter = 500

    bst = lgb.train(param, train_dataset, n_iter, valid_sets=test_dataset, early_stopping_rounds=50)

    y_pred = bst.predict(X_test)
    y_pred_c = [1 if p >= 0.5 else 0 for p in y_pred]

    print('LightGBM')
    thresholds = [0.5, 0.6, 0.7, 0.8, 0.9]
    for t in thresholds:
        y_pred_c = [1 if p >= t else 0 for p in y_pred]
        print()
        print('LightGBM', 'Threshold:', t)
        print('\t\tNumber DC: {}, Number classified as DC: {}'.format(sum(y_test), sum(y_pred_c)))
        print('\t\tNumber DC correctly classified: {}'.format(sum([1 if p==1 and t==1 else 0 for p, t in zip(y_pred_c, y_test)])))
        false_positive = [1 if p==1 and t==0 else 0 for p, t in zip(y_pred_c, y_test)]
        print('\t\tNumber False Positives: {}'.format(sum(false_positive)))
        print('\t\tFalsePositiveRate: {}'.format(
            round(
                sum(false_positive)/(len(y_test)-sum(y_test)),
                2)))
        print(metrics.classification_report(y_true=y_test, y_pred=y_pred_c))
        print('###########################################')


    classifiers = {
        "Nearest Neighbors": KNeighborsClassifier(3),
        "Gaussian Process": GaussianProcessClassifier(1.0 * RBF(1.0)),
        "Decision Tree": DecisionTreeClassifier(max_depth=8), 
        "Random Forest": RandomForestClassifier(max_depth=10, n_estimators=15, max_features='auto'), 
        "Neural Net": MLPClassifier(alpha=1, max_iter=2000), 
        "AdaBoost": AdaBoostClassifier(),
        "Naive Bayes": GaussianNB(), 
    }

    for clf_name in classifiers:

        clf = classifiers[clf_name]
        clf.fit(X_train, y_train)

        y_pred = clf.predict(X_test)
        y_pred_p = clf.predict_proba(X_test)

        print(clf_name)
        for t in thresholds:
            y_pred_c = [1 if p[1] >= t else 0 for p in y_pred_p]
            precision = round(metrics.precision_score(y_true=y_test, y_pred=y_pred_c),2)
            recall = round(metrics.recall_score(y_true=y_test, y_pred=y_pred_c),2)
            print()
            print(clf_name, 'Threshold:', t)
            print('\t\tNumber DC: {}, Number classified as DC: {}'.format(sum(y_test), sum(y_pred_c)))
            print('\t\tNumber DC correctly classified: {}'.format(sum([1 if p==1 and t==1 else 0 for p, t in zip(y_pred_c, y_test)])))
            false_positive = [1 if p==1 and t==0 else 0 for p, t in zip(y_pred_c, y_test)]
            print('\t\tNumber False Positives: {}'.format(sum(false_positive)))
            print('\t\tFalsePositiveRate: {}'.format(
                round(
                    sum(false_positive)/(len(y_test)-sum(y_test)),
                    2)))

            print(metrics.classification_report(y_true=y_test, y_pred=y_pred_c))
            print('###########################################')
# Out:
# C:\Users\glappe\anaconda3\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	valid_0's auc: 0.767916
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.777694
# [3]	valid_0's auc: 0.776939
# [4]	valid_0's auc: 0.791853
# [5]	valid_0's auc: 0.791372
# [6]	valid_0's auc: 0.791795
# [7]	valid_0's auc: 0.79303
# [8]	valid_0's auc: 0.794689
# [9]	valid_0's auc: 0.795158
# [10]	valid_0's auc: 0.797639
# [11]	valid_0's auc: 0.795821
# [12]	valid_0's auc: 0.796267
# [13]	valid_0's auc: 0.799732
# [14]	valid_0's auc: 0.80083
# [15]	valid_0's auc: 0.80051
# [16]	valid_0's auc: 0.801768
# [17]	valid_0's auc: 0.802752
# [18]	valid_0's auc: 0.8029
# [19]	valid_0's auc: 0.800453
# [20]	valid_0's auc: 0.801825
# [21]	valid_0's auc: 0.799355
# [22]	valid_0's auc: 0.797182
# [23]	valid_0's auc: 0.798131
# [24]	valid_0's auc: 0.799824
# [25]	valid_0's auc: 0.800579
# [26]	valid_0's auc: 0.80019
# [27]	valid_0's auc: 0.801173
# [28]	valid_0's auc: 0.800556
# [29]	valid_0's auc: 0.799321
# [30]	valid_0's auc: 0.800384
# [31]	valid_0's auc: 0.799607
# [32]	valid_0's auc: 0.79844
# [33]	valid_0's auc: 0.797434
# [34]	valid_0's auc: 0.795855
# [35]	valid_0's auc: 0.795718
# [36]	valid_0's auc: 0.796519
# [37]	valid_0's auc: 0.796885
# [38]	valid_0's auc: 0.796679
# [39]	valid_0's auc: 0.797388
# [40]	valid_0's auc: 0.797571
# [41]	valid_0's auc: 0.797617
# [42]	valid_0's auc: 0.796198
# [43]	valid_0's auc: 0.795238
# [44]	valid_0's auc: 0.79581
# [45]	valid_0's auc: 0.795169
# [46]	valid_0's auc: 0.795215
# [47]	valid_0's auc: 0.79494
# [48]	valid_0's auc: 0.796015
# [49]	valid_0's auc: 0.794735
# [50]	valid_0's auc: 0.793751
# [51]	valid_0's auc: 0.793271
# [52]	valid_0's auc: 0.793225
# [53]	valid_0's auc: 0.791624
# [54]	valid_0's auc: 0.790869
# [55]	valid_0's auc: 0.791075
# [56]	valid_0's auc: 0.79064
# [57]	valid_0's auc: 0.789291
# [58]	valid_0's auc: 0.788604
# [59]	valid_0's auc: 0.789039
# [60]	valid_0's auc: 0.788078
# [61]	valid_0's auc: 0.789085
# [62]	valid_0's auc: 0.789291
# [63]	valid_0's auc: 0.788422
# [64]	valid_0's auc: 0.788033
# [65]	valid_0's auc: 0.787301
# [66]	valid_0's auc: 0.787369
# [67]	valid_0's auc: 0.788101
# [68]	valid_0's auc: 0.788147
# Early stopping, best iteration is:
# [18]	valid_0's auc: 0.8029
# LightGBM
#
# LightGBM Threshold: 0.5
# 		Number DC: 177, Number classified as DC: 181
# 		Number DC correctly classified: 123
# 		Number False Positives: 58
# 		FalsePositiveRate: 0.23
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77       247
#            1       0.68      0.69      0.69       177
#
#    micro avg       0.74      0.74      0.74       424
#    macro avg       0.73      0.73      0.73       424
# weighted avg       0.74      0.74      0.74       424
#
# ###########################################
#
# LightGBM Threshold: 0.6
# 		Number DC: 177, Number classified as DC: 152
# 		Number DC correctly classified: 108
# 		Number False Positives: 44
# 		FalsePositiveRate: 0.18
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.78       247
#            1       0.71      0.61      0.66       177
#
#    micro avg       0.73      0.73      0.73       424
#    macro avg       0.73      0.72      0.72       424
# weighted avg       0.73      0.73      0.73       424
#
# ###########################################
#
# LightGBM Threshold: 0.7
# 		Number DC: 177, Number classified as DC: 104
# 		Number DC correctly classified: 76
# 		Number False Positives: 28
# 		FalsePositiveRate: 0.11
#               precision    recall  f1-score   support
#
#            0       0.68      0.89      0.77       247
#            1       0.73      0.43      0.54       177
#
#    micro avg       0.70      0.70      0.70       424
#    macro avg       0.71      0.66      0.66       424
# weighted avg       0.70      0.70      0.68       424
#
# ###########################################
#
# LightGBM Threshold: 0.8
# 		Number DC: 177, Number classified as DC: 54
# 		Number DC correctly classified: 48
# 		Number False Positives: 6
# 		FalsePositiveRate: 0.02
#               precision    recall  f1-score   support
#
#            0       0.65      0.98      0.78       247
#            1       0.89      0.27      0.42       177
#
#    micro avg       0.68      0.68      0.68       424
#    macro avg       0.77      0.62      0.60       424
# weighted avg       0.75      0.68      0.63       424
#
# ###########################################
#
# LightGBM Threshold: 0.9
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
# Nearest Neighbors
#
# Nearest Neighbors Threshold: 0.5
# 		Number DC: 177, Number classified as DC: 179
# 		Number DC correctly classified: 103
# 		Number False Positives: 76
# 		FalsePositiveRate: 0.31
#               precision    recall  f1-score   support
#
#            0       0.70      0.69      0.70       247
#            1       0.58      0.58      0.58       177
#
#    micro avg       0.65      0.65      0.65       424
#    macro avg       0.64      0.64      0.64       424
# weighted avg       0.65      0.65      0.65       424
#
# ###########################################
#
# Nearest Neighbors Threshold: 0.6
# 		Number DC: 177, Number classified as DC: 179
# 		Number DC correctly classified: 103
# 		Number False Positives: 76
# 		FalsePositiveRate: 0.31
#               precision    recall  f1-score   support
#
#            0       0.70      0.69      0.70       247
#            1       0.58      0.58      0.58       177
#
#    micro avg       0.65      0.65      0.65       424
#    macro avg       0.64      0.64      0.64       424
# weighted avg       0.65      0.65      0.65       424
#
# ###########################################
#
# Nearest Neighbors Threshold: 0.7
# 		Number DC: 177, Number classified as DC: 63
# 		Number DC correctly classified: 36
# 		Number False Positives: 27
# 		FalsePositiveRate: 0.11
#               precision    recall  f1-score   support
#
#            0       0.61      0.89      0.72       247
#            1       0.57      0.20      0.30       177
#
#    micro avg       0.60      0.60      0.60       424
#    macro avg       0.59      0.55      0.51       424
# weighted avg       0.59      0.60      0.55       424
#
# ###########################################
#
# Nearest Neighbors Threshold: 0.8
# 		Number DC: 177, Number classified as DC: 63
# 		Number DC correctly classified: 36
# 		Number False Positives: 27
# 		FalsePositiveRate: 0.11
#               precision    recall  f1-score   support
#
#            0       0.61      0.89      0.72       247
#            1       0.57      0.20      0.30       177
#
#    micro avg       0.60      0.60      0.60       424
#    macro avg       0.59      0.55      0.51       424
# weighted avg       0.59      0.60      0.55       424
#
# ###########################################
#
# Nearest Neighbors Threshold: 0.9
# 		Number DC: 177, Number classified as DC: 63
# 		Number DC correctly classified: 36
# 		Number False Positives: 27
# 		FalsePositiveRate: 0.11
#               precision    recall  f1-score   support
#
#            0       0.61      0.89      0.72       247
#            1       0.57      0.20      0.30       177
#
#    micro avg       0.60      0.60      0.60       424
#    macro avg       0.59      0.55      0.51       424
# weighted avg       0.59      0.60      0.55       424
#
# ###########################################
# Gaussian Process
#
# Gaussian Process Threshold: 0.5
# 		Number DC: 177, Number classified as DC: 195
# 		Number DC correctly classified: 109
# 		Number False Positives: 86
# 		FalsePositiveRate: 0.35
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.68       247
#            1       0.56      0.62      0.59       177
#
#    micro avg       0.64      0.64      0.64       424
#    macro avg       0.63      0.63      0.63       424
# weighted avg       0.64      0.64      0.64       424
#
# ###########################################
#
# Gaussian Process Threshold: 0.6
# 		Number DC: 177, Number classified as DC: 84
# 		Number DC correctly classified: 43
# 		Number False Positives: 41
# 		FalsePositiveRate: 0.17
#               precision    recall  f1-score   support
#
#            0       0.61      0.83      0.70       247
#            1       0.51      0.24      0.33       177
#
#    micro avg       0.59      0.59      0.59       424
#    macro avg       0.56      0.54      0.52       424
# weighted avg       0.57      0.59      0.55       424
#
# ###########################################
#
# Gaussian Process Threshold: 0.7
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
#
# Gaussian Process Threshold: 0.8
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
#
# Gaussian Process Threshold: 0.9
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
# Decision Tree
#
# Decision Tree Threshold: 0.5
# 		Number DC: 177, Number classified as DC: 191
# 		Number DC correctly classified: 113
# 		Number False Positives: 78
# 		FalsePositiveRate: 0.32
#               precision    recall  f1-score   support
#
#            0       0.73      0.68      0.70       247
#            1       0.59      0.64      0.61       177
#
#    micro avg       0.67      0.67      0.67       424
#    macro avg       0.66      0.66      0.66       424
# weighted avg       0.67      0.67      0.67       424
#
# ###########################################
#
# Decision Tree Threshold: 0.6
# 		Number DC: 177, Number classified as DC: 144
# 		Number DC correctly classified: 90
# 		Number False Positives: 54
# 		FalsePositiveRate: 0.22
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.73       247
#            1       0.62      0.51      0.56       177
#
#    micro avg       0.67      0.67      0.67       424
#    macro avg       0.66      0.64      0.65       424
# weighted avg       0.66      0.67      0.66       424
#
# ###########################################
#
# Decision Tree Threshold: 0.7
# 		Number DC: 177, Number classified as DC: 136
# 		Number DC correctly classified: 85
# 		Number False Positives: 51
# 		FalsePositiveRate: 0.21
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73       247
#            1       0.62      0.48      0.54       177
#
#    micro avg       0.66      0.66      0.66       424
#    macro avg       0.65      0.64      0.64       424
# weighted avg       0.66      0.66      0.65       424
#
# ###########################################
#
# Decision Tree Threshold: 0.8
# 		Number DC: 177, Number classified as DC: 127
# 		Number DC correctly classified: 81
# 		Number False Positives: 46
# 		FalsePositiveRate: 0.19
#               precision    recall  f1-score   support
#
#            0       0.68      0.81      0.74       247
#            1       0.64      0.46      0.53       177
#
#    micro avg       0.67      0.67      0.67       424
#    macro avg       0.66      0.64      0.64       424
# weighted avg       0.66      0.67      0.65       424
#
# ###########################################
#
# Decision Tree Threshold: 0.9
# 		Number DC: 177, Number classified as DC: 86
# 		Number DC correctly classified: 51
# 		Number False Positives: 35
# 		FalsePositiveRate: 0.14
#               precision    recall  f1-score   support
#
#            0       0.63      0.86      0.72       247
#            1       0.59      0.29      0.39       177
#
#    micro avg       0.62      0.62      0.62       424
#    macro avg       0.61      0.57      0.56       424
# weighted avg       0.61      0.62      0.58       424
#
# ###########################################
# Random Forest
#
# Random Forest Threshold: 0.5
# 		Number DC: 177, Number classified as DC: 165
# 		Number DC correctly classified: 111
# 		Number False Positives: 54
# 		FalsePositiveRate: 0.22
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.76       247
#            1       0.67      0.63      0.65       177
#
#    micro avg       0.72      0.72      0.72       424
#    macro avg       0.71      0.70      0.71       424
# weighted avg       0.71      0.72      0.72       424
#
# ###########################################
#
# Random Forest Threshold: 0.6
# 		Number DC: 177, Number classified as DC: 130
# 		Number DC correctly classified: 93
# 		Number False Positives: 37
# 		FalsePositiveRate: 0.15
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.78       247
#            1       0.72      0.53      0.61       177
#
#    micro avg       0.71      0.71      0.71       424
#    macro avg       0.71      0.69      0.69       424
# weighted avg       0.71      0.71      0.71       424
#
# ###########################################
#
# Random Forest Threshold: 0.7
# 		Number DC: 177, Number classified as DC: 91
# 		Number DC correctly classified: 70
# 		Number False Positives: 21
# 		FalsePositiveRate: 0.09
#               precision    recall  f1-score   support
#
#            0       0.68      0.91      0.78       247
#            1       0.77      0.40      0.52       177
#
#    micro avg       0.70      0.70      0.70       424
#    macro avg       0.72      0.66      0.65       424
# weighted avg       0.72      0.70      0.67       424
#
# ###########################################
#
# Random Forest Threshold: 0.8
# 		Number DC: 177, Number classified as DC: 65
# 		Number DC correctly classified: 55
# 		Number False Positives: 10
# 		FalsePositiveRate: 0.04
#               precision    recall  f1-score   support
#
#            0       0.66      0.96      0.78       247
#            1       0.85      0.31      0.45       177
#
#    micro avg       0.69      0.69      0.69       424
#    macro avg       0.75      0.64      0.62       424
# weighted avg       0.74      0.69      0.65       424
#
# ###########################################
#
# Random Forest Threshold: 0.9
# 		Number DC: 177, Number classified as DC: 29
# 		Number DC correctly classified: 28
# 		Number False Positives: 1
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77       247
#            1       0.97      0.16      0.27       177
#
#    micro avg       0.65      0.65      0.65       424
#    macro avg       0.79      0.58      0.52       424
# weighted avg       0.77      0.65      0.56       424
#
# ###########################################
# Neural Net
#
# Neural Net Threshold: 0.5
# 		Number DC: 177, Number classified as DC: 133
# 		Number DC correctly classified: 78
# 		Number False Positives: 55
# 		FalsePositiveRate: 0.22
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.71       247
#            1       0.59      0.44      0.50       177
#
#    micro avg       0.64      0.64      0.64       424
#    macro avg       0.62      0.61      0.61       424
# weighted avg       0.63      0.64      0.63       424
#
# ###########################################
#
# Neural Net Threshold: 0.6
# 		Number DC: 177, Number classified as DC: 133
# 		Number DC correctly classified: 78
# 		Number False Positives: 55
# 		FalsePositiveRate: 0.22
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.71       247
#            1       0.59      0.44      0.50       177
#
#    micro avg       0.64      0.64      0.64       424
#    macro avg       0.62      0.61      0.61       424
# weighted avg       0.63      0.64      0.63       424
#
# ###########################################
#
# Neural Net Threshold: 0.7
# 		Number DC: 177, Number classified as DC: 133
# 		Number DC correctly classified: 78
# 		Number False Positives: 55
# 		FalsePositiveRate: 0.22
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.71       247
#            1       0.59      0.44      0.50       177
#
#    micro avg       0.64      0.64      0.64       424
#    macro avg       0.62      0.61      0.61       424
# weighted avg       0.63      0.64      0.63       424
#
# ###########################################
#
# Neural Net Threshold: 0.8
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 		Number DC: 177, Number classified as DC: 132
# 		Number DC correctly classified: 78
# 		Number False Positives: 54
# 		FalsePositiveRate: 0.22
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.72       247
#            1       0.59      0.44      0.50       177
#
#    micro avg       0.64      0.64      0.64       424
#    macro avg       0.63      0.61      0.61       424
# weighted avg       0.63      0.64      0.63       424
#
# ###########################################
#
# Neural Net Threshold: 0.9
# 		Number DC: 177, Number classified as DC: 132
# 		Number DC correctly classified: 78
# 		Number False Positives: 54
# 		FalsePositiveRate: 0.22
#               precision    recall  f1-score   support
#
#            0       0.66      0.78      0.72       247
#            1       0.59      0.44      0.50       177
#
#    micro avg       0.64      0.64      0.64       424
#    macro avg       0.63      0.61      0.61       424
# weighted avg       0.63      0.64      0.63       424
#
# ###########################################
# AdaBoost
#
# AdaBoost Threshold: 0.5
# 		Number DC: 177, Number classified as DC: 169
# 		Number DC correctly classified: 109
# 		Number False Positives: 60
# 		FalsePositiveRate: 0.24
#               precision    recall  f1-score   support
#
#            0       0.73      0.76      0.75       247
#            1       0.64      0.62      0.63       177
#
#    micro avg       0.70      0.70      0.70       424
#    macro avg       0.69      0.69      0.69       424
# weighted avg       0.70      0.70      0.70       424
#
# ###########################################
#
# AdaBoost Threshold: 0.6
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
#
# AdaBoost Threshold: 0.7
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
#
# AdaBoost Threshold: 0.8
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
#
# AdaBoost Threshold: 0.9
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
# Naive Bayes
#
# Naive Bayes Threshold: 0.5
# 		Number DC: 177, Number classified as DC: 209
# 		Number DC correctly classified: 117
# 		Number False Positives: 92
# 		FalsePositiveRate: 0.37
#               precision    recall  f1-score   support
#
#            0       0.72      0.63      0.67       247
#            1       0.56      0.66      0.61       177
#
#    micro avg       0.64      0.64      0.64       424
#    macro avg       0.64      0.64      0.64       424
# weighted avg       0.65      0.64      0.64       424
#
# ###########################################
#
# Naive Bayes Threshold: 0.6
# 		Number DC: 177, Number classified as DC: 96
# 		Number DC correctly classified: 48
# 		Number False Positives: 48
# 		FalsePositiveRate: 0.19
#               precision    recall  f1-score   support
#
#            0       0.61      0.81      0.69       247
#            1       0.50      0.27      0.35       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.55      0.54      0.52       424
# weighted avg       0.56      0.58      0.55       424
#
# ###########################################
#
# Naive Bayes Threshold: 0.7
# 		Number DC: 177, Number classified as DC: 18
# 		Number DC correctly classified: 11
# 		Number False Positives: 7
# 		FalsePositiveRate: 0.03
#               precision    recall  f1-score   support
#
#            0       0.59      0.97      0.74       247
#            1       0.61      0.06      0.11       177
#
#    micro avg       0.59      0.59      0.59       424
#    macro avg       0.60      0.52      0.42       424
# weighted avg       0.60      0.59      0.48       424
#
# ###########################################
#
# Naive Bayes Threshold: 0.8
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
#
# Naive Bayes Threshold: 0.9
# 		Number DC: 177, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74       247
#            1       0.00      0.00      0.00       177
#
#    micro avg       0.58      0.58      0.58       424
#    macro avg       0.29      0.50      0.37       424
# weighted avg       0.34      0.58      0.43       424
#
# ###########################################
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	valid_0's auc: 0.808285
# Training until validation scores don't improve for 50 rounds.
# [2]	valid_0's auc: 0.79961
# [3]	valid_0's auc: 0.807851
# [4]	valid_0's auc: 0.805465
# [5]	valid_0's auc: 0.803947
# [6]	valid_0's auc: 0.80026
# [7]	valid_0's auc: 0.797332
# [8]	valid_0's auc: 0.796465
# [9]	valid_0's auc: 0.791477
# [10]	valid_0's auc: 0.793971
# [11]	valid_0's auc: 0.796248
# [12]	valid_0's auc: 0.78779
# [13]	valid_0's auc: 0.788115
# [14]	valid_0's auc: 0.784862
# [15]	valid_0's auc: 0.783344
# [16]	valid_0's auc: 0.782477
# [17]	valid_0's auc: 0.78226
# [18]	valid_0's auc: 0.781609
# [19]	valid_0's auc: 0.785296
# [20]	valid_0's auc: 0.784103
# [21]	valid_0's auc: 0.783669
# [22]	valid_0's auc: 0.776946
# [23]	valid_0's auc: 0.776838
# [24]	valid_0's auc: 0.775862
# [25]	valid_0's auc: 0.775862
# [26]	valid_0's auc: 0.776079
# [27]	valid_0's auc: 0.775862
# [28]	valid_0's auc: 0.77391
# [29]	valid_0's auc: 0.772175
# [30]	valid_0's auc: 0.770657
# [31]	valid_0's auc: 0.769573
# [32]	valid_0's auc: 0.768488
# [33]	valid_0's auc: 0.769139
# [34]	valid_0's auc: 0.767404
# [35]	valid_0's auc: 0.767838
# [36]	valid_0's auc: 0.766103
# [37]	valid_0's auc: 0.767621
# [38]	valid_0's auc: 0.764368
# [39]	valid_0's auc: 0.765669
# [40]	valid_0's auc: 0.763934
# [41]	valid_0's auc: 0.763934
# [42]	valid_0's auc: 0.765235
# [43]	valid_0's auc: 0.761982
# [44]	valid_0's auc: 0.761332
# [45]	valid_0's auc: 0.761115
# [46]	valid_0's auc: 0.758946
# [47]	valid_0's auc: 0.757862
# [48]	valid_0's auc: 0.758079
# [49]	valid_0's auc: 0.758946
# [50]	valid_0's auc: 0.758729
# [51]	valid_0's auc: 0.758946
# Early stopping, best iteration is:
# [1]	valid_0's auc: 0.808285
# LightGBM
#
# LightGBM Threshold: 0.5
# 		Number DC: 87, Number classified as DC: 140
# 		Number DC correctly classified: 87
# 		Number False Positives: 53
# 		FalsePositiveRate: 1.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        53
#            1       0.62      1.00      0.77        87
#
#    micro avg       0.62      0.62      0.62       140
#    macro avg       0.31      0.50      0.38       140
# weighted avg       0.39      0.62      0.48       140
#
# ###########################################
#
# LightGBM Threshold: 0.6
# 		Number DC: 87, Number classified as DC: 121
# 		Number DC correctly classified: 85
# 		Number False Positives: 36
# 		FalsePositiveRate: 0.68
#               precision    recall  f1-score   support
#
#            0       0.89      0.32      0.47        53
#            1       0.70      0.98      0.82        87
#
#    micro avg       0.73      0.73      0.73       140
#    macro avg       0.80      0.65      0.64       140
# weighted avg       0.78      0.73      0.69       140
#
# ###########################################
#
# LightGBM Threshold: 0.7
# 		Number DC: 87, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55        53
#            1       0.00      0.00      0.00        87
#
#    micro avg       0.38      0.38      0.38       140
#    macro avg       0.19      0.50      0.27       140
# weighted avg       0.14      0.38      0.21       140
#
# ###########################################
#
# LightGBM Threshold: 0.8
# 		Number DC: 87, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55        53
#            1       0.00      0.00      0.00        87
#
#    micro avg       0.38      0.38      0.38       140
#    macro avg       0.19      0.50      0.27       140
# weighted avg       0.14      0.38      0.21       140
#
# ###########################################
#
# LightGBM Threshold: 0.9
# 		Number DC: 87, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55        53
#            1       0.00      0.00      0.00        87
#
#    micro avg       0.38      0.38      0.38       140
#    macro avg       0.19      0.50      0.27       140
# weighted avg       0.14      0.38      0.21       140
#
# ###########################################
# Nearest Neighbors
#
# Nearest Neighbors Threshold: 0.5
# 		Number DC: 87, Number classified as DC: 87
# 		Number DC correctly classified: 65
# 		Number False Positives: 22
# 		FalsePositiveRate: 0.42
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58        53
#            1       0.75      0.75      0.75        87
#
#    micro avg       0.69      0.69      0.69       140
#    macro avg       0.67      0.67      0.67       140
# weighted avg       0.69      0.69      0.69       140
#
# ###########################################
#
# Nearest Neighbors Threshold: 0.6
# 		Number DC: 87, Number classified as DC: 87
# 		Number DC correctly classified: 65
# 		Number False Positives: 22
# 		FalsePositiveRate: 0.42
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58        53
#            1       0.75      0.75      0.75        87
#
#    micro avg       0.69      0.69      0.69       140
#    macro avg       0.67      0.67      0.67       140
# weighted avg       0.69      0.69      0.69       140
#
# ###########################################
#
# Nearest Neighbors Threshold: 0.7
# 		Number DC: 87, Number classified as DC: 49
# 		Number DC correctly classified: 43
# 		Number False Positives: 6
# 		FalsePositiveRate: 0.11
#               precision    recall  f1-score   support
#
#            0       0.52      0.89      0.65        53
#            1       0.88      0.49      0.63        87
#
#    micro avg       0.64      0.64      0.64       140
#    macro avg       0.70      0.69      0.64       140
# weighted avg       0.74      0.64      0.64       140
#
# ###########################################
#
# Nearest Neighbors Threshold: 0.8
# 		Number DC: 87, Number classified as DC: 49
# 		Number DC correctly classified: 43
# 		Number False Positives: 6
# 		FalsePositiveRate: 0.11
#               precision    recall  f1-score   support
#
#            0       0.52      0.89      0.65        53
#            1       0.88      0.49      0.63        87
#
#    micro avg       0.64      0.64      0.64       140
#    macro avg       0.70      0.69      0.64       140
# weighted avg       0.74      0.64      0.64       140
#
# ###########################################
#
# Nearest Neighbors Threshold: 0.9
# 		Number DC: 87, Number classified as DC: 49
# 		Number DC correctly classified: 43
# 		Number False Positives: 6
# 		FalsePositiveRate: 0.11
#               precision    recall  f1-score   support
#
#            0       0.52      0.89      0.65        53
#            1       0.88      0.49      0.63        87
#
#    micro avg       0.64      0.64      0.64       140
#    macro avg       0.70      0.69      0.64       140
# weighted avg       0.74      0.64      0.64       140
#
# ###########################################
# Gaussian Process
#
# Gaussian Process Threshold: 0.5
# 		Number DC: 87, Number classified as DC: 93
# 		Number DC correctly classified: 67
# 		Number False Positives: 26
# 		FalsePositiveRate: 0.49
#               precision    recall  f1-score   support
#
#            0       0.57      0.51      0.54        53
#            1       0.72      0.77      0.74        87
#
#    micro avg       0.67      0.67      0.67       140
#    macro avg       0.65      0.64      0.64       140
# weighted avg       0.67      0.67      0.67       140
#
# ###########################################
#
# Gaussian Process Threshold: 0.6
# 		Number DC: 87, Number classified as DC: 68
# 		Number DC correctly classified: 53
# 		Number False Positives: 15
# 		FalsePositiveRate: 0.28
#               precision    recall  f1-score   support
#
#            0       0.53      0.72      0.61        53
#            1       0.78      0.61      0.68        87
#
#    micro avg       0.65      0.65      0.65       140
#    macro avg       0.65      0.66      0.65       140
# weighted avg       0.68      0.65      0.66       140
#
# ###########################################
#
# Gaussian Process Threshold: 0.7
# 		Number DC: 87, Number classified as DC: 48
# 		Number DC correctly classified: 40
# 		Number False Positives: 8
# 		FalsePositiveRate: 0.15
#               precision    recall  f1-score   support
#
#            0       0.49      0.85      0.62        53
#            1       0.83      0.46      0.59        87
#
#    micro avg       0.61      0.61      0.61       140
#    macro avg       0.66      0.65      0.61       140
# weighted avg       0.70      0.61      0.60       140
#
# ###########################################
#
# Gaussian Process Threshold: 0.8
# 		Number DC: 87, Number classified as DC: 24
# 		Number DC correctly classified: 18
# 		Number False Positives: 6
# 		FalsePositiveRate: 0.11
#               precision    recall  f1-score   support
#
#            0       0.41      0.89      0.56        53
#            1       0.75      0.21      0.32        87
#
#    micro avg       0.46      0.46      0.46       140
#    macro avg       0.58      0.55      0.44       140
# weighted avg       0.62      0.46      0.41       140
#
# ###########################################
#
# Gaussian Process Threshold: 0.9
# 		Number DC: 87, Number classified as DC: 3
# 		Number DC correctly classified: 3
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.39      1.00      0.56        53
#            1       1.00      0.03      0.07        87
#
#    micro avg       0.40      0.40      0.40       140
#    macro avg       0.69      0.52      0.31       140
# weighted avg       0.77      0.40      0.25       140
#
# ###########################################
# Decision Tree
#
# Decision Tree Threshold: 0.5
# 		Number DC: 87, Number classified as DC: 90
# 		Number DC correctly classified: 62
# 		Number False Positives: 28
# 		FalsePositiveRate: 0.53
#               precision    recall  f1-score   support
#
#            0       0.50      0.47      0.49        53
#            1       0.69      0.71      0.70        87
#
#    micro avg       0.62      0.62      0.62       140
#    macro avg       0.59      0.59      0.59       140
# weighted avg       0.62      0.62      0.62       140
#
# ###########################################
#
# Decision Tree Threshold: 0.6
# 		Number DC: 87, Number classified as DC: 82
# 		Number DC correctly classified: 56
# 		Number False Positives: 26
# 		FalsePositiveRate: 0.49
#               precision    recall  f1-score   support
#
#            0       0.47      0.51      0.49        53
#            1       0.68      0.64      0.66        87
#
#    micro avg       0.59      0.59      0.59       140
#    macro avg       0.57      0.58      0.57       140
# weighted avg       0.60      0.59      0.60       140
#
# ###########################################
#
# Decision Tree Threshold: 0.7
# 		Number DC: 87, Number classified as DC: 78
# 		Number DC correctly classified: 52
# 		Number False Positives: 26
# 		FalsePositiveRate: 0.49
#               precision    recall  f1-score   support
#
#            0       0.44      0.51      0.47        53
#            1       0.67      0.60      0.63        87
#
#    micro avg       0.56      0.56      0.56       140
#    macro avg       0.55      0.55      0.55       140
# weighted avg       0.58      0.56      0.57       140
#
# ###########################################
#
# Decision Tree Threshold: 0.8
# 		Number DC: 87, Number classified as DC: 78
# 		Number DC correctly classified: 52
# 		Number False Positives: 26
# 		FalsePositiveRate: 0.49
#               precision    recall  f1-score   support
#
#            0       0.44      0.51      0.47        53
#            1       0.67      0.60      0.63        87
#
#    micro avg       0.56      0.56      0.56       140
#    macro avg       0.55      0.55      0.55       140
# weighted avg       0.58      0.56      0.57       140
#
# ###########################################
#
# Decision Tree Threshold: 0.9
# 		Number DC: 87, Number classified as DC: 60
# 		Number DC correctly classified: 41
# 		Number False Positives: 19
# 		FalsePositiveRate: 0.36
#               precision    recall  f1-score   support
#
#            0       0.42      0.64      0.51        53
#            1       0.68      0.47      0.56        87
#
#    micro avg       0.54      0.54      0.54       140
#    macro avg       0.55      0.56      0.53       140
# weighted avg       0.59      0.54      0.54       140
#
# ###########################################
# Random Forest
#
# Random Forest Threshold: 0.5
# 		Number DC: 87, Number classified as DC: 88
# 		Number DC correctly classified: 67
# 		Number False Positives: 21
# 		FalsePositiveRate: 0.4
#               precision    recall  f1-score   support
#
#            0       0.62      0.60      0.61        53
#            1       0.76      0.77      0.77        87
#
#    micro avg       0.71      0.71      0.71       140
#    macro avg       0.69      0.69      0.69       140
# weighted avg       0.71      0.71      0.71       140
#
# ###########################################
#
# Random Forest Threshold: 0.6
# 		Number DC: 87, Number classified as DC: 77
# 		Number DC correctly classified: 63
# 		Number False Positives: 14
# 		FalsePositiveRate: 0.26
#               precision    recall  f1-score   support
#
#            0       0.62      0.74      0.67        53
#            1       0.82      0.72      0.77        87
#
#    micro avg       0.73      0.73      0.73       140
#    macro avg       0.72      0.73      0.72       140
# weighted avg       0.74      0.73      0.73       140
#
# ###########################################
#
# Random Forest Threshold: 0.7
# 		Number DC: 87, Number classified as DC: 63
# 		Number DC correctly classified: 52
# 		Number False Positives: 11
# 		FalsePositiveRate: 0.21
#               precision    recall  f1-score   support
#
#            0       0.55      0.79      0.65        53
#            1       0.83      0.60      0.69        87
#
#    micro avg       0.67      0.67      0.67       140
#    macro avg       0.69      0.70      0.67       140
# weighted avg       0.72      0.67      0.68       140
#
# ###########################################
#
# Random Forest Threshold: 0.8
# 		Number DC: 87, Number classified as DC: 50
# 		Number DC correctly classified: 42
# 		Number False Positives: 8
# 		FalsePositiveRate: 0.15
#               precision    recall  f1-score   support
#
#            0       0.50      0.85      0.63        53
#            1       0.84      0.48      0.61        87
#
#    micro avg       0.62      0.62      0.62       140
#    macro avg       0.67      0.67      0.62       140
# weighted avg       0.71      0.62      0.62       140
#
# ###########################################
#
# Random Forest Threshold: 0.9
# 		Number DC: 87, Number classified as DC: 32
# 		Number DC correctly classified: 26
# 		Number False Positives: 6
# 		FalsePositiveRate: 0.11
#               precision    recall  f1-score   support
#
#            0       0.44      0.89      0.58        53
#            1       0.81      0.30      0.44        87
#
#    micro avg       0.52      0.52      0.52       140
#    macro avg       0.62      0.59      0.51       140
# weighted avg       0.67      0.52      0.49       140
#
# ###########################################
# Neural Net
#
# Neural Net Threshold: 0.5
# 		Number DC: 87, Number classified as DC: 85
# 		Number DC correctly classified: 68
# 		Number False Positives: 17
# 		FalsePositiveRate: 0.32
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.67        53
#            1       0.80      0.78      0.79        87
#
#    micro avg       0.74      0.74      0.74       140
#    macro avg       0.73      0.73      0.73       140
# weighted avg       0.74      0.74      0.74       140
#
# ###########################################
#
# Neural Net Threshold: 0.6
# 		Number DC: 87, Number classified as DC: 85
# 		Number DC correctly classified: 68
# 		Number False Positives: 17
# 		FalsePositiveRate: 0.32
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.67        53
#            1       0.80      0.78      0.79        87
#
#    micro avg       0.74      0.74      0.74       140
#    macro avg       0.73      0.73      0.73       140
# weighted avg       0.74      0.74      0.74       140
#
# ###########################################
#
# Neural Net Threshold: 0.7
# 		Number DC: 87, Number classified as DC: 85
# 		Number DC correctly classified: 68
# 		Number False Positives: 17
# 		FalsePositiveRate: 0.32
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.67        53
#            1       0.80      0.78      0.79        87
#
#    micro avg       0.74      0.74      0.74       140
#    macro avg       0.73      0.73      0.73       140
# weighted avg       0.74      0.74      0.74       140
#
# ###########################################
#
# Neural Net Threshold: 0.8
# 		Number DC: 87, Number classified as DC: 85
# 		Number DC correctly classified: 68
# 		Number False Positives: 17
# 		FalsePositiveRate: 0.32
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.67        53
#            1       0.80      0.78      0.79        87
#
#    micro avg       0.74      0.74      0.74       140
#    macro avg       0.73      0.73      0.73       140
# weighted avg       0.74      0.74      0.74       140
#
# ###########################################
#
# Neural Net Threshold: 0.9
# 		Number DC: 87, Number classified as DC: 85
# 		Number DC correctly classified: 68
# 		Number False Positives: 17
# 		FalsePositiveRate: 0.32
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.67        53
#            1       0.80      0.78      0.79        87
#
#    micro avg       0.74      0.74      0.74       140
#    macro avg       0.73      0.73      0.73       140
# weighted avg       0.74      0.74      0.74       140
#
# ###########################################
# AdaBoost
#
# AdaBoost Threshold: 0.5
# 		Number DC: 87, Number classified as DC: 99
# 		Number DC correctly classified: 74
# 		Number False Positives: 25
# 		FalsePositiveRate: 0.47
#               precision    recall  f1-score   support
#
#            0       0.68      0.53      0.60        53
#            1       0.75      0.85      0.80        87
#
#    micro avg       0.73      0.73      0.73       140
#    macro avg       0.72      0.69      0.70       140
# weighted avg       0.72      0.73      0.72       140
#
# ###########################################
#
# AdaBoost Threshold: 0.6
# 		Number DC: 87, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55        53
#            1       0.00      0.00      0.00        87
#
#    micro avg       0.38      0.38      0.38       140
#    macro avg       0.19      0.50      0.27       140
# weighted avg       0.14      0.38      0.21       140
#
# ###########################################
#
# AdaBoost Threshold: 0.7
# 		Number DC: 87, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55        53
#            1       0.00      0.00      0.00        87
#
#    micro avg       0.38      0.38      0.38       140
#    macro avg       0.19      0.50      0.27       140
# weighted avg       0.14      0.38      0.21       140
#
# ###########################################
#
# AdaBoost Threshold: 0.8
# 		Number DC: 87, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55        53
#            1       0.00      0.00      0.00        87
#
#    micro avg       0.38      0.38      0.38       140
#    macro avg       0.19      0.50      0.27       140
# weighted avg       0.14      0.38      0.21       140
#
# ###########################################
#
# AdaBoost Threshold: 0.9
# 		Number DC: 87, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.38      1.00      0.55        53
#            1       0.00      0.00      0.00        87
#
#    micro avg       0.38      0.38      0.38       140
#    macro avg       0.19      0.50      0.27       140
# weighted avg       0.14      0.38      0.21       140
#
# ###########################################
# Naive Bayes
#
# Naive Bayes Threshold: 0.5
# 		Number DC: 87, Number classified as DC: 84
# 		Number DC correctly classified: 68
# 		Number False Positives: 16
# 		FalsePositiveRate: 0.3
#               precision    recall  f1-score   support
#
#            0       0.66      0.70      0.68        53
#            1       0.81      0.78      0.80        87
#
#    micro avg       0.75      0.75      0.75       140
#    macro avg       0.74      0.74      0.74       140
# weighted avg       0.75      0.75      0.75       140
#
# ###########################################
#
# Naive Bayes Threshold: 0.6
# 		Number DC: 87, Number classified as DC: 81
# 		Number DC correctly classified: 66
# 		Number False Positives: 15
# 		FalsePositiveRate: 0.28
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68        53
#            1       0.81      0.76      0.79        87
#
#    micro avg       0.74      0.74      0.74       140
#    macro avg       0.73      0.74      0.73       140
# weighted avg       0.75      0.74      0.75       140
#
# ###########################################
#
# Naive Bayes Threshold: 0.7
# 		Number DC: 87, Number classified as DC: 81
# 		Number DC correctly classified: 66
# 		Number False Positives: 15
# 		FalsePositiveRate: 0.28
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68        53
#            1       0.81      0.76      0.79        87
#
#    micro avg       0.74      0.74      0.74       140
#    macro avg       0.73      0.74      0.73       140
# weighted avg       0.75      0.74      0.75       140
#
# ###########################################
#
# Naive Bayes Threshold: 0.8
# 		Number DC: 87, Number classified as DC: 81
# 		Number DC correctly classified: 66
# 		Number False Positives: 15
# 		FalsePositiveRate: 0.28
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68        53
#            1       0.81      0.76      0.79        87
#
#    micro avg       0.74      0.74      0.74       140
# ...
#            1       1.00      0.02      0.03       130
#
#    micro avg       0.41      0.41      0.41       217
#    macro avg       0.70      0.51      0.30       217
# weighted avg       0.76      0.41      0.25       217
#
# ###########################################
#
# Gaussian Process Threshold: 0.9
# 		Number DC: 130, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57        87
#            1       0.00      0.00      0.00       130
#
#    micro avg       0.40      0.40      0.40       217
#    macro avg       0.20      0.50      0.29       217
# weighted avg       0.16      0.40      0.23       217
#
# ###########################################
# Decision Tree
#
# Decision Tree Threshold: 0.5
# 		Number DC: 130, Number classified as DC: 131
# 		Number DC correctly classified: 96
# 		Number False Positives: 35
# 		FalsePositiveRate: 0.4
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        87
#            1       0.73      0.74      0.74       130
#
#    micro avg       0.68      0.68      0.68       217
#    macro avg       0.67      0.67      0.67       217
# weighted avg       0.68      0.68      0.68       217
#
# ###########################################
#
# Decision Tree Threshold: 0.6
# 		Number DC: 130, Number classified as DC: 131
# 		Number DC correctly classified: 96
# 		Number False Positives: 35
# 		FalsePositiveRate: 0.4
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        87
#            1       0.73      0.74      0.74       130
#
#    micro avg       0.68      0.68      0.68       217
#    macro avg       0.67      0.67      0.67       217
# weighted avg       0.68      0.68      0.68       217
#
# ###########################################
#
# Decision Tree Threshold: 0.7
# 		Number DC: 130, Number classified as DC: 127
# 		Number DC correctly classified: 93
# 		Number False Positives: 34
# 		FalsePositiveRate: 0.39
#               precision    recall  f1-score   support
#
#            0       0.59      0.61      0.60        87
#            1       0.73      0.72      0.72       130
#
#    micro avg       0.67      0.67      0.67       217
#    macro avg       0.66      0.66      0.66       217
# weighted avg       0.67      0.67      0.67       217
#
# ###########################################
#
# Decision Tree Threshold: 0.8
# 		Number DC: 130, Number classified as DC: 71
# 		Number DC correctly classified: 50
# 		Number False Positives: 21
# 		FalsePositiveRate: 0.24
#               precision    recall  f1-score   support
#
#            0       0.45      0.76      0.57        87
#            1       0.70      0.38      0.50       130
#
#    micro avg       0.53      0.53      0.53       217
#    macro avg       0.58      0.57      0.53       217
# weighted avg       0.60      0.53      0.53       217
#
# ###########################################
#
# Decision Tree Threshold: 0.9
# 		Number DC: 130, Number classified as DC: 71
# 		Number DC correctly classified: 50
# 		Number False Positives: 21
# 		FalsePositiveRate: 0.24
#               precision    recall  f1-score   support
#
#            0       0.45      0.76      0.57        87
#            1       0.70      0.38      0.50       130
#
#    micro avg       0.53      0.53      0.53       217
#    macro avg       0.58      0.57      0.53       217
# weighted avg       0.60      0.53      0.53       217
#
# ###########################################
# Random Forest
#
# Random Forest Threshold: 0.5
# 		Number DC: 130, Number classified as DC: 131
# 		Number DC correctly classified: 101
# 		Number False Positives: 30
# 		FalsePositiveRate: 0.34
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66        87
#            1       0.77      0.78      0.77       130
#
#    micro avg       0.73      0.73      0.73       217
#    macro avg       0.72      0.72      0.72       217
# weighted avg       0.73      0.73      0.73       217
#
# ###########################################
#
# Random Forest Threshold: 0.6
# 		Number DC: 130, Number classified as DC: 110
# 		Number DC correctly classified: 91
# 		Number False Positives: 19
# 		FalsePositiveRate: 0.22
#               precision    recall  f1-score   support
#
#            0       0.64      0.78      0.70        87
#            1       0.83      0.70      0.76       130
#
#    micro avg       0.73      0.73      0.73       217
#    macro avg       0.73      0.74      0.73       217
# weighted avg       0.75      0.73      0.74       217
#
# ###########################################
#
# Random Forest Threshold: 0.7
# 		Number DC: 130, Number classified as DC: 82
# 		Number DC correctly classified: 69
# 		Number False Positives: 13
# 		FalsePositiveRate: 0.15
#               precision    recall  f1-score   support
#
#            0       0.55      0.85      0.67        87
#            1       0.84      0.53      0.65       130
#
#    micro avg       0.66      0.66      0.66       217
#    macro avg       0.69      0.69      0.66       217
# weighted avg       0.72      0.66      0.66       217
#
# ###########################################
#
# Random Forest Threshold: 0.8
# 		Number DC: 130, Number classified as DC: 57
# 		Number DC correctly classified: 48
# 		Number False Positives: 9
# 		FalsePositiveRate: 0.1
#               precision    recall  f1-score   support
#
#            0       0.49      0.90      0.63        87
#            1       0.84      0.37      0.51       130
#
#    micro avg       0.58      0.58      0.58       217
#    macro avg       0.66      0.63      0.57       217
# weighted avg       0.70      0.58      0.56       217
#
# ###########################################
#
# Random Forest Threshold: 0.9
# 		Number DC: 130, Number classified as DC: 28
# 		Number DC correctly classified: 27
# 		Number False Positives: 1
# 		FalsePositiveRate: 0.01
#               precision    recall  f1-score   support
#
#            0       0.46      0.99      0.62        87
#            1       0.96      0.21      0.34       130
#
#    micro avg       0.52      0.52      0.52       217
#    macro avg       0.71      0.60      0.48       217
# weighted avg       0.76      0.52      0.45       217
#
# ###########################################
# Neural Net
#
# Neural Net Threshold: 0.5
# 		Number DC: 130, Number classified as DC: 217
# 		Number DC correctly classified: 130
# 		Number False Positives: 87
# 		FalsePositiveRate: 1.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        87
#            1       0.60      1.00      0.75       130
#
#    micro avg       0.60      0.60      0.60       217
#    macro avg       0.30      0.50      0.37       217
# weighted avg       0.36      0.60      0.45       217
#
# ###########################################
#
# Neural Net Threshold: 0.6
# 		Number DC: 130, Number classified as DC: 217
# 		Number DC correctly classified: 130
# 		Number False Positives: 87
# 		FalsePositiveRate: 1.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        87
#            1       0.60      1.00      0.75       130
#
#    micro avg       0.60      0.60      0.60       217
#    macro avg       0.30      0.50      0.37       217
# weighted avg       0.36      0.60      0.45       217
#
# ###########################################
#
# Neural Net Threshold: 0.7
# 		Number DC: 130, Number classified as DC: 217
# 		Number DC correctly classified: 130
# 		Number False Positives: 87
# 		FalsePositiveRate: 1.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        87
#            1       0.60      1.00      0.75       130
#
#    micro avg       0.60      0.60      0.60       217
#    macro avg       0.30      0.50      0.37       217
# weighted avg       0.36      0.60      0.45       217
#
# ###########################################
#
# Neural Net Threshold: 0.8
# 		Number DC: 130, Number classified as DC: 217
# 		Number DC correctly classified: 130
# 		Number False Positives: 87
# 		FalsePositiveRate: 1.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        87
#            1       0.60      1.00      0.75       130
#
#    micro avg       0.60      0.60      0.60       217
#    macro avg       0.30      0.50      0.37       217
# weighted avg       0.36      0.60      0.45       217
#
# ###########################################
#
# Neural Net Threshold: 0.9
# 		Number DC: 130, Number classified as DC: 217
# 		Number DC correctly classified: 130
# 		Number False Positives: 87
# 		FalsePositiveRate: 1.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        87
#            1       0.60      1.00      0.75       130
#
#    micro avg       0.60      0.60      0.60       217
#    macro avg       0.30      0.50      0.37       217
# weighted avg       0.36      0.60      0.45       217
#
# ###########################################
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# AdaBoost
#
# AdaBoost Threshold: 0.5
# 		Number DC: 130, Number classified as DC: 139
# 		Number DC correctly classified: 111
# 		Number False Positives: 28
# 		FalsePositiveRate: 0.32
#               precision    recall  f1-score   support
#
#            0       0.76      0.68      0.72        87
#            1       0.80      0.85      0.83       130
#
#    micro avg       0.78      0.78      0.78       217
#    macro avg       0.78      0.77      0.77       217
# weighted avg       0.78      0.78      0.78       217
#
# ###########################################
#
# AdaBoost Threshold: 0.6
# 		Number DC: 130, Number classified as DC: 2
# 		Number DC correctly classified: 1
# 		Number False Positives: 1
# 		FalsePositiveRate: 0.01
#               precision    recall  f1-score   support
#
#            0       0.40      0.99      0.57        87
#            1       0.50      0.01      0.02       130
#
#    micro avg       0.40      0.40      0.40       217
#    macro avg       0.45      0.50      0.29       217
# weighted avg       0.46      0.40      0.24       217
#
# ###########################################
#
# AdaBoost Threshold: 0.7
# 		Number DC: 130, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57        87
#            1       0.00      0.00      0.00       130
#
#    micro avg       0.40      0.40      0.40       217
#    macro avg       0.20      0.50      0.29       217
# weighted avg       0.16      0.40      0.23       217
#
# ###########################################
#
# AdaBoost Threshold: 0.8
# 		Number DC: 130, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57        87
#            1       0.00      0.00      0.00       130
#
#    micro avg       0.40      0.40      0.40       217
#    macro avg       0.20      0.50      0.29       217
# weighted avg       0.16      0.40      0.23       217
#
# ###########################################
#
# AdaBoost Threshold: 0.9
# 		Number DC: 130, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57        87
#            1       0.00      0.00      0.00       130
#
#    micro avg       0.40      0.40      0.40       217
#    macro avg       0.20      0.50      0.29       217
# weighted avg       0.16      0.40      0.23       217
#
# ###########################################
# Naive Bayes
#
# Naive Bayes Threshold: 0.5
# 		Number DC: 130, Number classified as DC: 139
# 		Number DC correctly classified: 103
# 		Number False Positives: 36
# 		FalsePositiveRate: 0.41
#               precision    recall  f1-score   support
#
#            0       0.65      0.59      0.62        87
#            1       0.74      0.79      0.77       130
#
#    micro avg       0.71      0.71      0.71       217
#    macro avg       0.70      0.69      0.69       217
# weighted avg       0.71      0.71      0.71       217
#
# ###########################################
#
# Naive Bayes Threshold: 0.6
# 		Number DC: 130, Number classified as DC: 139
# 		Number DC correctly classified: 103
# 		Number False Positives: 36
# 		FalsePositiveRate: 0.41
#               precision    recall  f1-score   support
#
#            0       0.65      0.59      0.62        87
#            1       0.74      0.79      0.77       130
#
#    micro avg       0.71      0.71      0.71       217
#    macro avg       0.70      0.69      0.69       217
# weighted avg       0.71      0.71      0.71       217
#
# ###########################################
#
# Naive Bayes Threshold: 0.7
# 		Number DC: 130, Number classified as DC: 139
# 		Number DC correctly classified: 103
# 		Number False Positives: 36
# 		FalsePositiveRate: 0.41
#               precision    recall  f1-score   support
#
#            0       0.65      0.59      0.62        87
#            1       0.74      0.79      0.77       130
#
#    micro avg       0.71      0.71      0.71       217
#    macro avg       0.70      0.69      0.69       217
# weighted avg       0.71      0.71      0.71       217
#
# ###########################################
#
# Naive Bayes Threshold: 0.8
# 		Number DC: 130, Number classified as DC: 11
# 		Number DC correctly classified: 9
# 		Number False Positives: 2
# 		FalsePositiveRate: 0.02
#               precision    recall  f1-score   support
#
#            0       0.41      0.98      0.58        87
#            1       0.82      0.07      0.13       130
#
#    micro avg       0.43      0.43      0.43       217
#    macro avg       0.62      0.52      0.35       217
# weighted avg       0.66      0.43      0.31       217
#
# ###########################################
#
# Naive Bayes Threshold: 0.9
# 		Number DC: 130, Number classified as DC: 0
# 		Number DC correctly classified: 0
# 		Number False Positives: 0
# 		FalsePositiveRate: 0.0
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57        87
#            1       0.00      0.00      0.00       130
#
#    micro avg       0.40      0.40      0.40       217
#    macro avg       0.20      0.50      0.29       217
# weighted avg       0.16      0.40      0.23       217
#
# ###########################################
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Narrowing down to the most promising models:
#
# 1. LightGBM (0.6 - 0.9 threshold)
#     * Precision: 0.89, 0.70, 1.00,
#     * Recall: 0.27, 0.98, 0.18
#     * False positive rate: 0.02, 0.68, 0.00
#
#
# 2. Random Forest (0.9 threshold)
#     * Precision: 0.81, 0.96, 0.97
#     * Recall:    0.30, 0.21, 0.16
#     * False positive rate: 0.11, 0.01, 0.01

# %% [markdown]
# ### Other
#
# Models performed best when training on only records RPV labels as "disconnected" or "disconnected-70" or only "disconnected"

# %% [markdown]
# # Hyperparameterization Gridsearch - Random Forest

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 120, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 7, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4, 7]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    
    precision = metrics.precision_score(y_true=test_labels, y_pred=predictions) 
    
    thresholds = [0.5, 0.6, 0.7, 0.8, 0.9]
    for t in thresholds:
        pred_p = model.predict_proba(test_features)
        pred_classes = [1 if p[1] >= t else 0 for p in pred_p]
        
        precision = round(metrics.precision_score(y_true=test_labels, y_pred=pred_classes),2)
        recall    = round(metrics.recall_score(y_true=test_labels, y_pred=pred_classes),2)
        num_false_positives = sum([1 if p==1 and t==0 else 0 for p, t in zip(pred_classes, test_labels)])
        fpr = round(1.0*num_false_positives/(len(test_labels)-sum(test_labels)),2)
        print('Threshold:', t)
        print('\tPrecision:', precision)
        print('\tRecall:', recall)
        print('\tNumFalsePositives:', num_false_positives)
        print('\tFalsePositiveRate:', fpr)

# %% [markdown]
# ### Part 1: dc only

# %%
# Data for ONLY RPV DISCONNECTED

X = data['dc']['X']
y = data['dc']['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
rf = RandomForestClassifier()

rf_random = RandomizedSearchCV(estimator=rf,
                               param_distributions=random_grid, 
                               n_iter = 100, 
                               cv = 3, 
                               verbose=2, 
                               random_state=42, 
                               n_jobs = -1)

rf_random.fit(X_train, y_train)

rf_random.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   35.2s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.1min finished
# {'n_estimators': 1000,
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 32,
#  'bootstrap': False}

# %% [markdown]
# ### Base RandomForest Model - DC only

# %%
base_model = RandomForestClassifier(n_estimators = 10, random_state = 42)
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.78
# 	Recall: 0.8
# 	NumFalsePositives: 19
# 	FalsePositiveRate: 0.35
# Threshold: 0.6
# 	Precision: 0.78
# 	Recall: 0.73
# 	NumFalsePositives: 17
# 	FalsePositiveRate: 0.31
# Threshold: 0.7
# 	Precision: 0.79
# 	Recall: 0.67
# 	NumFalsePositives: 15
# 	FalsePositiveRate: 0.27
# Threshold: 0.8
# 	Precision: 0.78
# 	Recall: 0.51
# 	NumFalsePositives: 12
# 	FalsePositiveRate: 0.22
# Threshold: 0.9
# 	Precision: 0.83
# 	Recall: 0.41
# 	NumFalsePositives: 7
# 	FalsePositiveRate: 0.13

# %% [markdown]
# ### RandomSearch RandomForest Model - DC only

# %%
best_random = rf_random.best_estimator_
random_accuracy = evaluate(best_random, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.78
# 	Recall: 0.82
# 	NumFalsePositives: 20
# 	FalsePositiveRate: 0.36
# Threshold: 0.6
# 	Precision: 0.8
# 	Recall: 0.75
# 	NumFalsePositives: 16
# 	FalsePositiveRate: 0.29
# Threshold: 0.7
# 	Precision: 0.81
# 	Recall: 0.66
# 	NumFalsePositives: 13
# 	FalsePositiveRate: 0.24
# Threshold: 0.8
# 	Precision: 0.9
# 	Recall: 0.45
# 	NumFalsePositives: 4
# 	FalsePositiveRate: 0.07
# Threshold: 0.9
# 	Precision: 1.0
# 	Recall: 0.18
# 	NumFalsePositives: 0
# 	FalsePositiveRate: 0.0

# %% [markdown]
# ### Comparison - RPV "DISCONNECTED" ONLY
#
# The RandomSearch RandomForest Model performed much better than the base model--with multiple thresholds yielding over 90% precision and false positive rates under 15%

# %% [markdown]
# # Part 2: dc and dc70

# %%
# Data for RPV DISCONNECTED and DISCONNECTED-70

X = data['dc70']['X']
y = data['dc70']['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
rf = RandomForestClassifier()

rf_random = RandomizedSearchCV(estimator=rf,
                               param_distributions=random_grid, 
                               n_iter = 100, 
                               cv = 3, 
                               verbose=2, 
                               random_state=42, 
                               n_jobs = -1)

rf_random.fit(X_train, y_train)

rf_random.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.2min finished
# {'n_estimators': 1600,
#  'min_samples_split': 10,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 10,
#  'bootstrap': True}

# %% [markdown]
# ### Base RandomForest Model - DC and DC70

# %%
base_model = RandomForestClassifier(n_estimators = 10, random_state = 42)
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.7
# 	Recall: 0.82
# 	NumFalsePositives: 42
# 	FalsePositiveRate: 0.42
# Threshold: 0.6
# 	Precision: 0.7
# 	Recall: 0.75
# 	NumFalsePositives: 38
# 	FalsePositiveRate: 0.38
# Threshold: 0.7
# 	Precision: 0.74
# 	Recall: 0.66
# 	NumFalsePositives: 28
# 	FalsePositiveRate: 0.28
# Threshold: 0.8
# 	Precision: 0.76
# 	Recall: 0.55
# 	NumFalsePositives: 21
# 	FalsePositiveRate: 0.21
# Threshold: 0.9
# 	Precision: 0.78
# 	Recall: 0.39
# 	NumFalsePositives: 13
# 	FalsePositiveRate: 0.13

# %% [markdown]
# ### RandomSearch RandomForest Model - DC and DC70

# %%
best_random = rf_random.best_estimator_
random_accuracy = evaluate(best_random, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.7
# 	Recall: 0.8
# 	NumFalsePositives: 40
# 	FalsePositiveRate: 0.4
# Threshold: 0.6
# 	Precision: 0.74
# 	Recall: 0.66
# 	NumFalsePositives: 28
# 	FalsePositiveRate: 0.28
# Threshold: 0.7
# 	Precision: 0.78
# 	Recall: 0.54
# 	NumFalsePositives: 18
# 	FalsePositiveRate: 0.18
# Threshold: 0.8
# 	Precision: 0.9
# 	Recall: 0.4
# 	NumFalsePositives: 5
# 	FalsePositiveRate: 0.05
# Threshold: 0.9
# 	Precision: 1.0
# 	Recall: 0.15
# 	NumFalsePositives: 0
# 	FalsePositiveRate: 0.0

# %% [markdown]
# # Part 3: Trying All Data Again

# %%
# All data

X = data['all']['X']
y = data['all']['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
rf = RandomForestClassifier()

rf_random = RandomizedSearchCV(estimator=rf,
                               param_distributions=random_grid, 
                               n_iter = 100, 
                               cv = 3, 
                               verbose=2, 
                               random_state=42, 
                               n_jobs = -1)

rf_random.fit(X_train, y_train)

rf_random.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  1.6min finished
# {'n_estimators': 800,
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 43,
#  'bootstrap': True}

# %% [markdown]
# ### Base RandomForest Model - all

# %%
base_model = RandomForestClassifier(n_estimators = 10, random_state = 42)
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.68
# 	Recall: 0.65
# 	NumFalsePositives: 60
# 	FalsePositiveRate: 0.26
# Threshold: 0.6
# 	Precision: 0.71
# 	Recall: 0.56
# 	NumFalsePositives: 45
# 	FalsePositiveRate: 0.2
# Threshold: 0.7
# 	Precision: 0.76
# 	Recall: 0.48
# 	NumFalsePositives: 29
# 	FalsePositiveRate: 0.13
# Threshold: 0.8
# 	Precision: 0.82
# 	Recall: 0.39
# 	NumFalsePositives: 17
# 	FalsePositiveRate: 0.07
# Threshold: 0.9
# 	Precision: 0.87
# 	Recall: 0.28
# 	NumFalsePositives: 8
# 	FalsePositiveRate: 0.03

# %% [markdown]
# ### RandomSearch RandomForest Model - all

# %%
best_random = rf_random.best_estimator_
random_accuracy = evaluate(best_random, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.75
# 	Recall: 0.63
# 	NumFalsePositives: 42
# 	FalsePositiveRate: 0.18
# Threshold: 0.6
# 	Precision: 0.84
# 	Recall: 0.51
# 	NumFalsePositives: 19
# 	FalsePositiveRate: 0.08
# Threshold: 0.7
# 	Precision: 0.86
# 	Recall: 0.36
# 	NumFalsePositives: 11
# 	FalsePositiveRate: 0.05
# Threshold: 0.8
# 	Precision: 0.96
# 	Recall: 0.23
# 	NumFalsePositives: 2
# 	FalsePositiveRate: 0.01
# Threshold: 0.9
# 	Precision: 0.92
# 	Recall: 0.06
# 	NumFalsePositives: 1
# 	FalsePositiveRate: 0.0

# %% [markdown]
# # LIGHTGBM

# %%
param_grid = {
    'learning_rate': [.01, .05, .1, .15, .2, 1],
    'n_estimators': [21, 31, 51, 81, 151],
    'max_depth': [int(x) for x in np.linspace(10, 120, num = 11)],
    'bagging_fraction': [1.0, 0.9, 0.8],
    'pos_bagging_fraction': [1.0, 0.9, 0.8],
    'neg_bagging_fraction': [1.0, 0.9, 0.8],
    'bagging_freq': [0, 3, 5, 10],
    'feature_fraction': [1.0, 0.9, 0.8]
}

# %% [markdown]
# ### Part 1 - DC only

# %%
# Data for ONLY RPV DISCONNECTED

X = data['dc']['X']
y = data['dc']['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
m = lgb.LGBMClassifier()

m_random = RandomizedSearchCV(estimator=m,
                               param_distributions=param_grid, 
                               n_iter = 100, 
                               cv = 3, 
                               verbose=2, 
                               random_state=42, 
                               n_jobs = -1)
m_random.fit(X_train, y_train)

m_random.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    5.3s finished
# {'pos_bagging_fraction': 0.8,
#  'neg_bagging_fraction': 0.9,
#  'n_estimators': 31,
#  'max_depth': 54,
#  'learning_rate': 0.05,
#  'feature_fraction': 1.0,
#  'bagging_freq': 5,
#  'bagging_fraction': 0.8}

# %% [markdown]
# ### Base - DC only

# %%
base_model = lgb.LGBMClassifier()
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.74
# 	Recall: 0.87
# 	NumFalsePositives: 25
# 	FalsePositiveRate: 0.44
# Threshold: 0.6
# 	Precision: 0.76
# 	Recall: 0.82
# 	NumFalsePositives: 21
# 	FalsePositiveRate: 0.37
# Threshold: 0.7
# 	Precision: 0.81
# 	Recall: 0.75
# 	NumFalsePositives: 15
# 	FalsePositiveRate: 0.26
# Threshold: 0.8
# 	Precision: 0.84
# 	Recall: 0.63
# 	NumFalsePositives: 10
# 	FalsePositiveRate: 0.18
# Threshold: 0.9
# 	Precision: 0.94
# 	Recall: 0.36
# 	NumFalsePositives: 2
# 	FalsePositiveRate: 0.04

# %% [markdown]
# ### LightGBM RandomSearch - DC Only

# %%
best_random = m_random.best_estimator_
random_accuracy = evaluate(best_random, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.75
# 	Recall: 0.93
# 	NumFalsePositives: 26
# 	FalsePositiveRate: 0.46
# Threshold: 0.6
# 	Precision: 0.77
# 	Recall: 0.83
# 	NumFalsePositives: 21
# 	FalsePositiveRate: 0.37
# Threshold: 0.7
# 	Precision: 0.81
# 	Recall: 0.69
# 	NumFalsePositives: 13
# 	FalsePositiveRate: 0.23
# Threshold: 0.8
# 	Precision: 0.84
# 	Recall: 0.37
# 	NumFalsePositives: 6
# 	FalsePositiveRate: 0.11
# Threshold: 0.9
# 	Precision: 0.0
# 	Recall: 0.0
# 	NumFalsePositives: 0
# 	FalsePositiveRate: 0.0
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Part 2 - DC and DC70 only

# %%
# Data for ONLY RPV DISCONNECTED

X = data['dc70']['X']
y = data['dc70']['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

m = lgb.LGBMClassifier()

m_random = RandomizedSearchCV(estimator=m,
                               param_distributions=param_grid, 
                               n_iter = 100, 
                               cv = 3, 
                               verbose=2, 
                               random_state=42, 
                               n_jobs = -1)
m_random.fit(X_train, y_train)

m_random.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    5.8s finished
# C:\Users\glappe\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'pos_bagging_fraction': 0.9,
#  'neg_bagging_fraction': 0.9,
#  'n_estimators': 51,
#  'max_depth': 43,
#  'learning_rate': 0.05,
#  'feature_fraction': 1.0,
#  'bagging_freq': 0,
#  'bagging_fraction': 0.8}

# %% [markdown]
# ### LightGBM Base - DC + DC70 only

# %%
base_model = lgb.LGBMClassifier()
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.81
# 	Recall: 0.8
# 	NumFalsePositives: 23
# 	FalsePositiveRate: 0.25
# Threshold: 0.6
# 	Precision: 0.83
# 	Recall: 0.76
# 	NumFalsePositives: 19
# 	FalsePositiveRate: 0.2
# Threshold: 0.7
# 	Precision: 0.85
# 	Recall: 0.65
# 	NumFalsePositives: 14
# 	FalsePositiveRate: 0.15
# Threshold: 0.8
# 	Precision: 0.88
# 	Recall: 0.52
# 	NumFalsePositives: 9
# 	FalsePositiveRate: 0.1
# Threshold: 0.9
# 	Precision: 0.91
# 	Recall: 0.31
# 	NumFalsePositives: 4
# 	FalsePositiveRate: 0.04

# %% [markdown]
# ### LightGBM RandomSearch - DC + DC70 only

# %%
best_random = m_random.best_estimator_
random_accuracy = evaluate(best_random, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.81
# 	Recall: 0.76
# 	NumFalsePositives: 22
# 	FalsePositiveRate: 0.24
# Threshold: 0.6
# 	Precision: 0.81
# 	Recall: 0.68
# 	NumFalsePositives: 20
# 	FalsePositiveRate: 0.22
# Threshold: 0.7
# 	Precision: 0.84
# 	Recall: 0.62
# 	NumFalsePositives: 15
# 	FalsePositiveRate: 0.16
# Threshold: 0.8
# 	Precision: 0.89
# 	Recall: 0.4
# 	NumFalsePositives: 6
# 	FalsePositiveRate: 0.06
# Threshold: 0.9
# 	Precision: 0.96
# 	Recall: 0.18
# 	NumFalsePositives: 1
# 	FalsePositiveRate: 0.01

# %% [markdown]
# ### Part 3 - LightGBM - all

# %%
# Data for ONLY RPV DISCONNECTED

X = data['all']['X']
y = data['all']['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

m = lgb.LGBMClassifier()

m_random = RandomizedSearchCV(estimator=m,
                               param_distributions=param_grid, 
                               n_iter = 100, 
                               cv = 3, 
                               verbose=2, 
                               random_state=42, 
                               n_jobs = -1)
m_random.fit(X_train, y_train)

m_random.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 293 out of 300 | elapsed:    7.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    7.2s finished
# {'pos_bagging_fraction': 0.9,
#  'neg_bagging_fraction': 0.9,
#  'n_estimators': 31,
#  'max_depth': 54,
#  'learning_rate': 0.1,
#  'feature_fraction': 0.8,
#  'bagging_freq': 3,
#  'bagging_fraction': 0.8}

# %% [markdown]
# ### LightGBM Base Model - All

# %%
base_model = lgb.LGBMClassifier()
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.72
# 	Recall: 0.55
# 	NumFalsePositives: 41
# 	FalsePositiveRate: 0.18
# Threshold: 0.6
# 	Precision: 0.76
# 	Recall: 0.51
# 	NumFalsePositives: 32
# 	FalsePositiveRate: 0.14
# Threshold: 0.7
# 	Precision: 0.8
# 	Recall: 0.44
# 	NumFalsePositives: 21
# 	FalsePositiveRate: 0.09
# Threshold: 0.8
# 	Precision: 0.83
# 	Recall: 0.3
# 	NumFalsePositives: 12
# 	FalsePositiveRate: 0.05
# Threshold: 0.9
# 	Precision: 0.87
# 	Recall: 0.17
# 	NumFalsePositives: 5
# 	FalsePositiveRate: 0.02

# %% [markdown]
# ### LightGBM RandomSearch - All

# %%
best_random = m_random.best_estimator_
random_accuracy = evaluate(best_random, X_test, y_test)
# Out:
# Threshold: 0.5
# 	Precision: 0.75
# 	Recall: 0.57
# 	NumFalsePositives: 37
# 	FalsePositiveRate: 0.16
# Threshold: 0.6
# 	Precision: 0.8
# 	Recall: 0.49
# 	NumFalsePositives: 25
# 	FalsePositiveRate: 0.11
# Threshold: 0.7
# 	Precision: 0.86
# 	Recall: 0.41
# 	NumFalsePositives: 13
# 	FalsePositiveRate: 0.06
# Threshold: 0.8
# 	Precision: 0.87
# 	Recall: 0.24
# 	NumFalsePositives: 7
# 	FalsePositiveRate: 0.03
# Threshold: 0.9
# 	Precision: 0.88
# 	Recall: 0.11
# 	NumFalsePositives: 3
# 	FalsePositiveRate: 0.01

# %%
Xy['rpv_status'].value_counts()
# Out:
# 1    678
# 4    464
# 3    259
# 0      9
# 2      2
# Name: rpv_status, dtype: int64

# %%
len(Xy[Xy['rpv_status']>=3])
# Out:
# 723

# %%
len(Xy)
# Out:
# 1412

# %%
y = data['all']['y']

n_dc = sum(y)

n_dc
# Out:
# 632

# %%
rpv_archive.head()
# Out:
#         phone     status error_text iscell              carrier date_checked
# 0  2012000318  connected        NaN      N        Comcast of MD   2019-08-29
# 1  2012002626  connected        NaN      N  MCImetro Former MCI   2019-08-29
# 2  2012040004  connected        NaN      N              Level 3   2019-08-29
# 3  2012071052  connected        NaN      Y     Verizon Wireless   2019-08-29
# 4  2012074846  connected        NaN      Y     Verizon Wireless   2019-08-29

# %%
rpv_archive['status'].value_counts() / len(rpv_archive)
# Out:
# connected          0.815012
# disconnected       0.107565
# disconnected-70    0.064618
# connected-75       0.008865
# invalid-phone      0.003940
# Name: status, dtype: float64
