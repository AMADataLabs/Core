# %%
import pandas as pd

# %%
everyone_connected = pd.read_csv('Telo/everyone_numbers_connected.csv')
ekata_connected = pd.read_csv('Ekata/ekata_connected.csv')

# %%
total = pd.merge(bitch, everyone_connected, on = 'OFFICE_TELEPHONE', how = 'outer')

# %%
total
# Out:
#     OFFICE_TELEPHONE    STATUS                              ADDRESS  \
# 0         6106702277  COMPLETE                   1981 State Hill Rd
# 1         7404543273  COMPLETE                         2854 Bell St
# 2         6158898802  COMPLETE            3901 Central Pike Ste 351
# 3         6128238001  COMPLETE           6601 Lyndale Ave S Ste 220
# 4         8066772002  COMPLETE            1215 S Coulter St Ste 403
# 5         4173357222  COMPLETE                              Ste 201
# 6         7033856870  COMPLETE                10721 Main St Ste 200
# 7         9147691600  COMPLETE                       645 Marble Ave
# 8         7275448300  COMPLETE                10707 66th St N Ste A
# 9         9164894400  COMPLETE           3301 Alta Arden Expy Ste 3
# 10        3193393917  COMPLETE                 613 E Bloomington St
# 11        7024876510       NaN                                  NaN
# 12        4803455200  COMPLETE                   1920 E Baseline Rd
# 13        4403124569  COMPLETE                                  NaN
# 14        8027701805       NaN                                  NaN
# 15        6097485380       NaN                                  NaN
# 16        7342422022       NaN                                  NaN
# 17        4069614661  COMPLETE                         1037 Main St
# 18        9496448722       NaN                                  NaN
# 19        6012685640       NaN                                  NaN
# 20        7182654454       NaN                                  NaN
# 21        7659833427       NaN                                  NaN
# 22        8047463505       NaN                                  NaN
# 23        9739725672       NaN                                  NaN
# 24        8709368000       NaN                                  NaN
# 25        5023945678  COMPLETE  4950 Norton Healthcare Blvd Ste 300
# 26        6014773550       NaN                                  NaN
# 27        8053703137       NaN                                  NaN
# 28        5704745072  COMPLETE                   35 S Mountain Blvd
# 29        8436921765       NaN                                  NaN
# 30        5087462000  COMPLETE                      275 Sandwich St
# 31        2484230700  COMPLETE          23077 Greenfield Rd Ste 195
# 32        5757697365       NaN                                  NaN
# 33        6034315858       NaN                                  NaN
# 34        9036143200       NaN                                  NaN
# 35        8648499555       NaN                                  NaN
# 36        8305383550       NaN                                  NaN
# 37        7817448046       NaN                                  NaN
# 38        3154712646  COMPLETE               475 Irving Ave Ste 210
# 39        2014883131  COMPLETE              160 Overlook Ave Ste 1a
#
#                 CITY             CNAM  LINETYPE  \
# 0            Reading  DR TIMOTHY C ST  landline
# 1         Zanesville       LAYNE,DREW  landline
# 2          Hermitage  ALLERGY ENT ASS  landline
# 3        Minneapolis  KIDNEY SPECIALI  landline
# 4           Amarillo  RAJ SARALAYA MD  landline
# 5            Branson  BRANSON NEUROLO  landline
# 6            Fairfax   ALLEN TERRY MD  landline
# 7          Thornwood  ANDERSEN MARGAR  landline
# 8      Pinellas Park  PINELLAS INTERN  landline
# 9         Sacramento  HEALTH ASSOCIAT  landline
# 10         Iowa City   CANCER CARE OF  landline
# 11               NaN              NaN       NaN
# 12             Tempe       CIGNA CORP  landline
# 13  Mayfield Heights      SCHNUR,GARY  landline
# 14               NaN              NaN       NaN
# 15               NaN              NaN       NaN
# 16               NaN              NaN       NaN
# 17         Corvallis  APRIL L WEINBER  landline
# 18               NaN              NaN       NaN
# 19               NaN              NaN       NaN
# 20               NaN              NaN       NaN
# 21               NaN              NaN       NaN
# 22               NaN              NaN       NaN
# 23               NaN              NaN       NaN
# 24               NaN              NaN       NaN
# 25        Louisville  CHILDRENS ORTHO  landline
# 26               NaN              NaN       NaN
# 27               NaN              NaN       NaN
# 28      Mountain Top        GEISINGER  landline
# 29               NaN              NaN       NaN
# 30          Plymouth  BETH ISRAEL DEA  landline
# 31        Southfield  PAVILION FAMILY  landline
# 32               NaN              NaN       NaN
# 33               NaN              NaN       NaN
# 34               NaN              NaN       NaN
# 35               NaN              NaN       NaN
# 36               NaN              NaN       NaN
# 37               NaN              NaN       NaN
# 38          Syracuse   MADISON IRVING  landline
# 39        Hackensack   ANDREW FINK MD  landline
#
#                                                 NAME STATE      TYPE  \
# 0           Dr Timothy C Stringer Physicians General    PA  business
# 1                                         Drew Layne    OH    person
# 2      Allergy Ent Associates Of Middle Tennessee Pc    TN  business
# 3          Kidney Specialists Of Minnesota Main Info    MN  business
# 4                Raj Saralaya Md Physicians Surgeons    TX  business
# 5                    Branson Neurology & Pain Center    MO  business
# 6                                     Allen Terry Md    VA  business
# 7   Andersen Margaret Md Doctors Physicians Surgeons    NY  business
# 8   Pinellas Internal Medicine Associates Physicians    FL  business
# 9    Health Associates Medical Group Doctors General    CA  business
# 10            Cancer Care Of Iowa City Llc Hospitals    IA  business
# 11                                               NaN   NaN       NaN
# 12                                        Cigna Corp    AZ  business
# 13                                       Gary Schnur    OH    person
# 14                                               NaN   NaN       NaN
# 15                                               NaN   NaN       NaN
# 16                                               NaN   NaN       NaN
# 17         April L Weinberger Md Physicians Surgeons    MT  business
# 18                                               NaN   NaN       NaN
# 19                                               NaN   NaN       NaN
# 20                                               NaN   NaN       NaN
# 21                                               NaN   NaN       NaN
# 22                                               NaN   NaN       NaN
# 23                                               NaN   NaN       NaN
# 24                                               NaN   NaN       NaN
# 25   Childrens Orthopaedics Of Louisville Physicians    KY  business
# 26                                               NaN   NaN       NaN
# 27                                               NaN   NaN       NaN
# 28                                         Geisinger    PA  business
# 29                                               NaN   NaN       NaN
# 30           Beth Israel Deaconess Hospital Plymouth    MA  business
# 31       Pavilion Family Practice Physicians General    MI  business
# 32                                               NaN   NaN       NaN
# 33                                               NaN   NaN       NaN
# 34                                               NaN   NaN       NaN
# 35                                               NaN   NaN       NaN
# 36                                               NaN   NaN       NaN
# 37                                               NaN   NaN       NaN
# 38    Madison Irving Pediatrics Developmental Health    NY  business
# 39                Andrew Fink Md Physicians Surgeons    NJ  business
#
#            ZIP
# 0        19610
# 1        43701
# 2        37076
# 3        55423
# 4        79106
# 5   65616-2062
# 6        22030
# 7        10594
# 8        33782
# 9        95825
# 10       52245
# 11         NaN
# 12       85283
# 13  44124-0000
# 14         NaN
# 15         NaN
# 16         NaN
# 17       59828
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25       40241
# 26         NaN
# 27         NaN
# 28       18707
# 29         NaN
# 30        2360
# 31       48075
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38       13210
# 39        7601

# %%
bitch = pd.read_csv('bitch.csv')
