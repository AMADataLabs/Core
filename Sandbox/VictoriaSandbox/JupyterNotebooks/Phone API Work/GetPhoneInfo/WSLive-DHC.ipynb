# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process 
import datetime as dt
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
dhc = pd.read_csv('DHC_data/DHC_data.csv')
# wslive = pd.read_csv('Data/wslive_with_results_2019-06-07_to_2020-02-21.csv')

# %%
['ws_year','ws_month']
phone = good_phone[(good_phone.ws_year==2020)&(good_phone.ws_month==1)]
address = good_address[(good_address.ws_year==2020)&(good_address.ws_month==1)]

# %%
good_phone = wslive[(wslive['OFFICE_PHONE_VERIFIED_UPDATED'].isin([1,2])) & (wslive['WSLIVE_SOURCE']=='UPDATED')]
good_address = wslive[(wslive['OFFICE_ADDRESS_VERIFIED_UPDATED'].isin([1,2])) & (wslive['WSLIVE_SOURCE']=='UPDATED')]

# %%
phone = good_phone[['PHYSICIAN_ME_NUMBER', 'PHYSICIAN_FIRST_NAME', 'PHYSICIAN_MIDDLE_NAME',
       'PHYSICIAN_LAST_NAME', 'SUFFIX', 'DEGREE', 'OFFICE_ADDRESS_LINE_1',
       'OFFICE_ADDRESS_LINE_2', 'OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE',
       'OFFICE_ADDRESS_ZIP', 'OFFICE_TELEPHONE', 'WSLIVE_FILE_DT']]
address = good_address[['PHYSICIAN_ME_NUMBER', 'PHYSICIAN_FIRST_NAME', 'PHYSICIAN_MIDDLE_NAME',
       'PHYSICIAN_LAST_NAME', 'SUFFIX', 'DEGREE', 'OFFICE_ADDRESS_LINE_1',
       'OFFICE_ADDRESS_LINE_2', 'OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE',
       'OFFICE_ADDRESS_ZIP', 'OFFICE_TELEPHONE', 'WSLIVE_FILE_DT']]

# %%
dhc = dhc.rename(columns ={'Additional Office Locations':'Add_Offices', 'Phone Number':'Phone_Number', 'Zip Code':'Zipcode_DHC', 'First Name':'First', 'Physician Name':'Name_DHC',
       'Middle Name':'Middle', 'Primary Specialty':'Spec', 'Primary Hospital Affiliation':'Affiliation',
       'Last Name':'Last'})

# %%
dhc_phone = pd.merge(dhc, GUTE, left_on='ME',right_on='PHYSICIAN_ME_NUMBER')

# %%
dhc_address = pd.merge(dhc, address, left_on='ME',right_on='PHYSICIAN_ME_NUMBER')

# %%
samp=samp.fillna('None')

# %%
dhc_address=dhc_address.fillna('None')

# %%
phones=[]
for row in dhc_phone.itertuples():
    phones.append(row.Phone_Number.replace('.',''))

# %%
dhc_phone.Phone_Number=phones

# %%
def add_match(df):
    count = 0
    for row in df.itertuples():
        match = False
        if row.OFFICE_ADDRESS_LINE_2 in row.Address.upper():
            match = True
        if row.Address.upper() in row.OFFICE_ADDRESS_LINE_2:
            match = True
        if fuzz.ratio(row.OFFICE_ADDRESS_LINE_2,row.Address.upper())>70:
            match = True
        if match == True:
            count +=1
    return count

def phone_match(df):
    count = 0
    for row in df.itertuples():
        if row.Phone_Number == str(int(row.OFFICE_TELEPHONE)):
            count+=1
    return count

def zip_match(df):
    count = 0
    for row in df.itertuples():
        if row.Zipcode_DHC == row.OFFICE_ADDRESS_ZIP:
            count+=1
    return count

def state_match(df):
    count = 0
    for row in df.itertuples():
        if row.State == row.OFFICE_ADDRESS_STATE:
            count+=1
    return count

def city_match(df):
    count = 0
    for row in df.itertuples():
        if row.City.upper() == row.OFFICE_ADDRESS_CITY:
            count+=1
    return count

# %%
def return_counts(phone_df, add_df):
    p =phone_match(phone_df)
    a =add_match(add_df)
    z =zip_match(add_df)
    c =city_match(add_df)
    s = state_match(add_df)
    print(f'{p} ({round(p/len(phone_df)*100,2)}%) phones match')
    print(f'{a} ({round(a/len(add_df)*100,2)}%) addresses match')
    print(f'{z} ({round(z/len(add_df)*100,2)}%) zipcodes match')
    print(f'{c} ({round(c/len(add_df)*100,2)}%) cities match')
    print(f'{s} ({round(s/len(add_df)*100,2)}%) states match')

# %%
# samp = dhc_phone.sample(500)
return_counts(sample, sample)
# Out:
# 311 (62.2%) phones match
# 341 (68.2%) addresses match
# 339 (67.8%) zipcodes match
# 376 (75.2%) cities match
# 459 (91.8%) states match

# %%
len(dhc_address)
# Out:
# 4799

# %%
good_phone.groupby(['ws_year','ws_month']).count()
# Out:
#                   PHYSICIAN_ME_NUMBER  PHYSICIAN_FIRST_NAME  \
# ws_year ws_month
# 2019    6                       13178                 13178
#         7                       12021                 12021
#         8                       12549                 12549
#         9                        8659                  8659
#         10                      10347                 10346
#         11                       9761                  9760
#         12                       8935                  8935
# 2020    1                        6919                  6918
#         2                        6360                  6360
#
#                   PHYSICIAN_MIDDLE_NAME  PHYSICIAN_LAST_NAME  SUFFIX  DEGREE  \
# ws_year ws_month
# 2019    6                         11124                13178     425       0
#         7                         10133                12021     393       0
#         8                         10397                12549     385       0
#         9                          7190                 8658     258       0
#         10                         8510                10347     314       0
#         11                         7933                 9761     262       0
#         12                         7246                 8935     249       0
# 2020    1                          5732                 6919     205       0
#         2                          5373                 6360     234       0
#
#                   OFFICE_ADDRESS_LINE_1  OFFICE_ADDRESS_LINE_2  \
# ws_year ws_month
# 2019    6                          7328                  13178
#         7                          4229                  12021
#         8                          4453                  12549
#         9                          2925                   8659
#         10                         2944                  10347
#         11                         2851                   9760
#         12                         2600                   8935
# 2020    1                          2233                   6919
#         2                          1772                   6360
#
#                   OFFICE_ADDRESS_CITY  OFFICE_ADDRESS_STATE  ...  \
# ws_year ws_month                                             ...
# 2019    6                       13178                 13178  ...
#         7                       12021                 12021  ...
#         8                       12549                 12549  ...
#         9                        8659                  8659  ...
#         10                      10347                 10347  ...
#         11                       9759                  9759  ...
#         12                       8932                  8932  ...
# 2020    1                        6919                  6919  ...
#         2                        6360                  6360  ...
#
#                   MATCH_ADDR_LONG  SPECIALTY  SPECIALTY_UPDATED  \
# ws_year ws_month
# 2019    6                       0      13178              13178
#         7                       0      12021              12021
#         8                       0      12549              12549
#         9                       0       8659               8659
#         10                      0      10347              10347
#         11                      0       9761               9761
#         12                      0       8935               8935
# 2020    1                       0       6919               6919
#         2                       0       6360               6360
#
#                   SOURCE_FILE_DT  new_metric  addr_status  pe_status  \
# ws_year ws_month
# 2019    6                      0       13178        13178      13178
#         7                      0       12021        12021      12021
#         8                      0       12549        12549      12549
#         9                      0        8659         8659       8659
#         10                  6025       10347        10347      10347
#         11                  9761        9761         9761       9761
#         12                  8935        8935         8935       8935
# 2020    1                   6919        6919         6919       6919
#         2                   6360        6360         6360       6360
#
#                   phone_status  fax_status  spec_status
# ws_year ws_month
# 2019    6                13178       13178        13178
#         7                12021       12021        12021
#         8                12549       12549        12549
#         9                 8659        8659         8659
#         10               10347       10347        10347
#         11                9761        9761         9761
#         12                8935        8935         8935
# 2020    1                 6919        6919         6919
#         2                 6360        6360         6360
#
# [9 rows x 36 columns]

# %%
# Out:
#         PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 299577         2.640691e+10                 YURI               EDUARDO
# 299578         2.512102e+09                CASEY             CATHERINE
# 299579         1.102932e+09            CATHERINE                     C
# 299580         2.401021e+09            CATHERINE                  PAGE
# 299581         4.301000e+08              CAROLYN                     M
# ...                     ...                  ...                   ...
# 310150         4.950295e+10              ROOPALI                   NaN
# 310151         5.104770e+09               ROBERT                CHILES
# 310152         7.029603e+08              PATRICK               CHARLES
# 310153         3.050101e+10                ROHIT                   NaN
# 310154         3.963287e+10                 PAUL                JOSEPH
#
#        PHYSICIAN_LAST_NAME SUFFIX  DEGREE  OFFICE_ADDRESS_LINE_1  \
# 299577            CORRALES    NaN     NaN       URB COUNTRY CLUB
# 299578               SAGER    NaN     NaN                    NaN
# 299579           MADAFFARI    NaN     NaN      COMM INTERNAL MED
# 299580            CROSLAND    NaN     NaN  UNITY HEALTH CARE INC
# 299581              BOLTIN    NaN     NaN                    NaN
# ...                    ...    ...     ...                    ...
# 310150            AGGARWAL    NaN     NaN                    NaN
# 310151               ALVIS    NaN     NaN                    NaN
# 310152               BARRY    NaN     NaN                    NaN
# 310153             KHIRBAT    NaN     NaN                    NaN
# 310154                 SOS    NaN     NaN                    NaN
#
#              OFFICE_ADDRESS_LINE_2 OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE  \
# 299577           820 AVE ITURREGUI            SAN JUAN                   PR
# 299578   3409 LUDINGTON ST STE 204            ESCANABA                   MI
# 299579         4500 SAN PABLO RD S        JACKSONVILLE                   FL
# 299580               425 2ND ST NW          WASHINGTON                   DC
# 299581               525 E 68TH ST            NEW YORK                   NY
# ...                            ...                 ...                  ...
# 310150                1 WEXFORD DR   MONMOUTH JUNCTION                   NJ
# 310151               3468 PARK AVE               BRONX                   NY
# 310152  45 COUNTY ROAD 804 STE 210              FRASER                   CO
# 310153      9901 MEDICAL CENTER DR           ROCKVILLE                   MD
# 310154  8575 E PRINCESS DR STE 117          SCOTTSDALE                   AZ
#
#         ... SPECIALTY_UPDATED  SOURCE_FILE_DT  ws_month  ws_year  new_metric  \
# 299577  ...               1.0      2019-12-19         2     2020     Updated
# 299578  ...               1.0      2019-12-19         2     2020     Updated
# 299579  ...               1.0      2019-12-19         2     2020     Updated
# 299580  ...               1.0      2019-12-19         2     2020     Updated
# 299581  ...               1.0      2019-12-19         2     2020     Updated
# ...     ...               ...             ...       ...      ...         ...
# 310150  ...               1.0      2020-01-27         2     2020     Updated
# 310151  ...               1.0      2020-01-27         2     2020     Updated
# 310152  ...               1.0      2020-01-27         2     2020     Updated
# 310153  ...               1.0      2020-01-27         2     2020     Updated
# 310154  ...               1.0      2020-01-27         2     2020     Updated
#
#         addr_status  pe_status  phone_status  fax_status  spec_status
# 299577    Confirmed    Updated     Confirmed   Confirmed    Confirmed
# 299578    Confirmed  Confirmed     Confirmed     Updated    Confirmed
# 299579    Confirmed    Updated     Confirmed   Confirmed    Confirmed
# 299580    Confirmed  Confirmed     Confirmed   Confirmed    Confirmed
# 299581    Confirmed  Confirmed       Updated     Updated    Confirmed
# ...             ...        ...           ...         ...          ...
# 310150      Updated    Updated     Confirmed   Confirmed    Confirmed
# 310151      Updated    Updated     Confirmed     Updated    Confirmed
# 310152      Updated  Confirmed     Confirmed   Confirmed    Confirmed
# 310153      Updated    Updated     Confirmed     Updated    Confirmed
# 310154    Confirmed    Updated       Updated   Confirmed    Confirmed
#
# [6360 rows x 38 columns]

# %%
good_phone.WS
# Out:
#         PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 0              1.002122e+09               TRAVIS                  JOHN
# 1              1.222090e+09              WILLIAM                 HENRY
# 2              1.606101e+09              WHITNEY             ELIZABETH
# 3              1.643631e+09               WALTER                  CHAS
# 4              2.002112e+09                SUSAN                BERSOT
# ...                     ...                  ...                   ...
# 310150         4.950295e+10              ROOPALI                   NaN
# 310151         5.104770e+09               ROBERT                CHILES
# 310152         7.029603e+08              PATRICK               CHARLES
# 310153         3.050101e+10                ROHIT                   NaN
# 310154         3.963287e+10                 PAUL                JOSEPH
#
#        PHYSICIAN_LAST_NAME SUFFIX  DEGREE OFFICE_ADDRESS_LINE_1  \
# 0                   MAIERS    NaN     NaN                   NaN
# 1                    MCRAE    III     NaN              STE 1400
# 2                   ZIRKLE    NaN     NaN              STE 1325
# 3                   WROBEL    NaN     NaN                   NaN
# 4                    VINCI    NaN     NaN                   NaN
# ...                    ...    ...     ...                   ...
# 310150            AGGARWAL    NaN     NaN                   NaN
# 310151               ALVIS    NaN     NaN                   NaN
# 310152               BARRY    NaN     NaN                   NaN
# 310153             KHIRBAT    NaN     NaN                   NaN
# 310154                 SOS    NaN     NaN                   NaN
#
#              OFFICE_ADDRESS_LINE_2 OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE  \
# 0                    1 CAPITAL WAY          PENNINGTON                   NJ
# 1                   471 E BROAD ST            COLUMBUS                   OH
# 2             675 N SAINT CLAIR ST             CHICAGO                   IL
# 3                  623 E MAUDE AVE   ARLINGTON HEIGHTS                   IL
# 4          200 ABRAHAM FLEXNER WAY          LOUISVILLE                   KY
# ...                            ...                 ...                  ...
# 310150                1 WEXFORD DR   MONMOUTH JUNCTION                   NJ
# 310151               3468 PARK AVE               BRONX                   NY
# 310152  45 COUNTY ROAD 804 STE 210              FRASER                   CO
# 310153      9901 MEDICAL CENTER DR           ROCKVILLE                   MD
# 310154  8575 E PRINCESS DR STE 117          SCOTTSDALE                   AZ
#
#         ... SPECIALTY_UPDATED  SOURCE_FILE_DT  ws_month  ws_year  new_metric  \
# 0       ...               1.0             NaN         6     2019     Updated
# 1       ...               1.0             NaN         6     2019     Updated
# 2       ...               1.0             NaN         6     2019     Updated
# 3       ...               1.0             NaN         6     2019     Updated
# 4       ...               1.0             NaN         6     2019     Updated
# ...     ...               ...             ...       ...      ...         ...
# 310150  ...               1.0      2020-01-27         2     2020     Updated
# 310151  ...               1.0      2020-01-27         2     2020     Updated
# 310152  ...               1.0      2020-01-27         2     2020     Updated
# 310153  ...               1.0      2020-01-27         2     2020     Updated
# 310154  ...               1.0      2020-01-27         2     2020     Updated
#
#         addr_status  pe_status  phone_status  fax_status  spec_status
# 0         Confirmed    Updated     Confirmed     Updated    Confirmed
# 1         Confirmed  Confirmed     Confirmed     Updated    Confirmed
# 2         Confirmed    Updated     Confirmed     Updated    Confirmed
# 3         Confirmed    Updated     Confirmed     Updated    Confirmed
# 4         Confirmed    Updated     Confirmed     Updated    Confirmed
# ...             ...        ...           ...         ...          ...
# 310150      Updated    Updated     Confirmed   Confirmed    Confirmed
# 310151      Updated    Updated     Confirmed     Updated    Confirmed
# 310152      Updated  Confirmed     Confirmed   Confirmed    Confirmed
# 310153      Updated    Updated     Confirmed     Updated    Confirmed
# 310154    Confirmed    Updated       Updated   Confirmed    Confirmed
#
# [88729 rows x 38 columns]

# %%
GUTE = good_phone[good_phone.WSLIVE_FILE_DT=='2020-02-14'].drop_duplicates('OFFICE_TELEPHONE')

# %%
dhc_phone.sample(500)
# Out:
#              NPI            ME                           Add_Offices  \
# 2451  1689056632  1.275150e+09                                   NaN
# 403   1275587578  3.840812e+09                                   NaN
# 1297  1932155884  7.040197e+10                                   NaN
# 912   1891793287  1.320286e+10                                   NaN
# 978   1659466639  5.611479e+10  Merrillville, IN - Michigan City, IN
# ...          ...           ...                                   ...
# 1083  1306892211  6.490381e+10                                   NaN
# 81    1083683833  2.275890e+09                                   NaN
# 193   1710986450  2.507990e+09                                   NaN
# 918   1568467447  4.705771e+09                                   NaN
# 880   1316934334  4.113920e+09                           Hanover, PA
#
#       Phone_Number Zipcode_DHC State        City  \
# 2451  517.205.4730       49201    MI     Jackson
# 403   614.221.3777       43222    OH    Columbus
# 1297  972.747.6042       75013    TX       Allen
# 912   239.985.1050       33912    FL  Fort Myers
# 978            NaN       46383    IN  Valparaiso
# ...            ...         ...   ...         ...
# 1083  239.343.9700       33905    FL  Fort Myers
# 81    603.433.8434    ="03801"    NH  Portsmouth
# 193   313.875.5377       48202    MI     Detroit
# 918   404.501.5256       30033    GA     Decatur
# 880   717.932.5200       17339    PA  Lewisberry
#
#                              Address      First            Name_DHC  ...  \
# 2451                  205 N East Ave     Farhad        Farhad Amani  ...
# 403                  51 S Souder Ave      James         James Sides  ...
# 1297             1105 Central Expy N       Jari           Jari Khan  ...
# 912   6840 International Center Blvd     Daniel  Daniel Bendetowicz  ...
# 978            85 E US-6 Frontage Rd     Joseph     Joseph Venditti  ...
# ...                              ...        ...                 ...  ...
# 1083         8960 Colonial Center Dr       John       John Macaluso  ...
# 81                 155 Borthwick Ave     Daniel       Daniel Davies  ...
# 193                2888 W Grand Blvd    Felicia    Felicia Randolph  ...
# 918                2701 N Decatur Rd      Edwin       Edwin Nunnery  ...
# 880                  629d Lowther Rd  Elizabeth    Elizabeth Bergey  ...
#
#      SPECIALTY_UPDATED SOURCE_FILE_DT ws_month ws_year new_metric  \
# 2451               1.0     2020-01-27        2    2020    Updated
# 403                1.0     2020-01-27        2    2020    Updated
# 1297               1.0     2020-01-27        2    2020    Updated
# 912                1.0     2020-01-27        2    2020    Updated
# 978                1.0     2020-01-27        2    2020    Updated
# ...                ...            ...      ...     ...        ...
# 1083               1.0     2020-01-27        2    2020    Updated
# 81                 1.0     2020-01-27        2    2020    Updated
# 193                1.0     2020-01-27        2    2020    Updated
# 918                1.0     2020-01-27        2    2020    Updated
# 880                1.0     2020-01-27        2    2020    Updated
#
#       addr_status  pe_status phone_status fax_status spec_status
# 2451    Confirmed  Confirmed    Confirmed    Updated   Confirmed
# 403     Confirmed  Confirmed    Confirmed  Confirmed   Confirmed
# 1297    Confirmed  Confirmed    Confirmed    Updated   Confirmed
# 912     Confirmed  Confirmed    Confirmed  Confirmed   Confirmed
# 978     Confirmed  Confirmed    Confirmed    Updated   Confirmed
# ...           ...        ...          ...        ...         ...
# 1083    Confirmed  Confirmed    Confirmed  Confirmed   Confirmed
# 81      Confirmed  Confirmed    Confirmed  Confirmed   Confirmed
# 193       Updated  Confirmed      Updated    Updated   Confirmed
# 918       Updated  Confirmed    Confirmed  Confirmed   Confirmed
# 880     Confirmed  Confirmed    Confirmed  Confirmed   Confirmed
#
# [500 rows x 53 columns]

# %%
dhc_phone = dhc_phone.fillna('None')

# %%
dhc_phone = dhc_phone[(dhc_phone['Phone_Number']!='None')&(dhc_phone['Address']!='None')]

# %%
samp = dhc_phone.sample(500)

# %%
DHC_PHONE = dhc_phone[['NPI', 'ME', 'Add_Offices', 'Phone_Number', 'Zipcode_DHC', 'State',
       'City', 'Address', 'First', 'Name_DHC', 'Middle', 'Spec', 'Affiliation',
       'Last', 'Address1', 'PHYSICIAN_ME_NUMBER', 'PHYSICIAN_FIRST_NAME',
       'PHYSICIAN_MIDDLE_NAME', 'PHYSICIAN_LAST_NAME', 'SUFFIX', 'DEGREE',
       'OFFICE_ADDRESS_LINE_1', 'OFFICE_ADDRESS_LINE_2', 'OFFICE_ADDRESS_CITY',
       'OFFICE_ADDRESS_STATE', 'OFFICE_ADDRESS_ZIP','OFFICE_TELEPHONE', 'WSLIVE_SOURCE',
       'SPECIALTY']]

# %%
sample = DHC_PHONE.sample(500)

# %%
DHC_PHONE = DHC_PHONE.drop_duplicates('Phone_Number')

# %%
sample.to_csv('Data/dhc_phone_sample.csv', index=False)
