# %%
key = 'WS77-XIQ4-KGS1'
import pandas as pd
import requests
import xmltodict
import matplotlib.pyplot as plt
from reverse_phone_lookup import reverse_lookup, test_numbers

# %%
disconnected_df = pd.read_csv("disconnected.csv")
disconnected_df.head()
disconnected_phone_df = disconnected_df.sample(n=100)
disconnected_phone_df_trunc = disconnected_phone_df[['PHYSICIAN_FIRST_NAME', 'PHYSICIAN_LAST_NAME','OFFICE_ADDRESS_LINE_2', 'OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE', 'OFFICE_ADDRESS_ZIP', 'OFFICE_TELEPHONE', 'COMMENTS']]

# %%
connected_df = pd.read_csv("connected.csv")
connected_df.head()
# Out:
#    PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 0            106060649                AARON                 DAVID
# 1            401060596                 ADAM                 BRIAN
# 2            506891124                AARON                   NaN
# 3            515880062                 ALAN                 CLARK
# 4            577080381            ALEXANDRE                   NaN
#
#   PHYSICIAN_LAST_NAME  SUFFIX  DEGREE      OFFICE_ADDRESS_LINE_1  \
# 0               SEIMS     NaN     NaN                    STE 500
# 1            WOODRUFF     NaN     NaN                        NaN
# 2            SPINGARN     NaN     NaN  WESTCHESTER E N T STE 100
# 3             BECKMAN     NaN     NaN                        NaN
# 4           EACCARINO     NaN     NaN                        NaN
#
#         OFFICE_ADDRESS_LINE_2 OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE  ...  \
# 0           1720 S ORANGE AVE             ORLANDO                   FL  ...
# 1          4802 E JOHNSON AVE           JONESBORO                   AR  ...
# 2           141 S CENTRAL AVE           HARTSDALE                   NY  ...
# 3       1700 NICHOLASVILLE RD           LEXINGTON                   KY  ...
# 4  2500 HOSPITAL BLVD STE 290             ROSWELL                   GA  ...
#
#   PRESENT_EMPLOYMENT_UPDATED  COMMENTS  Source  WSLIVE_SOURCE  WSLIVE_FILE_DT  \
# 0                          1  COMPLETE       C        UPDATED      07/12/2019
# 1                          2  COMPLETE       C        UPDATED      07/12/2019
# 2                          1  COMPLETE       C        UPDATED      07/12/2019
# 3                          2  COMPLETE       C        UPDATED      07/12/2019
# 4                          1  COMPLETE       C        UPDATED      07/12/2019
#
#             MATCH_ADDR           MATCH_PHONE  MATCH_ADDR_LONG  SPECIALTY  \
# 0  0010606064172032806  00106060644075401000              NaN        PDS
# 1  0040106059480272401  00401060598709368000              NaN        NEP
# 2   005068911214110530  00506891129146863950              NaN        OTO
# 3  0051588006170040503  00515880068592606460              NaN         RO
# 4  0057708038250030076  00577080384044335650              NaN        OBG
#
#    SPECIALTY_UPDATED
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
#
# [5 rows x 29 columns]

# %%
connected_phone_df = connected_df.sample(n =100)
connected_phone_df_trunc = connected_phone_df[['PHYSICIAN_FIRST_NAME', 'PHYSICIAN_LAST_NAME','OFFICE_ADDRESS_LINE_2', 'OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE', 'OFFICE_ADDRESS_ZIP', 'OFFICE_TELEPHONE', 'COMMENTS']]
connected_phone_df_trunc.head()
# Out:
#      PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME       OFFICE_ADDRESS_LINE_2  \
# 1822               SHRUTI              KAPOOR             5100 W BROAD ST
# 2064               THOMAS             JANSSEN           9600 BROADWAY EXT
# 1994                PAYAM              YASHAR      8635 W 3RD ST STE 265W
# 334             MACKENZIE               BARTZ  2755 S HIGHWAY 14 STE 2200
# 447                   ANN               BLACK             1501 HOUSTON ST
#
#      OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE OFFICE_ADDRESS_ZIP  \
# 1822            COLUMBUS                   OH              43228
# 2064       OKLAHOMA CITY                   OK              73114
# 1994         LOS ANGELES                   CA              90048
# 334                GREER                   SC              29650
# 447          CASTROVILLE                   TX              78009
#
#       OFFICE_TELEPHONE  COMMENTS
# 1822        6147884440  COMPLETE
# 2064        4052309435  COMPLETE
# 1994        3105562020  COMPLETE
# 334         8648499555  COMPLETE
# 447         8305383550  COMPLETE

# %%
def reverse_lookup(phone_number, column_name, apikey):
    info_dict = {}
    base_url = "https://trial.serviceobjects.com/GPPL2/api.svc/GetPhoneInfo"
    parameters = {'PhoneNumber':phone_number, 'LicenseKey': apikey}
    response =  requests.get(base_url, params=parameters)
    results = xmltodict.parse(response.content)
    try:
        phone_results = results["PhoneInfoResponse"]["PhoneInfo"]
    except:
        pass
    info_dict[column_name] = phone_number
    try:
        info_dict["Name"] = phone_results["Contacts"]['Contact']["Name"]
    except:
        info_dict["Name"] = 'None'
    try:
        info_dict["Address"] = phone_results["Contacts"]['Contact']["Address"]
    except:
        info_dict["Address"] = 'None'
    try:
        info_dict["Zipcode"] = phone_results["Contacts"]['Contact']["PostalCode"]
    except:
        info_dict["Zipcode"] = 'None'
    try:
        info_dict["City"] = phone_results["Contacts"]['Contact']["City"]
    except:
        info_dict["City"] = 'None'
    try:
        info_dict["Zipcode"] = phone_results["Contacts"]['Contact']["PostalCode"][0:5]
    except:
        info_dict["Zipcode"] = 'None'
    try:
        info_dict["State"] = phone_results["Contacts"]['Contact']["State"]
    except:
        info_dict["State"] = 'None'
    try:
        info_dict["PhoneType"] = phone_results["Contacts"]['Contact']["PhoneType"]
    except:
        info_dict["PhoneType"] = 'None'
    try:
        info_dict["QualityScore"] = phone_results["Contacts"]['Contact']["QualityScore"]
    except:
        info_dict["QualityScore"] = 'None'
    try:
        info_dict["Date"] = phone_results["DateOfPorting"]
    except:
        info_dict["Date"] = 'None'
    try:
        info_dict["Notes"] = phone_results["NoteDescriptions"]
    except:
        info_dict["Notes"] = 'None'
    try:
        info_dict["Provider"] = phone_results['Provider']['Name']
    except:
        info_dict["Provider"] = 'None'
    return(info_dict, results)

# %%
def test_numbers(dataframe, apikey):

    #Create two empty lists:
    results_dict_list = []
    fun_massive_list = []

    #Iterate through dataframe and call reverse_lookup on each number:
    for row in dataframe.itertuples():
        new_dict = {}
        phone = row.OFFICE_TELEPHONE
        try:
            new_dict, phone_results = reverse_lookup(phone, 'OFFICE_TELEPHONE', apikey)
            results_dict_list.append(new_dict)
            fun_massive_list.append(phone_results)
        except:
            pass

    #Save lists of dictionaries as dataframes:
    new_df = pd.DataFrame(results_dict_list)
    final_df = pd.merge(new_df, dataframe, on = 'OFFICE_TELEPHONE')

    #Return dataframes:
    return(fun_massive_list, final_df)

# %%
massive_list, final_df = test_numbers(connected_phone_df_trunc.head(), key)
final_df
# Out:
#            Address          City        Date  \
# 0  1111 AUGUSTA DR       HOUSTON        None
# 1             None          None  2015-03-25
# 2             None     CAMARILLO  2018-06-05
# 3             None  PHILADELPHIA        None
# 4             None   LONG BRANCH        None
#
#                                             Name                 Notes  \
# 0                                 KELSEY SEYBOLD            IsMailable
# 1                    UC HEALTH WEST CHESTER HOSP              IsPorted
# 2  SPANISH HILLS MEDICAL GROUP OHARA ROBERT R MD  IsConnected,IsPorted
# 3         THE CHILDRENS HOSPITAL OF PHILADELPHIA           IsConnected
# 4                                MONMOUTH MED CN           IsConnected
#
#    OFFICE_TELEPHONE PhoneType              Provider QualityScore State  \
# 0        7134423222  BUSINESS     SOUTHWESTERN BELL          LOW    TX
# 1        5132987325  BUSINESS  CIN BELL ANY DIST OH          MED  None
# 2        8054453310  BUSINESS    PEERLESS NTWK - CA         HIGH    CA
# 3        2155904446  BUSINESS  VERIZON PENNSYLVANIA          MED    PA
# 4        7329235195  BUSINESS    VERIZON NEW JERSEY          MED    NJ
#
#   Zipcode PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME     OFFICE_ADDRESS_LINE_2  \
# 0   77057                  AMY                CHEN  560 MEYERLAND PLAZA MALL
# 1     N/A              MARISSA             RAMIREZ        7700 UNIVERSITY DR
# 2   93010                 LYNN              PLUCHE      400 MOBIL AVE STE C2
# 3   19108               ROBERT                DOMS    3401 CIVIC CENTER BLVD
# 4   07740              SHANNON                URSU               300 2ND AVE
#
#   OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE OFFICE_ADDRESS_ZIP  COMMENTS
# 0             HOUSTON                   TX              77096  COMPLETE
# 1        WEST CHESTER                   OH              45069  COMPLETE
# 2           CAMARILLO                   CA              93010  COMPLETE
# 3        PHILADELPHIA                   PA              19104  COMPLETE
# 4         LONG BRANCH                   NJ              07740  COMPLETE

# %%
info_dict2, results2 = reverse_lookup('5704745072', 'OFFICE_TELEPHONE', key)
info_dict2
# Out:
# {'OFFICE_TELEPHONE': '5704745072',
#  'Name': 'GEISINGER',
#  'Address': '35 S MOUNTAIN BLVD',
#  'City': 'MOUNTAIN TOP',
#  'State': 'PA',
#  'PhoneType': 'BUSINESS',
#  'QualityScore': 'LOW',
#  'Date': '2015-11-23',
#  'Notes': 'IsMailable,IsPorted',
#  'Provider': 'CTSI, INC. - PA'}

# %%
# Out:
# '18707'

# %%
connected_massive_list, connected_final_df = test_numbers(connected_phone_df_trunc, key)
connected_final_df.head()
# Out:
#                       Address           City        Date  \
# 0                        None           None  2019-04-01
# 1                        None  OKLAHOMA CITY  2017-03-31
# 2      8635 W 3RD ST STE 265W    LOS ANGELES  2018-05-09
# 3  2755 S HIGHWAY 14 STE 2500          GREER  2008-12-23
# 4             1501 HOUSTON ST    CASTROVILLE  2017-10-12
#
#                                             Name  \
# 0                                     OHIOHEALTH
# 1                                MCBRIDE ORTHOPE
# 2  PAYAM ROBERT YASHAR MD INC PHYSICIANS GENERAL
# 3      MEDICAL GROUP OF THE CAROLINASDIVISION OF
# 4    LITTLE ALSACE URGENT CARE CENTER CHILD CARE
#
#                                                Notes  OFFICE_TELEPHONE  \
# 0        IsConnected,IsPorted,IsPossiblePortableVOIP        6147884440
# 1                               IsConnected,IsPorted        4052309435
# 2  IsMailable,IsConnected,IsPorted,IsPossiblePort...        3105562020
# 3                    IsMailable,IsConnected,IsPorted        8648499555
# 4                    IsMailable,IsConnected,IsPorted        8305383550
#
#   PhoneType              Provider QualityScore State Zipcode  \
# 0  BUSINESS     LEVEL 3 COMM - OH          MED  None     N/A
# 1  BUSINESS   COX OKLAHOMA TELECO          MED    OK   73102
# 2  BUSINESS     LEVEL 3 COMM - CA         HIGH    CA   90048
# 3  BUSINESS  NUVOX COMMUNICATIONS         HIGH    SC   29650
# 4  BUSINESS    BANDWIDTH.COM - TX         HIGH    TX   78009
#
#   PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME       OFFICE_ADDRESS_LINE_2  \
# 0               SHRUTI              KAPOOR             5100 W BROAD ST
# 1               THOMAS             JANSSEN           9600 BROADWAY EXT
# 2                PAYAM              YASHAR      8635 W 3RD ST STE 265W
# 3            MACKENZIE               BARTZ  2755 S HIGHWAY 14 STE 2200
# 4                  ANN               BLACK             1501 HOUSTON ST
#
#   OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE OFFICE_ADDRESS_ZIP  COMMENTS
# 0            COLUMBUS                   OH              43228  COMPLETE
# 1       OKLAHOMA CITY                   OK              73114  COMPLETE
# 2         LOS ANGELES                   CA              90048  COMPLETE
# 3               GREER                   SC              29650  COMPLETE
# 4         CASTROVILLE                   TX              78009  COMPLETE

# %%
disconnected_massive_list, disconnected_final_df = test_numbers(disconnected_phone_df_trunc, key)
disconnected_final_df.head()
# Out:
#        Address      City  Date                  Name       Notes  \
# 0  885 3RD AVE  NEW YORK  None  HQ GLOBAL WORKPLACES  IsMailable
# 1  885 3RD AVE  NEW YORK  None  HQ GLOBAL WORKPLACES  IsMailable
# 2  885 3RD AVE  NEW YORK  None  HQ GLOBAL WORKPLACES  IsMailable
# 3  885 3RD AVE  NEW YORK  None  HQ GLOBAL WORKPLACES  IsMailable
# 4  885 3RD AVE  NEW YORK  None  HQ GLOBAL WORKPLACES  IsMailable
#
#    OFFICE_TELEPHONE PhoneType              Provider QualityScore State  \
# 0        2128295581  BUSINESS  VERIZON NEW YORK INC          LOW    NY
# 1        2128295581  BUSINESS  VERIZON NEW YORK INC          LOW    NY
# 2        2128295581  BUSINESS  VERIZON NEW YORK INC          LOW    NY
# 3        2128295581  BUSINESS  VERIZON NEW YORK INC          LOW    NY
# 4        2128295581  BUSINESS  VERIZON NEW YORK INC          LOW    NY
#
#   Zipcode PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME      OFFICE_ADDRESS_LINE_2  \
# 0   10022               ROBERT              TURNER      4341 US HIGHWAY 412 W
# 1   10022               ROBERT            THORNTON               3701 LOOP RD
# 2   10022               NIKHIL                SHAH  275 COLLIER RD NW STE 400
# 3   10022                MATEO      PORRES AGUILAR         7700 FLOYD CURL DR
# 4   10022             SHIRISHA              BODANA             453 HESPER AVE
#
#   OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE  OFFICE_ADDRESS_ZIP        COMMENTS
# 0             JACKSON                   TN             38305.0  NOT IN SERVICE
# 1          TUSCALOOSA                   AL             35404.0  NOT IN SERVICE
# 2             ATLANTA                   GA             30309.0  NOT IN SERVICE
# 3         SAN ANTONIO                   TX             78229.0  NOT IN SERVICE
# 4            METAIRIE                   LA             70005.0  NOT IN SERVICE

# %%
disconnected_final_df.to_csv('wtf.csv')
connected_final_df.to_csv('connected_final.csv')

# %%
disconnected_massive_list[10]
# Out:
# OrderedDict([('PhoneInfoResponse',
#               OrderedDict([('@xmlns', 'http://www.serviceobjects.com'),
#                            ('@xmlns:i',
#                             'http://www.w3.org/2001/XMLSchema-instance'),
#                            ('PhoneInfo',
#                             OrderedDict([('Provider',
#                                           OrderedDict([('Name',
#                                                         'PACIFIC BELL'),
#                                                        ('City', 'FONTANA'),
#                                                        ('State', 'CALIFORNIA'),
#                                                        ('Latitude', '34.0862'),
#                                                        ('Longitude',
#                                                         '-117.469'),
#                                                        ('LineType',
#                                                         'LANDLINE')])),
#                                          ('Contacts',
#                                           OrderedDict([('Contact',
#                                                         OrderedDict([('Name',
#                                                                       'KAISER PERMANEN'),
#                                                                      ('Address',
#                                                                       None),
#                                                                      ('City',
#                                                                       'FONTANA'),
#                                                                      ('State',
#                                                                       'CA'),
#                                                                      ('PostalCode',
#                                                                       '92331'),
#                                                                      ('PhoneType',
#                                                                       'BUSINESS'),
#                                                                      ('Latitude',
#                                                                       None),
#                                                                      ('Longitude',
#                                                                       None),
#                                                                      ('SICCode',
#                                                                       None),
#                                                                      ('SICDesc',
#                                                                       None),
#                                                                      ('QualityScore',
#                                                                       'MED')]))])),
#                                          ('SMSAddress', None),
#                                          ('MMSAddress', None),
#                                          ('DateFirstSeen', None),
#                                          ('DateOfPorting', None),
#                                          ('NoteCodes', '2'),
#                                          ('NoteDescriptions', 'IsConnected'),
#                                          ('TokensUsed', '65')]))]))])

# %%
disconnected_phone_df_trunc
# Out:
#     PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME  \
# 174               ROBERT              TURNER
# 173               ROBERT            THORNTON
# 227                 STEN            SOLANDER
# 13               AIZHANA             REPCHAK
# 2                  ABNER              LANDRY
# 275              WILLIAM             KIRKSEY
# 31             ANASTACIA             LAMBROU
# 233                SUNIL        VALLURUPALLI
# 228              STEPHEN          MASSICOTTE
# 271                  TAE                 RHO
# 72                 KENJI             SHIBATA
# 253                  ZAW                HTAY
# 177               ROBERT            HATFIELD
# 182             PATRICIA            PISINGER
# 47              KIMBERLY              PETERS
# 230               STEVEN            MARGOLIS
# 137               ROBERT                 TOM
# 132               RAJANI              UPPALA
# 125              MICHAEL             MAZUREK
# 205            SUGUNAKAR             VANGALA
# 214                    V               REDDY
# 65              TAIWANNA         BROWN-BOLDS
# 121              MATTHEW             MOLISON
# 165                RALPH           ZWOLINSKI
# 225              STEPHEN              NGUYEN
# 4                  AHMED              KAFAJI
# 16                ALICIA            LEADFORD
# 178               ROBERT               BLEZA
# 115                 MARK             SHEPARD
# 46             KATHERINE             HUFFMAN
# ..                   ...                 ...
# 145         MOHAN.SAHEB.             GUNDETI
# 189              RICHARD                  OH
# 75                  TINA          YOXTHEIMER
# 152              NEFTALI           RODRIGUEZ
# 211             TOCHUKWU            IKEJIANI
# 43                HANNAH                ZHOU
# 185                 RAVI               GUTTA
# 67                  MARK          CUNNINGHAM
# 274              WILLIAM            GRUNDLER
# 149               MULETA                OBSU
# 150               MYKOLA          ALYSKEWYCZ
# 234             SURINDER                GILL
# 209               THOMAS              LAMKIN
# 248               VRINDA              SUNEJA
# 120              MATTHEW              THOMAS
# 59               PRAVEEN         PONNAMREDDY
# 199             SHIRISHA              BODANA
# 222               SHEILA                FORD
# 144             MOHAMMAD                ARIF
# 221                SCOTT              SEWELL
# 262                SUNAH                FENG
# 136               ROBERT                 LEE
# 25                AIREEN           GUTIERREZ
# 58                 MIRTA               VEBER
# 200               SHOBHA                SAHI
# 56               MICHAEL             PASCALE
# 216              SANDHYA             BONDADA
# 196               SHARON               RODDY
# 146                 MONA                BODA
# 168                 REVA               KLEIN
#
#                 OFFICE_ADDRESS_LINE_2 OFFICE_ADDRESS_CITY  \
# 174             4341 US HIGHWAY 412 W             JACKSON
# 173                      3701 LOOP RD          TUSCALOOSA
# 227                    101 MANNING DR         CHAPEL HILL
# 13                    3302 GALLOWS RD        FALLS CHURCH
# 2         12551 INDIAN ROCKS RD STE 7               LARGO
# 275                  830 S GLOSTER ST              TUPELO
# 31              1001 JOHNSON FERRY RD             ATLANTA
# 233      1505 NORTHSIDE BLVD STE 3000             CUMMING
# 228       3955 EAGLE CREEK PKWY STE C        INDIANAPOLIS
# 271                590 FARRINGTON HWY             KAPOLEI
# 72                     14011 PARK AVE         VICTORVILLE
# 253    1301 W EAU GALLIE BLVD STE 108           MELBOURNE
# 177                  205 CORPORATE PL               ALCOA
# 182                      971 LANE AVE         CHULA VISTA
# 47            811 NEW YORK AVE RM 405            BROOKLYN
# 230                44201 DEQUINDRE RD                TROY
# 137        1500 CITYWEST BLVD STE 300             HOUSTON
# 132                   905 FRANKLIN ST            WATERLOO
# 125     705 RILEY HOSPITAL DR RM 2820        INDIANAPOLIS
# 205                5000 W CHAMBERS ST           MILWAUKEE
# 214         312 N L ROGERS WELLS BLVD             GLASGOW
# 65              1301 WELLBROOK CIR NE             CONYERS
# 121                 119 NORTHPORT AVE             BELFAST
# 165            1673 MASON AVE STE 305       DAYTONA BEACH
# 225                1190 VETERANS BLVD        REDWOOD CITY
# 4                28105 THREE NOTCH RD       MECHANICSVLLE
# 16                     2000 CHURCH ST           NASHVILLE
# 178                   115 E 113TH AVE         CROWN POINT
# 115                 7442 FRANK AVE NW        NORTH CANTON
# 46                                NaN                 NaN
# ..                                ...                 ...
# 145               10 ORLAND SQUARE DR         ORLAND PARK
# 189           3367 S MERCY RD STE 210             GILBERT
# 75                   3025 LIBRARY CIR              TOLEDO
# 152     381 AVE FELISA RINCON GAUTIER            SAN JUAN
# 211                 1607 S LOCUST AVE        LAWRENCEBURG
# 43                                NaN                 NaN
# 185                  5601 DE SOTO AVE        WOODLAND HLS
# 67                                NaN                 NaN
# 274              369 CONTRA COSTA AVE             VENTURA
# 149  6990 COLUMBIA GATEWAY DR STE 350            COLUMBIA
# 150              8906 135TH ST STE 2T       RICHMOND HILL
# 234                  5637 MARINE PKWY        NEW PRT RCHY
# 209       3181 SW SAM JACKSON PARK RD            PORTLAND
# 248                     41100 FOX RUN                NOVI
# 120                  100 GREENWAY CIR               ERWIN
# 59                1 MEDICAL CENTER DR             LEBANON
# 199                    453 HESPER AVE            METAIRIE
# 222         14642 NEWPORT AVE STE 410              TUSTIN
# 144            25 JOHN A CUMMINGS WAY          WOONSOCKET
# 221           30 MARK WEST SPRINGS RD          SANTA ROSA
# 262            302 PROSPECT ST UNIT 4            LA JOLLA
# 136                      220 E 1ST ST         GIBSON CITY
# 25                  10173 FAIRHILL DR       SPRING VALLEY
# 58                     773 ROUTE 9W S               NYACK
# 200                    3201 MIDDLE DR            COLUMBUS
# 56          3005 112TH AVE NE STE 210            BELLEVUE
# 216                 400 PARNASSUS AVE       SAN FRANCISCO
# 196        19111 W 10 MILE RD STE 164          SOUTHFIELD
# 146                    777 BANNOCK ST              DENVER
# 168                    605 LINCOLN ST           WORCESTER
#
#     OFFICE_ADDRESS_STATE  OFFICE_ADDRESS_ZIP  OFFICE_TELEPHONE        COMMENTS
# 174                   TN             38305.0        2128295581  NOT IN SERVICE
# 173                   AL             35404.0        2128295581  NOT IN SERVICE
# 227                   NC             27514.0        9199661288  NOT IN SERVICE
# 13                    VA             22042.0        2043957827  NOT IN SERVICE
# 2                     FL             33774.0        7275860545  NOT IN SERVICE
# 275                   MS             38801.0        3852132546  NOT IN SERVICE
# 31                    GA             30342.0        6036228963  NOT IN SERVICE
# 233                   GA             30041.0        7708860036  NOT IN SERVICE
# 228                   IN             46254.0        3172808410  NOT IN SERVICE
# 271                   HI             96707.0        8085219551  NOT IN SERVICE
# 72                    CA             92392.0        9094273910  NOT IN SERVICE
# 253                   FL             32935.0        3213081666  NOT IN SERVICE
# 177                   TN             37701.0        8659339050  NOT IN SERVICE
# 182                   CA             91914.0        6194027300  NOT IN SERVICE
# 47                    NY             11203.0        2128448888  NOT IN SERVICE
# 230                   MI             48085.0        5863231122  NOT IN SERVICE
# 137                   TX             77042.0        7136593284  NOT IN SERVICE
# 132                   IA             50703.0        3198743200  NOT IN SERVICE
# 125                   IN             46202.0        3172740273  NOT IN SERVICE
# 205                   WI             53210.0        8476665031  NOT IN SERVICE
# 214                   KY             42141.0        2706519393  NOT IN SERVICE
# 65                    GA             30012.0        7705860017  NOT IN SERVICE
# 121                   ME              4915.0        2079302639  NOT IN SERVICE
# 165                   FL             32117.0        3867634484  NOT IN SERVICE
# 225                   CA             94063.0        3232267556  NOT IN SERVICE
# 4                     MD             20659.0        3012743706  NOT IN SERVICE
# 16                    TN             37236.0        2059393361  NOT IN SERVICE
# 178                   IN             46307.0        2196638110  NOT IN SERVICE
# 115                   OH             44720.0        3304555367  NOT IN SERVICE
# 46                   NaN                 NaN        9199664996  NOT IN SERVICE
# ..                   ...                 ...               ...             ...
# 145                   IL             60462.0        4232232232  NOT IN SERVICE
# 189                   AZ             85297.0        4806333995  NOT IN SERVICE
# 75                    OH             43614.0        4193834244  NOT IN SERVICE
# 152                   PR               926.0        7879935215  NOT IN SERVICE
# 211                   TN             38464.0        6158674753  NOT IN SERVICE
# 43                   NaN                 NaN        2168441000  NOT IN SERVICE
# 185                   CA             91367.0        8187193770  NOT IN SERVICE
# 67                   NaN                 NaN        9012912427  NOT IN SERVICE
# 274                   CA             93004.0        8056526556  NOT IN SERVICE
# 149                   MD             21046.0        4108728590  NOT IN SERVICE
# 150                   NY             11418.0        2123047330  NOT IN SERVICE
# 234                   FL             34652.0        8139727629  NOT IN SERVICE
# 209                   OR             97239.0        2058242227  NOT IN SERVICE
# 248                   MI             48377.0        2489605104  NOT IN SERVICE
# 120                   TN             37650.0        4237433141  NOT IN SERVICE
# 59                    NH              3756.0        6036506247  NOT IN SERVICE
# 199                   LA             70005.0        2128295581  NOT IN SERVICE
# 222                   CA             92780.0        7142794000  NOT IN SERVICE
# 144                   RI              2895.0        4017665959  NOT IN SERVICE
# 221                   CA             95403.0        7075848000  NOT IN SERVICE
# 262                   CA             92037.0        8583506036  NOT IN SERVICE
# 136                   IL             60936.0        2177848442  NOT IN SERVICE
# 25                    CA             91977.0        8585739902  NOT IN SERVICE
# 58                    NY             10960.0        2013586776  NOT IN SERVICE
# 200                   IN             47203.0        8123728293  NOT IN SERVICE
# 56                    WA             98004.0        4254514144  NOT IN SERVICE
# 216                   CA             94143.0        4153522161  NOT IN SERVICE
# 196                   MI             48075.0        2483540767  NOT IN SERVICE
# 146                   CO             80204.0        9736230606  NOT IN SERVICE
# 168                   MA              1605.0        6172481457  NOT IN SERVICE
#
# [100 rows x 8 columns]

# %%
disconnected_phone_df_trunc.iloc[45:90]
# Out:
#     PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME  \
# 243                VELMA            CASANOVA
# 38              CHINYERE               NNADI
# 236                SUSAN            WUTHRICH
# 10                 ALLAN               YOUNG
# 24               ADELITA             GREELEY
# 54                 DAVID              DUNCAN
# 12                  AHDY               BOLIS
# 254             ZIAULHAQ                 ZIA
# 57               MICHAEL              RAMSAY
# 259              WILLIAM           BASTNAGEL
# 191              ROBERTO     ALVAREZ-SWIHART
# 11                 ALLYN              NORMAN
# 242                  VAN               SILKA
# 276              WILLIAM       DURAN SERRANO
# 241                 ULKA             ZALESKI
# 219               SANJAY           KUDTARKAR
# 116               MARTHA               KUTKO
# 34              CAROLINE             WINSLOW
# 123              MICHAEL             WINKLER
# 94                  LISA               BOULT
# 206                SUMIN                SHAH
# 100                MARIO               RAMOS
# 88                 LARRY             BOWLING
# 83              KIMBERLY               ERWAY
# 106                 LORA            MELNICOE
# 145         MOHAN.SAHEB.             GUNDETI
# 189              RICHARD                  OH
# 75                  TINA          YOXTHEIMER
# 152              NEFTALI           RODRIGUEZ
# 211             TOCHUKWU            IKEJIANI
# 43                HANNAH                ZHOU
# 185                 RAVI               GUTTA
# 67                  MARK          CUNNINGHAM
# 274              WILLIAM            GRUNDLER
# 149               MULETA                OBSU
# 150               MYKOLA          ALYSKEWYCZ
# 234             SURINDER                GILL
# 209               THOMAS              LAMKIN
# 248               VRINDA              SUNEJA
# 120              MATTHEW              THOMAS
# 59               PRAVEEN         PONNAMREDDY
# 199             SHIRISHA              BODANA
# 222               SHEILA                FORD
# 144             MOHAMMAD                ARIF
# 221                SCOTT              SEWELL
#
#                   OFFICE_ADDRESS_LINE_2 OFFICE_ADDRESS_CITY  \
# 243           9850 KEY WEST AVE STE 100           ROCKVILLE
# 38                   228 W ALEXANDER ST          PLANT CITY
# 236                 200 MAIN ST STE 350           PAWTUCKET
# 10              165 N VILLAGE AVE STE 5       ROCKVILLE CTR
# 24                        525 THIRD AVE         CHULA VISTA
# 54               3723 W 12600 S STE 150            RIVERTON
# 12               5 MOBILE INFIRMARY CIR              MOBILE
# 254             56 SCHOOLHOUSE RD STE B             WHITING
# 57                       169 ASHLEY AVE          CHARLESTON
# 259              1407 UNION AVE STE 620             MEMPHIS
# 191              DEPT OF INTERN MEDICIN            AIBONITO
# 11                1825 MAPLE RD STE 100       WILLIAMSVILLE
# 242                       55 LAKE AVE N           WORCESTER
# 276  500 GRAND BLVD LOS PRADOS APT 1203              CAGUAS
# 241             301 SAINT PAUL ST FL 17           BALTIMORE
# 219                  395 TERRACINA BLVD            REDLANDS
# 116                 525 E 68TH ST # 302            NEW YORK
# 34              895 SW 30TH AVE STE 101       POMPANO BEACH
# 123               800 ROSE ST STE HX313           LEXINGTON
# 94                 407 EAST AVE STE 110           PAWTUCKET
# 206                  1012 95TH ST STE 7          NAPERVILLE
# 100          369 CALLE DE DIEGO STE 307            SAN JUAN
# 88                      644 N MORTON ST         BLOOMINGTON
# 83                   150 MOUNT HOPE AVE           ROCHESTER
# 106                         501 28TH ST              DENVER
# 145                 10 ORLAND SQUARE DR         ORLAND PARK
# 189             3367 S MERCY RD STE 210             GILBERT
# 75                     3025 LIBRARY CIR              TOLEDO
# 152       381 AVE FELISA RINCON GAUTIER            SAN JUAN
# 211                   1607 S LOCUST AVE        LAWRENCEBURG
# 43                                  NaN                 NaN
# 185                    5601 DE SOTO AVE        WOODLAND HLS
# 67                                  NaN                 NaN
# 274                369 CONTRA COSTA AVE             VENTURA
# 149    6990 COLUMBIA GATEWAY DR STE 350            COLUMBIA
# 150                8906 135TH ST STE 2T       RICHMOND HILL
# 234                    5637 MARINE PKWY        NEW PRT RCHY
# 209         3181 SW SAM JACKSON PARK RD            PORTLAND
# 248                       41100 FOX RUN                NOVI
# 120                    100 GREENWAY CIR               ERWIN
# 59                  1 MEDICAL CENTER DR             LEBANON
# 199                      453 HESPER AVE            METAIRIE
# 222           14642 NEWPORT AVE STE 410              TUSTIN
# 144              25 JOHN A CUMMINGS WAY          WOONSOCKET
# 221             30 MARK WEST SPRINGS RD          SANTA ROSA
#
#     OFFICE_ADDRESS_STATE  OFFICE_ADDRESS_ZIP  OFFICE_TELEPHONE        COMMENTS
# 243                   MD             20850.0        3017621818  NOT IN SERVICE
# 38                    FL             33563.0        8137542251  NOT IN SERVICE
# 236                   RI              2860.0        4017267300  NOT IN SERVICE
# 10                    NY             11570.0        5164839020  NOT IN SERVICE
# 24                    CA             91910.0        8584992261  NOT IN SERVICE
# 54                    UT             84065.0        8014081980  NOT IN SERVICE
# 12                    AL             36607.0        2514357223  NOT IN SERVICE
# 254                   NJ              8759.0        7323507900  NOT IN SERVICE
# 57                    SC             29425.0        8644556372  NOT IN SERVICE
# 259                   TN             38104.0        9014486657  NOT IN SERVICE
# 191                   PR               705.0        7848098180  NOT IN SERVICE
# 11                    NY             14221.0        7162044532  NOT IN SERVICE
# 242                   MA              1655.0        5088562939  NOT IN SERVICE
# 276                   PR               727.0        5202145354  NOT IN SERVICE
# 241                   MD             21202.0        4106590689  NOT IN SERVICE
# 219                   CA             92373.0        9098838058  NOT IN SERVICE
# 116                   NY             10065.0        2019962403  NOT IN SERVICE
# 34                    FL             33069.0        9544935065  NOT IN SERVICE
# 123                   KY             40536.0        8593235069  NOT IN SERVICE
# 94                    RI              2860.0        4017288245  NOT IN SERVICE
# 206                   IL             60564.0        6304283828  NOT IN SERVICE
# 100                   PR               923.0        7877714163  NOT IN SERVICE
# 88                    IN             47404.0        8123337326  NOT IN SERVICE
# 83                    NY             14620.0        5857773511  NOT IN SERVICE
# 106                   CO             80205.0        3038937666  NOT IN SERVICE
# 145                   IL             60462.0        4232232232  NOT IN SERVICE
# 189                   AZ             85297.0        4806333995  NOT IN SERVICE
# 75                    OH             43614.0        4193834244  NOT IN SERVICE
# 152                   PR               926.0        7879935215  NOT IN SERVICE
# 211                   TN             38464.0        6158674753  NOT IN SERVICE
# 43                   NaN                 NaN        2168441000  NOT IN SERVICE
# 185                   CA             91367.0        8187193770  NOT IN SERVICE
# 67                   NaN                 NaN        9012912427  NOT IN SERVICE
# 274                   CA             93004.0        8056526556  NOT IN SERVICE
# 149                   MD             21046.0        4108728590  NOT IN SERVICE
# 150                   NY             11418.0        2123047330  NOT IN SERVICE
# 234                   FL             34652.0        8139727629  NOT IN SERVICE
# 209                   OR             97239.0        2058242227  NOT IN SERVICE
# 248                   MI             48377.0        2489605104  NOT IN SERVICE
# 120                   TN             37650.0        4237433141  NOT IN SERVICE
# 59                    NH              3756.0        6036506247  NOT IN SERVICE
# 199                   LA             70005.0        2128295581  NOT IN SERVICE
# 222                   CA             92780.0        7142794000  NOT IN SERVICE
# 144                   RI              2895.0        4017665959  NOT IN SERVICE
# 221                   CA             95403.0        7075848000  NOT IN SERVICE

# %%
# Out:
# 174          TURNER
# 173        THORNTON
# 227        SOLANDER
# 13          REPCHAK
# 2            LANDRY
# 275         KIRKSEY
# 31          LAMBROU
# 233    VALLURUPALLI
# 228      MASSICOTTE
# 271             RHO
# 72          SHIBATA
# 253            HTAY
# 177        HATFIELD
# 182        PISINGER
# 47           PETERS
# 230        MARGOLIS
# 137             TOM
# 132          UPPALA
# 125         MAZUREK
# 205         VANGALA
# 214           REDDY
# 65      BROWN-BOLDS
# 121         MOLISON
# 165       ZWOLINSKI
# 225          NGUYEN
# 4            KAFAJI
# 16         LEADFORD
# 178           BLEZA
# 115         SHEPARD
# 46          HUFFMAN
#            ...
# 145         GUNDETI
# 189              OH
# 75       YOXTHEIMER
# 152       RODRIGUEZ
# 211        IKEJIANI
# 43             ZHOU
# 185           GUTTA
# 67       CUNNINGHAM
# 274        GRUNDLER
# 149            OBSU
# 150      ALYSKEWYCZ
# 234            GILL
# 209          LAMKIN
# 248          SUNEJA
# 120          THOMAS
# 59      PONNAMREDDY
# 199          BODANA
# 222            FORD
# 144            ARIF
# 221          SEWELL
# 262            FENG
# 136             LEE
# 25        GUTIERREZ
# 58            VEBER
# 200            SAHI
# 56          PASCALE
# 216         BONDADA
# 196           RODDY
# 146            BODA
# 168           KLEIN
# Name: PHYSICIAN_LAST_NAME, Length: 100, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-1e007d05c1f8> in <module>
# ----> 1 info_dict4, results4 = reverse_lookup('7848098180', 'phone', key)
#
# <ipython-input-35-cd290ea724c1> in reverse_lookup(phone_number, column_name, apikey)
#       5     response =  requests.get(base_url, params=parameters)
#       6     results = xmltodict.parse(response.content)
# ----> 7     phone_results = results["PhoneInfoResponse"]["PhoneInfo"]
#       8     info_dict[column_name] = phone_number
#       9     try:
#
# KeyError: 'PhoneInfo'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-981bc8a143ff> in <module>
# ----> 1 results4
#
# NameError: name 'results4' is not defined

# %%
info_dict = {}
base_url = "https://trial.serviceobjects.com/GPPL2/api.svc/GetPhoneInfo"
parameters = {'PhoneNumber': '7848098180', 'LicenseKey': key}
response =  requests.get(base_url, params=parameters)
results4 = xmltodict.parse(response.content)

# %%
results4
# Out:
# OrderedDict([('PhoneInfoResponse',
#               OrderedDict([('@xmlns', 'http://www.serviceobjects.com'),
#                            ('@xmlns:i',
#                             'http://www.w3.org/2001/XMLSchema-instance'),
#                            ('Error',
#                             OrderedDict([('Type', 'Domain Specific'),
#                                          ('TypeCode', '4'),
#                                          ('Desc',
#                                           'Phone Number is not valid.'),
#                                          ('DescCode', '1')]))]))])

# %%
if results4['PhoneInfoResponse']['Error']['Desc'] == 'Phone Number is not valid.'
# Out:
# 'Phone Number is not valid.'

# %%
massive_list
# Out:
# [OrderedDict([('PhoneInfoResponse',
#                OrderedDict([('@xmlns', 'http://www.serviceobjects.com'),
#                             ('@xmlns:i',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('PhoneInfo',
#                              OrderedDict([('Provider',
#                                            OrderedDict([('Name',
#                                                          'SOUTHWESTERN BELL'),
#                                                         ('City', 'HOUSTON'),
#                                                         ('State', 'TEXAS'),
#                                                         ('Latitude',
#                                                          '29.7652'),
#                                                         ('Longitude',
#                                                          '-95.4071'),
#                                                         ('LineType',
#                                                          'LANDLINE')])),
#                                           ('Contacts',
#                                            OrderedDict([('Contact',
#                                                          OrderedDict([('Name',
#                                                                        'KELSEY SEYBOLD'),
#                                                                       ('Address',
#                                                                        '1111 AUGUSTA DR'),
#                                                                       ('City',
#                                                                        'HOUSTON'),
#                                                                       ('State',
#                                                                        'TX'),
#                                                                       ('PostalCode',
#                                                                        '77057-2209'),
#                                                                       ('PhoneType',
#                                                                        'BUSINESS'),
#                                                                       ('Latitude',
#                                                                        '29.753734'),
#                                                                       ('Longitude',
#                                                                        '-95.482685'),
#                                                                       ('SICCode',
#                                                                        None),
#                                                                       ('SICDesc',
#                                                                        None),
#                                                                       ('QualityScore',
#                                                                        'LOW')]))])),
#                                           ('SMSAddress', None),
#                                           ('MMSAddress', None),
#                                           ('DateFirstSeen', None),
#                                           ('DateOfPorting', None),
#                                           ('NoteCodes', '1'),
#                                           ('NoteDescriptions', 'IsMailable'),
#                                           ('TokensUsed', '65')]))]))]),
#  OrderedDict([('PhoneInfoResponse',
#                OrderedDict([('@xmlns', 'http://www.serviceobjects.com'),
#                             ('@xmlns:i',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('PhoneInfo',
#                              OrderedDict([('Provider',
#                                            OrderedDict([('Name',
#                                                          'CIN BELL ANY DIST OH'),
#                                                         ('City', 'CINCINNATI'),
#                                                         ('State', 'OHIO'),
#                                                         ('Latitude', '39.17'),
#                                                         ('Longitude',
#                                                          '-84.4929'),
#                                                         ('LineType',
#                                                          'LANDLINE')])),
#                                           ('Contacts',
#                                            OrderedDict([('Contact',
#                                                          OrderedDict([('Name',
#                                                                        'UC HEALTH WEST CHESTER HOSP'),
#                                                                       ('Address',
#                                                                        None),
#                                                                       ('City',
#                                                                        None),
#                                                                       ('State',
#                                                                        None),
#                                                                       ('PostalCode',
#                                                                        None),
#                                                                       ('PhoneType',
#                                                                        'BUSINESS'),
#                                                                       ('Latitude',
#                                                                        None),
#                                                                       ('Longitude',
#                                                                        None),
#                                                                       ('SICCode',
#                                                                        None),
#                                                                       ('SICDesc',
#                                                                        None),
#                                                                       ('QualityScore',
#                                                                        'MED')]))])),
#                                           ('SMSAddress', None),
#                                           ('MMSAddress', None),
#                                           ('DateFirstSeen', None),
#                                           ('DateOfPorting', '2015-03-25'),
#                                           ('NoteCodes', '3'),
#                                           ('NoteDescriptions', 'IsPorted'),
#                                           ('TokensUsed', '35')]))]))]),
#  OrderedDict([('PhoneInfoResponse',
#                OrderedDict([('@xmlns', 'http://www.serviceobjects.com'),
#                             ('@xmlns:i',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('PhoneInfo',
#                              OrderedDict([('Provider',
#                                            OrderedDict([('Name',
#                                                          'PEERLESS NTWK - CA'),
#                                                         ('City', 'ANAHEIM'),
#                                                         ('State',
#                                                          'CALIFORNIA'),
#                                                         ('Latitude', '33.837'),
#                                                         ('Longitude',
#                                                          '-117.89'),
#                                                         ('LineType',
#                                                          'LANDLINE')])),
#                                           ('Contacts',
#                                            OrderedDict([('Contact',
#                                                          OrderedDict([('Name',
#                                                                        'SPANISH HILLS MEDICAL GROUP OHARA ROBERT R MD'),
#                                                                       ('Address',
#                                                                        None),
#                                                                       ('City',
#                                                                        'CAMARILLO'),
#                                                                       ('State',
#                                                                        'CA'),
#                                                                       ('PostalCode',
#                                                                        '93010'),
#                                                                       ('PhoneType',
#                                                                        'BUSINESS'),
#                                                                       ('Latitude',
#                                                                        None),
#                                                                       ('Longitude',
#                                                                        None),
#                                                                       ('SICCode',
#                                                                        '80110000'),
#                                                                       ('SICDesc',
#                                                                        'OFFICES AND CLINICS OF MEDICAL DOCTORS'),
#                                                                       ('QualityScore',
#                                                                        'HIGH')]))])),
#                                           ('SMSAddress', None),
#                                           ('MMSAddress', None),
#                                           ('DateFirstSeen', None),
#                                           ('DateOfPorting', '2018-06-05'),
#                                           ('NoteCodes', '2,3'),
#                                           ('NoteDescriptions',
#                                            'IsConnected,IsPorted'),
#                                           ('TokensUsed', '65')]))]))]),
#  OrderedDict([('PhoneInfoResponse',
#                OrderedDict([('@xmlns', 'http://www.serviceobjects.com'),
#                             ('@xmlns:i',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('PhoneInfo',
#                              OrderedDict([('Provider',
#                                            OrderedDict([('Name',
#                                                          'VERIZON PENNSYLVANIA'),
#                                                         ('City',
#                                                          'PHILADELPHIA'),
#                                                         ('State',
#                                                          'PENNSYLVANIA'),
#                                                         ('Latitude',
#                                                          '39.9844'),
#                                                         ('Longitude',
#                                                          '-75.1534'),
#                                                         ('LineType',
#                                                          'LANDLINE')])),
#                                           ('Contacts',
#                                            OrderedDict([('Contact',
#                                                          OrderedDict([('Name',
#                                                                        'THE CHILDRENS HOSPITAL OF PHILADELPHIA'),
#                                                                       ('Address',
#                                                                        None),
#                                                                       ('City',
#                                                                        'PHILADELPHIA'),
#                                                                       ('State',
#                                                                        'PA'),
#                                                                       ('PostalCode',
#                                                                        '19108'),
#                                                                       ('PhoneType',
#                                                                        'BUSINESS'),
#                                                                       ('Latitude',
#                                                                        None),
#                                                                       ('Longitude',
#                                                                        None),
#                                                                       ('SICCode',
#                                                                        None),
#                                                                       ('SICDesc',
#                                                                        None),
#                                                                       ('QualityScore',
#                                                                        'MED')]))])),
#                                           ('SMSAddress', None),
#                                           ('MMSAddress', None),
#                                           ('DateFirstSeen', None),
#                                           ('DateOfPorting', None),
#                                           ('NoteCodes', '2'),
#                                           ('NoteDescriptions', 'IsConnected'),
#                                           ('TokensUsed', '65')]))]))]),
#  OrderedDict([('PhoneInfoResponse',
#                OrderedDict([('@xmlns', 'http://www.serviceobjects.com'),
#                             ('@xmlns:i',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('PhoneInfo',
#                              OrderedDict([('Provider',
#                                            OrderedDict([('Name',
#                                                          'VERIZON NEW JERSEY'),
#                                                         ('City',
#                                                          'LONG BRANCH'),
#                                                         ('State',
#                                                          'NEW JERSEY'),
#                                                         ('Latitude',
#                                                          '40.2945'),
#                                                         ('Longitude',
#                                                          '-73.9952'),
#                                                         ('LineType',
#                                                          'LANDLINE')])),
#                                           ('Contacts',
#                                            OrderedDict([('Contact',
#                                                          OrderedDict([('Name',
#                                                                        'MONMOUTH MED CN'),
#                                                                       ('Address',
#                                                                        None),
#                                                                       ('City',
#                                                                        'LONG BRANCH'),
#                                                                       ('State',
#                                                                        'NJ'),
#                                                                       ('PostalCode',
#                                                                        '07740'),
#                                                                       ('PhoneType',
#                                                                        'BUSINESS'),
#                                                                       ('Latitude',
#                                                                        None),
#                                                                       ('Longitude',
#                                                                        None),
#                                                                       ('SICCode',
#                                                                        None),
#                                                                       ('SICDesc',
#                                                                        None),
#                                                                       ('QualityScore',
#                                                                        'MED')]))])),
#                                           ('SMSAddress', None),
#                                           ('MMSAddress', None),
#                                           ('DateFirstSeen', None),
#                                           ('DateOfPorting', None),
#                                           ('NoteCodes', '2'),
#                                           ('NoteDescriptions', 'IsConnected'),
#                                           ('TokensUsed', '65')]))]))])]

# %%
disconnected_phone_df2 = disconnected_df.sample(n=10)

# %%
disconnected_phone_df2_trunc = disconnected_phone_df2[['PHYSICIAN_FIRST_NAME', 'PHYSICIAN_LAST_NAME','OFFICE_ADDRESS_LINE_2', 'OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE', 'OFFICE_ADDRESS_ZIP', 'OFFICE_TELEPHONE', 'COMMENTS']]

# %%
disconnected_phone_df2_trunc
# Out:
#     PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME          OFFICE_ADDRESS_LINE_2  \
# 160                PEDRO               RAMOS             6 CALLE DR LOPEZ W
# 40                EDWARD            HOLSCHER                            NaN
# 178               ROBERT               BLEZA                115 E 113TH AVE
# 191              ROBERTO     ALVAREZ-SWIHART         DEPT OF INTERN MEDICIN
# 109                MAREN                DUNN           18 MEADOW VILLAGE DR
# 190               POLLIE               LUMBY                            NaN
# 23                 ABHAY              VAIDYA                 8687 GRAND AVE
# 103                KEVIN              URDAHL             307 WESTLAKE AVE N
# 110             MARGARET          DIGERONIMO  7887 E BELLEVIEW AVE STE 1100
# 195                SCOTT              LIPOFF        4131 NW 13TH ST STE 101
#
#     OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE  OFFICE_ADDRESS_ZIP  \
# 160             FAJARDO                   PR               738.0
# 40                  NaN                  NaN                 NaN
# 178         CROWN POINT                   IN             46307.0
# 191            AIBONITO                   PR               705.0
# 109             BIG SKY                   MT             59716.0
# 190                 NaN                  NaN                 NaN
# 23         YUCCA VALLEY                   CA             92284.0
# 103             SEATTLE                   WA             98109.0
# 110           ENGLEWOOD                   CO             80111.0
# 195         GAINESVILLE                   FL             32609.0
#
#      OFFICE_TELEPHONE        COMMENTS
# 160        7878701529  NOT IN SERVICE
# 40         8033351219  NOT IN SERVICE
# 178        2196638110  NOT IN SERVICE
# 191        7848098180  NOT IN SERVICE
# 109        4069953111  NOT IN SERVICE
# 190        8889222732  NOT IN SERVICE
# 23         7603651068  NOT IN SERVICE
# 103        2062567293  NOT IN SERVICE
# 110        3034367142  NOT IN SERVICE
# 195        3523761887  NOT IN SERVICE

# %%
disconnected_df.drop_duplicates(subset='OFFICE_TELEPHONE',  inplace=True)

# %%
this = disconnected_df.sample(n=10)

# %%
this
# Out:
#      PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 126           3501900817              MICHAEL                 JAMES
# 207          49565730168      TAMARISAKANDALA                   NaN
# 135           1676880409               ROBERT                NORMAN
# 133           1643821547              RICHARD                 EATON
# 97            3605970493            MARGARETE                 SMITH
# 246          30801000041               VICTOR                    A.
# 196           2507873033               SHARON                 MARIE
# 167          91706760011            RAZAULLAH                     A
# 62            2401070233              RUCHIRA                 MENKA
# 116           3305952019               MARTHA             CHRISTINA
#
#     PHYSICIAN_LAST_NAME  SUFFIX  DEGREE         OFFICE_ADDRESS_LINE_1  \
# 126               KLOTZ     NaN     NaN                           NaN
# 207             NARAYAN     NaN     NaN                           NaN
# 135               WHITE     NaN     NaN                           NaN
# 133            BESINGER     NaN     NaN                           NaN
# 97                HOYLE     NaN     NaN                         # 371
# 246       COLON SANCHEZ     NaN     NaN                    OCEAN PARK
# 196               RODDY     NaN     NaN                           NaN
# 167              KHWAJA     NaN     NaN                           NaN
# 62                  JHA     NaN     NaN         6TH FLOOR SCAIFE HALL
# 116               KUTKO     NaN     NaN  WEILL CORNELL MEDICAL CENTER
#
#           OFFICE_ADDRESS_LINE_2 OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE  ...  \
# 126    125 RED CREEK DR STE 205           ROCHESTER                   NY  ...
# 207  939 OFFICE PARK RD STE 308        W DES MOINES                   IA  ...
# 135         800 BIESTERFIELD RD       ELK GROVE VLG                   IL  ...
# 133           3700 SARATOGA AVE       DOWNERS GROVE                   IL  ...
# 97        1959 N PEACE HAVEN RD       WINSTON SALEM                   NC  ...
# 246     2069 CALLE BUENOS AIRES            SAN JUAN                   PR  ...
# 196  19111 W 10 MILE RD STE 164          SOUTHFIELD                   MI  ...
# 167             311 MARLBORO RD          KENNETT SQ                   PA  ...
# 62              3550 TERRACE ST          PITTSBURGH                   PA  ...
# 116         525 E 68TH ST # 302            NEW YORK                   NY  ...
#
#      PRESENT_EMPLOYMENT_UPDATED        COMMENTS  Source  WSLIVE_SOURCE  \
# 126                           1  NOT IN SERVICE       C         OTHERS
# 207                           1  NOT IN SERVICE       C         OTHERS
# 135                           1  NOT IN SERVICE       C         OTHERS
# 133                           1  NOT IN SERVICE       C         OTHERS
# 97                            1  NOT IN SERVICE       C         OTHERS
# 246                           1  NOT IN SERVICE       C         OTHERS
# 196                           1  NOT IN SERVICE       C         OTHERS
# 167                           1  NOT IN SERVICE       C         OTHERS
# 62                            1  NOT IN SERVICE      VT         OTHERS
# 116                           1  NOT IN SERVICE       C         OTHERS
#
#      WSLIVE_FILE_DT            MATCH_ADDR           MATCH_PHONE  \
# 126      07/12/2019    035019008112514623  03501900815853210340
# 207      07/12/2019    495657301693950265  49565730165152801252
# 135      07/12/2019    016768804080060007  01676880408478273455
# 133      07/12/2019   0164382154370060515  01643821547082168563
# 97       07/12/2019   0360597049195927106  03605970493362771600
# 246      07/12/2019   3080100004206900911  30801000047877283184
# 196      07/12/2019  02507873031911148075  02507873032483540767
# 167      07/12/2019    917067600131119348  91706760014106588420
# 62       07/12/2019   0240107023355015213  02401070236177262862
# 116      07/12/2019    033059520152510065  03305952012019962403
#
#      MATCH_ADDR_LONG  SPECIALTY  SPECIALTY_UPDATED
# 126              NaN        ORS                  1
# 207              NaN        CCA                  1
# 135              NaN         GP                  1
# 133              NaN        MFM                  1
# 97               NaN         PD                  1
# 246              NaN         US                  1
# 196              NaN        OBG                  1
# 167              NaN         HS                  1
# 62               NaN          N                  1
# 116              NaN        CCP                  1
#
# [10 rows x 29 columns]

# %%
massive_list3, final_df3 = test_numbers(this.head(), key)

# %%
final_df3[['PHYSICIAN_FIRST_NAME', 'PHYSICIAN_LAST_NAME','OFFICE_ADDRESS_LINE_2', 'OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE', 'OFFICE_ADDRESS_ZIP', 'OFFICE_TELEPHONE', 'COMMENTS']]
# Out:
#   PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME       OFFICE_ADDRESS_LINE_2  \
# 0              MICHAEL               KLOTZ    125 RED CREEK DR STE 205
# 1      TAMARISAKANDALA             NARAYAN  939 OFFICE PARK RD STE 308
# 2               ROBERT               WHITE         800 BIESTERFIELD RD
# 3              RICHARD            BESINGER           3700 SARATOGA AVE
# 4            MARGARETE               HOYLE       1959 N PEACE HAVEN RD
#
#   OFFICE_ADDRESS_CITY OFFICE_ADDRESS_STATE  OFFICE_ADDRESS_ZIP  \
# 0           ROCHESTER                   NY             14623.0
# 1        W DES MOINES                   IA             50265.0
# 2       ELK GROVE VLG                   IL             60007.0
# 3       DOWNERS GROVE                   IL             60515.0
# 4       WINSTON SALEM                   NC             27106.0
#
#    OFFICE_TELEPHONE        COMMENTS
# 0        5853210340  NOT IN SERVICE
# 1        5152801252  NOT IN SERVICE
# 2        8478273455  NOT IN SERVICE
# 3        7082168563  NOT IN SERVICE
# 4        3362771600  NOT IN SERVICE
