# %%
import pandas as pd

# %%
connected_all = pd.read_csv('../GetPhoneInfo/CONNECTED.csv')
disconnected_all = pd.read_csv('../GetPhoneInfo/DISCONNECTED.csv')
connected_ekata = pd.read_csv('ekata_connected.csv')
disconnected_ekata = pd.read_csv('ekata_disconnected.csv')

# %%
connected_all = connected_all[['OFFICE_TELEPHONE','PHYSICIAN_FIRST_NAME','PHYSICIAN_LAST_NAME','OFFICE_ADDRESS_LINE_2','OFFICE_ADDRESS_CITY','OFFICE_ADDRESS_STATE','OFFICE_ADDRESS_ZIP','PHYSICIAN_ME_NUMBER','OFFICE_ADDRESS_LINE_1']]

# %%
connected_ekata = connected_ekata.drop(columns = ['Unnamed: 0'])

# %%
CONNECTED = pd.merge(connected_all, connected_ekata, on = 'OFFICE_TELEPHONE', how = 'outer')

# %%
NEW_CONNECTED = CONNECTED[CONNECTED['Commercial']!=True]

# %%
disconnected_all = disconnected_all[['OFFICE_TELEPHONE','PHYSICIAN_FIRST_NAME','PHYSICIAN_LAST_NAME','OFFICE_ADDRESS_LINE_2','OFFICE_ADDRESS_CITY','OFFICE_ADDRESS_STATE','OFFICE_ADDRESS_ZIP','PHYSICIAN_ME_NUMBER','OFFICE_ADDRESS_LINE_1']]
# disconnected_ekata = disconnected_ekata.drop(columns = ['Unnamed: 0'])
DISCONNECTED = pd.merge(disconnected_all, disconnected_ekata, on = 'OFFICE_TELEPHONE', how = 'outer')
DISCONNECTED = DISCONNECTED.drop_duplicates('OFFICE_TELEPHONE')
DISCONNECTED[DISCONNECTED['Valid']!=True]
# Out:
#      OFFICE_TELEPHONE PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME  \
# 0          7848098180              ROBERTO     ALVAREZ-SWIHART
# 1          2123047330               MYKOLA          ALYSKEWYCZ
# 2          4017665959             MOHAMMAD                ARIF
# 3          9014486657              WILLIAM           BASTNAGEL
# 4          4156412140              YAMILEE          BERMINGHAM
# 6          2196638110               ROBERT               BLEZA
# 7          9736230606                 MONA                BODA
# 8          2514357223                 AHDY               BOLIS
# 9          4153522161              SANDHYA             BONDADA
# 10         6106481510                NAHED              BOTROS
# 11         4017288245                 LISA               BOULT
# 14         3017621818                VELMA            CASANOVA
# 15         7877283184               VICTOR       COLON SANCHEZ
# 16         9012912427                 MARK          CUNNINGHAM
# ...

# %%
DISCONNECTED = DISCONNECTED.drop_duplicates('OFFICE_TELEPHONE')

# %%
NEW_DISCONNECTED.to_csv('new_disconnected_ekata_for_model.csv')
NEW_CONNECTED.to_csv('new_connected_ekata_for_model.csv')

# %%
disconnected_all
# Out:
#     OFFICE_TELEPHONE PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME  \
# 0         7848098180              ROBERTO     ALVAREZ-SWIHART
# 1         2123047330               MYKOLA          ALYSKEWYCZ
# 2         4017665959             MOHAMMAD                ARIF
# 3         9014486657              WILLIAM           BASTNAGEL
# 4         4156412140              YAMILEE          BERMINGHAM
# 5         7273020000           LAKSHMISRI       BHATTACHARJEE
# 6         2196638110               ROBERT               BLEZA
# 7         9736230606                 MONA                BODA
# 8         2514357223                 AHDY               BOLIS
# 9         4153522161              SANDHYA             BONDADA
# 10        6106481510                NAHED              BOTROS
# 11        4017288245                 LISA               BOULT
# 12        8123337326                LARRY             BOWLING
# 13        7705860017             TAIWANNA         BROWN-BOLDS
# ...

# %%
DISCONNECTED.drop_duplicates('OFFICE_TELEPHONE')
# Out:
#      OFFICE_TELEPHONE PHYSICIAN_FIRST_NAME PHYSICIAN_LAST_NAME  \
# 0          7848098180              ROBERTO     ALVAREZ-SWIHART
# 1          2123047330               MYKOLA          ALYSKEWYCZ
# 2          4017665959             MOHAMMAD                ARIF
# 3          9014486657              WILLIAM           BASTNAGEL
# 4          4156412140              YAMILEE          BERMINGHAM
# 5          7273020000           LAKSHMISRI       BHATTACHARJEE
# 6          2196638110               ROBERT               BLEZA
# 7          9736230606                 MONA                BODA
# 8          2514357223                 AHDY               BOLIS
# 9          4153522161              SANDHYA             BONDADA
# 10         6106481510                NAHED              BOTROS
# 11         4017288245                 LISA               BOULT
# 12         8123337326                LARRY             BOWLING
# 13         7705860017             TAIWANNA         BROWN-BOLDS
# ...

# %%
disconnected_ekata.groupby('OFFICE_TELEPHONE').count()
# Out:
#                   Unnamed: 0  Address  AlternatePhone  Carrier  City  \
# OFFICE_TELEPHONE
# 2013586776                 1        0               0        1     1
# 2019962403                 1        0               0        1     1
# 2043957827                 1        0               0        1     1
# 2058242227                 1        0               0        1     1
# 2059393361                 1        1               1        1     1
# 2079302639                 1        1               1        1     1
# 2168441000                 1        1               0        1     1
# 2394036350                 1        1               1        1     1
# 2489605104                 1        1               0        1     1
# 2706519393                 1        0               0        1     1
# 2768898380                 2        0               0        2     2
# 3012743706                 2        2               2        2     2
# ...
