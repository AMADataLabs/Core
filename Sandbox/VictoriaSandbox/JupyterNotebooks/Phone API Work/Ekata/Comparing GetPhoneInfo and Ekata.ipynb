# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd

# %% [markdown]
# ## Read csvs

# %%
ekata_disconnected = pd.read_csv('ekata_disconnected.csv')
ekata_connected = pd.read_csv('ekata_connected.csv')
disconnected = pd.read_csv('disconnected_final.csv')
connected = pd.read_csv('connected_final.csv')

# %% [markdown]
# ## Merge the disconnected dataframes

# %%
disconnected_df = pd.merge(disconnected, ekata_disconnected, on = 'OFFICE_TELEPHONE', suffixes = ('_GetPhoneInfo', '_Ekata'))
disconnected_df = disconnected_df.fillna("None")
disconnected_df.to_csv("combination_disconnected.csv")

# %% [markdown]
# ## Merge the connected dataframes and print to screen

# %%
connected_df = pd.merge(connected, ekata_connected, on = 'OFFICE_TELEPHONE', suffixes = ('_GetPhoneInfo', '_Ekata'))
connected_df
# Out:
#                    Address_GetPhoneInfo City_GetPhoneInfo Date_GetPhoneInfo  \
# 0            2755 S HIGHWAY 14 STE 2500             GREER        12/23/2008
# 1                       1501 HOUSTON ST       CASTROVILLE        10/12/2017
# 2                                   NaN        BURLINGTON               NaN
# 3                475 IRVING AVE STE 210          SYRACUSE         5/28/2015
# 4               160 OVERLOOK AVE STE 1A        HACKENSACK         1/25/2018
# 5                    1981 STATE HILL RD           READING         12/8/2015
# 6                          2854 BELL ST        ZANESVILLE         7/15/2016
# 7             3901 CENTRAL PIKE STE 351         HERMITAGE          9/7/2018
# 8            6601 LYNDALE AVE S STE 220       MINNEAPOLIS        10/27/2016
# 9             1215 S COULTER ST STE 403          AMARILLO         2/17/2012
# 10                                  NaN           BRANSON               NaN
# 11                10721 MAIN ST STE 200           FAIRFAX        10/31/2013
# 12                       645 MARBLE AVE         THORNWOOD         6/10/2016
# 13                10707 66TH ST N STE A     PINELLAS PARK          5/8/2014
# 14           3301 ALTA ARDEN EXPY STE 3        SACRAMENTO         12/7/2018
# 15                 613 E BLOOMINGTON ST         IOWA CITY               NaN
# 16                                  NaN         HENDERSON         6/28/2019
# 17                   1920 E BASELINE RD             TEMPE          9/8/2016
# 18                                  NaN         CLEVELAND               NaN
# 19                     6 ALBERT CREE DR           RUTLAND         6/24/2016
# 20                 61 W JIMMIE LEEDS RD            POMONA         4/29/2014
# 21                           55 COLE RD            MONROE          7/8/2016
# 22                         1037 MAIN ST         CORVALLIS         9/27/2016
# 23             1401 AVOCADO AVE STE 209     NEWPORT BEACH         2/15/2011
# 24                       421 S 28TH AVE       HATTIESBURG         8/18/2016
# 25                3007 OCEAN PKWY STE A          BROOKLYN         4/15/2013
# 26                       1100 REID PKWY          RICHMOND               NaN
# 27                     7041 LEE PARK RD    MECHANICSVILLE         6/21/2002
# 28                  30 BERGEN ST RM 206            NEWARK        10/25/2012
# 29                   4800 E JOHNSON AVE         JONESBORO               NaN
# 30  4950 NORTON HEALTHCARE BLVD STE 300        LOUISVILLE               NaN
# 31                           1203 B AVE        ELLISVILLE          6/4/2015
# 32                 2230 LYNN RD STE 102     THOUSAND OAKS         12/1/2018
# 33                   35 S MOUNTAIN BLVD      MOUNTAIN TOP        11/23/2015
# 34                        809 82ND PKWY      MYRTLE BEACH               NaN
# 35                      275 SANDWICH ST          PLYMOUTH         1/31/2014
# 36          23077 GREENFIELD RD STE 195        SOUTHFIELD        11/14/2018
# 37                       2219 DILLON RD            CLOVIS         1/11/2019
# 38                    333 BORTHWICK AVE        PORTSMOUTH         6/29/2018
# 39                     2931 RICHMOND RD         TEXARKANA        12/15/2018
#
#                                     Name_GetPhoneInfo  \
# 0           MEDICAL GROUP OF THE CAROLINASDIVISION OF
# 1         LITTLE ALSACE URGENT CARE CENTER CHILD CARE
# 2                                        BRUCE TRONIC
# 3      MADISON IRVING PEDIATRICS DEVELOPMENTAL HEALTH
# 4                  ANDREW FINK MD PHYSICIANS SURGEONS
# 5            DR TIMOTHY C STRINGER PHYSICIANS GENERAL
# 6                                          DREW LAYNE
# 7       ALLERGY ENT ASSOCIATES OF MIDDLE TENNESSEE PC
# 8           KIDNEY SPECIALISTS OF MINNESOTA MAIN INFO
# 9                 RAJ SARALAYA MD PHYSICIANS SURGEONS
# 10         COOPER KENT MD DOCTORS PHYSICIANS SURGEONS
# 11                                     ALLEN TERRY MD
# 12   ANDERSEN MARGARET MD DOCTORS PHYSICIANS SURGEONS
# 13   PINELLAS INTERNAL MEDICINE ASSOCIATES PHYSICIANS
# 14    HEALTH ASSOCIATES MEDICAL GROUP DOCTORS GENERAL
# 15             CANCER CARE OF IOWA CITY LLC HOSPITALS
# 16                             TIME FACTOR MANAGEMENT
# 17                                         CIGNA CORP
# 18          SCHNUR GARY MD CLEVELAND CLINIC HILLCREST
# 19                                    BRUCE D BULLOCK
# 20                  BACHARACH REHABILITATION MEDICINE
# 21                                    AHADI SUE MD PC
# 22          APRIL L WEINBERGER MD PHYSICIANS SURGEONS
# 23                ROBERT J BAE MD PHYSICIANS SURGEONS
# 24                                     ARTHUR L GLAZE
# 25                LEV KOVARSKY MD PHYSICIANS SURGEONS
# 26  E PAUL HOWANITZ MD PHYSICIANS SURGEONS CARDIOLOGY
# 27            LEEDAVIS MEDICAL CENTER DOCTORS GENERAL
# 28            UNIVERSITY OF MEDICINE AND DENTISTRY OF
# 29       NEA BAPTIST CLINIC HEARING CENTER PHYSICIANS
# 30    CHILDRENS ORTHOPAEDICS OF LOUISVILLE PHYSICIANS
# 31                                  ACHYUTHA S PUJARI
# 32                            LYNN EYE SURGERY CENTER
# 33                                          GEISINGER
# 34                                    GRAND STRAND RE
# 35            BETH ISRAEL DEACONESS HOSPITAL PLYMOUTH
# 36        PAVILION FAMILY PRACTICE PHYSICIANS GENERAL
# 37                                  MANUEL MACAPINLAC
# 38   KNEE HIP SHOULDER CENTER THE PHYSICIANS SURGEONS
# 39         TEXARKANA REGIONAL DIALYSIS REEP W LYNN MD
#
#                                                 Notes  OFFICE_TELEPHONE  \
# 0                     IsMailable,IsConnected,IsPorted        8648499555
# 1                     IsMailable,IsConnected,IsPorted        8305383550
# 2                                                 NaN        7817448046
# 3                     IsMailable,IsConnected,IsPorted        3154712646
# 4                     IsMailable,IsConnected,IsPorted        2014883131
# 5                     IsMailable,IsConnected,IsPorted        6106702277
# 6                     IsMailable,IsConnected,IsPorted        7404543273
# 7                     IsMailable,IsConnected,IsPorted        6158898802
# 8                                 IsMailable,IsPorted        6128238001
# 9                     IsMailable,IsConnected,IsPorted        8066772002
# 10                                        IsConnected        4173357222
# 11         IsMailable,IsPorted,IsPossiblePortableVOIP        7033856870
# 12                    IsMailable,IsConnected,IsPorted        9147691600
# 13                    IsMailable,IsConnected,IsPorted        7275448300
# 14                    IsMailable,IsConnected,IsPorted        9164894400
# 15                             IsMailable,IsConnected        3193393917
# 16                                           IsPorted        7024876510
# 17                                IsMailable,IsPorted        4803455200
# 18                         IsPossibleDisconnected,INF        4403124569
# 19                    IsMailable,IsConnected,IsPorted        8027701805
# 20                                IsMailable,IsPorted        6097485380
# 21                                IsMailable,IsPorted        7342422022
# 22                    IsMailable,IsConnected,IsPorted        4069614661
# 23                    IsMailable,IsConnected,IsPorted        9496448722
# 24                    IsMailable,IsConnected,IsPorted        6012685640
# 25                    IsMailable,IsConnected,IsPorted        7182654454
# 26                             IsMailable,IsConnected        7659833427
# 27                    IsMailable,IsConnected,IsPorted        8047463505
# 28                                IsMailable,IsPorted        9739725672
# 29                             IsMailable,IsConnected        8709368000
# 30                             IsMailable,IsConnected        5023945678
# 31                    IsMailable,IsConnected,IsPorted        6014773550
# 32     IsMailable,IsPorted,IsPossibleDisconnected,INF        8053703137
# 33                                IsMailable,IsPorted        5704745072
# 34                                         IsMailable        8436921765
# 35                    IsMailable,IsConnected,IsPorted        5087462000
# 36                    IsMailable,IsConnected,IsPorted        2484230700
# 37  IsMailable,IsConnected,IsPorted,IsPossiblePort...        5757697365
# 38  IsMailable,IsConnected,IsPorted,IsPossiblePort...        6034315858
# 39  IsMailable,IsConnected,IsPorted,IsPossiblePort...        9036143200
#
#    PhoneType_GetPhoneInfo              Provider QualityScore  \
# 0                BUSINESS  NUVOX COMMUNICATIONS         HIGH
# 1                BUSINESS    BANDWIDTH.COM - TX         HIGH
# 2             RESIDENTIAL   VERIZON NEW ENGLAND          LOW
# 3                BUSINESS    NORTHLAND NETWORKS         HIGH
# 4                BUSINESS      AIRUS, INC. - NJ         HIGH
# 5                BUSINESS    COMCAST PHONE - PA         HIGH
# 6             RESIDENTIAL  TIME WARNER CABLE OH         HIGH
# 7                BUSINESS    COMCAST PHONE - TN         HIGH
# 8                BUSINESS    COMCAST PHONE - MN          LOW
# 9                BUSINESS    PATHWAYZ COMM - TX         HIGH
# 10               BUSINESS           CENTURYLINK         HIGH
# 11               BUSINESS     LEVEL 3 COMM - MD          LOW
# 12               BUSINESS  CABLEVSN LGHTPATH NY         HIGH
# 13               BUSINESS  BRIGHT HOUSE NTWS FL         HIGH
# 14               BUSINESS    BANDWIDTH.COM - CA         HIGH
# 15               BUSINESS     QWEST CORPORATION         HIGH
# 16               BUSINESS          COMCAST - NV          LOW
# 17               BUSINESS      MCIMETRO ATS LLC          LOW
# 18               BUSINESS        AMERITECH OHIO          LOW
# 19            RESIDENTIAL    COMCAST PHONE - VT         HIGH
# 20               BUSINESS   COMCAST BUS COMM-NJ          LOW
# 21               BUSINESS    COMCAST PHONE - MI          LOW
# 22               BUSINESS  BLACKFOOT COMM. - MT         HIGH
# 23               BUSINESS    COX CA TELCOM - CA         HIGH
# 24            RESIDENTIAL  TELEPORT COM AM - MS         HIGH
# 25               BUSINESS  VERIZON NEW YORK INC         HIGH
# 26               BUSINESS   FRONTIER NORTH - IN         HIGH
# 27               BUSINESS          US LEC OF VA         HIGH
# 28               BUSINESS  MCI WORLDCOM COMM NJ          LOW
# 29               BUSINESS       RITTER COMMS AR         HIGH
# 30               BUSINESS     BELLSOUTH SO CNTL         HIGH
# 31            RESIDENTIAL  TELEPORT COM AM - MS         HIGH
# 32               BUSINESS    PEERLESS NTWK - CA          LOW
# 33               BUSINESS       CTSI, INC. - PA          LOW
# 34               BUSINESS   FRONTIER CAROL - SC          LOW
# 35               BUSINESS  CTC COMMS CORP. - MA         HIGH
# 36               BUSINESS    COMCAST PHONE - MI         HIGH
# 37            RESIDENTIAL     LEVEL 3 COMM - NM         HIGH
# 38               BUSINESS     LEVEL 3 COMM - NH         HIGH
# 39               BUSINESS     LEVEL 3 COMM - TX         HIGH
#
#    State_GetPhoneInfo  ...          City_Ekata Commercial  Date_Ekata Error  \
# 0                  SC  ...               Greer       True   2/28/2019  None
# 1                  TX  ...         Castroville       True  11/18/2016  None
# 2                  MA  ...  Burlington               True   8/28/2018  None
# 3                  NY  ...    Syracuse               True   2/28/2019  None
# 4                  NJ  ...  Hackensack               True   2/28/2019  None
# 5                  PA  ...             Reading       True  11/19/2016  None
# 6                  OH  ...          Zanesville       True   2/28/2019  None
# 7                  TN  ...           Hermitage       True  11/20/2016  None
# 8                  MN  ...         Minneapolis       True  11/17/2016  None
# 9                  TX  ...            Amarillo       True  11/17/2016  None
# 10                 MO  ...             Branson       True  11/18/2016  None
# 11                 VA  ...             Fairfax       True  11/17/2016  None
# 12                 NY  ...           Thornwood       True  11/19/2016  None
# 13                 FL  ...       Pinellas Park       True  11/15/2016  None
# 14                 CA  ...          Sacramento       True  11/15/2016  None
# 15                 IA  ...           Iowa City       True  11/18/2016  None
# 16                 NV  ...           Las Vegas       True  11/20/2016  None
# 17                 AZ  ...             Phoenix       True        None  None
# 18                 OH  ...           Cleveland       True   2/28/2019  None
# 19                 VT  ...             Rutland       True   6/12/2016  None
# 20                 NJ  ...              Pomona       True  11/18/2016  None
# 21                 MI  ...              Monroe       True  11/15/2016  None
# 22                 MT  ...           Corvallis       True    5/6/2017  None
# 23                 CA  ...       Newport Beach       True  11/19/2016  None
# 24                 MS  ...         Hattiesburg       True    5/6/2017  None
# 25                 NY  ...            Brooklyn       True  11/19/2016  None
# 26                 IN  ...            Richmond       True  11/20/2016  None
# 27                 VA  ...      Mechanicsville       True   12/8/2016  None
# 28                 NJ  ...              Newark       True   2/28/2019  None
# 29                 AR  ...           Jonesboro       True    8/9/2017  None
# 30                 KY  ...          Louisville       True    5/6/2017  None
# 31                 MS  ...          Ellisville       True  11/17/2016  None
# 32                 CA  ...       Thousand Oaks       True   12/8/2016  None
# 33                 PA  ...        Mountain Top       True  11/19/2016  None
# 34                 SC  ...        Myrtle Beach       True  11/20/2016  None
# 35                 MA  ...            Plymouth       True   2/28/2019  None
# 36                 MI  ...          Southfield       True  11/15/2016  None
# 37                 NM  ...              Clovis       True  11/19/2016  None
# 38                 NH  ...          Portsmouth       True   8/28/2018  None
# 39                 TX  ...           Texarkana       True    5/6/2017  None
#
#                                    Industry  \
# 0        Ambulatory Health Care Services
# 1        Ambulatory Health Care Services
# 2        Ambulatory Health Care Services
# 3        Ambulatory Health Care Services
# 4        Ambulatory Health Care Services
# 5           Ambulatory Health Care Services
# 6           Ambulatory Health Care Services
# 7           Ambulatory Health Care Services
# 8           Ambulatory Health Care Services
# 9           Ambulatory Health Care Services
# 10          Ambulatory Health Care Services
# 11          Ambulatory Health Care Services
# 12          Ambulatory Health Care Services
# 13          Ambulatory Health Care Services
# 14          Ambulatory Health Care Services
# 15          Ambulatory Health Care Services
# 16                                Hospitals
# 17                                     None
# 18          Ambulatory Health Care Services
# 19          Ambulatory Health Care Services
# 20                                Hospitals
# 21          Ambulatory Health Care Services
# 22          Ambulatory Health Care Services
# 23          Ambulatory Health Care Services
# 24          Ambulatory Health Care Services
# 25          Ambulatory Health Care Services
# 26          Ambulatory Health Care Services
# 27          Ambulatory Health Care Services
# 28          Ambulatory Health Care Services
# 29          Ambulatory Health Care Services
# 30          Ambulatory Health Care Services
# 31          Ambulatory Health Care Services
# 32          Ambulatory Health Care Services
# 33  Nursing and Residential Care Facilities
# 34          Ambulatory Health Care Services
# 35          Ambulatory Health Care Services
# 36          Ambulatory Health Care Services
# 37          Ambulatory Health Care Services
# 38          Ambulatory Health Care Services
# 39          Ambulatory Health Care Services
#
#                                LineType  \
# 0                    Landline
# 1         NonFixedVOIP
# 2               Landline
# 3                            Landline
# 4   NonFixedVOIP
# 5                             FixedVOIP
# 6                             FixedVOIP
# 7                             FixedVOIP
# 8                             FixedVOIP
# 9                              Landline
# 10                             Landline
# 11                         NonFixedVOIP
# 12                            FixedVOIP
# 13                            FixedVOIP
# 14                         NonFixedVOIP
# 15                             Landline
# 16                            FixedVOIP
# 17                             Landline
# 18                             Landline
# 19                            FixedVOIP
# 20                            FixedVOIP
# 21                            FixedVOIP
# 22                             Landline
# 23                            FixedVOIP
# 24                             Landline
# 25                             Landline
# 26                             Landline
# 27                         NonFixedVOIP
# 28                             Landline
# 29                             Landline
# 30                             Landline
# 31                             Landline
# 32                         NonFixedVOIP
# 33                         NonFixedVOIP
# 34                             Landline
# 35                             Landline
# 36                            FixedVOIP
# 37                         NonFixedVOIP
# 38                         NonFixedVOIP
# 39                         NonFixedVOIP
#
#                                  Name_Ekata PhoneType_Ekata State_Ekata Valid
# 0          Cash, Allyson L N.P.                    Business       SC     True
# 1                  Fritz, Rebecca PA               Business          TX  True
# 2                  Bilic, Masha MD                 Business        MA    True
# 3   Madison Irving Pediatrics Pc                   Business          NY  True
# 4                           Fink, Andrew MD        Business          NJ  True
# 5                    Timothy C Stringer DPM        Business          PA  True
# 6                           Toth, Randall S        Business          OH  True
# 7            Gowda Ear Nose & Throat Clinic        Business          TN  True
# 8                          Esten, Andrew MD        Business          MN  True
# 9                 Amarillo Medical Spec Llp        Business          TX  True
# 10          Branson Neurology & Pain Center        Business          MO  True
# 11                          Allen & Forrest        Business          VA  True
# 12                   Margaret M Andersen MD        Business          NY  True
# 13                      Sarah Anne Digby DO        Business          FL  True
# 14                  William Kenneth Mora MD        Business          CA  True
# 15                 Cancer Care Of Iowa City        Business          IA  True
# 16        Summerlin Hospital Medical Center        Business          NV  True
# 17                               Cigna Corp        Business          AZ  True
# 18                       Hillcrest Hospital        Business          OH  True
# 19                      Jones, Suzanne S PA        Business          VT  True
# 20                Bacharach Institute-Rehab        Business          NJ  True
# 21                       Azadeh Khaghany MD        Business          MI  True
# 22                 April Lynn Weinberger MD        Business          MT  True
# 23                   Robert J Bae Amed Corp        Business          CA  True
# 24                        Louis W Benton MD        Business          MS  True
# 25                          Lev Kovarsky MD        Business          NY  True
# 26                       E Paul Howanitz MD        Business          IN  True
# 27                 Lee-Davis Medical Center        Business          VA  True
# 28        Chetankumar Chauhan, M.d., M.p.h.        Business          NJ  True
# 29                       Nea Baptist Clinic        Business          AR  True
# 30                       Jennifer M Brey MD        Business          KY  True
# 31              Ellisville Pediatric Clinic        Business          MS  True
# 32                  Lynn Eye Surgery Center        Business          CA  True
# 33                  Geisinger Medical Group        Business          PA  True
# 34     Grand Strand Regional Medical Center        Business          SC  True
# 35                       Byse, Barbara H MD        Business          MA  True
# 36               Stanley Keemer Saunders MD        Business          MI  True
# 37                  Manuel Macapinlac Jr MD        Business          NM  True
# 38                       Mooradian, Mark PA        Business          NH  True
# 39                          Paul D Sarna MD        Business          TX  True
#
# [40 rows x 31 columns]

# %% [markdown]
# ## Define the function that determines if the phone owner's name contains medical words

# %%
def is_healthy(name):
    med_words = ['cancer', 'cardiology', 'neurology', 'family care', 'pulmonary', 'anesthesia', 'orthope', 'urgent care', 'allergy', 'kidney', 'surgery', 'hosp', 'mri', 'throat', 'dentist', 'med', 'clinic', 'health', 'gastroenter','anesthesiologist','patient','physician','surgeon','doctor','hospital', 'md', 'medical', 'pediatrics', 'm.d.']
    healthy = False
    for word in med_words:
        if word in str(name).lower():
            healthy = True   
    return(healthy)

# %% [markdown]
# ## Define the function that calculates aggregate numbers for variabes of interest

# %%
def analyze_numbers(dataframe):
    
    name_match = 0
    healthy = 0
    address_match = 0
    city_match = 0
    commercial = 0
    no_address = 0
    no_date = 0
    industry = 0
    landline = 0
    business = 0

    for row in dataframe.itertuples():
        address_matched = False
        if str(row.PHYSICIAN_LAST_NAME).lower() in str(row.Name_Ekata).lower():
            name_match +=1
        if is_healthy(row.Name_Ekata) == True:
            healthy += 1
        if str(row.OFFICE_ADDRESS_LINE_2).lower() in str(row.Address_Ekata).lower():
            address_match +=1
            address_matched = True
        if address_matched == False:
            print (f'{row.OFFICE_ADDRESS_LINE_2} is not {row.Address_Ekata}')
        if str(row.OFFICE_ADDRESS_CITY).lower() in str(row.City_Ekata).lower():
            city_match += 1
        if row.Commercial == True:
            commercial += 1
        if 'Ambulatory Health Care Services' in str(row.Industry):
            industry += 1
        if row.Industry == 'Nursing and Residential Care Facilities':
            industry += 1
        if row.Industry == 'Hospitals':
            industry += 1
        if row.LineType == 'Landline':
            landline += 1

        if row.Address_Ekata == 'None':
            no_address += 1
        if row.Date_Ekata == 'None':
            no_date += 1
        if row.PhoneType_Ekata == 'Business':
            business += 1


    new_dict = {
        'Address Matches': address_match,
        'City Matches': city_match,
        'Exact Name Matches': name_match,
        'Relevant Names': healthy,
        'No Address': no_address,
        'No Date': no_date,
        'Business Phone': business,
        'Commercial': commercial,
        'Correct Industry': industry,
        'Landline': landline
        }
        
    return(new_dict)

# %% [markdown]
# ## Call the function on the merged connected dataframe

# %%
analyze_numbers(connected_df)
# Out:
# 385 PROSPECT AVE  STE 200 is not 385 Prospect Ave Ste 20
# 1981 STATE HILL ROAD is not 320 Abington Dr Ste 4
# 465 COLUMBUS AVE is not 645 Marble Ave
# 540 E JEFFERSON ST STE 105 is not 613 E Bloomington St # 100
# PO BOX 93358 is not 657 N Town Center Dr
# 1920 E BASELINE RD is not None
# 1401 AVACODA AVE STE 602 is not 1401 Avocado Ave Ste 602
# 59 BAY 29 ST is not 59 Bay 29th St
# 1100 RED PARKWEY is not 1100 Reid Pkwy
# 150 DERGEN ST STE H245 is not 150 Bergen St
# 4802 E JOHNSON AVE is not 1111 Windover Rd
# 9880 ANGIES WAY STE 205 is not 3999 Dutchmans Ln Ste 6f
# 275 SANWICH ST is not 275 Sandwich St
# {'Address Matches': 27,
#  'City Matches': 33,
#  'Exact Name Matches': 8,
#  'Relevant Names': 30,
#  'No Address': 1,
#  'No Date': 1,
#  'Business Phone': 40,
#  'Commercial': 40,
#  'Correct Industry': 39,
#  'Landline': 15}

# %% [markdown]
# ## Save to a dictionary

# %%
disconnected_dict = analyze_numbers(disconnected_df)

# %% [markdown]
# ## Turn dictionaries into summary dataframes

# %%
pd.DataFrame([connected_dict, disconnected_dict])
# Out:
#    Address Matches  Business Phone  City Matches  Commercial  \
# 0               27              40            33          40
# 1                8              29            21          29
#
#    Correct Industry  Exact Name Matches  Landline  No Address  No Date  \
# 0                39                   8        15           1        1
# 1                25                   9        27          10       10
#
#    Relevant Names
# 0              30
# 1              20

# %% [markdown]
# ## Call function on the connected df

# %%
analyze_numbers(connected_df)
# Out:
# 385 PROSPECT AVE  STE 200 is not 385 Prospect Ave Ste 20
# 1981 STATE HILL ROAD is not 320 Abington Dr Ste 4
# 465 COLUMBUS AVE is not 645 Marble Ave
# 540 E JEFFERSON ST STE 105 is not 613 E Bloomington St # 100
# PO BOX 93358 is not 657 N Town Center Dr
# 1920 E BASELINE RD is not None
# 1401 AVACODA AVE STE 602 is not 1401 Avocado Ave Ste 602
# 59 BAY 29 ST is not 59 Bay 29th St
# 1100 RED PARKWEY is not 1100 Reid Pkwy
# 150 DERGEN ST STE H245 is not 150 Bergen St
# 4802 E JOHNSON AVE is not 1111 Windover Rd
# 9880 ANGIES WAY STE 205 is not 3999 Dutchmans Ln Ste 6f
# 275 SANWICH ST is not 275 Sandwich St
# {'Address Matches': 27,
#  'City Matches': 33,
#  'Exact Name Matches': 8,
#  'Relevant Names': 30,
#  'No Address': 1,
#  'No Date': 1,
#  'Business Phone': 40,
#  'Commercial': 40,
#  'Correct Industry': 39,
#  'Landline': 15}

# %% [markdown]
# ## Define med words

# %%
med_words = ['cancer', 'cardiology', 'neurology', 'family care', 'pulmonary', 'anesthesia', 'orthope', 'urgent care', 'allergy', 'kidney', 'surgery', 'hosp', 'mri', 'throat', 'dentist', 'med', 'clinic', 'health', 'gastroenter','anesthesiologist','patient','physician','surgeon','doctor','hospital', 'md', 'medical', 'pediatrics', 'm.d.']

# %% [markdown]
# ## Define function that analyzes GetPhoneInfo results

# %%
def analyze_numbers_2(dataframe):
    
    
    address_match = 0
    city_match = 0
    zipcode_match = 0
    healthcount = 0
    mailcount = 0
    connectcount = 0
    portcount = 0
    novalidcount = 0
    unknowncount = 0
    disconnectedcount = 0
    voipcount = 0
    wirelesscount = 0
    no_address_count = 0
    no_date_count = 0
    business_count = 0
    residential_count = 0
    low_count = 0
    high_count = 0
    med_count = 0


    for row in dataframe.itertuples():
        if row.Address_GetPhoneInfo == row.OFFICE_ADDRESS_LINE_2:
            address_match += 1
        if row.City_GetPhoneInfo == row.OFFICE_ADDRESS_CITY:
            city_match += 1
        if row.Zipcode == row.OFFICE_ADDRESS_ZIP:
            zipcode_match += 1

        healthy = False
        for word in med_words:
            if word in str(row.Name_GetPhoneInfo).lower():
                healthy = True
        if healthy == True:    
            healthcount += 1

        if 'IsMailable' in str(row.Notes):
            mailcount += 1
        if 'IsConnected' in str(row.Notes):
            connectcount += 1
        if 'IsPorted' in str(row.Notes):
            portcount += 1
        if 'NotValid' in str(row.Notes):
            novalidcount += 1
        if 'IsUnknownContact' in str(row.Notes):
            unknowncount += 1
        if 'IsPossibleDisconnected' in str(row.Notes):
            disconnectedcount += 1
        if 'IsPossiblePortableVOIP' in str(row.Notes):
            voipcount += 1
        if 'IsWireless' in str(row.Notes):
            wirelesscount += 1

        if row.Address_GetPhoneInfo == 'None':
            no_address_count += 1
        if row.Date_GetPhoneInfo == 'None':
            no_date_count += 1
        if row.PhoneType_GetPhoneInfo == 'BUSINESS':
            business_count += 1
        if row.PhoneType_GetPhoneInfo == 'RESIDENTIAL':
            residential_count += 1
        if row.QualityScore == 'LOW':
            low_count += 1
        if row.QualityScore == 'HIGH':
            high_count += 1
        if row.QualityScore == 'MED':
            med_count += 1

    new_dict = {
        'Address Matches': address_match,
        'City Matches': city_match,
        'ZipCode Matches': zipcode_match,
        'No Address': no_address_count,
        'No Date': no_date_count,
        'Relevant Name': healthcount,
        'Business Phone': business_count,
        'Residential Phone': residential_count,
        'Low Quality': low_count,
        'Medium Quality': med_count,
        'High Quality': high_count,
        'Mailable': mailcount,
        'Connected': connectcount,
        'Ported': portcount,
        'Not Valid': novalidcount,
        'Unknown Contact': unknowncount,
        'Possibly Disconnected': disconnectedcount,
        'Possibly Portable VOIP': voipcount,
        'Wireless': wirelesscount,
        }
        
    return(new_dict)

# %% [markdown]
# ## Call function

# %%
analyze_numbers_2(connected_df)
# Out:
# {'Address Matches': 19,
#  'City Matches': 32,
#  'ZipCode Matches': 35,
#  'No Address': 0,
#  'No Date': 0,
#  'Relevant Name': 30,
#  'Business Phone': 34,
#  'Residential Phone': 6,
#  'Low Quality': 12,
#  'Medium Quality': 0,
#  'High Quality': 28,
#  'Mailable': 36,
#  'Connected': 28,
#  'Ported': 32,
#  'Not Valid': 0,
#  'Unknown Contact': 0,
#  'Possibly Disconnected': 2,
#  'Possibly Portable VOIP': 4,
#  'Wireless': 0}

# %%
analyze_numbers_2(disconnected_df)
# Out:
# {'Address Matches': 4,
#  'City Matches': 15,
#  'ZipCode Matches': 13,
#  'No Address': 18,
#  'No Date': 20,
#  'Relevant Name': 15,
#  'Business Phone': 27,
#  'Residential Phone': 8,
#  'Low Quality': 15,
#  'Medium Quality': 6,
#  'High Quality': 14,
#  'Mailable': 23,
#  'Connected': 20,
#  'Ported': 20,
#  'Not Valid': 0,
#  'Unknown Contact': 5,
#  'Possibly Disconnected': 9,
#  'Possibly Portable VOIP': 1,
#  'Wireless': 1}
