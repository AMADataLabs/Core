# %%
import pandas as pd

# %%
connected = pd.read_csv('everyone_numbers_connected.csv')
disconnected = pd.read_csv('everyone_numbers_disconnected.csv')
wrong = pd.read_csv('everyone_numbers_wrong.csv')

# %%
CONNECTED = pd.read_csv('../GetPhoneInfo/CONNECTED.csv')
DISCONNECTED = pd.read_csv('../GetPhoneInfo/DISCONNECTED.csv')
WRONG = pd.read_csv('../GetPhoneInfo/WRONG.csv')

# %%
CONNECTED.dtypes
# Out:
# Unnamed: 0                int64
# Address                  object
# City                     object
# Date                     object
# Name                     object
# Notes                    object
# OFFICE_TELEPHONE          int64
# PhoneType                object
# Provider                 object
# QualityScore             object
# State                    object
# Zipcode                  object
# PHYSICIAN_FIRST_NAME     object
# PHYSICIAN_LAST_NAME      object
# OFFICE_ADDRESS_LINE_2    object
# OFFICE_ADDRESS_CITY      object
# OFFICE_ADDRESS_STATE     object
# OFFICE_ADDRESS_ZIP        int64
# COMMENTS                 object
# PHYSICIAN_ME_NUMBER       int64
# OFFICE_ADDRESS_LINE_1    object
# dtype: object

# %%
connected_info=CONNECTED[['OFFICE_TELEPHONE','PHYSICIAN_FIRST_NAME','PHYSICIAN_LAST_NAME','OFFICE_ADDRESS_LINE_2','OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE','OFFICE_ADDRESS_ZIP','PHYSICIAN_ME_NUMBER','OFFICE_ADDRESS_LINE_1']]
disconnected_info=DISCONNECTED[['OFFICE_TELEPHONE','PHYSICIAN_FIRST_NAME','PHYSICIAN_LAST_NAME','OFFICE_ADDRESS_LINE_2','OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE','OFFICE_ADDRESS_ZIP','PHYSICIAN_ME_NUMBER','OFFICE_ADDRESS_LINE_1']]
wrong_info=WRONG[['OFFICE_TELEPHONE','PHYSICIAN_FIRST_NAME','PHYSICIAN_LAST_NAME','OFFICE_ADDRESS_LINE_2','OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE','OFFICE_ADDRESS_ZIP','PHYSICIAN_ME_NUMBER','OFFICE_ADDRESS_LINE_1']]

# %%
conn = pd.merge(connected, connected_info, on='OFFICE_TELEPHONE')
dis = pd.merge(disconnected, disconnected_info, on='OFFICE_TELEPHONE')
wro = pd.merge(wrong, wrong_info, on='OFFICE_TELEPHONE')

# %%
dis = dis.fillna("None")

# %%
def is_healthy(name):
    med_words = ['cancer', 'cardiology', 'neurology', 'family care', 'pulmonary', 'anesthesia', 'orthope', 'urgent care', 'allergy', 'kidney', 'surgery', 'hosp', 'mri', 'throat', 'dentist', 'med', 'clinic', 'health', 'gastroenter','anesthesiologist','patient','physician','surgeon','doctor','hospital', 'md', 'medical', 'pediatrics', 'm.d.']
    healthy = False
    for word in med_words:
        if word in str(name).lower():
            healthy = True   
    return(healthy)

# %%
def analyze_numbers(dataframe):
    
    healthy = 0
    first_name_match = 0
    last_name_match = 0
    workplace_match = 0
    no_name = 0
    address_match = 0
    zipcode_match = 0
    city_match = 0
    state_match = 0
    no_address = 0
    business_phone = 0
    landline = 0
    cnam_name_exact = 0


    for row in dataframe.itertuples():
        if is_healthy(row.NAME) == True:
            healthy += 1
        if str(row.PHYSICIAN_FIRST_NAME).lower() in str(row.NAME).lower():
            first_name_match +=1
        if str(row.PHYSICIAN_LAST_NAME).lower() in str(row.NAME).lower():
            last_name_match +=1
        if str(row.OFFICE_ADDRESS_LINE_1).lower() in str(row.NAME).lower():
            workplace_match +=1
        if row.NAME == 'None':
            no_name += 1
            
        if str(row.NAME).lower() == str(row.CNAM).lower():
            cnam_name_exact += 1
            
        if str(row.OFFICE_ADDRESS_LINE_2).lower() in str(row.ADDRESS).lower():
            address_match +=1
#             address_matched = True
        if str(row.ZIP) in str(row.OFFICE_ADDRESS_ZIP):
            zipcode_match +=1
        if str(row.OFFICE_ADDRESS_CITY).lower() in str(row.CITY).lower():
            city_match += 1
        if str(row.OFFICE_ADDRESS_STATE).lower() in str(row.STATE).lower():
            state_match += 1
        if row.ADDRESS == 'None':
            no_address += 1
        if str(row.OFFICE_ADDRESS_LINE_1).lower() in str(row.NAME).lower():
            workplace_match +=1
#         print(f' {row.OFFICE_ADDRESS_LINE_1} is not {row.NAME}')
#         if address_matched == False:
#             print (f'{row.OFFICE_ADDRESS_LINE_2} is not {row.ADDRESS}')
        if 'business' in str(row.TYPE):
            business_phone += 1
        if row.LINETYPE == 'landline':
            landline += 1
        
        



    new_dict = {
        'Address Matches': address_match,
        'City Matches': city_match,
        'Zipcode Matches': zipcode_match,
        'Relevant Names': healthy,
        'No Address': no_address,
        'Business Phone': business_phone,
        'Landline': landline,
        'First Name Match':first_name_match,
        'Last Name Match':last_name_match,
        'Workplace Match': workplace_match,
        'State Match': state_match, 
        'No Name': no_name,
        'CNAM Sitation': cnam_name_exact 
        }
        
    return(new_dict)

# %%
analyze_numbers(dis)
# Out:
# {'Address Matches': 4,
#  'City Matches': 21,
#  'Zipcode Matches': 18,
#  'Relevant Names': 14,
#  'No Address': 25,
#  'Business Phone': 29,
#  'Landline': 50,
#  'First Name Match': 6,
#  'Last Name Match': 8,
#  'Workplace Match': 16,
#  'State Match': 38,
#  'No Name': 11,
#  'CNAM Sitation': 13}

# %%
wro= wro.fillna('None') 8, 7, 11

# %%
dis
# Out:
#     OFFICE_TELEPHONE                             ADDRESS              CITY  \
# 0         2013586776                    645 Westwood Ave         Rivervale
# 1         2019962403                     30 Prospect Ave        Hackensack
# 2         2043957827                                None         Bloodvein
# 3         2043957827                                None         Bloodvein
# 4         2059393361                       619 19th St S        Birmingham
# 5         2079302639           116 Northport Ave Ste 112           Belfast
# 6         2168441000                                None         Cleveland
# 7         2394036350            8360 Sierra Meadows Blvd            Naples
# 8         2706519393                                None           Glasgow
# 9         2706519393                                None           Glasgow
# 10        2768898380                                None  Lebanon (warren)
# ...

# %%
def variable_breakdown(dataframe):
    list_of_dicts =[]
    for row in dataframe.itertuples():
        healthy = 0
        first_name_match = 0
        last_name_match = 0
        workplace_match = 0
        no_name = 0
        address_match = 0
        zipcode_match = 0
        city_match = 0
        state_match = 0
        no_address = 0
        business_phone = 0
        landline = 0
        cnam_name_exact = 0

    
        if is_healthy(row.NAME) == True:
            healthy = 1
        if str(row.PHYSICIAN_FIRST_NAME).lower() in str(row.NAME).lower():
            first_name_match =1
        if str(row.PHYSICIAN_LAST_NAME).lower() in str(row.NAME).lower():
            last_name_match =1
        if str(row.OFFICE_ADDRESS_LINE_1).lower() in str(row.NAME).lower():
            workplace_match =1
        if row.NAME == 'None':
            no_name = 1
            
        if str(row.NAME).lower() == str(row.CNAM).lower():
            cnam_name_exact = 1
            
        if str(row.OFFICE_ADDRESS_LINE_2).lower() in str(row.ADDRESS).lower():
            address_match =1
#             address_matched = True
        if str(row.ZIP) in str(row.OFFICE_ADDRESS_ZIP):
            zipcode_match =1
        if str(row.OFFICE_ADDRESS_CITY).lower() in str(row.CITY).lower():
            city_match = 1
        if str(row.OFFICE_ADDRESS_STATE).lower() in str(row.STATE).lower():
            state_match = 1
        if row.ADDRESS == 'None':
            no_address = 1
        if str(row.OFFICE_ADDRESS_LINE_1).lower() in str(row.NAME).lower():
            workplace_match =1
#         print(f' {row.OFFICE_ADDRESS_LINE_1} is not {row.NAME}')
#         if address_matched == False:
#             print (f'{row.OFFICE_ADDRESS_LINE_2} is not {row.ADDRESS}')
        if 'business' in str(row.TYPE):
            business_phone = 1
        if row.LINETYPE == 'landline':
            landline = 1
        

        new_dict = {
            'OFFICE_TELEPHONE': row.OFFICE_TELEPHONE,
            'Address Matches': address_match,
            'City Matches': city_match,
            'Zipcode Matches': zipcode_match,
            'Relevant Names': healthy,
            'No Address': no_address,
            'Business Phone': business_phone,
            'Landline': landline,
            'First Name Match':first_name_match,
            'Last Name Match':last_name_match,
            'Workplace Match': workplace_match,
            'State Match': state_match, 
            'No Name': no_name,
            'CNAM Sitation': cnam_name_exact 
            }
    
        list_of_dicts.append(new_dict)
        
    return(list_of_dicts)

# %%
# conn_var = variable_breakdown(conn)
dis_var = variable_breakdown(dis)

# %%
connected_df = pd.DataFrame(conn_var)
disconnected_df = pd.DataFrame(dis_var)
# connected_df.to_csv('connected_variables.csv')
disconnected_df.to_csv('disconnected_variables.csv')
