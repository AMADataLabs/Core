# %%
import pandas as pd
import requests
account_sid = "AC3f5ea9ca99884402baac7d6a32e1a618"
auth_token = "AUc1138b32e04a42e68a73cf9b8fcaa329"

# %%
dis = pd.read_csv("../new_EVERYONE_disconnected_numbers.csv")
dis.head()
conn = pd.read_csv("../new_EVERYONE_connected_numbers.csv")
conn.head()
wrong = pd.read_csv("../new_wrong_numbers.csv")
wrong.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        Name_CNAM  OFFICE_TELEPHONE  \
# 0           5          90.0         CAREMORE        2035335911
# 1          27          73.0   CARTER CTR THE        4044205100
# 2          88          14.0   OSF ST FRANCIS        9067863311
# 3          14          93.0  COASTAL FAM HLT        2284749511
# 4          55          70.0  SUN CITIES MEDI        6238159733
#
#    PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 0         5.101011e+09                 PAUL                 ALLEN
# 1         4.804783e+09               DONALD               GREGORY
# 2         2.507062e+09              PATRICK                  JOHN
# 3         4.177030e+09               TANIYA                LAMIKA
# 4         3.660192e+10               SAMUEL               HAILEAB
#
#   PHYSICIAN_LAST_NAME         OFFICE_ADDRESS_LINE_1  PHYSICIAN_NAME  STATUS  \
# 0          DI CAMILLO   RADIOLOGY RESIDENCY PROGRAM             NaN     NaN
# ...

# %%
def reverse_lookup_everyone(phone_number):

    params = {'account_sid': account_sid, 'auth_token': auth_token}
    base_url = f'https://api.everyoneapi.com/v1/phone/+1{phone_number}'
    response = requests.get(base_url, params=params)
    results = response.json()
    NEW_DICT = {}
    try:
        NEW_DICT['ADDRESS'] = results['data']['address']   
    except:
        NEW_DICT['ADDRESS'] = 'N/A'
    try:
        NEW_DICT['CNAM'] = results['data']['cnam']
    except:
        NEW_DICT['CNAM'] = 'N/A'
    try:
        NEW_DICT['LINETYPE'] = results['data']['linetype']
    except:
        NEW_DICT['LINETYPE'] = 'N/A'
    try:
        NEW_DICT['CITY'] = results['data']['location']['city']
    except:
        NEW_DICT['CITY'] = 'N/A'
    try:
        NEW_DICT['STATE'] = results['data']['location']['state']
    except:
        NEW_DICT['STATE'] = 'N/A'
    try:
        NEW_DICT['ZIP'] = results['data']['location']['zip']
    except:
        NEW_DICT['ZIP'] = 'N/A'
    try:
        NEW_DICT['NAME'] = results['data']['name']
    except:
        NEW_DICT['NAME'] = 'N/A'  
    try:
        NEW_DICT['TYPE'] = results['type']
    except:
        NEW_DICT['TYPE'] = 'N/A'  
    
    return(NEW_DICT, results)

# %%
y = pd.read_csv('../new_connected_numbers.csv')

# %%
results_list5 =[]
dict_list5 = []
for num in NUMS:
    new_dicto, resultso = reverse_lookup_everyone(num)
    results_list5.append(resultso)
    dict_list5.append(new_dicto)

# %%
dfff = pd.DataFrame(dict_list5)

# %%
dct_list3 = dict_list + dict_list2

# %%
df = pd.DataFrame(dct_list3)
df.to_csv('new_wrong_everyone.csv')

# %%
dfff
# Out:
#            ADDRESS              CITY             CNAM  LINETYPE  \
# 0              N/A           Glasgow      GLASGOW, KY  landline
# 1              N/A         Bloodvein    BLOODVEIN, MB  landline
# 2              N/A  Lebanon (warren)   LEBANON WA, VA  landline
# 3              N/A  Lebanon (warren)   LEBANON WA, VA  landline
# 4              N/A    Salt Lake City  SALT LAKE C, UT  landline
# 5              N/A            Tucson       TUCSON, AZ  landline
# 6              N/A           Hanover  DARTMOUTH,HITCH  landline
# 7   2219 Dillon Rd            Clovis  PLAINS REGIONAL  landline
# 8              N/A        Birmingham       GLAUCOMA C  landline
# 9    41140 Fox Run              Novi  ERICKSON RETIRE  landline
# 10             N/A       Des Plaines  AMC MEDICAL CEN  landline
#
#                                           NAME STATE      TYPE      ZIP
# 0                                          N/A    KY   unknown    42141
# ...

# %%
wrong[0:15]
# Out:
#     Unnamed: 0  Unnamed: 0.1        Name_CNAM  OFFICE_TELEPHONE  \
# 0            5          90.0         CAREMORE        2035335911
# 1           27          73.0   CARTER CTR THE        4044205100
# 2           88          14.0   OSF ST FRANCIS        9067863311
# 3           14          93.0  COASTAL FAM HLT        2284749511
# 4           55          70.0  SUN CITIES MEDI        6238159733
# 5           11          66.0  PERSPECTUS ARCH        2167521800
# 6           80          60.0  MIDWEST CENTER         8478641200
# 7           52          43.0       VANDERBILT        6153434000
# 8           24          37.0     INDIANA UNIV        3172789100
# 9           87          94.0  MILLENN PHYSGRP        9047275151
# 10          19          12.0   WILSON MEDICAL        2523995300
# 11          15          99.0   CRISP REG HOSP        2292763100
# 12          99          95.0   GORDON CONWELL        9784687111
# 13          28          11.0         SACSCOCS        4046794500
# ...

# %%
results_list2 =[]
dict_list2 = []
for row in wrong[15:].itertuples():
    new_dicto, resultso = reverse_lookup_everyone(row.OFFICE_TELEPHONE)
    results_list2.append(resultso)
    dict_list2.append(new_dicto)

# %%
disconnected2 = pd.read_csv('../Ekata/ekata_disconnected.csv')

# %%
disconnected3 = pd.read_csv('everyone_numbers_disconnected.csv')

# %%
x = pd.merge(disconnected2, disconnected3, on='OFFICE_TELEPHONE', how = 'outer')

# %%
x = x.fillna('None')

# %%
NUMS = x[x['NAME']=='None']['OFFICE_TELEPHONE']

# %%
x.dtypes
# Out:
# Unnamed: 0           int64
# Address             object
# AlternatePhone      object
# Carrier             object
# City                object
# Commercial          object
# Date                object
# Error               object
# Industry            object
# LineType            object
# Name                object
# OFFICE_TELEPHONE     int64
# PhoneType           object
# State               object
# Valid                 bool
# Zipcode             object
# ADDRESS             object
# CITY                object
# CNAM                object
# LINETYPE            object
# NAME                object
# STATE               object
# TYPE                object
# ZIP                 object
# dtype: object

# %%
for num in NUMS:
    print(num)
# Out:
# 2706519393
# 2043957827
# 2768898380
# 2768898380
# 3852132546
# 5202145354
# 6036506247
# 5757697669
# 2058242227
# 2489605104
# 8478273455
