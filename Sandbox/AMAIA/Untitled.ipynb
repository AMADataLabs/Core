# %%
import pandas as pd

# %%
getp = pd.read_csv('../../../Data/AMAIA/GetPhone_Insurance_Sample.csv')
# Out:
#                            Address         City        Date  \
# 0          2660 10TH AVE S STE 503   BIRMINGHAM         NaN
# 1                              NaN     MOREHEAD  2019-04-03
# 2                              NaN          NaN  2014-04-10
# 3                              NaN   LOVES PARK  2017-08-03
# 4                 1 BRACE RD STE B  CHERRY HILL  2013-09-04
# ..                             ...          ...         ...
# 495               700 CHILDRENS DR     COLUMBUS  2018-08-01
# 496  3340 PEACHTREE RD NE STE 2025      ATLANTA  2017-02-24
# 497       12687 W CEDAR DR STE 200     LAKEWOOD  2013-05-17
# 498              9320 W SAHARA AVE    LAS VEGAS         NaN
# 499                            NaN      WINDBER  2015-01-22
#
#                                                   Name  \
# 0     JOHN T KILLIAN MD PHYSICIANS SURGEONS PEDIATRICS
# 1                               ST CLAIRE PRIMARY CARE
# 2                                              CHENMED
# ...
