# %%
import pandas as pd

# %%
ins = pd.read_csv('../../../Data/AMAIA/True_Sample.csv')
ws_live_1 = pd.read_excel('../../../Data/AMAIA/AMA_PHYSICIAN_NEW_SURVEY_040120-040320_UPDATED.xls')
ws_live_2 = pd.read_excel('../../../Data/AMAIA/AMA_PHYSICIAN_NEW_SURVEY_040320_OTHER.xls')

# %%
all_ws = pd.concat([ws_live_1,ws_live_2])

# %%
all_test = pd.merge(all_ws, ins_1, left_on = 'PHYSICIAN_ME_NUMBER', right_on='ME')

# %%
all_ws.columns = [c.replace(' ','_') for c in all_ws.columns.values]

# %%
ins.columns
# Out:
# Index(['PARTY_ID', 'ME', 'POST_CD_ID', 'FROM_DT', 'ADDR_TYPE', 'ADDR_1',
#        'ADDR_2', 'ADDR_3', 'CITY', 'STATE_CD', 'ZIP', 'POST_CD_ID_PPMA',
#        'ADDR_1_PPMA', 'ADDR_2_PPMA', 'ADDR_3_PPMA', 'CITY_PPMA',
#        'STATE_CD_PPMA', 'ZIP_PPMA', 'FROM_DT_PPMA', 'POST_CD_ID_POLO',
#        'ADDR_1_POLO', 'ADDR_2_POLO', 'ADDR_3_POLO', 'CITY_POLO',
#        'STATE_CD_POLO', 'ZIP_POLO', 'FROM_DT_POLO', 'POST_KEY', 'Match',
#        'Match_2', 'NPI', 'ME_feb', 'Additional Office Locations_feb',
#        'Phone_Number_feb', 'Zip Code_feb', 'State_feb', 'City_feb',
#        'Address_feb', 'First Name_feb', 'Physician Name_feb',
#        'Middle Name_feb', 'Primary Specialty_feb',
#        'Primary Hospital Affiliation_feb', 'Last Name_feb', 'Address1_feb',
#        'ME_mar', 'Additional Office Locations_mar', 'Phone_Number_mar',
#        'Zip Code_mar', 'State_mar', 'City_mar', 'Address_mar',
#        'First Name_mar', 'Physician_Name_mar', 'Middle Name_mar',
# ...

# %%
ins_1 = ins.drop_duplicates(subset=['ME'])

# %%
all_test.groupby('COMMENTS').count()
# Out:
#                            PHYSICIAN_ME_NUMBER  PHYSICIAN_FIRST_NAME  \
# COMMENTS
# ANSWERING SERVICE                            1                     1
# COMPLETE                                   175                   175
# FAX MODEM                                    1                     1
# MOVED, NO FORWARDING INFO                   29                    29
# NOT IN SERVICE                               5                     5
# REFUSAL                                      9                     9
#
#                            PHYSICIAN_MIDDLE_NAME  PHYSICIAN_LAST_NAME  SUFFIX  \
# COMMENTS
# ANSWERING SERVICE                              1                    1       0
# COMPLETE                                     127                  175       3
# FAX MODEM                                      1                    1       0
# MOVED, NO FORWARDING INFO                     20                   29       1
# ...

# %%
all_ws[all_ws['SOURCE']=='DHC']
# Out:
#      PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 980          57501100392                AHMED           MAZEN AHMED
# 981           2507152123            ALEXANDER                JOSEPH
# 982           4102060712               ALISON                  BETH
# 983           4101101181               ANDREW                  HILL
# 984          27501830106              ARMANDO                   NaN
# ..                   ...                  ...                   ...
# 439           1720140345              JENALEE                    JO
# 440           4102040762                 JOHN               BROADUS
# 454           2802930634                JAMES                     C
# 455          49521020724               RAJESH                   NaN
# 458           2507131649              JASLEEN                     K
#
#     PHYSICIAN_LAST_NAME  SUFFIX  DEGREE OFFICE_ADDRESS_LINE_1  \
# 980               SALEH     NaN     NaN  MEMORIAL HEALTH CARE
# ...

# %%
all_test[all_test.COMMENTS=='COMPLETE']
# Out:
#      PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 0            57501100392                AHMED           MAZEN AHMED
# 1             2507152123            ALEXANDER                JOSEPH
# 2             4102060712               ALISON                  BETH
# 3             4101101181               ANDREW                  HILL
# 4            27501830106              ARMANDO                   NaN
# ..                   ...                  ...                   ...
# 170            515130462              MICHAEL                 ALLAN
# 171            518090135                 MARK                   NaN
# 172            519120224            ALEXANDRA                   NaN
# 173            801050841              AYONIJA                   NaN
# 174           2106120709               HANNAH               KAITLIN
#
#     PHYSICIAN_LAST_NAME  SUFFIX  DEGREE  OFFICE_ADDRESS_LINE_1  \
# 0                 SALEH     NaN     NaN   MEMORIAL HEALTH CARE
# ...

# %%
all_test.groupby('COMMENTS').mean()
# Out:
#                            PHYSICIAN_ME_NUMBER  SUFFIX  DEGREE  \
# COMMENTS
# ANSWERING SERVICE                 5.502130e+09     NaN     NaN
# COMPLETE                          1.499077e+10     2.0     NaN
# FAX MODEM                         3.547131e+09     NaN     NaN
# MOVED, NO FORWARDING INFO         1.644672e+10     2.0     NaN
# NOT IN SERVICE                    1.213065e+10     NaN     NaN
# REFUSAL                           1.406725e+10     2.0     NaN
#
#                            OFFICE_ADDRESS_VERIFIED/UPDATED  OFFICE_TELEPHONE  \
# COMMENTS
# ANSWERING SERVICE                                     1.00      8.648795e+09
# COMPLETE                                              1.24      6.196512e+09
# FAX MODEM                                             1.00      4.103286e+09
# MOVED, NO FORWARDING INFO                             1.00      4.739575e+09
# NOT IN SERVICE                                        1.00      3.610294e+09
# ...

# %%
all_test[all_test.Score>200]
# Out:
#      PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 15            4101141026             GABRIELA                ANDREA
# 17           77501030069               FARAYI                JONNES
# 20            3006090566              JESSICA                 LEIGH
# 22            4203890139               HECTOR                  JOSE
# 26           42201880399                 JOHN                     E
# ..                   ...                  ...                   ...
# 199          49659090103             CHARANYA                   NaN
# 209          16503790100               SAMUEL                     M
# 210          91313950013               YULIYA                    P.
# 211           3840121312                AMBER                 MARIE
# 215           2512120752            SHIVANSHU                   NaN
#
#     PHYSICIAN_LAST_NAME  SUFFIX  DEGREE               OFFICE_ADDRESS_LINE_1  \
# ...

# %%
all_test.to_csv('../../../Data/AMAIA/Sample_WS_Results.csv', index=False)

# %%
ins.columns
# Out:
# Index(['PARTY_ID', 'ME', 'POST_CD_ID', 'FROM_DT', 'ADDR_TYPE', 'ADDR_1',
#        'ADDR_2', 'ADDR_3', 'CITY', 'STATE_CD', 'ZIP', 'POST_CD_ID_PPMA',
#        'ADDR_1_PPMA', 'ADDR_2_PPMA', 'ADDR_3_PPMA', 'CITY_PPMA',
#        'STATE_CD_PPMA', 'ZIP_PPMA', 'FROM_DT_PPMA', 'POST_CD_ID_POLO',
#        'ADDR_1_POLO', 'ADDR_2_POLO', 'ADDR_3_POLO', 'CITY_POLO',
#        'STATE_CD_POLO', 'ZIP_POLO', 'FROM_DT_POLO', 'POST_KEY', 'Match',
#        'Match_2', 'NPI', 'ME_feb', 'Additional Office Locations_feb',
#        'Phone_Number_feb', 'Zip Code_feb', 'State_feb', 'City_feb',
#        'Address_feb', 'First Name_feb', 'Physician Name_feb',
#        'Middle Name_feb', 'Primary Specialty_feb',
#        'Primary Hospital Affiliation_feb', 'Last Name_feb', 'Address1_feb',
#        'ME_mar', 'Additional Office Locations_mar', 'Phone_Number_mar',
#        'Zip Code_mar', 'State_mar', 'City_mar', 'Address_mar',
#        'First Name_mar', 'Physician_Name_mar', 'Middle Name_mar',
# ...
