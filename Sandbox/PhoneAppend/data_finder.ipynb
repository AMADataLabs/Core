# %%
import pandas as pd
import requests

# %%
url = 'https://api.datafinder.com/v2/qdf.php?service=phone&k2=kefaio0tjjwbkquppfzlvgj9'
key = 'kefaio0tjjwbkquppfzlvgj9'

# %%
DATA = pd.read_csv('../../../Data/Humach/confirmed_phone_sample.csv')

# %%
first = 'larry'
last = 'grose'
address= '10819 South Drake Avenue'
city= 'Chicago'
state= 'IL'
zipcode= '60655'
parameters = {
    'd_first':first,
    'd_last' :last,
    'd_address':address, 
    'd_city':city,
    'd_state':state,
    'd_zip':zipcode
}
response =  requests.get(url, params=parameters)
results = response.json()

# %%
# Out:
# [{'#RawScore': '88.125',
#   '#WeightedScore': '789.23925',
#   '#RawMatchCodes': 'F7,L0,C0,S0,Z0,AHN0,AS0,A0,LF0,ACSZ,-0F,-0CS,INDIV,HHLD,R1',
#   '#MergeCtr': '43',
#   '#MaxRawScore': '96.025',
#   '#NormalizedRawScore': '90',
#   '#MaxWeightedScore': '864.225',
#   '#NormalizedWeightedScore': '90',
#   'FirstName': 'LAWRENCE',
#   'MiddleName': 'G',
#   'LastName': 'GROSE',
#   'Address': '10819 S Drake Ave',
#   'City': 'Chicago',
#   'County': 'Cook',
#   'State': 'IL',
#   'Zip': '60655',
#   'Zip4': '2607',
#   'Country': 'US',
#   'Phone': '7738916422',
#   'TimeStamp': '20190701',
#   'LineType': 'Mobile'}]

# %%
DATA.columns
# Out:
# Index(['Unnamed: 0', 'PHYSICIAN_ME_NUMBER', 'PHYSICIAN_FIRST_NAME',
#        'PHYSICIAN_MIDDLE_NAME', 'PHYSICIAN_LAST_NAME', 'SUFFIX', 'DEGREE',
#        'OFFICE_ADDRESS_LINE_1', 'OFFICE_ADDRESS_LINE_2', 'OFFICE_ADDRESS_CITY',
#        'OFFICE_ADDRESS_STATE', 'OFFICE_ADDRESS_ZIP',
#        'OFFICE_ADDRESS_VERIFIED_UPDATED', 'OFFICE_TELEPHONE',
#        'OFFICE_PHONE_VERIFIED_UPDATED', 'OFFICE_FAX',
#        'OFFICE_FAX_VERIFIED_UPDATED', 'EMAIL_ADDRESS',
#        'EMAIL_ADDRESS_VERIFIED_UPDATED', 'PRESENT_EMPLOYMENT_CODE',
#        'PRESENT_EMPLOYMENT_UPDATED', 'COMMENTS', 'Source', 'WSLIVE_SOURCE',
#        'WSLIVE_FILE_DT', 'MATCH_ADDR', 'MATCH_PHONE', 'MATCH_ADDR_LONG',
#        'SPECIALTY', 'SPECIALTY_UPDATED', 'SOURCE_FILE_DT', 'ws_month',
#        'ws_year', 'new_metric', 'addr_status', 'pe_status', 'phone_status',
#        'fax_status', 'spec_status'],
#       dtype='object')

# %%
# all_results = []
# dict_list = []
for row in DATA[26:].itertuples():
    print('----')
    print(row.PHYSICIAN_LAST_NAME)
    parameters = {
    'd_first':row.PHYSICIAN_FIRST_NAME,
    'd_last' :row.PHYSICIAN_LAST_NAME,
    'd_address':row.OFFICE_ADDRESS_LINE_2, 
    'd_city':row.OFFICE_ADDRESS_CITY,
    'd_state':row.OFFICE_ADDRESS_STATE,
    'd_zip':row.OFFICE_ADDRESS_ZIP}
    response =  requests.get(url, params=parameters)
    new_results = response.json()
    all_results.append(new_results)
    if new_results['datafinder']['num-results']>0:
        for result in new_results['datafinder']['results']:
            new_dict = {}
            print('RESULT FOUND')
            new_dict['ME']=row.PHYSICIAN_ME_NUMBER
            for key in potential_keys:
                if key in result.keys():
                    new_dict[key]=result[key]
                else:
                    new_dict[key]='None'
            dict_list.append(new_dict)
# Out:
# ----
# MYERS
# RESULT FOUND
# ----
# ALTMAN
# RESULT FOUND
# ----
# AGNEW
# RESULT FOUND
# ----
# ZAPATERO
# RESULT FOUND
# ----
# SCHLEUSENER
# RESULT FOUND
# ----
# HART
# RESULT FOUND
# ----
# SHAFA
# RESULT FOUND
# ----
# PALUMBO
# RESULT FOUND
# ----
# ROBINSON
# RESULT FOUND
# ----
# CESARETTI
# RESULT FOUND
# ----
# PATEL
# RESULT FOUND
# ----
# CONWAY
# RESULT FOUND
# ----
# ROBERTSON
# RESULT FOUND
# ----
# VAZQUEZ
# RESULT FOUND
# ----
# LOCKSHAW
# RESULT FOUND
# ----
# RITTER
# RESULT FOUND
# ----
# ZAMUDIO
# RESULT FOUND
# ----
# KELLER
# RESULT FOUND
# ----
# MILLER
# ----
# SATOURI
# ----
# VITUALLA
# RESULT FOUND
# ----
# CHI
# RESULT FOUND
# ----
# CHAN
# RESULT FOUND
# ----
# TOSADO RIVERA
# ----
# BURTON
# RESULT FOUND
# ----
# WANG
# RESULT FOUND
# ----
# JOHNSON
# ----
# BHATIA
# RESULT FOUND
# ----
# HOTCHKISS
# RESULT FOUND
# ----
# SALFITI
# RESULT FOUND
# ----
# GREINER
# RESULT FOUND
# ----
# APOSTOLES
# RESULT FOUND
# ----
# KALLI
# RESULT FOUND
# ----
# ...

# %%
DATA[25:]
# Out:
#     Unnamed: 0  PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME  \
# 25      308997         2.405890e+09                 MARK
# 26      306413         3.806040e+09              KASIANI
# 27      300414         5.187800e+08                 ALAN
# 28      301485         2.307951e+09              DEBORAH
# 29      304573         1.102841e+09               ILEANA
# ..         ...                  ...                  ...
# 95      300376         2.803061e+09            BRIDGETTE
# 96      309818         4.804892e+09               ROBERT
# 97      304871         5.002831e+09            FORTUNATO
# 98      303961         3.546932e+09               DANIEL
# 99      304290         2.405911e+09               EDWARD
#
#    PHYSICIAN_MIDDLE_NAME PHYSICIAN_LAST_NAME  SUFFIX  DEGREE  \
# 25                RAMSIS               ELIAS     NaN     NaN
# 26             CHRISTINA               MYERS     NaN     NaN
# 27               LEONARD              ALTMAN     NaN     NaN
# ...

# %%
for result in new_results['datafinder']['results']:
    print('RESULT FOUND')
    new_dict = {'ME': row.PHYSICIAN_ME_NUMBER,
                    '#RawScore': result['#RawScore'],
                    '#WeightedScore': result['#WeightedScore'],
                    '#RawMatchCodes': result['#RawMatchCodes'],
                    '#MergeCtr': result['#MergeCtr'],
                    '#MaxRawScore': result['#MaxRawScore'],
                    '#NormalizedRawScore': result['#NormalizedRawScore'],
                    '#MaxWeightedScore': result['#MaxWeightedScore'],
                    '#NormalizedWeightedScore': result['#NormalizedWeightedScore'],
                    'FirstName': result['FirstName'],
                    'MiddleName': result['MiddleName'],
                    'LastName': result['LastName'],
                    'Address': result['Address'],
                    'City': result['City'],
                    'State': result['State'],
                    'Zip': result['Zip'],
                    'Zip4': result['Zip4'],
                    'Country': result['Country'],
                    'Phone': result['Phone'],
                    'TimeStamp': result['TimeStamp'],
                    'LineType': result['LineType']
                   }
    dict_list.append(new_dict)
# Out:
# RESULT FOUND

# %%
potential_keys = [
    new_results['datafinder']['results']
# Out:
# [{'#RawScore': '28.133333333333',
#   '#WeightedScore': '174.56166666667',
#   '#RawMatchCodes': 'F0,L0,C0,S0,Z0,LF0,CS,-0F,-0L,-0LF,PINDIV4,PINDIV3,R1',
#   '#MergeCtr': '1',
#   '#MaxRawScore': '88.166666666667',
#   '#NormalizedRawScore': '30',
#   '#MaxWeightedScore': '793.5',
#   '#NormalizedWeightedScore': '21',
#   'FirstName': 'CHRISTOPHER',
#   'LastName': 'QUINN',
#   'Address': 'BOX 1067',
#   'City': 'GRANGER',
#   'State': 'IN',
#   'Zip': '46530',
#   'Country': 'US',
#   'Phone': '2487909210',
#   'TimeStamp': '20130101',
#   'LineType': 'Mobile'}]

# %%
DATA[1:5]['PHYSICIAN_ME_NUMBER']
# Out:
# 1    4.813982e+09
# 2    1.606721e+09
# 3    1.720892e+09
# 4    1.611981e+09
# Name: PHYSICIAN_ME_NUMBER, dtype: float64

# %%
new_results
# Out:
# {'datafinder': {'version': '2.0',
#   'query-id': 'b4b2fed2301396fe05d679d97292860c',
#   'results': [{'#RawScore': '110.55',
#     '#WeightedScore': '909.4545',
#     '#RawMatchCodes': 'F0,L0,C0,S0,Z0,AHN0,AS0,A0,LF0,ACSZ,-0F,PINDIV4,PINDIV3,PINDIV2,INDIV,HHLD,R1',
#     '#MergeCtr': '7',
#     '#MaxRawScore': '98.9',
#     '#NormalizedRawScore': '100',
#     '#MaxWeightedScore': '890.1',
#     '#NormalizedWeightedScore': '100',
#     'FirstName': 'MARY',
#     'MiddleName': 'L',
#     'LastName': 'VADER',
#     'Address': '947 S 5TH ST',
#     'City': 'MONTROSE',
#     'State': 'CO',
#     'Zip': '81401',
#     'Zip4': '5716',
#     'Country': 'US',
#     'Phone': '9702492421',
#     'TimeStamp': '20190700',
#     'LineType': 'Landline'}],
#   'input-query': {'FirstName': 'MARY',
#    'LastName': 'VADER',
#    'Address': '947 S 5TH ST',
#    'City': 'MONTROSE',
#    'State': 'CO',
#    'PostalCode': '81401',
#    'HouseNum': '947',
#    'Street': 'S 5TH ST'},
#   'num-results': 1,
# ...

# %%
potential_keys = list(results['datafinder']['results'][0].keys())

# %%
for result in new_results['datafinder']['results']:
    new_dict['ME']=1.720892e+09
    for key in potential_keys:
        if key in result.keys():
            new_dict[key]=result[key]
        else:
            new_dict[key]='None'

# %%
dict_list.append(new_dict)

# %%
pd.DataFrame(dict_list)
# Out:
#              ME        #RawScore   #WeightedScore  \
# 0  4.878870e+09           110.55         909.4545
# 1  4.813982e+09             32.8          207.555
# 2  1.720892e+09  28.133333333333  174.56166666667
# 3  1.720892e+09  28.133333333333  174.56166666667
#
#                                       #RawMatchCodes #MergeCtr  \
# 0  F0,L0,C0,S0,Z0,AHN0,AS0,A0,LF0,ACSZ,-0F,PINDIV...         7
# 1       F0,L0,C0,S0,Z0,LF0,CS,-0F,PINDIV4,PINDIV3,R1        12
# 2  F0,L0,C0,S0,Z0,LF0,CS,-0F,-0L,-0LF,PINDIV4,PIN...         1
# 3  F0,L0,C0,S0,Z0,LF0,CS,-0F,-0L,-0LF,PINDIV4,PIN...         1
#
#       #MaxRawScore #NormalizedRawScore #MaxWeightedScore  \
# 0             98.9                 100             890.1
# 1             98.9                  31             890.1
# 2  88.166666666667                  30             793.5
# 3  88.166666666667                  30             793.5
#
#   #NormalizedWeightedScore    FirstName  ...           Address        City  \
# ...

# %%
DATA[5:]
# Out:
#     Unnamed: 0  PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME  \
# 5       306187         4.120193e+10               KWADWO
# 6       309474         4.812871e+09              PHILLIP
# 7       306267         6.001820e+09              MICHAEL
# 8       304896         1.676921e+09                 JEAN
# 9       305519         3.545851e+09                 JUDE
# ..         ...                  ...                  ...
# 95      300376         2.803061e+09            BRIDGETTE
# 96      309818         4.804892e+09               ROBERT
# 97      304871         5.002831e+09            FORTUNATO
# 98      303961         3.546932e+09               DANIEL
# 99      304290         2.405911e+09               EDWARD
#
#    PHYSICIAN_MIDDLE_NAME PHYSICIAN_LAST_NAME  SUFFIX  DEGREE  \
# 5                    NaN        AGYEI-GYAMFI     NaN     NaN
# 6               CARNEGIE               GREIG     NaN     NaN
# 7                WAI-TAK                 LEE     NaN     NaN
# ...

# %%
DATA.head(50)
# Out:
#     Unnamed: 0  PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME  \
# 0       309262         4.878870e+09                 MARY
# 1       306003         4.813982e+09              MICHAEL
# 2       309925         1.606721e+09                ROGER
# 3       301640         1.720892e+09          CHRISTOPHER
# 4       300308         1.611981e+09              ALFREDO
# 5       306187         4.120193e+10               KWADWO
# 6       309474         4.812871e+09              PHILLIP
# 7       306267         6.001820e+09              MICHAEL
# 8       304896         1.676921e+09                 JEAN
# 9       305519         3.545851e+09                 JUDE
# 10      304891         2.101902e+09                 JOEL
# 11      309712         3.843021e+09               NICOLE
# 12      310096         3.010010e+08                PRITI
# 13      303996         5.104960e+09                DAVID
# 14      301001         4.101790e+09               CARMEN
# ...

# %%
all_results
# Out:
# [{'datafinder': {'version': '2.0',
#    'query-id': 'b4b2fed2301396fe05d679d97292860c',
#    'results': [{'#RawScore': '110.55',
#      '#WeightedScore': '909.4545',
#      '#RawMatchCodes': 'F0,L0,C0,S0,Z0,AHN0,AS0,A0,LF0,ACSZ,-0F,PINDIV4,PINDIV3,PINDIV2,INDIV,HHLD,R1',
#      '#MergeCtr': '7',
#      '#MaxRawScore': '98.9',
#      '#NormalizedRawScore': '100',
#      '#MaxWeightedScore': '890.1',
#      '#NormalizedWeightedScore': '100',
#      'FirstName': 'MARY',
#      'MiddleName': 'L',
#      'LastName': 'VADER',
#      'Address': '947 S 5TH ST',
#      'City': 'MONTROSE',
#      'State': 'CO',
#      'Zip': '81401',
#      'Zip4': '5716',
#      'Country': 'US',
#      'Phone': '9702492421',
#      'TimeStamp': '20190700',
#      'LineType': 'Landline'}],
#    'input-query': {'FirstName': 'MARY',
#     'LastName': 'VADER',
#     'Address': '947 S 5TH ST',
#     'City': 'MONTROSE',
#     'State': 'CO',
#     'PostalCode': '81401',
#     'HouseNum': '947',
# ...

# %%
data_finder_results = pd.DataFrame(dict_list).drop_duplicates()
data_finder_results[data_finder_results.Phone.isna()]
# Out:
# Empty DataFrame
# Columns: [ME, #RawScore, #WeightedScore, #RawMatchCodes, #MergeCtr, #MaxRawScore, #NormalizedRawScore, #MaxWeightedScore, #NormalizedWeightedScore, FirstName, MiddleName, LastName, Address, City, State, Zip, Zip4, Country, Phone, TimeStamp, LineType, County]
# Index: []
#
# [0 rows x 22 columns]

# %%
all_results[84]
# Out:
# {'datafinder': {'version': '2.0',
#   'query-id': '5cd19e882383f3bb719ae8e89c1c9fe6',
#   'results': [{'#RawScore': '23.4',
#     '#WeightedScore': '83.4',
#     '#RawMatchCodes': 'F0,L0,S0,LF0,-0F,PINDIV3,PINDIV2',
#     '#MaxRawScore': '98.9',
#     '#NormalizedRawScore': '23',
#     '#MaxWeightedScore': '890.1',
#     '#NormalizedWeightedScore': '9',
#     'FirstName': 'CHARLES',
#     'LastName': 'STALEY',
#     'Address': '5 SHORE DR',
#     'City': 'ORONO',
#     'State': 'ME',
#     'Zip': '04473',
#     'Zip4': '4489',
#     'Country': 'US',
#     'Phone': '2078660255',
#     'TimeStamp': '20190800',
#     'LineType': 'Landline'}],
#   'input-query': {'FirstName': 'CHARLES',
#    'LastName': 'STALEY',
#    'Address': '489 STATE ST',
#    'City': 'BANGOR',
#    'State': 'ME',
#    'PostalCode': '4401',
#    'HouseNum': '489',
#    'Street': 'STATE ST'},
#   'num-results': 1,
#   'query-time': '0.517'}}

# %%
len(data_finder_results)
# Out:
# 71

# %%
X = pd.merge(data_finder_results, DATA, left_on='ME', right_on='PHYSICIAN_ME_NUMBER')

# %%
for thing in list(data_finder_results['ME']):
    if thing not in list(DATA['PHYSICIAN_ME_NUMBER']):
        print(thing)
1720891979.0
# Out:
# 1720892000.0

# %%
data_finder_results[data_finder_results.ME==1720892000.0]['ME']=1720891979.0
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data_finder_results.loc[2,'ME']=1720891979.0

# %%
dfc.loc[0, 'A'] = 11

# %%
X[['Phone','OFFICE_TELEPHONE']]
# Out:
#          Phone  OFFICE_TELEPHONE
# 0   9702492421      9.702492e+09
# 1   8066371477      8.066370e+09
# 2   2487909210      5.742711e+09
# 3   7603531015      7.603527e+09
# 4   9107395389      9.107395e+09
# ..         ...               ...
# 66  5408955934      5.409829e+09
# 67  7574641680      7.579532e+09
# 68  8286672429      8.648551e+09
# 69  3609411228      3.604244e+09
# 70  2078660255      2.079737e+09
#
# [71 rows x 2 columns]

# %%
right =[]
for row in X.itertuples():
    if row.Phone==str(int(row.OFFICE_TELEPHONE)):
        right.append(True)
    else:
        right.append(False)

# %%
X.to_csv('../../../Data/Results/Data_Finder_Results.csv', index=False)

# %%
X[X['LineType']!='Mobile']
# Out:
#               ME        #RawScore   #WeightedScore  \
# 0   4.878870e+09           110.55         909.4545
# 1   4.813982e+09             32.8          207.555
# 3   1.611981e+09             35.5            221.5
# 4   4.120193e+10             52.8          239.875
# 5   4.812871e+09             33.8          202.505
# 6   6.001820e+09  83.266666666667          749.685
# 7   1.676921e+09               31              190
# 8   3.545851e+09           127.65         962.8835
# 9   2.101902e+09  106.55357142857        872.86725
# 10  3.843021e+09             39.4             99.4
# 12  5.104960e+09  28.133333333333  174.56166666667
# 13  4.101790e+09    126.651001001         962.8835
# 14  6.491486e+10            28.35        182.29625
# 15  1.001940e+09    107.676001001        883.32075
# 17  4.113861e+09             32.3            191.9
# 18  5.605961e+09    126.651001001         962.8835
# 19  1.029215e+08  28.133333333333  174.56166666667
# ...

# %%
X.columns
# Out:
# Index(['ME', '#RawScore', '#WeightedScore', '#RawMatchCodes', '#MergeCtr',
#        '#MaxRawScore', '#NormalizedRawScore', '#MaxWeightedScore',
#        '#NormalizedWeightedScore', 'FirstName', 'MiddleName', 'LastName',
#        'Address', 'City', 'State', 'Zip', 'Zip4', 'Country', 'Phone',
#        'TimeStamp', 'LineType', 'County', 'Unnamed: 0', 'PHYSICIAN_ME_NUMBER',
#        'PHYSICIAN_FIRST_NAME', 'PHYSICIAN_MIDDLE_NAME', 'PHYSICIAN_LAST_NAME',
#        'SUFFIX', 'DEGREE', 'OFFICE_ADDRESS_LINE_1', 'OFFICE_ADDRESS_LINE_2',
#        'OFFICE_ADDRESS_CITY', 'OFFICE_ADDRESS_STATE', 'OFFICE_ADDRESS_ZIP',
#        'OFFICE_ADDRESS_VERIFIED_UPDATED', 'OFFICE_TELEPHONE',
#        'OFFICE_PHONE_VERIFIED_UPDATED', 'OFFICE_FAX',
#        'OFFICE_FAX_VERIFIED_UPDATED', 'EMAIL_ADDRESS',
#        'EMAIL_ADDRESS_VERIFIED_UPDATED', 'PRESENT_EMPLOYMENT_CODE',
#        'PRESENT_EMPLOYMENT_UPDATED', 'COMMENTS', 'Source', 'WSLIVE_SOURCE',
# ...

# %%
X[X['Right']==True]
# Out:
#               ME      #RawScore #WeightedScore  \
# 0   4.878870e+09         110.55       909.4545
# 8   3.545851e+09         127.65       962.8835
# 18  5.605961e+09  126.651001001       962.8835
# 25  5.187800e+08         34.925        238.865
# 27  1.102841e+09         150.57      1102.0312
# 32  2.401871e+09          94.68       828.3818
# 43  5.606910e+09         105.95       904.8085
# 44  5.606750e+09  116.876001001      874.02875
# 49  6.301020e+09         151.95       988.4365
#
#                                        #RawMatchCodes #MergeCtr #MaxRawScore  \
# 0   F0,L0,C0,S0,Z0,AHN0,AS0,A0,LF0,ACSZ,-0F,PINDIV...         7         98.9
# 8   F0,L0,C0,S0,Z0,AHN0,AS0,A0,LF0,ACSZ,PINDIV4,PI...        26        103.5
# 18  F0,L0,C0,S0,Z0,AHN0,AS0,A0,LF0,ACSZ,PINDIV4,PI...         8        103.5
# 25  F0,L0,C0,S0,Z0,AHN15,LF0,CS,-0F,-0CS,PINDIV4,P...         3      100.625
# 27  F0,L0,C3,S0,Z0,AHN0,AS0,AU0,A0,LF0,ACSZ,PINDIV...         3        108.1
# ...

# %%
X[(X['#NormalizedRawScore']=='100')&(X.LineType!='Mobile')]
# Out:
#               ME        #RawScore #WeightedScore  \
# 0   4.878870e+09           110.55       909.4545
# 8   3.545851e+09           127.65       962.8835
# 9   2.101902e+09  106.55357142857      872.86725
# 13  4.101790e+09    126.651001001       962.8835
# 15  1.001940e+09    107.676001001      883.32075
# 18  5.605961e+09    126.651001001       962.8835
# 27  1.102841e+09           150.57      1102.0312
# 39  3.508971e+09    103.076001001      878.67475
# 40  3.006631e+09          104.075      841.50675
# 42  7.481172e+10           151.95       988.4365
# 43  5.606910e+09           105.95       904.8085
# 44  5.606750e+09    116.876001001      874.02875
# 49  6.301020e+09           151.95       988.4365
# 53  1.606953e+09           101.43       880.6493
# 56  1.103801e+09           102.73       901.5563
# 57  3.375880e+09    134.701001001        831.634
#
#                                        #RawMatchCodes #MergeCtr #MaxRawScore  \
# ...
