# %%
import pandas as pd
import requests
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from nameparser import HumanName
import json
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
requests.get('http://wikipedia.com')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1646         else:
# -> 1647             _raise_current_error()
#    1648
#
# ...

# %%
# data = pd.read_csv('address_sample.csv')
for col in data.columns:
    print(col)
# Out:
# PARTY_ID
# ME
# POST_CD_ID
# FROM_DT_x
# ADDR_TYPE
# ADDR_1
# ADDR_2
# ADDR_3
# CITY_x
# STATE_CD
# ZIP_x
# NPI
# Additional Office Locations
# Phone Number
# ZipCode
# State
# City
# Address
# First Name
# Physician Name
# Middle Name
# Primary Specialty
# Primary Hospital Affiliation
# Last Name
# Address1
# RECORD_ID
# UPDATE_TYPE
# ADDRESS_TYPE
# MAILING_NAME
# LAST_NAME
# FIRST_NAME
# MIDDLE_NAME
# SUFFIX
# MAILING_LINE_1
# MAILING_LINE_2
# CITY_y
# STATE
# ZIP_y
# SECTOR
# CARRIER_ROUTE
# ADDRESS_UNDELIVERABLE_FLAG
# FIPS_COUNTY
# FIPS_STATE
# PRINTER_CONTROL_CODE
# PC_ZIP
# PC_SECTOR
# DELIVERY_POINT_CODE
# CHECK_DIGIT
# PRINTER_CONTROL_CODE_2
# REGION
# DIVISION
# GROUP
# TRACT
# SUFFIX_CENSUS
# BLOCK_GROUP
# MSA_POPULATION_SIZE
# MICRO_METRO_IND
# CBSA
# CBSA_DIV_IND
# MD_DO_CODE
# BIRTH_YEAR
# BIRTH_CITY
# BIRTH_STATE
# BIRTH_COUNTRY
# GENDER
# TELEPHONE_NUMBER
# PRESUMED_DEAD_FLAG
# FAX_NUMBER
# TOP_CD
# PE_CD
# PRIM_SPEC_CD
# SEC_SPEC_CD
# MPA_CD
# PRA_RECIPIENT
# ...

# %%
data.ADDR_1
# Out:
# 0                         201 State St
# 1                  2 Village Grn Apt A
# 2                     579A Cranbury Rd
# 3             2423 Williams Dr Ste 105
# 4                    100 Brewster Blvd
#                     ...
# 995                         20 York St
# 996                      900 E Main St
# 997                     2320 E 93rd St
# 998    1820 Preston Park Blvd Ste 2400
# 999                   3999 Richmond Rd
# Name: ADDR_1, Length: 1000, dtype: object

# %%
key = 'AIzaSyCGOwnycSPj5jUrjz_7figjGKFvpO3mA-I'
base_url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json'
fields = 'formatted_address,geometry,name,permanently_closed,place_id,plus_code,types'
inputtype='textquery'

# %%
for row in data[5:500].itertuples():
    print("")
    print('----------------------')
    address = row.ADDR_1 + ' ' +  row.CITY_x + ' ' + row.STATE_CD
    parameters = {'fields': fields, 'inputtype':inputtype, 'key':key,'input': address}
    response =  requests.get(base_url, params=parameters)

    if response.status_code == 200:
        results = response.json()
        all_results.append(results)
        if len(results['candidates'])>0:
            for candidate in results['candidates']:
                person_dict = {
                    'ME':row.ME,
                    'Address_AMAIA':address,
                    'Name': candidate["name"],
                    'Address_Google': candidate['formatted_address'],
                    'Types': candidate['types'],
                    'Place_ID': candidate['place_id']
                }
                
                list_of_dicts.append(person_dict)
                index = results['candidates'].index(candidate)
                print(f'{index + 1}. {candidate["name"]}')

        elif len(results['candidates'])==0:   
            print(f'{address} not found')
# Out:
# ----------------------
# 1. 3400 Spruce St
#
# ----------------------
# 1. 1401 E State St
#
# ----------------------
# 1. 2333 McCallie Ave
#
# ----------------------
# 1. 40100 US-27
#
# ----------------------
# 1. 8900 N Kendall Dr
#
# ----------------------
# 1. 1495 Mill St
#
# ----------------------
# 1. 255 Terracina Blvd STE 105
#
# ----------------------
# 1. 1139 E High St
#
# ----------------------
# 1. One Medical
#
# ----------------------
# 1. 1025 Morehead Medical Dr
#
# ----------------------
# 1. 9300 DeWitt Loop
#
# ----------------------
# 1. 1270 Friendship Rd
#
# ----------------------
# 1. 200 W Arbor Dr #8770
#
# ----------------------
# 1. 4031 US-287
#
# ----------------------
# 1. 525 E 68th St
#
# ----------------------
# 1. 3050 Montvale Dr
#
# ----------------------
# 1. 6345 Balboa Blvd #199
#
# ----------------------
# 1. 416 Belmont St
#
# ----------------------
# 1. 8199 E 1st Ave
#
# ----------------------
# 1. 1401 Foucher St
#
# ...

# %%
all_results
# Out:
# [{'candidates': [{'formatted_address': '201 N State St, Chicago, IL 60601, USA',
#     'geometry': {'location': {'lat': 41.8860414, 'lng': -87.62762330000001},
#      'viewport': {'northeast': {'lat': 41.88739037989272,
#        'lng': -87.62639937010728},
#       'southwest': {'lat': 41.88469072010728, 'lng': -87.62909902989273}}},
#     'name': '201 N State St',
#     'place_id': 'ChIJ-_lk7q8sDogRFgd_Ni1tFmk',
#     'types': ['premise']},
#    {'formatted_address': '201 S State St, Chicago, IL 60604, USA',
#     'geometry': {'location': {'lat': 41.8792858, 'lng': -87.6272375},
#      'viewport': {'northeast': {'lat': 41.88073932989272,
#        'lng': -87.62584402010728},
#       'southwest': {'lat': 41.87803967010728, 'lng': -87.62854367989273}}},
#     'name': '201 S State St',
#     'place_id': 'ChIJ2VBzaqMsDogRjr0gfa2nQUc',
#     'types': ['premise']}],
#   'status': 'OK'},
#  {'candidates': [{'formatted_address': '3121 Village Ct, Janesville, WI 53546, United States',
# ...

# %%
pd.DataFrame(list_of_dicts).to_csv('AMAIA_Address_Test.csv',index=False)

# %%
data.head()[['ADDR_1','Address','CITY_x','City']]
# Out:
#                      ADDR_1                   Address        CITY_x  \
# 0              201 State St              201 State St          Erie
# 1       2 Village Grn Apt A       2 Village Grn Apt A     Budd Lake
# 2          579A Cranbury Rd           483 Cranbury Rd  E Brunswick
# 3  2423 Williams Dr Ste 105  2423 Williams Dr Ste 105    Georgetown
# 4         100 Brewster Blvd         100 Brewster Blvd  Camp Lejeune
#
#              City
# 0            Erie
# 1       Budd Lake
# 2  East Brunswick
# 3      Georgetown
# 4    Camp Lejeune

# %%
with_goog = pd.DataFrame(list_of_dicts)

# %%
all_results
# Out:
# [{'candidates': [{'formatted_address': '201 N State St, Chicago, IL 60601, USA',
#     'geometry': {'location': {'lat': 41.8860414, 'lng': -87.62762330000001},
#      'viewport': {'northeast': {'lat': 41.88739037989272,
#        'lng': -87.62639937010728},
#       'southwest': {'lat': 41.88469072010728, 'lng': -87.62909902989273}}},
#     'name': '201 N State St',
#     'place_id': 'ChIJ-_lk7q8sDogRFgd_Ni1tFmk',
#     'types': ['premise']},
#    {'formatted_address': '201 S State St, Chicago, IL 60604, USA',
#     'geometry': {'location': {'lat': 41.8792858, 'lng': -87.6272375},
#      'viewport': {'northeast': {'lat': 41.88073932989272,
#        'lng': -87.62584402010728},
#       'southwest': {'lat': 41.87803967010728, 'lng': -87.62854367989273}}},
#     'name': '201 S State St',
#     'place_id': 'ChIJ2VBzaqMsDogRjr0gfa2nQUc',
#     'types': ['premise']}],
#   'status': 'OK'},
#  {'candidates': [{'formatted_address': '3121 Village Ct, Janesville, WI 53546, United States',
# ...

# %%
with open(f'google_data.txt', 'w') as outfile:
            json.dump(all_results, outfile)

# %%
ALL = pd.merge(with_goog, data, on='ME')

# %%
count =0
for row in ALL.itertuples():
    if row.STATE_CD != row.STATE:
        if row.STATE_CD != row.POLO_STATE:
            count += 1
            print('nope')
# Out:
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope
# nope

# %%
count
# Out:
# 141

# %%
# Out:
# C:\Users\vigrose\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,10,16,27,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         PHYSICIAN_ME_NUMBER PHYSICIAN_FIRST_NAME PHYSICIAN_MIDDLE_NAME  \
# 0              7.482097e+10               RONALD               ANTHONY
# 1              1.902962e+09               ANGELA                 MARIE
# 2              6.703650e+09                DENIS                     J
# 3              2.507981e+09             MOHAMMED                 OVAIS
# 4              6.490384e+10            ALEJANDRO                     G
# ...                     ...                  ...                   ...
# 451202         2.106031e+09                 RYAN                 DAVID
# 451203         1.606091e+09             SAMANTHA                 MARIE
# ...
